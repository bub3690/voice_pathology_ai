# %% [markdown]
# # wav sample 에서 실시
#
# 이 파일은 fusion을 위해 파일 분류하는데 사용

# %%
#파일 분류에 사용
#출처: https://ourcstory.tistory.com/96

import shutil
filename = 'C:/Users/Desktop/Desktop/pathology/a/export/파일설명.txt' 
to = 
shutil.move(filename,to )
# Out:
# './파일설명.txt'

# %%
from glob import glob
glob('C:/Users/Desktop/Desktop/pathology/a/export/*-phrase.wav')
# Out:
# []

# %%
import re

# %%
sample1=glob('C:/Users/Desktop/Desktop/pathology/a/export/*-phrase.wav')[1]
sample1
re.search('\\\\(.*)',sample1).group(1)#아이템 번호
# Out:
# '1039-phrase.wav'

# %%
#같은 환자 찾는 코드
from glob import glob
import shutil

phrase = glob('D:/project/voice_pathology_ai/voice_data/all_data/healthy/phrase/*-phrase.wav')
a = glob('D:/project/voice_pathology_ai/voice_data/all_data/healthy/a/*-a_n.wav')
i = glob('D:/project/voice_pathology_ai/voice_data/all_data/healthy/i/*-i_n.wav')
u = glob('D:/project/voice_pathology_ai/voice_data/all_data/healthy/u/*-u_n.wav')


#phrase로 dict를 만들고 그 안에 path를 담은 리스트를 넣기.
healthy_dict = {}
for text in phrase:
    text_parse = text.split('\\')[-1].split('-')[0]
    healthy_dict[text_parse]= [text,]

for text in a:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        healthy_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

for text in i:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        healthy_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

        
for text in u:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        healthy_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")
        

print(len(healthy_dict))
# Out:
# 1925 key error
# 1926 key error
# 1947 key error
# 1995 key error
# 1996 key error
# 2018 key error
# 2036 key error
# 2037 key error
# 2038 key error
# 2039 key error
# 2040 key error
# 2041 key error
# 2042 key error
# 2043 key error
# 2044 key error
# 2045 key error
# 2046 key error
# 2047 key error
# 2048 key error
# 2049 key error
# 2050 key error
# 2051 key error
# 2052 key error
# 2053 key error
# 2054 key error
# 2162 key error
# 2163 key error
# 2164 key error
# 2165 key error
# 2166 key error
# 2167 key error
# 2168 key error
# 2169 key error
# 2170 key error
# 2171 key error
# 2172 key error
# 2173 key error
# 2174 key error
# 2175 key error
# 2176 key error
# 2177 key error
# 2178 key error
# 2179 key error
# 2180 key error
# 2181 key error
# 2195 key error
# 2196 key error
# 2197 key error
# 2198 key error
# 2199 key error
# 2200 key error
# 2201 key error
# 2202 key error
# 1925 key error
# 1926 key error
# 1947 key error
# 1995 key error
# 1996 key error
# ...

# %%
from glob import glob
import shutil

#healthy데이터 옮기기
for key in healthy_dict:
    
    phrase_name=healthy_dict[key][0].split('\\')[-1].split('-')[0]+'-phrase.wav'
    to_phrase = 'D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/'
    
    a_name=healthy_dict[key][1].split('\\')[-1].split('-')[0]+'-a_n.wav'
    to_a = 'D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/a/'
    
    i_name=healthy_dict[key][2].split('\\')[-1].split('-')[0]+'-i_n.wav'
    to_i = 'D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/i/'
    
    u_name=healthy_dict[key][3].split('\\')[-1].split('-')[0]+'-u_n.wav'
    to_u = 'D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/u/'
    
    shutil.copy(healthy_dict[key][0],to_phrase+phrase_name) #phrase
    shutil.copy(healthy_dict[key][1],to_a+a_name) #a
    shutil.copy(healthy_dict[key][2],to_i+i_name) #i
    shutil.copy(healthy_dict[key][3],to_u+u_name) #u
# Out:
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# D:/project/voice_pathology_ai/voice_data/fusion_new/healthy/phrase/
# ...

# %%
#같은 환자 찾는 코드
from glob import glob
import shutil

phrase = glob('D:/project/voice_pathology_ai/voice_data/all_data/pathology/phrase/*-phrase.wav')
a = glob('D:/project/voice_pathology_ai/voice_data/all_data/pathology/a/*-a_n.wav')
i = glob('D:/project/voice_pathology_ai/voice_data/all_data/pathology/i/*-i_n.wav')
u = glob('D:/project/voice_pathology_ai/voice_data/all_data/pathology/u/*-u_n.wav')


#phrase로 dict를 만들고 그 안에 path를 담은 리스트를 넣기.
pathology_new_dict = {}
for text in phrase:
    text_parse = text.split('\\')[-1].split('-')[0]
    pathology_new_dict[text_parse]= [text,]

for text in a:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

for text in i:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

        
for text in u:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")
        

print(len(pathology_new_dict))
# Out:
# 1669 key error
# 1669 key error
# 713 key error
# 1669 key error
# 1354

# %%
for key in pathology_new_dict:
    if len(pathology_new_dict[key])!=4:
        print(key)
# Out:
# 2611

# %%
from glob import glob
import shutil

#healthy데이터 옮기기
for key in pathology_new_dict:
    
    try:
        phrase_name=pathology_new_dict[key][0].split('\\')[-1].split('-')[0]+'-phrase.wav'
        to_phrase = 'D:/project/voice_pathology_ai/voice_data/fusion_new/pathology/phrase/'

        a_name=pathology_new_dict[key][1].split('\\')[-1].split('-')[0]+'-a_n.wav'
        to_a = 'D:/project/voice_pathology_ai/voice_data/fusion_new/pathology/a/'

        i_name=pathology_new_dict[key][2].split('\\')[-1].split('-')[0]+'-i_n.wav'
        to_i = 'D:/project/voice_pathology_ai/voice_data/fusion_new/pathology/i/'

        u_name=pathology_new_dict[key][3].split('\\')[-1].split('-')[0]+'-u_n.wav'
        to_u = 'D:/project/voice_pathology_ai/voice_data/fusion_new/pathology/u/'

        shutil.copy(pathology_new_dict[key][0],to_phrase+phrase_name) #phrase
        shutil.copy(pathology_new_dict[key][1],to_a+a_name) #a
        shutil.copy(pathology_new_dict[key][2],to_i+i_name) #i
        shutil.copy(pathology_new_dict[key][3],to_u+u_name) #u
    except:
        print("key :", key)
        continue
# Out:
# key : 2611

# %%
len(healthy_dict)
# Out:
# 634

# %%
pathology_new_dict["2611"]
# Out:
# ['D:/projects/voice_pathology_ai/voice_data/pathology_new/phrase/export\\2611-phrase.wav',
#  'D:/projects/voice_pathology_ai/voice_data/pathology_new/u/export\\2611-u_n.wav']

# %%
healthy_dict
# Out:
# {'1': ['D:/projects/voice_pathology_ai/voice_data/healthy_new/phrase/export\\1-phrase.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/a/export\\1-a_n.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/i/export\\1-i_n.wav'],
#  '10': ['D:/projects/voice_pathology_ai/voice_data/healthy_new/phrase/export\\10-phrase.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/a/export\\10-a_n.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/i/export\\10-i_n.wav'],
#  '100': ['D:/projects/voice_pathology_ai/voice_data/healthy_new/phrase/export\\100-phrase.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/a/export\\100-a_n.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/i/export\\100-i_n.wav'],
#  '1000': ['D:/projects/voice_pathology_ai/voice_data/healthy_new/phrase/export\\1000-phrase.wav',
#   'D:/projects/voice_pathology_ai/voice_data/healthy_new/a/export\\1000-a_n.wav',
# ...

# %%
text = 'D:/projects/voice_pathology_ai/voice_data/healthy_new/u/export\\100-u_n.wav'

text = text.split('\\')[-1].split('-')[0]

text
# Out:
# '100'

# %% [markdown]
# # egg sample에서 실시

# %%
from glob import glob
import shutil

phrase =  glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/pathology/u/*-u_n-egg.egg')
len(phrase)
# Out:
# 1355

# %%
#같은 환자 찾는 코드
from glob import glob
import shutil

phrase = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/pathology/phrase/*-phrase-egg.egg')
a = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/pathology/a/*-a_n-egg.egg')
i = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/pathology/i/*-i_n-egg.egg')
u = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/pathology/u/*-u_n-egg.egg')


#phrase로 dict를 만들고 그 안에 path를 담은 리스트를 넣기.
pathology_new_dict = {}
for text in phrase:
    text_parse = text.split('\\')[-1].split('-')[0]
    pathology_new_dict[text_parse]= [text,]

for text in a:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

for text in i:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

        
for text in u:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")
        

print(len(pathology_new_dict))
# Out:
# 1669 key error
# 1669 key error
# 713 key error
# 1669 key error
# 1354

# %%
from glob import glob
import shutil

#pathology 데이터 옮기기
for key in pathology_new_dict:
    
    try:
        phrase_name=pathology_new_dict[key][0].split('\\')[-1].split('-')[0]+'-phrase.egg'
        to_phrase = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/pathology/phrase/'

        a_name=pathology_new_dict[key][1].split('\\')[-1].split('-')[0]+'-a_n.egg'
        to_a = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/pathology/a/'

        i_name=pathology_new_dict[key][2].split('\\')[-1].split('-')[0]+'-i_n.egg'
        to_i = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/pathology/i/'

        u_name=pathology_new_dict[key][3].split('\\')[-1].split('-')[0]+'-u_n.egg'
        to_u = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/pathology/u/'

        shutil.copy(pathology_new_dict[key][0],to_phrase+phrase_name) #phrase
        shutil.copy(pathology_new_dict[key][2],to_i+i_name) #i
        shutil.copy(pathology_new_dict[key][1],to_a+a_name) #a
        shutil.copy(pathology_new_dict[key][3],to_u+u_name) #u
    except:
        print("key :", key)
        continue
# Out:
# key : 2611

# %%
#같은 healthy 찾는 코드
from glob import glob
import shutil

phrase = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/healthy/phrase/*-phrase-egg.egg')
a = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/healthy/a/*-a_n-egg.egg')
i = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/healthy/i/*-i_n-egg.egg')
u = glob('D:/projects/voice_pathology_ai/voice_data/fusion_egg/healthy/u/*-u_n-egg.egg')


#phrase로 dict를 만들고 그 안에 path를 담은 리스트를 넣기.
pathology_new_dict = {}
for text in phrase:
    text_parse = text.split('\\')[-1].split('-')[0]
    pathology_new_dict[text_parse]= [text,]

for text in a:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

for text in i:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

        
for text in u:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")
        

print(len(pathology_new_dict))
# Out:
# 1925 key error
# 1926 key error
# 1947 key error
# 1995 key error
# 1996 key error
# 2018 key error
# 2036 key error
# 2037 key error
# 2038 key error
# 2039 key error
# 2040 key error
# 2041 key error
# 2042 key error
# 2043 key error
# 2044 key error
# 2045 key error
# 2046 key error
# 2047 key error
# 2048 key error
# 2049 key error
# 2050 key error
# 2051 key error
# 2052 key error
# 2053 key error
# 2054 key error
# 2162 key error
# 2163 key error
# 2164 key error
# 2165 key error
# 2166 key error
# 2167 key error
# 2168 key error
# 2169 key error
# 2170 key error
# 2171 key error
# 2172 key error
# 2173 key error
# 2174 key error
# 2175 key error
# 2176 key error
# 2177 key error
# 2178 key error
# 2179 key error
# 2180 key error
# 2181 key error
# 2195 key error
# 2196 key error
# 2197 key error
# 2198 key error
# 2199 key error
# 2200 key error
# 2201 key error
# 2202 key error
# 1925 key error
# 1926 key error
# 1947 key error
# 1995 key error
# 1996 key error
# ...

# %%
from glob import glob
import shutil

#healthy 데이터 옮기기
for key in pathology_new_dict:
    
    try:
        phrase_name=pathology_new_dict[key][0].split('\\')[-1].split('-')[0]+'-phrase.egg'
        to_phrase = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/healthy/phrase/'

        a_name=pathology_new_dict[key][1].split('\\')[-1].split('-')[0]+'-a_n.egg'
        to_a = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/healthy/a/'

        i_name=pathology_new_dict[key][2].split('\\')[-1].split('-')[0]+'-i_n.egg'
        to_i = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/healthy/i/'

        u_name=pathology_new_dict[key][3].split('\\')[-1].split('-')[0]+'-u_n.egg'
        to_u = 'D:/projects/voice_pathology_ai/voice_data/fusion_egg2/healthy/u/'

        shutil.copy(pathology_new_dict[key][0],to_phrase+phrase_name) #phrase
        shutil.copy(pathology_new_dict[key][2],to_i+i_name) #i
        shutil.copy(pathology_new_dict[key][1],to_a+a_name) #a
        shutil.copy(pathology_new_dict[key][3],to_u+u_name) #u
    except:
        print("key :", key)
        continue

# %%
path1="D:\\projects\\voice_pathology_ai\\voice_data\\fusion_egg\\healthy\\a\\1-a_n.wav"

# %%
# !unzip D:\\projects\\voice_pathology_ai\\voice_data\\fusion_egg\\healthy\\a\\1-a_n.egg.egg.
# Out:
# 'unzip'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

librosa.load(path1, sr=50000)
# Out:
# D:\miniconda3\envs\local_torch\lib\site-packages\librosa\core\audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# D:\miniconda3\envs\local_torch\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# D:\miniconda3\envs\local_torch\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ...

# %% [markdown]
# # organics fusion set

# %%
#같은 healthy 환자 찾는 코드
from glob import glob
import shutil

phrase = glob('D:/project/voice_pathology_ai/voice_data/organics/healthy/phrase/*-phrase.wav')
a = glob('D:/project/voice_pathology_ai/voice_data/organics/healthy/a/*-a_n.wav')
i = glob('D:/project/voice_pathology_ai/voice_data/organics/healthy/i/*-i_n.wav')
u = glob('D:/project/voice_pathology_ai/voice_data/organics/healthy/u/*-u_n.wav')


#phrase로 dict를 만들고 그 안에 path를 담은 리스트를 넣기.
healthy_dict = {}
for text in phrase:
    text_parse = text.split('\\')[-1].split('-')[0]
    healthy_dict[text_parse]= [text,]

for text in a:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        healthy_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

for text in i:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        healthy_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

        
for text in u:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        healthy_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")
        

print(len(healthy_dict))
# Out:
# 1925 key error
# 1926 key error
# 1947 key error
# 1995 key error
# 1996 key error
# 2018 key error
# 2036 key error
# 2037 key error
# 2038 key error
# 2039 key error
# 2040 key error
# 2041 key error
# 2042 key error
# 2043 key error
# 2044 key error
# 2045 key error
# 2046 key error
# 2047 key error
# 2048 key error
# 2049 key error
# 2050 key error
# 2051 key error
# 2052 key error
# 2053 key error
# 2054 key error
# 2162 key error
# 2163 key error
# 2164 key error
# 2165 key error
# 2166 key error
# 2167 key error
# 2168 key error
# 2169 key error
# 2170 key error
# 2171 key error
# 2172 key error
# 2173 key error
# 2174 key error
# 2175 key error
# 2176 key error
# 2177 key error
# 2178 key error
# 2179 key error
# 2180 key error
# 2181 key error
# 2195 key error
# 2196 key error
# 2197 key error
# 2198 key error
# 2199 key error
# 2200 key error
# 2201 key error
# 2202 key error
# 1925 key error
# 1926 key error
# 1947 key error
# 1995 key error
# 1996 key error
# ...

# %%
from glob import glob
import shutil

#healthy데이터 옮기기
for key in healthy_dict:
    
    try:
        phrase_name=healthy_dict[key][0].split('\\')[-1].split('-')[0]+'-phrase.wav'
        to_phrase = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/healthy/phrase/'

        a_name=healthy_dict[key][1].split('\\')[-1].split('-')[0]+'-a_n.wav'
        to_a = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/healthy/a/'

        i_name=healthy_dict[key][2].split('\\')[-1].split('-')[0]+'-i_n.wav'
        to_i = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/healthy/i/'

        u_name=healthy_dict[key][3].split('\\')[-1].split('-')[0]+'-u_n.wav'
        to_u = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/healthy/u/'

        shutil.copy(healthy_dict[key][0],to_phrase+phrase_name) #phrase
        shutil.copy(healthy_dict[key][1],to_a+a_name) #a
        shutil.copy(healthy_dict[key][2],to_i+i_name) #i
        shutil.copy(healthy_dict[key][3],to_u+u_name) #u
    except:
        print("error. key :", key)
        continue

# %%
#같은 환자 찾는 코드
from glob import glob
import shutil

phrase = glob('D:/project/voice_pathology_ai/voice_data/organics/pathology/phrase/*-phrase.wav')
a = glob('D:/project/voice_pathology_ai/voice_data/organics/pathology/a/*-a_n.wav')
i = glob('D:/project/voice_pathology_ai/voice_data/organics/pathology/i/*-i_n.wav')
u = glob('D:/project/voice_pathology_ai/voice_data/organics/pathology/u/*-u_n.wav')



#phrase로 dict를 만들고 그 안에 path를 담은 리스트를 넣기.
pathology_new_dict = {}
for text in phrase:
    text_parse = text.split('\\')[-1].split('-')[0]
    pathology_new_dict[text_parse]= [text,]

for text in a:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

for text in i:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")

        
for text in u:
    text_parse = text.split('\\')[-1].split('-')[0]
    try:
        pathology_new_dict[text_parse].append(text)
    except:
        print(text_parse,"key error")
        

print(len(pathology_new_dict))
# Out:
# 597

# %%
from glob import glob
import shutil

#healthy데이터 옮기기
for key in pathology_new_dict:
    
    try:
        phrase_name=pathology_new_dict[key][0].split('\\')[-1].split('-')[0]+'-phrase.wav'
        to_phrase = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/pathology/phrase/'

        a_name=pathology_new_dict[key][1].split('\\')[-1].split('-')[0]+'-a_n.wav'
        to_a = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/pathology/a/'

        i_name=pathology_new_dict[key][2].split('\\')[-1].split('-')[0]+'-i_n.wav'
        to_i = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/pathology/i/'

        u_name=pathology_new_dict[key][3].split('\\')[-1].split('-')[0]+'-u_n.wav'
        to_u = 'D:/project/voice_pathology_ai/voice_data/organics_fusion/pathology/u/'

        shutil.copy(pathology_new_dict[key][0],to_phrase+phrase_name) #phrase
        shutil.copy(pathology_new_dict[key][1],to_a+a_name) #a
        shutil.copy(pathology_new_dict[key][2],to_i+i_name) #i
        shutil.copy(pathology_new_dict[key][3],to_u+u_name) #u
    except:
        print("error key :", key)
        continue
