# %% [markdown]
# # organic sample들 가져오는 노트북
#
# 논문 저자가 선정한 organic data들만 가져오기

# %%
import time
import pandas as pd
import re
import shutil
import os
import openpyxl
from glob import glob

# %%
all_data=pd.read_excel("D:/project/voice_pathology_ai/voice_data/svdlimit.xlsx")
all_data
# Out:
#       RECORDING PATHOLOGY        DATE  SPEAKER GENDER  AGE  \
# 0             1         n  20/11/1997        1      w   20
# 1          1862         p  27/11/2000        1      w   23
# 2             2         n  20/11/1997        2      w   22
# 3             3         n  20/11/1997        3      w   23
# 4             4         n  20/11/1997        4      m   22
# ...         ...       ...         ...      ...    ...  ...
# 2220       1051         p  11.11.1998     1402      w   29
# 2221        693         p  15.05.1998     1403      w   28
# 2222        712         p  20.05.1998     1404      w   42
# 2223        713         p  20.05.1998     1405      m   13
# 2224        714         p  20.05.1998     1406      m   71
#
#                                                  DETAIL         DIAG
# 0                                               control      control
# 1                                Funktionelle Dysphonie  non-organic
# ...

# %%
all_data['DIAG'].value_counts()
# Out:
# control        869
# non-organic    346
# structural     325
# neurogenic     272
# Name: DIAG, dtype: int64

# %%
str_expr = "DIAG == 'neurogenic' or DIAG == 'structural'"    # 나이가 10 이다 (비교연산자 ==)
organic_data= all_data.query(str_expr) # 조건 부합 데이터 추출

organic_data
#논문처럼 597건이 주어진다.
# Out:
#       RECORDING PATHOLOGY        DATE  SPEAKER GENDER  AGE  \
# 20          715         p  20.05.1998     1407      w   63
# 21         1303         p  21.04.1999     1407      w   64
# 22         1557         p  08.12.1999     1407      w   65
# 23         1559         p  15.12.1999     1407      w   65
# 24         1864         p  29.11.2000     1407      w   66
# ...         ...       ...         ...      ...    ...  ...
# 2211       1314         p  28.04.1999     1397      m   77
# 2212       1564         p  15.12.1999     1397      m   78
# 2213        671         p  13.05.1998     1398      w   66
# 2214        879         p  15.07.1998     1398      w   66
# 2222        712         p  20.05.1998     1404      w   42
#
#                        DETAIL        DIAG
# 20    Laryngitis; Leukoplakie  structural
# 21                Leukoplakie  structural
# 22                Leukoplakie  structural
# 23                Leukoplakie  structural
# ...

# %%
organic_data['RECORDING']
# Out:
# 20       715
# 21      1303
# 22      1557
# 23      1559
# 24      1864
#         ...
# 2211    1314
# 2212    1564
# 2213     671
# 2214     879
# 2222     712
# Name: RECORDING, Length: 597, dtype: int64

# %%
organic_list = organic_data['RECORDING'].tolist()
organic_list
# Out:
# [715,
#  1303,
#  1557,
#  1559,
#  1864,
#  716,
#  718,
#  1481,
#  720,
#  721,
#  725,
#  1604,
#  1901,
#  726,
#  742,
#  819,
#  821,
#  824,
#  825,
#  828,
#  844,
#  849,
#  896,
#  1548,
#  2088,
#  2395,
#  2455,
#  855,
#  895,
#  1190,
#  863,
#  875,
#  864,
#  859,
#  869,
#  871,
#  874,
#  876,
#  880,
#  1721,
#  883,
#  912,
#  884,
#  886,
#  897,
#  893,
#  901,
#  902,
#  918,
#  904,
#  1554,
#  910,
#  919,
#  923,
#  1290,
#  1646,
#  924,
#  926,
#  928,
#  930,
#  931,
#  932,
#  935,
#  1040,
#  1045,
#  1056,
#  1046,
#  1047,
#  1048,
#  1049,
#  1052,
#  1164,
#  1221,
#  1054,
#  1755,
#  1119,
#  1192,
#  1157,
#  1161,
#  1166,
#  1186,
#  1188,
#  1195,
#  1218,
#  1223,
#  1325,
#  1262,
#  1292,
#  1402,
#  2150,
#  2469,
#  1228,
#  1229,
#  1274,
#  1447,
#  1233,
#  1235,
#  1246,
#  1237,
#  1239,
#  1245,
#  1247,
#  1248,
#  1249,
#  1263,
#  1472,
#  1252,
#  1253,
#  1270,
#  1277,
#  1289,
#  1256,
#  1257,
#  1259,
#  1264,
#  1260,
# ...

# %%
#1. pathology - phrase


from glob import glob
phrase_list = glob('D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/phrase/export/*-phrase.wav')
print(len(phrase_list))


## a
a_h_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/a/high/export/*-a_h.wav")
print(len(a_h_list))

a_l_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/a/low/export/*-a_l.wav")
print(len(a_l_list))

a_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/a/neutral/export/*-a_n.wav")
print(len(a_n_list))


##i

i_h_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/high/export/*-i_h.wav")
print(len(i_h_list))

i_l_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/low/export/*-i_l.wav")
print(len(i_l_list))

i_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/neutral/export/*-i_n.wav")
print(len(i_n_list))

#u

u_h_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/high/export/*-i_h.wav")
print(len(u_h_list))

u_l_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/low/export/*-i_l.wav")
print(len(u_l_list))

u_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/neutral/export/*-i_n.wav")
print(len(u_n_list))
# Out:
# 1354
# 1354
# 1353
# 1354
# 1353
# 1353
# 1355
# 1353
# 1353
# 1355

# %%
a_h_list[0].split('\\')[-1].split('-')[0]
# Out:
# '101'

# %%
phrase_of_parse =[]
for text in phrase_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        phrase_of_parse.append(text_parse)

## a
        
a_h_of_parse =[]
for text in a_h_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        a_h_of_parse.append(text_parse)

a_l_of_parse =[]
for text in a_l_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        a_l_of_parse.append(text_parse)

a_n_of_parse =[]
for text in a_n_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        a_n_of_parse.append(text_parse)        


##i

i_h_of_parse =[]
for text in i_h_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        i_h_of_parse.append(text_parse)

i_l_of_parse =[]
for text in i_l_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        i_l_of_parse.append(text_parse)

i_n_of_parse =[]
for text in i_n_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        i_n_of_parse.append(text_parse)        
        

##u


u_h_of_parse =[]
for text in u_h_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        u_h_of_parse.append(text_parse)

u_l_of_parse =[]
for text in u_l_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        u_l_of_parse.append(text_parse)

u_n_of_parse =[]
for text in u_n_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        u_n_of_parse.append(text_parse)

# %%
print('phrase : ',len(phrase_of_parse))
print('a h : ',len(a_h_of_parse))
print('a l : ',len(a_l_of_parse))
print('a n : ',len(a_n_of_parse))

print('i h : ',len(i_h_of_parse))
print('i l : ',len(i_l_of_parse))
print('i n : ',len(i_n_of_parse))

print('u h : ',len(u_h_of_parse))
print('u l : ',len(u_l_of_parse))
print('u n : ',len(u_n_of_parse))
# Out:
# phrase :  597
# a h :  597
# a l :  596
# a n :  597
# i h :  597
# i l :  596
# i n :  597
# u h :  597
# u l :  596
# u n :  597

# %%
i_h_of_parse
# Out:
# ['1040',
#  '1045',
#  '1046',
#  '1047',
#  '1048',
#  '1049',
#  '105',
#  '1052',
#  '1054',
#  '1056',
#  '107',
#  '108',
#  '109',
#  '1090',
#  '110',
#  '1119',
#  '1120',
#  '1157',
#  '1161',
#  '1164',
#  '1166',
#  '1186',
#  '1188',
#  '119',
#  '1190',
#  '1192',
#  '1195',
#  '120',
#  '1206',
#  '1218',
#  '1221',
#  '1223',
#  '1228',
#  '1229',
#  '1233',
#  '1235',
#  '1237',
#  '1239',
#  '1245',
#  '1246',
#  '1247',
#  '1248',
#  '1249',
#  '1252',
#  '1253',
#  '1256',
#  '1257',
#  '1259',
#  '1260',
#  '1262',
#  '1263',
#  '1264',
#  '1265',
#  '1269',
#  '1270',
#  '1271',
#  '1272',
#  '1273',
#  '1274',
#  '1277',
#  '128',
#  '1283',
#  '1289',
#  '129',
#  '1290',
#  '1292',
#  '1293',
#  '1295',
#  '130',
#  '1300',
#  '1301',
#  '1303',
#  '1304',
#  '1305',
#  '1307',
#  '131',
#  '1311',
#  '1314',
#  '1315',
#  '1317',
#  '1325',
#  '1330',
#  '1332',
#  '1334',
#  '1341',
#  '138',
#  '1382',
#  '1383',
#  '1386',
#  '1388',
#  '1389',
#  '139',
# ...

# %%
# 파일 복사

for num in phrase_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/phrase/export/'+num+'-phrase.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/phrase/export/'
    shutil.copy(name,to)

## a
for num in a_h_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/a/high/export/'+num+'-a_h.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/a/high/export/'
    shutil.copy(name,to)


for num in a_l_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/a/low/export/'+num+'-a_l.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/a/low/export/'
    shutil.copy(name,to)

for num in a_n_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/a/neutral/export/'+num+'-a_n.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/a/neutral/export/'
    shutil.copy(name,to)

## i

for num in i_h_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/high/export/'+num+'-i_h.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/i/high/export/'
    shutil.copy(name,to)


for num in i_l_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/low/export/'+num+'-i_l.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/i/low/export/'
    shutil.copy(name,to)

for num in i_n_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/i/neutral/export/'+num+'-i_n.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/i/neutral/export/'
    shutil.copy(name,to)



## u
for num in u_h_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/u/high/export/'+num+'-u_h.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/u/high/export/'
    shutil.copy(name,to)


for num in u_l_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/u/low/export/'+num+'-u_l.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/u/low/export/'
    shutil.copy(name,to)

for num in u_n_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data_ver2/pathology/u/neutral/export/'+num+'-u_n.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organcis_ver2/pathology/u/neutral/export/'
    shutil.copy(name,to)

# %%
#healthy 데이터 분포


#1. pathology - phrase


from glob import glob
phrase_list = glob('D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/phrase/export/*-phrase.wav')
print(len(phrase_list))


## a
a_h_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/a/high/export/*-a_h.wav")
print(len(a_h_list))

a_l_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/a/low/export/*-a_l.wav")
print(len(a_l_list))

a_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/a/neutral/export/*-a_n.wav")
print(len(a_n_list))


##i

i_h_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/i/high/export/*-i_h.wav")
print(len(i_h_list))

i_l_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/i/low/export/*-i_l.wav")
print(len(i_l_list))

i_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/i/neutral/export/*-i_n.wav")
print(len(i_n_list))

#u

u_h_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/u/high/export/*-u_h.wav")
print(len(u_h_list))

u_l_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/u/low/export/*-u_l.wav")
print(len(u_l_list))

u_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data_ver2/healthy/u/neutral/export/*-u_n.wav")
print(len(u_n_list))
# Out:
# 634
# 687
# 687
# 687
# 687
# 687
# 687
# 687
# 687
# 687

# %% [markdown]
# # EGG Phrase, vowel neutral

# %%
import time
import pandas as pd
import re
import shutil
import os
import openpyxl
from glob import glob

# %%
all_data=pd.read_excel("D:/project/voice_pathology_ai/voice_data/svdlimit.xlsx")
all_data
# Out:
#       RECORDING PATHOLOGY        DATE  SPEAKER GENDER  AGE  \
# 0             1         n  20/11/1997        1      w   20
# 1          1862         p  27/11/2000        1      w   23
# 2             2         n  20/11/1997        2      w   22
# 3             3         n  20/11/1997        3      w   23
# 4             4         n  20/11/1997        4      m   22
# ...         ...       ...         ...      ...    ...  ...
# 2220       1051         p  11.11.1998     1402      w   29
# 2221        693         p  15.05.1998     1403      w   28
# 2222        712         p  20.05.1998     1404      w   42
# 2223        713         p  20.05.1998     1405      m   13
# 2224        714         p  20.05.1998     1406      m   71
#
#                                                  DETAIL         DIAG
# 0                                               control      control
# 1                                Funktionelle Dysphonie  non-organic
# ...

# %%
str_expr = "DIAG == 'neurogenic' or DIAG == 'structural'"    # 나이가 10 이다 (비교연산자 ==)
organic_data= all_data.query(str_expr) # 조건 부합 데이터 추출

organic_data
#논문처럼 597건이 주어진다.
# Out:
#       RECORDING PATHOLOGY        DATE  SPEAKER GENDER  AGE  \
# 20          715         p  20.05.1998     1407      w   63
# 21         1303         p  21.04.1999     1407      w   64
# 22         1557         p  08.12.1999     1407      w   65
# 23         1559         p  15.12.1999     1407      w   65
# 24         1864         p  29.11.2000     1407      w   66
# ...         ...       ...         ...      ...    ...  ...
# 2211       1314         p  28.04.1999     1397      m   77
# 2212       1564         p  15.12.1999     1397      m   78
# 2213        671         p  13.05.1998     1398      w   66
# 2214        879         p  15.07.1998     1398      w   66
# 2222        712         p  20.05.1998     1404      w   42
#
#                        DETAIL        DIAG
# 20    Laryngitis; Leukoplakie  structural
# 21                Leukoplakie  structural
# 22                Leukoplakie  structural
# 23                Leukoplakie  structural
# ...

# %%
organic_list = organic_data['RECORDING'].tolist()
organic_list
# Out:
# [715,
#  1303,
#  1557,
#  1559,
#  1864,
#  716,
#  718,
#  1481,
#  720,
#  721,
#  725,
#  1604,
#  1901,
#  726,
#  742,
#  819,
#  821,
#  824,
#  825,
#  828,
#  844,
#  849,
#  896,
#  1548,
#  2088,
#  2395,
#  2455,
#  855,
#  895,
#  1190,
#  863,
#  875,
#  864,
#  859,
#  869,
#  871,
#  874,
#  876,
#  880,
#  1721,
#  883,
#  912,
#  884,
#  886,
#  897,
#  893,
#  901,
#  902,
#  918,
#  904,
#  1554,
#  910,
#  919,
#  923,
#  1290,
#  1646,
#  924,
#  926,
#  928,
#  930,
#  931,
#  932,
#  935,
#  1040,
#  1045,
#  1056,
#  1046,
#  1047,
#  1048,
#  1049,
#  1052,
#  1164,
#  1221,
#  1054,
#  1755,
#  1119,
#  1192,
#  1157,
#  1161,
#  1166,
#  1186,
#  1188,
#  1195,
#  1218,
#  1223,
#  1325,
#  1262,
#  1292,
#  1402,
#  2150,
#  2469,
#  1228,
#  1229,
#  1274,
#  1447,
#  1233,
#  1235,
#  1246,
#  1237,
#  1239,
#  1245,
#  1247,
#  1248,
#  1249,
#  1263,
#  1472,
#  1252,
#  1253,
#  1270,
#  1277,
#  1289,
#  1256,
#  1257,
#  1259,
#  1264,
#  1260,
# ...

# %%
#1. pathology - phrase


from glob import glob
phrase_list = glob('D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/phrase/*-egg.wav')
print(len(phrase_list))


## a
a_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/a/*-egg.wav")
print(len(a_n_list))


##i
i_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/i/*-egg.wav")
print(len(i_n_list))

#u
u_n_list = glob("D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/u/*-egg.wav")
print(len(u_n_list))
# Out:
# 1354
# 1354
# 1355
# 1355

# %%
phrase_of_parse =[]
for text in phrase_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        phrase_of_parse.append(text_parse)

# %%
## a
a_n_of_parse =[]
for text in a_n_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        a_n_of_parse.append(text_parse)        


##i
i_n_of_parse =[]
for text in i_n_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        i_n_of_parse.append(text_parse)        
        

##u
u_n_of_parse =[]
for text in u_n_list:
    text_parse = text.split('\\')[-1].split('-')[0]
    if int(text_parse) in organic_list:
        u_n_of_parse.append(text_parse)

# %%
# 파일 복사

for num in phrase_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/phrase/'+num+'-phrase-egg.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/phrase/export/'
    shutil.copy(name,to)

## a
for num in a_n_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/a/'+num+'-a_n-egg.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/a/neutral/export'
    shutil.copy(name,to)

## i
for num in i_n_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/i/'+num+'-i_n-egg.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/i/neutral/export'
    shutil.copy(name,to)



## u
for num in u_n_of_parse:
    name = 'D:/project/voice_pathology_ai/voice_data/all_data/pathology/egg_wav/u/'+num+'-u_n-egg.wav'
    to = 'D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/u/neutral/export'
    shutil.copy(name,to)

# %%
#1. pathology - phrase


from glob import glob
phrase_list = glob('D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/u/neutral/export/*-egg.wav')
print(len(phrase_list))


## a
a_n_list = glob("D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/u/neutral/export/*-egg.wav")
print(len(a_n_list))


##i
i_n_list = glob("D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/u/neutral/export/*-egg.wav")
print(len(i_n_list))

#u
u_n_list = glob("D:/project/voice_pathology_ai/voice_data/organics_ver2/pathology/egg_wav/u/neutral/export/*-egg.wav")
print(len(u_n_list))
# Out:
# 597
# 597
# 597
# 597
