# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
resnet18_uar_list = [0.850332777,0.846878937,0.838554085,0.839785309,0.814973778]
resnet18_speicificity_list = [0.872698413,0.879047619,0.882539683,0.853968254,0.865396825]
resnet18_sensitivity_list = [0.827967141,0.814710255,0.794568488,0.825602364,0.764550731]

resnet101_uar_list = [0.84313205,0.842466991,0.840971721,0.834838188,0.803940349]
resnet101_speicificity_list = [0.869206349,0.857777778,0.860952381,0.865714286,0.867936508]
resnet101_sensitivity_list = [0.81705775,0.827156205,0.82099106,0.803962091,0.73994419]

resnet34_uar_list = [0.841560889,0.836154093,0.831559264,0.822297979,0.802207941]
resnet34_speicificity_list = [0.882539683,0.8352984616,0.813002579,0.8351753131,0.8403523035]
resnet34_sensitivity_list = [0.800582095,0.870793651,0.876825397,0.865079365,0.86952381]

resnet50_uar_list = [0.846610609,0.848035485,0.841227802,0.822371427,0.812776749]
resnet50_speicificity_list = [0.871746032,0.877460317,0.877460317,0.86,0.870793651]
resnet50_sensitivity_list = [0.821475185,0.818610653,0.804995287,0.784742855,0.754759846]

efficientb0_uar_list = [0.839412153,0.836682497,0.834741049,0.825194815,0.803685756]
efficientb0_speicificity_list = [0.874603175,0.867936508,0.863492063,0.851746032,0.848571429]
efficientb0_sensitivity_list = [0.804221132,0.805428487,0.805990034,0.798643598,0.758800084]

efficientb1_uar_list = [0.836037202,0.832143387,0.827263128,0.813422281,0.77782449]
efficientb1_speicificity_list = [0.875873016,0.860634921,0.87047619,0.863492063,0.862222222]
efficientb1_sensitivity_list = [0.796201388,0.803651854,0.784050066,0.763352498,0.693426758]

efficientb2_uar_list = [0.833762061,0.834038032,0.823951216,0.824081627,0.793339211]
efficientb2_speicificity_list = [0.845079365,0.845714286,0.844761905,0.845714286,0.813333333]
efficientb2_sensitivity_list = [0.822444756,0.822361778,0.803140528,0.802448968,0.773345089]

#--

alexnet_uar_list = [0.828603499,0.829676341,0.825406769,0.817892013,0.797223338]
alexnet_speicificity_list = [0.85015873,0.862539683,0.876825397,0.84031746,0.845079365]
alexnet_sensitivity_list = [0.807048268,0.796812999,0.77398814,0.795466567,0.749367311]

densenet121_uar_list = [0.834520492,0.832319982,0.832859266,0.827709692,0.798789389]
densenet121_speicificity_list = [0.802374317,0.810036788,0.803178849,0.822086052,0.742023222]
densenet121_sensitivity_list = [0.866666667,0.854603175,0.862539683,0.833333333,0.855555556]

vgg16_uar_list = [0.853144939,0.840864411,0.837083033,0.831533528,0.810925366]
vgg16_speicificity_list = [0.88984127,0.880952381,0.877460317,0.881587302,0.888253968]
vgg16_sensitivity_list = [0.816448609,0.80077644,0.796705748,0.781479754,0.733596764]

vgg19_uar_list = [0.841886394,0.837555626,0.834493829,0.834730044,0.810825017]
vgg19_speicificity_list = [0.867619048,0.852380952,0.875555556,0.882539683,0.881269841]
vgg19_sensitivity_list = [0.81615374,0.8227303,0.793432102,0.786920406,0.740380193]

vgg11_uar_list = [0.843093696,0.842511992,0.838031472,0.833503006,0.808415066]
vgg11_speicificity_list = [0.87968254,0.865396825,0.880634921,0.873015873,0.875238095]
vgg11_sensitivity_list = [0.806504851,0.819627158,0.795428023,0.793990139,0.741592037]

vgg13_uar_list = [0.846686637,0.853271917,0.837418054,0.83199999,0.814022184]
vgg13_speicificity_list = [0.884126984,0.875238095,0.874603175,0.868888889,0.873968254]
vgg13_sensitivity_list = [0.809246291,0.831305738,0.800232932,0.795111092,0.754076114]






x=['168','337','506','675','844(100%)']

plt.figure(figsize=(10,12))


def draw_plot(x,y,label):
    
    plt.plot(x,y[::-1],label=label)
    plt.text(x[-1], y[0], f'{label}')

draw_plot(x,resnet18_uar_list,'resnet18')
draw_plot(x,resnet34_uar_list,'resnet34')
draw_plot(x,resnet50_uar_list,'resnet50')
draw_plot(x,resnet101_uar_list,'resnet101')
draw_plot(x,efficientb0_uar_list,'efficientb0')
draw_plot(x,efficientb1_uar_list,'efficientb1')
draw_plot(x,efficientb2_uar_list,'efficientb2')
draw_plot(x,densenet121_uar_list,'densenet121')
draw_plot(x,vgg11_uar_list,'vgg11')
draw_plot(x,vgg13_uar_list,'vgg13')
draw_plot(x,vgg16_uar_list,'vgg16')
draw_plot(x,vgg19_uar_list,'vgg19')
draw_plot(x,alexnet_uar_list,'alexnet')



plt.xlabel("Train probs")
plt.ylabel("Test UAR")


plt.legend()
plt.show()

# %%
x=['168','337','506','675','844(100%)']

plt.figure(figsize=(10,12))



def draw_plot(x,y,label):
    plt.plot(x,y[::-1],label=label)
    plt.text(x[-1], y[0], f'{label}')

draw_plot(x,resnet18_speicificity_list,'resnet18')
draw_plot(x,resnet34_speicificity_list,'resnet34')
draw_plot(x,resnet50_speicificity_list,'resnet50')
draw_plot(x,resnet101_speicificity_list,'resnet101')
draw_plot(x,efficientb0_speicificity_list,'efficientb0')
draw_plot(x,efficientb1_speicificity_list,'efficientb1')
draw_plot(x,efficientb2_speicificity_list,'efficientb2')
draw_plot(x,densenet121_speicificity_list,'densenet121')
draw_plot(x,vgg11_speicificity_list,'vgg11')
draw_plot(x,vgg13_speicificity_list,'vgg13')
draw_plot(x,vgg16_speicificity_list,'vgg16')
draw_plot(x,vgg19_speicificity_list,'vgg19')
draw_plot(x,alexnet_speicificity_list,'alexnet')

plt.xlabel("Train probs")
plt.ylabel("Specificity")


plt.legend()
plt.show()

# %%
x=['168','337','506','675','844(100%)']

plt.figure(figsize=(10,12))



def draw_plot(x,y,label):
    plt.plot(x,y[::-1],label=label)
    plt.text(x[-1], y[0], f'{label}')

draw_plot(x,resnet18_sensitivity_list,'resnet18')
draw_plot(x,resnet34_sensitivity_list,'resnet34')
draw_plot(x,resnet50_sensitivity_list,'resnet50')
draw_plot(x,resnet101_sensitivity_list,'resnet101')
draw_plot(x,efficientb0_sensitivity_list,'efficientb0')
draw_plot(x,efficientb1_sensitivity_list,'efficientb1')
draw_plot(x,efficientb2_sensitivity_list,'efficientb2')
draw_plot(x,densenet121_sensitivity_list,'densenet121')
draw_plot(x,vgg11_sensitivity_list,'vgg11')
draw_plot(x,vgg13_sensitivity_list,'vgg13')
draw_plot(x,vgg16_sensitivity_list,'vgg16')
draw_plot(x,vgg19_sensitivity_list,'vgg19')
draw_plot(x,alexnet_sensitivity_list,'alexnet')

plt.xlabel("Train probs")
plt.ylabel("Sensitivity")


plt.legend()
plt.show()
