# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5
# - https://quokkas.tistory.com/37 : early stopping
# - https://continuous-development.tistory.com/166 : stratified kfold
# - https://deep-learning-study.tistory.com/476 fiter 시각화
# - https://wyatt37.tistory.com/10 : random over sampling

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
from pytorchtools.pytorchtools import EarlyStopping # 현재 폴더에 추가된 모듈.
import torchvision.models as models


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.0  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../voice_data/pathology_new/phrase/export'):
    sig, sr = librosa.load('../voice_data/pathology_new/phrase/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
    pathology.append(MFCCs)
    

#Healthy data
for audio_path in os.listdir('../voice_data/healthy_new/phrase/export'):
    sig, sr = librosa.load('../voice_data/healthy_new/phrase/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
    healthy.append(MFCCs)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  1194
# healthy data 수 :  634
# 가장 긴 path sample : 318596
# 가장 긴 healthy sample : 207017

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 6.37192 초
# 4.14034 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
pd.DataFrame(healthy[0].T,columns=headers)
# Out:
#           mfcc1       mfcc2      mfcc3      mfcc4      mfcc5      mfcc6  \
# 0   -664.554626   42.987347  19.686474  17.893703   5.439660  15.109371
# 1   -661.093262   49.232384  25.329206  19.615351   3.622414  11.143848
# 2   -648.416748   59.700802  29.251112  24.551907   5.502740   8.653680
# 3   -641.470398   64.023300  33.875042  33.504829  10.996720  10.126940
# 4   -640.913208   65.740158  37.212051  34.325729  11.286431  10.338776
# ..          ...         ...        ...        ...        ...        ...
# 321 -583.004944  103.957199  27.952496  24.078373  17.805786  23.063251
# 322 -586.246582  101.427971  23.151981  18.545017  17.543690  25.053162
# 323 -583.195374  100.612839  25.392967  22.381254  10.108490  20.151932
# 324 -591.548950   96.951584  27.558010  26.244709   9.731692  15.010460
# 325 -598.023804   90.819595  32.691036  40.272263  18.734198  16.876379
#
#          mfcc7      mfcc8      mfcc9     mfcc10     mfcc11     mfcc12  \
# 0    25.698231  15.588242  12.777233  12.864212   5.049675   9.790856
# 1    20.681860  11.148173  10.953643  11.828959   5.742883  12.660656
# 2    17.301186   9.595351  11.883838  13.101999   3.480697   4.985496
# 3    20.400213  15.367504  13.606176  16.794329   5.960305   6.227929
# 4    17.450600  13.628424  13.935904  19.616440   8.325340  10.149256
# ..         ...        ...        ...        ...        ...        ...
# 321   9.110998   1.523904   4.881299  12.015348  11.527958  -1.548046
# 322  12.090671   5.663183  11.320034  20.145441  22.497694  10.250479
# 323  11.551888   2.375782   9.401663  18.179150  18.509979   5.336875
# 324  17.244743   8.297908  10.048748  12.094748   5.907953   2.231760
# 325  19.807566   8.091202   6.432930  13.209663   8.640621   4.569102
#
#         mfcc13
# 0    18.775772
# 1    19.052063
# 2     9.246387
# 3    16.133617
# 4    23.181538
# ..         ...
# 321   1.509846
# 322   8.224429
# 323   2.377342
# 324   2.409741
# 325  10.659433
#
# [326 rows x 13 columns]

# %%
healthy[0].shape[1]
# Out:
# 326

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기 - Stratified KFold
#
# - pathology : 1194 / healthy : 634 / 총 1828
# - k = 5
# - random over sampling 추가 ( healthy 데이터가 부족하기 때문)
# - 변경 후 -> pathology : 1194 / healthy : 1194 / 총: 2388

# %% [markdown]
# kfold와 random over sampling을 같이 실시하려면, 미리 test set을 나눠야 한다.
#
# 먼저 테스트셋을 나누고, 그 후에 random over sampling을 실시한다.

# %% [markdown]
# ## 1. test/ train 나누기
#
# - train+valid : 1462 / test : 366

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.

pathology = glob('../voice_data/pathology_new/phrase/export/*.wav')
healthy = glob('../voice_data/healthy_new/phrase/export/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))

X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1194:
        Y.append("pathology")
    else:
        Y.append("healthy")

#train 1462   test: 366
X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1194
# Healthy:  634
# 총 데이터수 :  1828
# ---
# 훈련 셋 :  1462 Counter({'pathology': 955, 'healthy': 507})
# 테스트 셋 :  366 Counter({'pathology': 239, 'healthy': 127})
# ---

# %% [markdown]
# ## 2. random over sampling

# %%
#2. random over sampling

X = np.array(X).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
#Y = np.array(Y)
ros = RandomOverSampler(random_state = 123)
X_res,Y_res = ros.fit_resample(X,Y)

print('before dataset shape {}'.format(Counter(Y)) )
print('Resampled dataset shape {}'.format(Counter(Y_res)) )
# Out:
# before dataset shape Counter({'pathology': 955, 'healthy': 507})
# Resampled dataset shape Counter({'pathology': 955, 'healthy': 955})

# %%
X_res
# Out:
# array([['../voice_data/pathology_new/phrase/export\\2231-phrase.wav'],
#        ['../voice_data/healthy_new/phrase/export\\1124-phrase.wav'],
#        ['../voice_data/pathology_new/phrase/export\\2340-phrase.wav'],
#        ...,
#        ['../voice_data/healthy_new/phrase/export\\2264-phrase.wav'],
#        ['../voice_data/healthy_new/phrase/export\\1871-phrase.wav'],
#        ['../voice_data/healthy_new/phrase/export\\1876-phrase.wav']],
#       dtype='<U57')

# %%
#원래대로 돌리기
X=X_res.reshape(1, -1)
print( '총 데이터수 : ',X[0].size )
print(  '복사된 수 : ',X[0].size - np.unique(X[0]).size )

X=X[0].tolist()
Y=Y_res
# Out:
# 총 데이터수 :  1910
# 복사된 수 :  448

# %%
X
# Out:
# ['../voice_data/pathology_new/phrase/export\\2231-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1124-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2340-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1611-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1157-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\705-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1918-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1410-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2130-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2279-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1632-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2240-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1179-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\982-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\967-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1112-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2345-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1883-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2013-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1720-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2322-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2031-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2419-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1143-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\962-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2556-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1913-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1426-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2403-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1863-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2509-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1311-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\688-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1412-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1762-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1356-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\41-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1414-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1250-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1871-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1503-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2522-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1604-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\942-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\818-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2528-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1932-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1711-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1136-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1017-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2524-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1615-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1545-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1113-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1740-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2218-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\124-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2160-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2533-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1316-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1831-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2135-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1505-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1392-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2226-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2482-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2092-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1281-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1894-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\810-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\109-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1700-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\680-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1958-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1880-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2275-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2213-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\746-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1006-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1163-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2520-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2034-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\14-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1067-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\837-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1787-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2183-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\821-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1730-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1914-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1930-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2247-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1504-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\930-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2006-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1129-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2585-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1196-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1678-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1672-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1862-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1828-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\10-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1861-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\984-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\446-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\11-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2413-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1225-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1181-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\840-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\37-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2254-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2577-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2557-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1552-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\32-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\99-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\991-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\59-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2415-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\958-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\684-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1111-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2235-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1901-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2285-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1991-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\33-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1744-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1239-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\139-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1668-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\862-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2396-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1314-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1477-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1289-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1083-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2329-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1385-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2115-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1460-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2204-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\952-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\819-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1613-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1071-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1616-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2445-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1302-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1660-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1866-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1509-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1676-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1597-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\146-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1637-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1957-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1605-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\66-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1161-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2093-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2108-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1562-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1141-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2137-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2538-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2542-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1826-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2292-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2575-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1527-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2184-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1750-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2342-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2602-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1333-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1555-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1211-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2489-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1358-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1194-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1402-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1848-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\491-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\137-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1830-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1142-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\834-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2255-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\979-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1116-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1780-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1980-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1587-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2443-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1376-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1853-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1855-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2448-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1149-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1936-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\364-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\855-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1596-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1542-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\94-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2294-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1939-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1591-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1897-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2193-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1888-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1760-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\48-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1783-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2134-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1658-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1228-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\4-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\724-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1738-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1659-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2433-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1819-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\978-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2495-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1565-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2309-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1148-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1944-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1456-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1712-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1377-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1638-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1797-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1036-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\803-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1010-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1525-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1959-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2441-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1521-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1684-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1577-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2010-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2343-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2107-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1209-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1073-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1151-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1766-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1942-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1726-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\925-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2479-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1070-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1304-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\809-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1171-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2296-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1775-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1109-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2410-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1312-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1789-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1769-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2353-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2027-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2456-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\951-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1734-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1654-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1977-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1095-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2238-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\842-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\733-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1270-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2563-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2214-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1294-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1629-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1231-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2537-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2425-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1245-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\567-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1429-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2058-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2369-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1054-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2464-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1238-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\687-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\677-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1884-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2315-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1546-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1910-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\690-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2290-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2250-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1541-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1940-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1537-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1098-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1607-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2299-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2148-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1133-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2450-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\54-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2079-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\15-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1876-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\922-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1352-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1285-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2463-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\56-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1553-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1307-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1984-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2217-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1973-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1292-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2572-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1815-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1743-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1167-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1988-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1736-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1500-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\916-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1706-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1084-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\817-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\634-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2078-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2436-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2461-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2561-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1367-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\918-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2103-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1822-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1771-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1368-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\735-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1790-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1840-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1865-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1600-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2096-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\107-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1042-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1518-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1539-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\716-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1912-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2157-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1690-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2504-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1838-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1020-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\969-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1881-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1334-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1160-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2398-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1501-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2591-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2590-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\814-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2365-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\903-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2487-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1216-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2371-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\899-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2127-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\833-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2068-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2421-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1205-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2317-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1309-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1770-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\87-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2082-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1962-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\974-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1481-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1733-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\122-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\135-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1130-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2308-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\26-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1082-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2386-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\70-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1817-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2429-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1719-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2301-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\500-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1009-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1584-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\847-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1905-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\727-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1012-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1983-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\95-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1792-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1355-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\824-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1671-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1350-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\74-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2325-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1564-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2483-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\860-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2312-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1683-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\67-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1185-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2393-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1576-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\849-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2439-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1710-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2444-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1946-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\628-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1841-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1529-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1467-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1450-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\911-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2228-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1190-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1214-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1005-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2012-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2565-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2187-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\12-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1633-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1446-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\948-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1308-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2332-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\85-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2573-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\71-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1156-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1938-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2607-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1648-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1714-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\47-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\148-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1656-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2283-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2264-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\890-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1455-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1375-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1359-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1784-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\820-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1255-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\806-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1200-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2028-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\113-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1657-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\25-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1105-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2330-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\976-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1680-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\106-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\923-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1803-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2323-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1351-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\629-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2269-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2258-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1517-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1079-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\846-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1686-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\884-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1839-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2259-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1532-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\808-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\977-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2118-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2288-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1078-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1434-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\703-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1522-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1627-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1798-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\134-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1128-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1102-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1230-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\123-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\129-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\983-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2550-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1967-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\959-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2611-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1318-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\58-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1849-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2609-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1609-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1506-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\960-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1387-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1280-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1100-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1221-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\853-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2326-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2334-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\714-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2153-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2426-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2484-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1219-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1724-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1993-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1626-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2478-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2156-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\896-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1278-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2123-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1182-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1188-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\563-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1681-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1598-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2075-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1933-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1899-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1535-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1688-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2003-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2347-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2580-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2293-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1252-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2088-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1295-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2378-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1048-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2300-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2005-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1556-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1201-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2406-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2372-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1251-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1620-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1961-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1644-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1123-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2289-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\852-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2536-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2394-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2604-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\943-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2358-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\29-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2362-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\35-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\60-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2124-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1823-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2494-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1403-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1241-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1599-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1558-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\136-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2376-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\101-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\721-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1034-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1072-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1670-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2083-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2408-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1362-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1592-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1699-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2521-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2587-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\850-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1921-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1652-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1335-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1275-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\125-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2109-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\679-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\811-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\77-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1244-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2339-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1728-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2021-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1101-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2567-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1752-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2404-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2470-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1298-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\854-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2222-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2099-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\892-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1850-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1892-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1234-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2091-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1137-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2476-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2209-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2307-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2194-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2541-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\747-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2331-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2388-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1574-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\65-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2280-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1869-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1554-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1882-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1320-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2500-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2505-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2375-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2502-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1580-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\34-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1393-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2462-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1110-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1708-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1548-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1227-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\503-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1217-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2405-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2094-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2606-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\981-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1121-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2110-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1643-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\929-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\694-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\782-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\726-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\105-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1886-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1284-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2368-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2562-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\89-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1053-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2608-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2387-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2266-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1972-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1489-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1357-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2560-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2555-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2306-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1193-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\365-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\349-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\973-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1386-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1916-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1279-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1074-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1087-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\999-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\988-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\897-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2581-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\815-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1788-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2286-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\447-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1800-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1572-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1364-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1966-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1453-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1176-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1145-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1512-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2302-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\844-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2319-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1490-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\38-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1283-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1029-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1165-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2257-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1422-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2519-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1215-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1829-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1286-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2469-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\701-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\841-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\72-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2471-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\691-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1274-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\902-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1321-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1807-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\904-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\720-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1673-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\827-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1729-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\816-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1682-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\941-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1705-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2243-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2191-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1950-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2128-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1058-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1677-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1192-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2480-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1002-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\992-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1812-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1068-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1641-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1747-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1837-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1170-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\119-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2252-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1757-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1027-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1346-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2360-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1064-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\80-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\946-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1104-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1427-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1567-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1569-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\631-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2232-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1674-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1158-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\151-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2297-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2007-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\9-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\838-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2236-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2437-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1348-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1774-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1685-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1523-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\964-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\121-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\939-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2457-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\826-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1953-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1649-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\990-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2282-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1836-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1698-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\44-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\50-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1264-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1635-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1452-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2015-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2514-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2546-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1544-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1718-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1759-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1174-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1126-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1742-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1389-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\971-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2241-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1868-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2474-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2150-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2391-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1159-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1117-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1874-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1873-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2102-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1014-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1485-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\126-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\98-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\875-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1323-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1781-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1060-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\61-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2185-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2223-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1263-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1086-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2594-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1965-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1872-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2576-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2145-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1187-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2422-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\78-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2024-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1802-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1568-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1835-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\719-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\6-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2112-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1055-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\953-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1999-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1391-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2267-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1725-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1589-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2190-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1791-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1353-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1106-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1296-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\945-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2147-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1920-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\949-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\805-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\940-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2011-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1508-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\972-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1354-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2256-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2084-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1301-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1026-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1634-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1902-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2002-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2327-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1640-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1767-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1384-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1955-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\954-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1488-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1735-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\968-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2020-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1885-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2281-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1666-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2499-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1099-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\832-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2154-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2596-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2318-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\20-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2584-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\695-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1516-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2085-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2503-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1242-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1693-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2143-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\961-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1297-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\141-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1631-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\698-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1602-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2212-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1753-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1122-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1651-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\147-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1571-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2364-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1197-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1075-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2554-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\153-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\987-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1365-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1147-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1139-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2601-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1451-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\894-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\30-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1737-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\17-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2338-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1107-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2304-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1022-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1119-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1968-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1282-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2370-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1400-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2189-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1982-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2392-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1120-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2381-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1218-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1927-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1345-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1168-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1373-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\915-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2603-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1709-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2363-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1578-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\104-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2481-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2272-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\910-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2568-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2077-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1630-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1081-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\730-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1360-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\2262-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1019-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1254-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1016-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\155-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2570-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\145-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1655-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1741-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1560-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1417-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1929-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\362-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\497-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\2321-phrase.wav',
#  '../voice_data/healthy_new/phrase/export\\1851-phrase.wav',
#  '../voice_data/pathology_new/phrase/export\\1338-phrase.wav',
#  ...]

# %% [markdown]
# ## 3. stratified k-fold

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.(여기서는 500frame)
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. mfcc를 500프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
        #mfcc 500 FRAME이 되도록 패딩.
        length = 500
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        MFCCs = pad2d(MFCCs, length)
        MFCCs= MFCCs.T
        
        if self.transform:
            #print('transform')
            MFCCs=self.transform(MFCCs).type(torch.float32)# 데이터 0~1 정규화
            MFCCs=torch.stack([MFCCs,MFCCs,MFCCs])# 3채널로 복사.
            MFCCs = MFCCs.squeeze(dim=1)
        else:
            #print("else")
            MFCCs = torch.from_numpy(MFCCs).type(torch.float32)
            MFCCs=MFCCs.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MFCCs, self.classes.index(self.label[idx])

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. mfcc를 500프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
        #mfcc 500 FRAME이 되도록 패딩.
        length = 500
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        MFCCs = pad2d(MFCCs, length)
        MFCCs= MFCCs.T
        
        if self.transform:
            #print('transform')
            MFCCs=self.transform(MFCCs).type(torch.float32)# 데이터 0~1 정규화
            MFCCs=torch.stack([MFCCs,MFCCs,MFCCs])# 3채널로 복사.
            MFCCs = MFCCs.squeeze(dim=1)
        else:
            #print("else")
            MFCCs = torch.from_numpy(MFCCs).type(torch.float32)
            MFCCs=MFCCs.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MFCCs, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 40 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인


train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                               classes,
                                               transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               transform = transforms.ToTensor(),
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])
librosa.display.specshow(X_train[0][0].numpy().T, sr=50000, x_axis='time')
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([32, 3, 500, 13]) type: torch.FloatTensor
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(1)

# %%
#valiation set 확인
for (X_valid,Y_valid) in validation_loader:
    print("X_valid : ",X_valid.size(),'type:',X_valid.type())
    print("Y_valid : ",Y_valid.size(),'type:',Y_valid.type())
    break

print(Y_valid[0])
librosa.display.specshow(X_valid[0][0].numpy().T, sr=50000, x_axis='time')
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_valid :  torch.Size([32, 3, 500, 13]) type: torch.FloatTensor
# Y_valid :  torch.Size([32]) type: torch.LongTensor
# tensor(1)

# %%
#test set 확인
for (test_data,test_label) in test_loader:
    print("X_valid : ",test_data.size(),'type:',test_data.type())
    print("Y_valid : ",test_label.size(),'type:',test_label.type())
    break

print(Y_valid[0])
librosa.display.specshow(test_data[0][0].numpy().T, sr=50000, x_axis='time')
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_valid :  torch.Size([32, 3, 500, 13]) type: torch.FloatTensor
# Y_valid :  torch.Size([32]) type: torch.LongTensor
# tensor(1)

# %% [markdown]
# # RESNET

# %%
# 모델 
# pretrained


def model_initialize():
    model = models.resnet18(pretrained=True).cuda()
    model.ftrs = model.fc.in_features # in_features : fully connected의 입력수.
    num_ftrs = model.fc.in_features

    model.fc = nn.Sequential(nn.Linear(num_ftrs, 256),
                             nn.BatchNorm1d(256),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(256,128),
                             nn.BatchNorm1d(128),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(128,64),
                             nn.BatchNorm1d(64),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(64,50),
                             nn.BatchNorm1d(50),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(50,2)
                            )

    model = model.cuda()
    return model
model=model_initialize()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=64, out_features=50, bias=True)
#     (13): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Linear(in_features=50, out_features=2, bias=True)
#   )
# )

# %%
# get the model summary
from torchsummary import summary
summary(model, input_size=(3, 500, 13), device=DEVICE.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 250, 7]           9,408
#        BatchNorm2d-2           [-1, 64, 250, 7]             128
#               ReLU-3           [-1, 64, 250, 7]               0
#          MaxPool2d-4           [-1, 64, 125, 4]               0
#             Conv2d-5           [-1, 64, 125, 4]          36,864
#        BatchNorm2d-6           [-1, 64, 125, 4]             128
#               ReLU-7           [-1, 64, 125, 4]               0
#             Conv2d-8           [-1, 64, 125, 4]          36,864
#        BatchNorm2d-9           [-1, 64, 125, 4]             128
#              ReLU-10           [-1, 64, 125, 4]               0
#        BasicBlock-11           [-1, 64, 125, 4]               0
#            Conv2d-12           [-1, 64, 125, 4]          36,864
#       BatchNorm2d-13           [-1, 64, 125, 4]             128
#              ReLU-14           [-1, 64, 125, 4]               0
#            Conv2d-15           [-1, 64, 125, 4]          36,864
#       BatchNorm2d-16           [-1, 64, 125, 4]             128
#              ReLU-17           [-1, 64, 125, 4]               0
#        BasicBlock-18           [-1, 64, 125, 4]               0
#            Conv2d-19           [-1, 128, 63, 2]          73,728
#       BatchNorm2d-20           [-1, 128, 63, 2]             256
#              ReLU-21           [-1, 128, 63, 2]               0
#            Conv2d-22           [-1, 128, 63, 2]         147,456
#       BatchNorm2d-23           [-1, 128, 63, 2]             256
#            Conv2d-24           [-1, 128, 63, 2]           8,192
#       BatchNorm2d-25           [-1, 128, 63, 2]             256
#              ReLU-26           [-1, 128, 63, 2]               0
#        BasicBlock-27           [-1, 128, 63, 2]               0
#            Conv2d-28           [-1, 128, 63, 2]         147,456
#       BatchNorm2d-29           [-1, 128, 63, 2]             256
#              ReLU-30           [-1, 128, 63, 2]               0
#            Conv2d-31           [-1, 128, 63, 2]         147,456
#       BatchNorm2d-32           [-1, 128, 63, 2]             256
#              ReLU-33           [-1, 128, 63, 2]               0
#        BasicBlock-34           [-1, 128, 63, 2]               0
#            Conv2d-35           [-1, 256, 32, 1]         294,912
#       BatchNorm2d-36           [-1, 256, 32, 1]             512
#              ReLU-37           [-1, 256, 32, 1]               0
#            Conv2d-38           [-1, 256, 32, 1]         589,824
#       BatchNorm2d-39           [-1, 256, 32, 1]             512
#            Conv2d-40           [-1, 256, 32, 1]          32,768
#       BatchNorm2d-41           [-1, 256, 32, 1]             512
#              ReLU-42           [-1, 256, 32, 1]               0
#        BasicBlock-43           [-1, 256, 32, 1]               0
#            Conv2d-44           [-1, 256, 32, 1]         589,824
#       BatchNorm2d-45           [-1, 256, 32, 1]             512
#              ReLU-46           [-1, 256, 32, 1]               0
#            Conv2d-47           [-1, 256, 32, 1]         589,824
#       BatchNorm2d-48           [-1, 256, 32, 1]             512
#              ReLU-49           [-1, 256, 32, 1]               0
#        BasicBlock-50           [-1, 256, 32, 1]               0
#            Conv2d-51           [-1, 512, 16, 1]       1,179,648
#       BatchNorm2d-52           [-1, 512, 16, 1]           1,024
#              ReLU-53           [-1, 512, 16, 1]               0
#            Conv2d-54           [-1, 512, 16, 1]       2,359,296
#       BatchNorm2d-55           [-1, 512, 16, 1]           1,024
#            Conv2d-56           [-1, 512, 16, 1]         131,072
#       BatchNorm2d-57           [-1, 512, 16, 1]           1,024
#              ReLU-58           [-1, 512, 16, 1]               0
#        BasicBlock-59           [-1, 512, 16, 1]               0
#            Conv2d-60           [-1, 512, 16, 1]       2,359,296
#       BatchNorm2d-61           [-1, 512, 16, 1]           1,024
#              ReLU-62           [-1, 512, 16, 1]               0
#            Conv2d-63           [-1, 512, 16, 1]       2,359,296
#       BatchNorm2d-64           [-1, 512, 16, 1]           1,024
#              ReLU-65           [-1, 512, 16, 1]               0
#        BasicBlock-66           [-1, 512, 16, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 256]         131,328
#       BatchNorm1d-69                  [-1, 256]             512
#              ReLU-70                  [-1, 256]               0
#           Dropout-71                  [-1, 256]               0
#            Linear-72                  [-1, 128]          32,896
#       BatchNorm1d-73                  [-1, 128]             256
#              ReLU-74                  [-1, 128]               0
#           Dropout-75                  [-1, 128]               0
#            Linear-76                   [-1, 64]           8,256
#       BatchNorm1d-77                   [-1, 64]             128
#              ReLU-78                   [-1, 64]               0
#           Dropout-79                   [-1, 64]               0
#            Linear-80                   [-1, 50]           3,250
#       BatchNorm1d-81                   [-1, 50]             100
#              ReLU-82                   [-1, 50]               0
#           Dropout-83                   [-1, 50]               0
#            Linear-84                    [-1, 2]             102
# ================================================================
# Total params: 11,353,340
# Trainable params: 11,353,340
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.07
# Forward/backward pass size (MB): 10.21
# Params size (MB): 43.31
# Estimated Total Size (MB): 53.60
# ----------------------------------------------------------------

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# resnet34 pretrained true
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = './checkpoint/checkpoint_resnet18_true_'+str(data_ind)+'.pt'

    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break

        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0226	 Train Acc:54.32 %  | 	Valid Loss:0.0204 	Valid Acc: 67.28 %
#
# Validation loss decreased (inf --> 0.020386).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0213	 Train Acc:58.90 %  | 	Valid Loss:0.0195 	Valid Acc: 71.20 %
#
# Validation loss decreased (0.020386 --> 0.019532).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0209	 Train Acc:60.67 %  | 	Valid Loss:0.0182 	Valid Acc: 76.96 %
#
# Validation loss decreased (0.019532 --> 0.018203).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0191	 Train Acc:65.25 %  | 	Valid Loss:0.0170 	Valid Acc: 80.63 %
#
# Validation loss decreased (0.018203 --> 0.017005).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0180	 Train Acc:70.22 %  | 	Valid Loss:0.0166 	Valid Acc: 78.80 %
#
# Validation loss decreased (0.017005 --> 0.016569).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0165	 Train Acc:74.80 %  | 	Valid Loss:0.0159 	Valid Acc: 79.84 %
#
# Validation loss decreased (0.016569 --> 0.015872).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0155	 Train Acc:76.83 %  | 	Valid Loss:0.0147 	Valid Acc: 83.77 %
#
# Validation loss decreased (0.015872 --> 0.014697).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0142	 Train Acc:81.22 %  | 	Valid Loss:0.0142 	Valid Acc: 82.20 %
#
# Validation loss decreased (0.014697 --> 0.014194).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0124	 Train Acc:86.98 %  | 	Valid Loss:0.0126 	Valid Acc: 86.39 %
#
# Validation loss decreased (0.014194 --> 0.012554).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0108	 Train Acc:90.18 %  | 	Valid Loss:0.0121 	Valid Acc: 87.43 %
#
# Validation loss decreased (0.012554 --> 0.012104).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0096	 Train Acc:92.47 %  | 	Valid Loss:0.0111 	Valid Acc: 87.96 %
#
# Validation loss decreased (0.012104 --> 0.011096).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0075	 Train Acc:96.27 %  | 	Valid Loss:0.0116 	Valid Acc: 86.65 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0070	 Train Acc:96.27 %  | 	Valid Loss:0.0126 	Valid Acc: 83.77 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0058	 Train Acc:98.04 %  | 	Valid Loss:0.0103 	Valid Acc: 86.39 %
#
# Validation loss decreased (0.011096 --> 0.010274).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0052	 Train Acc:98.56 %  | 	Valid Loss:0.0099 	Valid Acc: 87.43 %
#
# Validation loss decreased (0.010274 --> 0.009906).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0045	 Train Acc:98.89 %  | 	Valid Loss:0.0103 	Valid Acc: 87.17 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0051	 Train Acc:97.12 %  | 	Valid Loss:0.0107 	Valid Acc: 87.17 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0048	 Train Acc:97.71 %  | 	Valid Loss:0.0107 	Valid Acc: 86.13 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:19]	 Train Loss:0.0038	 Train Acc:98.49 %  | 	Valid Loss:0.0097 	Valid Acc: 89.27 %
#
# Validation loss decreased (0.009906 --> 0.009734).  Saving model ...
#
# [EPOCH:20]	 Train Loss:0.0035	 Train Acc:98.69 %  | 	Valid Loss:0.0116 	Valid Acc: 86.39 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:21]	 Train Loss:0.0030	 Train Acc:99.02 %  | 	Valid Loss:0.0097 	Valid Acc: 88.74 %
#
# Validation loss decreased (0.009734 --> 0.009725).  Saving model ...
#
# [EPOCH:22]	 Train Loss:0.0036	 Train Acc:97.64 %  | 	Valid Loss:0.0104 	Valid Acc: 86.65 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:23]	 Train Loss:0.0034	 Train Acc:97.38 %  | 	Valid Loss:0.0105 	Valid Acc: 86.91 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:24]	 Train Loss:0.0031	 Train Acc:98.04 %  | 	Valid Loss:0.0152 	Valid Acc: 82.72 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:25]	 Train Loss:0.0031	 Train Acc:98.43 %  | 	Valid Loss:0.0101 	Valid Acc: 88.74 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:26]	 Train Loss:0.0030	 Train Acc:97.97 %  | 	Valid Loss:0.0094 	Valid Acc: 89.53 %
#
# Validation loss decreased (0.009725 --> 0.009386).  Saving model ...
#
# [EPOCH:27]	 Train Loss:0.0031	 Train Acc:97.97 %  | 	Valid Loss:0.0106 	Valid Acc: 88.22 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:28]	 Train Loss:0.0031	 Train Acc:97.77 %  | 	Valid Loss:0.0133 	Valid Acc: 83.77 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:29]	 Train Loss:0.0031	 Train Acc:97.71 %  | 	Valid Loss:0.0136 	Valid Acc: 85.08 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:30]	 Train Loss:0.0026	 Train Acc:98.56 %  | 	Valid Loss:0.0109 	Valid Acc: 88.48 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:31]	 Train Loss:0.0026	 Train Acc:98.10 %  | 	Valid Loss:0.0115 	Valid Acc: 87.17 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0225	 Train Acc:54.97 %  | 	Valid Loss:0.0208 	Valid Acc: 66.49 %
#
# Validation loss decreased (inf --> 0.020774).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0213	 Train Acc:57.26 %  | 	Valid Loss:0.0187 	Valid Acc: 74.87 %
#
# Validation loss decreased (0.020774 --> 0.018672).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0208	 Train Acc:60.27 %  | 	Valid Loss:0.0188 	Valid Acc: 74.61 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0190	 Train Acc:65.71 %  | 	Valid Loss:0.0172 	Valid Acc: 76.96 %
#
# Validation loss decreased (0.018672 --> 0.017208).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0180	 Train Acc:69.96 %  | 	Valid Loss:0.0171 	Valid Acc: 80.10 %
#
# Validation loss decreased (0.017208 --> 0.017137).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0173	 Train Acc:71.73 %  | 	Valid Loss:0.0162 	Valid Acc: 79.58 %
#
# Validation loss decreased (0.017137 --> 0.016207).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0166	 Train Acc:74.48 %  | 	Valid Loss:0.0153 	Valid Acc: 80.89 %
#
# Validation loss decreased (0.016207 --> 0.015281).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0153	 Train Acc:78.80 %  | 	Valid Loss:0.0148 	Valid Acc: 82.98 %
#
# Validation loss decreased (0.015281 --> 0.014815).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0136	 Train Acc:84.03 %  | 	Valid Loss:0.0137 	Valid Acc: 82.72 %
#
# Validation loss decreased (0.014815 --> 0.013689).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0120	 Train Acc:87.24 %  | 	Valid Loss:0.0133 	Valid Acc: 84.55 %
#
# Validation loss decreased (0.013689 --> 0.013268).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0104	 Train Acc:90.77 %  | 	Valid Loss:0.0124 	Valid Acc: 85.08 %
#
# Validation loss decreased (0.013268 --> 0.012423).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0090	 Train Acc:94.18 %  | 	Valid Loss:0.0124 	Valid Acc: 86.91 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0079	 Train Acc:95.03 %  | 	Valid Loss:0.0115 	Valid Acc: 84.82 %
#
# Validation loss decreased (0.012423 --> 0.011493).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0072	 Train Acc:96.47 %  | 	Valid Loss:0.0104 	Valid Acc: 86.65 %
#
# Validation loss decreased (0.011493 --> 0.010431).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0061	 Train Acc:97.71 %  | 	Valid Loss:0.0099 	Valid Acc: 88.48 %
#
# Validation loss decreased (0.010431 --> 0.009865).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0054	 Train Acc:98.23 %  | 	Valid Loss:0.0102 	Valid Acc: 86.91 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0044	 Train Acc:99.02 %  | 	Valid Loss:0.0101 	Valid Acc: 88.22 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0042	 Train Acc:99.15 %  | 	Valid Loss:0.0094 	Valid Acc: 88.48 %
#
# Validation loss decreased (0.009865 --> 0.009362).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0034	 Train Acc:99.93 %  | 	Valid Loss:0.0097 	Valid Acc: 88.48 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0031	 Train Acc:99.80 %  | 	Valid Loss:0.0101 	Valid Acc: 86.91 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0026	 Train Acc:100.00 %  | 	Valid Loss:0.0093 	Valid Acc: 88.48 %
#
# Validation loss decreased (0.009362 --> 0.009282).  Saving model ...
#
# [EPOCH:22]	 Train Loss:0.0025	 Train Acc:99.67 %  | 	Valid Loss:0.0105 	Valid Acc: 86.91 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:23]	 Train Loss:0.0029	 Train Acc:99.15 %  | 	Valid Loss:0.0109 	Valid Acc: 87.17 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:24]	 Train Loss:0.0040	 Train Acc:96.66 %  | 	Valid Loss:0.0166 	Valid Acc: 79.84 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:25]	 Train Loss:0.0068	 Train Acc:93.26 %  | 	Valid Loss:0.0158 	Valid Acc: 80.10 %
#
# EarlyStopping counter: 4 out of 5
# [EPOCH:26]	 Train Loss:0.0047	 Train Acc:95.62 %  | 	Valid Loss:0.0105 	Valid Acc: 86.13 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0228	 Train Acc:52.81 %  | 	Valid Loss:0.0210 	Valid Acc: 67.02 %
#
# Validation loss decreased (inf --> 0.021040).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0221	 Train Acc:56.15 %  | 	Valid Loss:0.0201 	Valid Acc: 71.47 %
#
# Validation loss decreased (0.021040 --> 0.020067).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0210	 Train Acc:58.64 %  | 	Valid Loss:0.0195 	Valid Acc: 71.73 %
#
# Validation loss decreased (0.020067 --> 0.019523).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0197	 Train Acc:63.61 %  | 	Valid Loss:0.0185 	Valid Acc: 72.77 %
#
# Validation loss decreased (0.019523 --> 0.018499).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0191	 Train Acc:65.38 %  | 	Valid Loss:0.0175 	Valid Acc: 76.44 %
#
# Validation loss decreased (0.018499 --> 0.017476).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0179	 Train Acc:70.62 %  | 	Valid Loss:0.0175 	Valid Acc: 73.30 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0169	 Train Acc:74.67 %  | 	Valid Loss:0.0166 	Valid Acc: 76.70 %
#
# Validation loss decreased (0.017476 --> 0.016647).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0157	 Train Acc:78.34 %  | 	Valid Loss:0.0163 	Valid Acc: 75.65 %
#
# Validation loss decreased (0.016647 --> 0.016322).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0147	 Train Acc:82.13 %  | 	Valid Loss:0.0151 	Valid Acc: 78.80 %
#
# Validation loss decreased (0.016322 --> 0.015113).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0131	 Train Acc:85.08 %  | 	Valid Loss:0.0149 	Valid Acc: 78.27 %
#
# Validation loss decreased (0.015113 --> 0.014950).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0122	 Train Acc:87.50 %  | 	Valid Loss:0.0156 	Valid Acc: 74.08 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0108	 Train Acc:91.49 %  | 	Valid Loss:0.0155 	Valid Acc: 73.56 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:13]	 Train Loss:0.0097	 Train Acc:92.67 %  | 	Valid Loss:0.0145 	Valid Acc: 78.01 %
#
# Validation loss decreased (0.014950 --> 0.014529).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0079	 Train Acc:96.34 %  | 	Valid Loss:0.0147 	Valid Acc: 78.53 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0071	 Train Acc:96.60 %  | 	Valid Loss:0.0146 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:16]	 Train Loss:0.0069	 Train Acc:95.42 %  | 	Valid Loss:0.0159 	Valid Acc: 76.18 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:17]	 Train Loss:0.0058	 Train Acc:97.19 %  | 	Valid Loss:0.0120 	Valid Acc: 84.29 %
#
# Validation loss decreased (0.014529 --> 0.011981).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0052	 Train Acc:98.43 %  | 	Valid Loss:0.0131 	Valid Acc: 82.72 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:19]	 Train Loss:0.0053	 Train Acc:97.45 %  | 	Valid Loss:0.0116 	Valid Acc: 84.55 %
#
# Validation loss decreased (0.011981 --> 0.011636).  Saving model ...
#
# [EPOCH:20]	 Train Loss:0.0045	 Train Acc:97.97 %  | 	Valid Loss:0.0115 	Valid Acc: 86.13 %
#
# Validation loss decreased (0.011636 --> 0.011463).  Saving model ...
#
# [EPOCH:21]	 Train Loss:0.0042	 Train Acc:97.71 %  | 	Valid Loss:0.0153 	Valid Acc: 80.10 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:22]	 Train Loss:0.0038	 Train Acc:98.43 %  | 	Valid Loss:0.0110 	Valid Acc: 86.39 %
#
# Validation loss decreased (0.011463 --> 0.010974).  Saving model ...
#
# [EPOCH:23]	 Train Loss:0.0037	 Train Acc:98.30 %  | 	Valid Loss:0.0118 	Valid Acc: 85.34 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:24]	 Train Loss:0.0036	 Train Acc:98.10 %  | 	Valid Loss:0.0145 	Valid Acc: 81.68 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:25]	 Train Loss:0.0044	 Train Acc:96.40 %  | 	Valid Loss:0.0119 	Valid Acc: 87.17 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:26]	 Train Loss:0.0047	 Train Acc:96.27 %  | 	Valid Loss:0.0129 	Valid Acc: 84.29 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:27]	 Train Loss:0.0034	 Train Acc:98.10 %  | 	Valid Loss:0.0143 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0229	 Train Acc:54.32 %  | 	Valid Loss:0.0210 	Valid Acc: 62.57 %
#
# Validation loss decreased (inf --> 0.021003).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0217	 Train Acc:57.66 %  | 	Valid Loss:0.0198 	Valid Acc: 70.94 %
#
# Validation loss decreased (0.021003 --> 0.019763).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0206	 Train Acc:61.91 %  | 	Valid Loss:0.0190 	Valid Acc: 70.94 %
#
# Validation loss decreased (0.019763 --> 0.018961).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0195	 Train Acc:63.94 %  | 	Valid Loss:0.0185 	Valid Acc: 72.25 %
#
# Validation loss decreased (0.018961 --> 0.018522).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0185	 Train Acc:67.93 %  | 	Valid Loss:0.0175 	Valid Acc: 72.51 %
#
# Validation loss decreased (0.018522 --> 0.017482).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0173	 Train Acc:71.99 %  | 	Valid Loss:0.0173 	Valid Acc: 75.39 %
#
# Validation loss decreased (0.017482 --> 0.017305).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0163	 Train Acc:76.37 %  | 	Valid Loss:0.0163 	Valid Acc: 78.80 %
#
# Validation loss decreased (0.017305 --> 0.016332).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0151	 Train Acc:79.91 %  | 	Valid Loss:0.0156 	Valid Acc: 79.84 %
#
# Validation loss decreased (0.016332 --> 0.015561).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0132	 Train Acc:83.70 %  | 	Valid Loss:0.0158 	Valid Acc: 76.96 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0120	 Train Acc:87.76 %  | 	Valid Loss:0.0150 	Valid Acc: 79.58 %
#
# Validation loss decreased (0.015561 --> 0.015019).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0106	 Train Acc:90.45 %  | 	Valid Loss:0.0142 	Valid Acc: 80.63 %
#
# Validation loss decreased (0.015019 --> 0.014222).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0089	 Train Acc:94.04 %  | 	Valid Loss:0.0150 	Valid Acc: 77.75 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0075	 Train Acc:95.88 %  | 	Valid Loss:0.0136 	Valid Acc: 80.37 %
#
# Validation loss decreased (0.014222 --> 0.013608).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0064	 Train Acc:97.71 %  | 	Valid Loss:0.0141 	Valid Acc: 79.58 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0055	 Train Acc:98.56 %  | 	Valid Loss:0.0134 	Valid Acc: 80.89 %
#
# Validation loss decreased (0.013608 --> 0.013390).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0048	 Train Acc:98.89 %  | 	Valid Loss:0.0128 	Valid Acc: 82.98 %
#
# Validation loss decreased (0.013390 --> 0.012848).  Saving model ...
#
# [EPOCH:17]	 Train Loss:0.0046	 Train Acc:98.56 %  | 	Valid Loss:0.0135 	Valid Acc: 81.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:18]	 Train Loss:0.0039	 Train Acc:99.35 %  | 	Valid Loss:0.0132 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:19]	 Train Loss:0.0040	 Train Acc:98.95 %  | 	Valid Loss:0.0121 	Valid Acc: 85.08 %
#
# Validation loss decreased (0.012848 --> 0.012093).  Saving model ...
#
# [EPOCH:20]	 Train Loss:0.0034	 Train Acc:99.35 %  | 	Valid Loss:0.0146 	Valid Acc: 81.15 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:21]	 Train Loss:0.0032	 Train Acc:98.89 %  | 	Valid Loss:0.0145 	Valid Acc: 81.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:22]	 Train Loss:0.0031	 Train Acc:98.89 %  | 	Valid Loss:0.0141 	Valid Acc: 84.29 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:23]	 Train Loss:0.0029	 Train Acc:98.95 %  | 	Valid Loss:0.0161 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:24]	 Train Loss:0.0036	 Train Acc:97.91 %  | 	Valid Loss:0.0203 	Valid Acc: 75.65 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0243	 Train Acc:53.34 %  | 	Valid Loss:0.0211 	Valid Acc: 62.83 %
#
# Validation loss decreased (inf --> 0.021101).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0226	 Train Acc:55.17 %  | 	Valid Loss:0.0205 	Valid Acc: 69.63 %
#
# Validation loss decreased (0.021101 --> 0.020470).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0215	 Train Acc:58.05 %  | 	Valid Loss:0.0194 	Valid Acc: 71.99 %
#
# Validation loss decreased (0.020470 --> 0.019398).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0203	 Train Acc:61.78 %  | 	Valid Loss:0.0182 	Valid Acc: 73.56 %
#
# Validation loss decreased (0.019398 --> 0.018213).  Saving model ...
# [EPOCH:5]	 Train Loss:0.0195	 Train Acc:64.20 %  | 	Valid Loss:0.0175 	Valid Acc: 76.70 %
#
# Validation loss decreased (0.018213 --> 0.017495).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0179	 Train Acc:70.16 %  | 	Valid Loss:0.0167 	Valid Acc: 77.49 %
#
# Validation loss decreased (0.017495 --> 0.016721).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0168	 Train Acc:73.36 %  | 	Valid Loss:0.0169 	Valid Acc: 74.35 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0151	 Train Acc:80.63 %  | 	Valid Loss:0.0155 	Valid Acc: 79.06 %
#
# Validation loss decreased (0.016721 --> 0.015505).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0141	 Train Acc:82.59 %  | 	Valid Loss:0.0138 	Valid Acc: 84.29 %
#
# Validation loss decreased (0.015505 --> 0.013759).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0122	 Train Acc:87.43 %  | 	Valid Loss:0.0140 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0110	 Train Acc:92.02 %  | 	Valid Loss:0.0132 	Valid Acc: 84.82 %
#
# Validation loss decreased (0.013759 --> 0.013220).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0095	 Train Acc:93.65 %  | 	Valid Loss:0.0117 	Valid Acc: 87.70 %
#
# Validation loss decreased (0.013220 --> 0.011749).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0084	 Train Acc:94.70 %  | 	Valid Loss:0.0116 	Valid Acc: 86.39 %
#
# Validation loss decreased (0.011749 --> 0.011638).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0068	 Train Acc:97.64 %  | 	Valid Loss:0.0106 	Valid Acc: 88.48 %
#
# Validation loss decreased (0.011638 --> 0.010617).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0062	 Train Acc:98.43 %  | 	Valid Loss:0.0109 	Valid Acc: 84.55 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0056	 Train Acc:98.10 %  | 	Valid Loss:0.0101 	Valid Acc: 87.70 %
#
# Validation loss decreased (0.010617 --> 0.010135).  Saving model ...
#
# [EPOCH:17]	 Train Loss:0.0049	 Train Acc:99.02 %  | 	Valid Loss:0.0095 	Valid Acc: 87.96 %
#
# Validation loss decreased (0.010135 --> 0.009473).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0043	 Train Acc:99.15 %  | 	Valid Loss:0.0099 	Valid Acc: 86.65 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:19]	 Train Loss:0.0043	 Train Acc:98.89 %  | 	Valid Loss:0.0111 	Valid Acc: 85.34 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:20]	 Train Loss:0.0043	 Train Acc:98.23 %  | 	Valid Loss:0.0102 	Valid Acc: 87.17 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:21]	 Train Loss:0.0049	 Train Acc:96.66 %  | 	Valid Loss:0.0107 	Valid Acc: 86.13 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:22]	 Train Loss:0.0044	 Train Acc:96.79 %  | 	Valid Loss:0.0123 	Valid Acc: 84.55 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %% [markdown]
# # Model 결과 확인

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 97.9712 |	 valid ACC: 89.5288
# [2 교차검증] train ACC : 100.0000 |	 valid ACC: 88.4817
# [3 교차검증] train ACC : 98.4293 |	 valid ACC: 86.3874
# [4 교차검증] train ACC : 98.9529 |	 valid ACC: 85.0785
# [5 교차검증] train ACC : 99.0183 |	 valid ACC: 87.9581
# 평균 검증 정확도 87.4869109947644 %

# %% [markdown]
# # Model Test
#
# - test set
# - confusion matrix

# %%
#confusion matrix 계산
#test set 계산.
def test_evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = './checkpoint/checkpoint_resnet18_true_'+str(data_ind)+'.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers,test_loss = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
# Out:
# 1번 모델
# Accuracy : 78.4153%
# Precision (pathology 예측한 것중 맞는 것) : 0.8077
# recall (실제 pathology 중  예측이 맞는 것) : 0.8787
# f score : 0.7513
# [[210  29]
#  [ 50  77]]
# -----
# 2번 모델
# Accuracy : 80.3279%
# Precision (pathology 예측한 것중 맞는 것) : 0.8436
# recall (실제 pathology 중  예측이 맞는 것) : 0.8577
# f score : 0.7813
# [[205  34]
#  [ 38  89]]
# -----
# 3번 모델
# Accuracy : 80.8743%
# Precision (pathology 예측한 것중 맞는 것) : 0.8565
# recall (실제 pathology 중  예측이 맞는 것) : 0.8494
# f score : 0.7898
# [[203  36]
#  [ 34  93]]
# -----
# 4번 모델
# Accuracy : 81.4208%
# Precision (pathology 예측한 것중 맞는 것) : 0.8226
# recall (실제 pathology 중  예측이 맞는 것) : 0.9121
# f score : 0.7834
# [[218  21]
#  [ 47  80]]
# -----
# 5번 모델
# Accuracy : 81.4208%
# Precision (pathology 예측한 것중 맞는 것) : 0.8519
# recall (실제 pathology 중  예측이 맞는 것) : 0.8661
# f score : 0.7935
# [[207  32]
#  [ 36  91]]
# -----
# 평균 acc : 0.8049
# 평균 f1score : 0.7799

# %% [markdown]
# # Loss 시각화

# %%
len([ a for a in range(1,len(train_losses)) ])
# Out:
# 7

# %%
#resnet34 pretrained true
#훈련이 진행되는 과정에 따라 loss를 시각화

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_losses)+1 ),train_losses,label='Training Loss')
plt.plot(range(1,len(valid_losses)+1 ),valid_losses,label='Validation Loss')

#validation loss의 최저값 지점
minposs = valid_losses.index(min(valid_losses))+1
plt.axvline(minposs,linestyle='--',color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')

plt.ylim(0.0,0.1)# 일정한 scale
plt.xlim(0,len(train_losses)+1) # 일정 sclae로

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('cnn_loss_flot.png',bbox_inches='tight')

# %%
#resnet34 pretrained false
#훈련이 진행되는 과정에 따라 loss를 시각화

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_losses)+1 ),train_losses,label='Training Loss')
plt.plot(range(1,len(valid_losses)+1 ),valid_losses,label='Validation Loss')

#validation loss의 최저값 지점
minposs = valid_losses.index(min(valid_losses))+1
plt.axvline(minposs,linestyle='--',color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')

plt.ylim(0.0,0.1)# 일정한 scale
plt.xlim(0,len(train_losses)+1) # 일정 sclae로

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('cnn_loss_flot.png',bbox_inches='tight')

# %% [markdown]
# # Accuracy 시각화

# %%
#resnet 34 true
#훈련이 진행되는 과정에 따라 loss를 시각화

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_accs)+1 ),train_accs,label='Training Accuracy')
plt.plot(range(1,len(valid_accs)+1 ),valid_accs,label='Validation Accuracy')

#validation loss의 최저값 지점
minposs = valid_accs.index(max(valid_accs))+1
plt.axvline(minposs,linestyle='--',color='r',label='Max Accuracy')

plt.xlabel('epochs')
plt.ylabel('Accuracy (%)')

plt.ylim(0,100.0)# 일정한 scale
plt.xlim(0,len(train_accs)+1) # 일정 sclae로

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('cnn_loss_flot.png',bbox_inches='tight')

# %%
#resnet 34 false
#훈련이 진행되는 과정에 따라 loss를 시각화

fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_accs)+1 ),train_accs,label='Training Accuracy')
plt.plot(range(1,len(valid_accs)+1 ),valid_accs,label='Validation Accuracy')

#validation loss의 최저값 지점
minposs = valid_accs.index(max(valid_accs))+1
plt.axvline(minposs,linestyle='--',color='r',label='Max Accuracy')

plt.xlabel('epochs')
plt.ylabel('Accuracy (%)')

plt.ylim(0,100.0)# 일정한 scale
plt.xlim(0,len(train_accs)+1) # 일정 sclae로

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('cnn_loss_flot.png',bbox_inches='tight')

# %% [markdown]
# # 기타

# %%
############ 안쓰는 코드, testset 없이 kfold만 사용시.
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 결과를 모두 합쳐줘야한다.

from sklearn.metrics import confusion_matrix

cf = np.zeros((2,2))

for data_ind in range(1,6):

    check_path = './checkpoint/checkpoint_resnet18_true_'+str(data_ind)+'.pt'
    model.load_state_dict(torch.load(check_path))
    _,validation_loader = load_data(data_ind-1)

    predictions,answers,test_loss = test_evaluate(model, validation_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]


    cf += confusion_matrix(answers, predictions)
    print(cf)

acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
precision=cf[0,0]/(cf[0,0]+cf[1,0])
recall=cf[0,0]/(cf[0,0]+cf[0,1])
fscore=2*precision*recall/(precision+recall)

print("Accuracy : {:.4f}% ".format(acc*100))
print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
print("f score : {:.4f} ".format(fscore))
# Out:
# [[194.  45.]
#  [ 19. 220.]]
# [[391.  87.]
#  [ 46. 432.]]
# [[596. 121.]
#  [ 74. 643.]]
# [[787. 169.]
#  [ 77. 878.]]
# [[1005.  189.]
#  [ 117. 1077.]]
# Accuracy : 87.1859%
# Precision (pathology 예측한 것중 맞는 것) : 0.8957
# recall (실제 pathology 중  예측이 맞는 것) : 0.8417
# f score : 0.8679

# %%
#크기 알아보기
#일반 CNN

m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 500, 13])
# torch.Size([32, 1, 250, 6])
# torch.Size([32, 1, 125, 3])

# %%
#크기 알아보기
#주파수 영역 CNN

input = torch.randn(32, 1, 500, 13)
m=nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 32,# FeatureMap 수,커널 수
            kernel_size = (1,13),#1x13  no padding
        )
output=m(input)
print(output.size())
m=nn.Conv2d(
            in_channels = 32,# 채널이 1개
            out_channels = 64,# FeatureMap 수,커널 수
            kernel_size = (27,1),#9 x 1 no padding
        )
output=m(output)
print(output.size())
# Out:
# torch.Size([32, 32, 500, 1])
# torch.Size([32, 64, 474, 1])

# %%
input = torch.randn(500, 13)

out=torch.stack([input,input,input])
out.size()
# Out:
# torch.Size([3, 500, 13])

# %%
test_model =
