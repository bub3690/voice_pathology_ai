# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys
import math



p = os.path.abspath('../') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %% [markdown]
# # data 분류

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('../../voice_data/fusion/pathology/phrase/*.wav')
healthy = glob('../../voice_data/fusion/healthy/phrase/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))


pathology= [ path.split("\\")[-1] for path in pathology] # path 데이터 변환.
healthy= [ path.split("\\")[-1] for path in healthy] # path 데이터 변환.
 # path 데이터 변환


X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1193:
        Y.append("pathology")
    else:
        Y.append("healthy")

X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1193
# Healthy:  634
# 총 데이터수 :  1827
# ---
# 훈련 셋 :  1461 Counter({'pathology': 954, 'healthy': 507})
# 테스트 셋 :  366 Counter({'pathology': 239, 'healthy': 127})
# ---

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 190}

# %%
#2. random over sampling
for i in range(5):
    X_temp = np.array(X_train_list[i]).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
    #Y = np.array(Y)
    ros = RandomOverSampler(random_state = 123)
    X_res,Y_res = ros.fit_resample(X_temp,Y_train_list[i])
    
    print("\n fold{} ".format(i))
    print('before dataset shape {}'.format(Counter(Y_train_list[i])) )
    print('Resampled dataset shape {}'.format(Counter(Y_res)) )
    
    #원래대로 돌리기
    X_res=X_res.reshape(1, -1)
    X_train_list[i]=X_res[0].tolist()
    Y_train_list[i]=Y_res
# Out:
#  fold0
# before dataset shape Counter({'pathology': 763, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold1
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold2
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold3
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold4
# before dataset shape Counter({'pathology': 764, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 764, 'healthy': 764})

# %%
import pickle

 
#load
with open("../../voice_data/fusion/phrase_sig_dict.pickle","rb") as fr:
    phrase_dict = pickle.load(fr)

# %% [markdown]
# # data set

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        
        
        
        return sig, self.classes.index(self.label[idx])

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes

        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        return sig, self.classes.index(self.label[idx])

# %% [markdown]
# # data loader

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  12 #한 배치당 32개 음성데이터
EPOCHS = 50 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인



train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                                   classes,
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # model
#
# https://pytorch.org/audio/main/tutorials/speech_recognition_pipeline_tutorial.html

# %% [markdown]
# dat1=torch.randn((32,12,318,768))
# model1=nn.Conv2d(12,3,(3,3))
# dat2=model1(dat1)
# print(dat2.size())
# #torch.Size([32, 3, 316, 766])
# res_18_sample = models.resnet18(pretrained=True)
# dat3=res_18_sample(dat2)
# print(dat3.size())

# %%
for x_train,_ in train_loader:
    break

bundle = torchaudio.pipelines.WAV2VEC2_BASE
model_wav2vec = bundle.get_model().to(DEVICE)
x,_ = model_wav2vec.extract_features(x_train.cuda())
#x_re,_ = model_wav2vec(x_train.cuda())    
x[0].size()
#x_re.size()
# Out:
# torch.Size([16, 318, 768])

# %%
del x_train
#del model_wav2vec
torch.cuda.empty_cache()

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.


        
class wav_path_Net(nn.Module):
    def __init__(self,):
        super(wav_path_Net,self).__init__()
        
        bundle = torchaudio.pipelines.WAV2VEC2_LARGE_LV60K
        self.model_wav2vec = bundle.get_model().to(DEVICE)
        
        self.fc = nn.Sequential(nn.Linear(21*1024,12*1024),
                                nn.BatchNorm1d(12*1024),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(12*1024,1024),
                                nn.BatchNorm1d(1024),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(1024,256),
                                nn.BatchNorm1d(256),
                                nn.ReLU(),
                                nn.Linear(256,2)
                               )
        
        
    def merge(self,hidden_feature):
        hidden_feature=[ feat.mean(axis=1) for feat  in  hidden_feature]
        return hidden_feature
        
        
    def forward(self,x):
        with torch.inference_mode():
            x,_ = self.model_wav2vec.extract_features(x)
        x=x[:-3]
        new_x=[dat.data.cpu() for dat in x]
        new_x = self.merge(new_x)
        new_x = torch.stack(new_x,dim=1)
        new_x = new_x.view(-1,21*1024)
        new_x= self.fc(new_x.cuda())
        return new_x

# %%
#7. Optimizer, Objective Function
def model_initialize():
    model = wav_path_Net().to(DEVICE)
    #원핫 인코딩값의 loss는 crossEntropyLoss로 비교
    #print(model)
    return model

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
        del output
        del image
        torch.cuda.empty_cache()

    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
            del output
            del image
            torch.cuda.empty_cache()
            
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_w2v_fully_large_test_'+str(data_ind)+'.pt'
    print(check_path)
    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break

        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# ../checkpoint/checkpoint_w2v_fully_large_test_1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0453	 Train Acc:73.92 %  | 	Valid Loss:0.0432 	Valid Acc: 71.33 %
#
# Validation loss decreased (inf --> 0.043204).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0376	 Train Acc:79.95 %  | 	Valid Loss:0.0409 	Valid Acc: 79.86 %
#
# Validation loss decreased (0.043204 --> 0.040889).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0349	 Train Acc:81.72 %  | 	Valid Loss:0.0405 	Valid Acc: 76.45 %
#
# Validation loss decreased (0.040889 --> 0.040478).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0341	 Train Acc:82.83 %  | 	Valid Loss:0.0607 	Valid Acc: 70.65 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0283	 Train Acc:85.65 %  | 	Valid Loss:0.0331 	Valid Acc: 84.64 %
#
# Validation loss decreased (0.040478 --> 0.033078).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0275	 Train Acc:86.37 %  | 	Valid Loss:0.0474 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0280	 Train Acc:86.57 %  | 	Valid Loss:0.0371 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0262	 Train Acc:87.48 %  | 	Valid Loss:0.0412 	Valid Acc: 78.50 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0265	 Train Acc:87.48 %  | 	Valid Loss:0.0291 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.033078 --> 0.029080).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0237	 Train Acc:88.27 %  | 	Valid Loss:0.0332 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0239	 Train Acc:89.38 %  | 	Valid Loss:0.0299 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0231	 Train Acc:89.12 %  | 	Valid Loss:0.0459 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0219	 Train Acc:90.37 %  | 	Valid Loss:0.0346 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0205	 Train Acc:89.78 %  | 	Valid Loss:0.0328 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_fully_large_test_2.pt
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0443	 Train Acc:74.51 %  | 	Valid Loss:0.0394 	Valid Acc: 80.14 %
#
# Validation loss decreased (inf --> 0.039436).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0366	 Train Acc:81.59 %  | 	Valid Loss:0.0363 	Valid Acc: 80.82 %
#
# Validation loss decreased (0.039436 --> 0.036260).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0336	 Train Acc:83.62 %  | 	Valid Loss:0.0395 	Valid Acc: 76.37 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0306	 Train Acc:84.47 %  | 	Valid Loss:0.0490 	Valid Acc: 79.45 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0283	 Train Acc:85.45 %  | 	Valid Loss:0.0346 	Valid Acc: 80.82 %
#
# Validation loss decreased (0.036260 --> 0.034616).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0268	 Train Acc:87.75 %  | 	Valid Loss:0.0507 	Valid Acc: 76.37 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0291	 Train Acc:85.65 %  | 	Valid Loss:0.0340 	Valid Acc: 82.53 %
#
# Validation loss decreased (0.034616 --> 0.033997).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0260	 Train Acc:87.55 %  | 	Valid Loss:0.0422 	Valid Acc: 77.40 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0259	 Train Acc:88.27 %  | 	Valid Loss:0.0495 	Valid Acc: 76.37 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0232	 Train Acc:89.19 %  | 	Valid Loss:0.0419 	Valid Acc: 80.82 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0218	 Train Acc:90.24 %  | 	Valid Loss:0.0556 	Valid Acc: 75.34 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0230	 Train Acc:89.97 %  | 	Valid Loss:0.0386 	Valid Acc: 80.48 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_fully_large_test_3.pt
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0467	 Train Acc:73.07 %  | 	Valid Loss:0.0369 	Valid Acc: 78.77 %
#
# Validation loss decreased (inf --> 0.036902).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0364	 Train Acc:81.72 %  | 	Valid Loss:0.0299 	Valid Acc: 85.96 %
#
# Validation loss decreased (0.036902 --> 0.029930).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0350	 Train Acc:81.26 %  | 	Valid Loss:0.0342 	Valid Acc: 78.42 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0356	 Train Acc:81.91 %  | 	Valid Loss:0.0349 	Valid Acc: 81.16 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0314	 Train Acc:84.86 %  | 	Valid Loss:0.0292 	Valid Acc: 86.30 %
#
# Validation loss decreased (0.029930 --> 0.029249).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0289	 Train Acc:85.78 %  | 	Valid Loss:0.0350 	Valid Acc: 81.16 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0280	 Train Acc:86.76 %  | 	Valid Loss:0.0349 	Valid Acc: 80.82 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0252	 Train Acc:88.73 %  | 	Valid Loss:0.0362 	Valid Acc: 82.53 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0244	 Train Acc:88.27 %  | 	Valid Loss:0.0400 	Valid Acc: 83.22 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:10]	 Train Loss:0.0246	 Train Acc:88.07 %  | 	Valid Loss:0.0446 	Valid Acc: 75.68 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_fully_large_test_4.pt
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0456	 Train Acc:75.10 %  | 	Valid Loss:0.0400 	Valid Acc: 77.05 %
#
# Validation loss decreased (inf --> 0.040039).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0368	 Train Acc:82.24 %  | 	Valid Loss:0.0411 	Valid Acc: 77.05 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0352	 Train Acc:80.93 %  | 	Valid Loss:0.0410 	Valid Acc: 77.05 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0313	 Train Acc:84.67 %  | 	Valid Loss:0.0386 	Valid Acc: 76.37 %
#
# Validation loss decreased (0.040039 --> 0.038629).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0320	 Train Acc:84.34 %  | 	Valid Loss:0.0414 	Valid Acc: 71.58 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0290	 Train Acc:86.24 %  | 	Valid Loss:0.0638 	Valid Acc: 69.52 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0274	 Train Acc:86.30 %  | 	Valid Loss:0.0513 	Valid Acc: 71.92 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:8]	 Train Loss:0.0266	 Train Acc:86.76 %  | 	Valid Loss:0.0481 	Valid Acc: 69.86 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:9]	 Train Loss:0.0261	 Train Acc:86.37 %  | 	Valid Loss:0.0335 	Valid Acc: 81.51 %
#
# Validation loss decreased (0.038629 --> 0.033535).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0228	 Train Acc:88.79 %  | 	Valid Loss:0.0383 	Valid Acc: 79.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0227	 Train Acc:90.37 %  | 	Valid Loss:0.0335 	Valid Acc: 85.27 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0205	 Train Acc:90.30 %  | 	Valid Loss:0.0347 	Valid Acc: 84.59 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0208	 Train Acc:90.96 %  | 	Valid Loss:0.0696 	Valid Acc: 68.15 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0205	 Train Acc:91.61 %  | 	Valid Loss:0.0485 	Valid Acc: 77.05 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_fully_large_test_5.pt
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0448	 Train Acc:73.89 %  | 	Valid Loss:0.0508 	Valid Acc: 67.47 %
#
# Validation loss decreased (inf --> 0.050814).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0368	 Train Acc:81.35 %  | 	Valid Loss:0.0386 	Valid Acc: 80.82 %
#
# Validation loss decreased (0.050814 --> 0.038598).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0330	 Train Acc:82.72 %  | 	Valid Loss:0.0507 	Valid Acc: 75.00 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0308	 Train Acc:84.03 %  | 	Valid Loss:0.0424 	Valid Acc: 78.42 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0305	 Train Acc:84.55 %  | 	Valid Loss:0.0594 	Valid Acc: 72.26 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:6]	 Train Loss:0.0271	 Train Acc:86.78 %  | 	Valid Loss:0.0537 	Valid Acc: 72.26 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:7]	 Train Loss:0.0260	 Train Acc:87.11 %  | 	Valid Loss:0.0535 	Valid Acc: 79.11 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 87.4836 |	 valid ACC: 86.6894
# [2 교차검증] train ACC : 85.6488 |	 valid ACC: 82.5342
# [3 교차검증] train ACC : 84.8624 |	 valid ACC: 86.3014
# [4 교차검증] train ACC : 86.3696 |	 valid ACC: 81.5068
# [5 교차검증] train ACC : 81.3482 |	 valid ACC: 80.8219
# 평균 검증 정확도 83.57076067137314 %

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def test_evaluate(model,test_loader):
    model.eval()
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            output = F.softmax(output, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
        return predictions,answers

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_w2v_fully_large_'+str(data_ind)+'.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
# Out:
# 1번 모델
# Accuracy : 83.8798%
# Precision (pathology 예측한 것중 맞는 것) : 0.8462
# recall (실제 pathology 중  예측이 맞는 것) : 0.9205
# f score : 0.8143
# [[220  19]
#  [ 40  87]]
# -----
# 2번 모델
# Accuracy : 78.6885%
# Precision (pathology 예측한 것중 맞는 것) : 0.9045
# recall (실제 pathology 중  예측이 맞는 것) : 0.7531
# f score : 0.7783
# [[180  59]
#  [ 19 108]]
# -----
# 3번 모델
# Accuracy : 84.1530%
# Precision (pathology 예측한 것중 맞는 것) : 0.9132
# recall (실제 pathology 중  예측이 맞는 것) : 0.8368
# f score : 0.8308
# [[200  39]
#  [ 19 108]]
# -----
# 4번 모델
# Accuracy : 78.9617%
# Precision (pathology 예측한 것중 맞는 것) : 0.8375
# recall (실제 pathology 중  예측이 맞는 것) : 0.8410
# f score : 0.7675
# [[201  38]
#  [ 39  88]]
# -----
# 5번 모델
# Accuracy : 81.9672%
# Precision (pathology 예측한 것중 맞는 것) : 0.8619
# recall (실제 pathology 중  예측이 맞는 것) : 0.8619
# f score : 0.8010
# [[206  33]
#  [ 33  94]]
# -----
# 평균 acc : 0.8153
# 평균 f1score : 0.7984
