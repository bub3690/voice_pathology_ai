# %% [markdown]
# # point wise conv2d를 통해 layer 이미지들을 압축.
#
# mean pooling 없이 진행해볼 예정.

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys
import math



p = os.path.abspath('../') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %% [markdown]
# # data 분류

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('../../voice_data/fusion/pathology/phrase/*.wav')
healthy = glob('../../voice_data/fusion/healthy/phrase/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))


pathology= [ path.split("\\")[-1] for path in pathology] # path 데이터 변환.
healthy= [ path.split("\\")[-1] for path in healthy] # path 데이터 변환.
 # path 데이터 변환


X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1193:
        Y.append("pathology")
    else:
        Y.append("healthy")

X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1193
# Healthy:  634
# 총 데이터수 :  1827
# ---
# 훈련 셋 :  1461 Counter({'pathology': 954, 'healthy': 507})
# 테스트 셋 :  366 Counter({'pathology': 239, 'healthy': 127})
# ---

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 190}

# %%
#2. random over sampling
for i in range(5):
    X_temp = np.array(X_train_list[i]).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
    #Y = np.array(Y)
    ros = RandomOverSampler(random_state = 123)
    X_res,Y_res = ros.fit_resample(X_temp,Y_train_list[i])
    
    print("\n fold{} ".format(i))
    print('before dataset shape {}'.format(Counter(Y_train_list[i])) )
    print('Resampled dataset shape {}'.format(Counter(Y_res)) )
    
    #원래대로 돌리기
    X_res=X_res.reshape(1, -1)
    X_train_list[i]=X_res[0].tolist()
    Y_train_list[i]=Y_res
# Out:
#  fold0
# before dataset shape Counter({'pathology': 763, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold1
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold2
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold3
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold4
# before dataset shape Counter({'pathology': 764, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 764, 'healthy': 764})

# %%
import pickle

 
#load
with open("../../voice_data/fusion/phrase_sig_dict.pickle","rb") as fr:
    phrase_dict = pickle.load(fr)

# %% [markdown]
# # data set

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        sig_length = sig.size #sig length 리턴에 사용. feature 추출및 학습에 사용.
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        return sig, self.classes.index(self.label[idx]),sig_length

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes

        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        sig_length = sig.size #sig length 리턴에 사용. feature 추출및 학습에 사용.
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        return sig, self.classes.index(self.label[idx]),sig_length

# %% [markdown]
# # data loader

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 50 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인



train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                                   classes,
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # model
#
# https://pytorch.org/audio/main/tutorials/speech_recognition_pipeline_tutorial.html

# %% [markdown]
# dat1=torch.randn((32,12,318,768))
# model1=nn.Conv2d(12,3,(3,3))
# dat2=model1(dat1)
# print(dat2.size())
# #torch.Size([32, 3, 316, 766])
# res_18_sample = models.resnet18(pretrained=True)
# dat3=res_18_sample(dat2)
# print(dat3.size())

# %% [markdown]
# ----

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.


        
class wav_path_Net(nn.Module):
    def __init__(self,):
        super(wav_path_Net,self).__init__()
        
        self.model_wav2vec2 = torchaudio.models.wav2vec2_large_lv60k(aux_num_out=32)
        self.model_wav2vec2.load_state_dict(torch.load("../checkpoint/wav2vec2-large-lv60.pt"))
        self.model_wav2vec2.aux = nn.Sequential(nn.Linear(1024,2,bias=True),)
        
        self.padded_frame=318
        
        input_dim =101951
        
        self.fc = nn.Sequential(nn.Linear(24*1024,1024),
                                nn.BatchNorm1d(1024),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(1024,256),
                                nn.BatchNorm1d(256),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(256,2),)
        
        
    def merge(self,hidden_feature):
        hidden_feature=[ feat.mean(axis=1) for feat  in  hidden_feature]
        return hidden_feature
        
        
    def forward(self,x,sig_size):
        x_trans,trans_len = self.model_wav2vec.extract_features(x,sig_size)
        self.model_wav2vec.extract_features(x_train,sig_size)
        x = self.merge(x)
        x = torch.stack(x,dim=1)
        x = x.view(-1,24*1024)
        x= self.fc(x)
    
        return x

# %%
data_sample1 = [torch.randn((32,318,1024))]*24
data_sample=torch.stack(data_sample1,dim=1)
data_sample.mean(axis=2).size()
# Out:
# torch.Size([32, 24, 1024])

# %%
#모델 테스트

data_sample1 = [torch.randn((32,318,1024))]*24
data_sample2 = torch.randn((32,318,512))


data_sample1=[dat.mean(axis=1) for dat in data_sample1]
data_sample=torch.stack(data_sample1,dim=1)
print(data_sample.size())
data_sample2=data_sample2.mean(axis=1)
print(data_sample2.size())

mod1=nn.Conv1d(24, 128 , kernel_size=1, padding=0, bias=False)
mod2=nn.Conv1d(128,128, kernel_size=1, padding=0, bias=False)
mod3=nn.Conv1d(128, 128, kernel_size=1, padding=0, bias=False)
mod4=nn.Conv1d(128, 128, kernel_size=1, padding=0, bias=False)

gavg1=nn.AdaptiveAvgPool1d(1)
last_lin = nn.Linear(128,2)

data_sample=mod1(data_sample)
print(data_sample.size())
data_sample=mod2(data_sample)
print(data_sample.size())
data_sample=mod3(data_sample)
print(data_sample.size())
data_sample=mod4(data_sample)
print(data_sample.size())
data_sample=gavg1(data_sample)
print(data_sample.size())
data_sample=data_sample.view(-1,128)
data_sample = last_lin(data_sample)
print(data_sample.size())
# Out:
# torch.Size([32, 24, 1024])
# torch.Size([32, 512])
# torch.Size([32, 128, 1024])
# torch.Size([32, 128, 1024])
# torch.Size([32, 128, 1024])
# torch.Size([32, 128, 1024])
# torch.Size([32, 128, 1])
# torch.Size([32, 2])

# %%
def zero_padding_list(self,hidden_feature,seq_len):

    zero_padding_array=np.ones((len(seq_len),self.padded_frame, hidden_feature.size()[-1] ))
    for i in range(len(seq_len)):
        zero_padding_array[i:,seq_len[i]:,:]=0

    hidden_feature=hidden_feature*torch.from_numpy(zero_padding_array).float().to(DEVICE) # 318 * 2
    return hidden_feature

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



        
class wav_path_Net(nn.Module):
    def __init__(self):
        super(wav_path_Net,self).__init__()
        
        self.model_wav2vec2 = torchaudio.models.wav2vec2_large_lv60k(aux_num_out=32)
        self.model_wav2vec2.load_state_dict(torch.load("../checkpoint/wav2vec2-large-lv60.pt"))
        #self.model_wav2vec2.aux = nn.Sequential(nn.Linear(1024,2,bias=True),)
        self.num = num
        
        #input_dim =101951
        
        self.padded_frame=318
        
        
        self.point_wise = nn.Sequential(
                                nn.Conv1d(24, 128, kernel_size=1, padding=0, bias=False),
                                nn.Conv1d(128,128, kernel_size=1, padding=0, bias=False),
                                nn.Conv1d(128, 128, kernel_size=1, padding=0, bias=False),
                                nn.Conv1d(128, 128, kernel_size=1, padding=0, bias=False),
                                )
        self.gavg1=nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(nn.Linear(128,2))
        
        
    def merge(self,hidden_feature):
        hidden_feature=hidden_feature.mean(axis=2)
        return hidden_feature
    
    def zero_padding_list(self,hidden_feature,seq_len):
        
        zero_padding_array=np.ones((len(seq_len),self.padded_frame, hidden_feature.size()[-1] ))
        for i in range(len(seq_len)):
            zero_padding_array[i:,seq_len[i]:,:]=0
            
        hidden_feature=hidden_feature*torch.from_numpy(zero_padding_array).float().to(DEVICE) # 318 * 2
        return hidden_feature
        
    def forward(self,x,sig_size):
        with torch.inference_mode():
            trans_x,trans_len = self.model_wav2vec2.extract_features(x,sig_size)
            #encoder_x,encoder_len = self.model_wav2vec2.extract_features(x,sig_size)
        trans_x=torch.stack(trans_x,dim=1)
        x = self.zero_padding_list(trans_x,trans_len)
        x = self.merge(x)
        #x = torch.stack(x,dim=1)
        x = x.view(-1,128)
        x= self.fc(x)
    
        return x

# %%
###
# model for enocoder

sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



        
class wav_path_Net(nn.Module):
    def __init__(self,num):
        super(wav_path_Net,self).__init__()
        
        self.model_wav2vec2 = torchaudio.models.wav2vec2_large_lv60k(aux_num_out=32)
        self.model_wav2vec2.load_state_dict(torch.load("../checkpoint/wav2vec2-large-lv60.pt"))
        #self.model_wav2vec2.aux = nn.Sequential(nn.Linear(1024,2,bias=True),)
        self.num = num
        
        #input_dim =101951
        
        self.padded_frame=318
        
        self.fc = nn.Sequential(
                                nn.Linear(512,50),
                                nn.BatchNorm1d(50),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(50,2),)
        
        
    def merge(self,hidden_feature):
        hidden_feature=hidden_feature.mean(axis=1)
        return hidden_feature
    
    def zero_padding(self,hidden_feature,seq_len):
        
        zero_padding_array=np.ones((len(seq_len),self.padded_frame, hidden_feature.size()[-1] ))
        for i in range(len(seq_len)):
            zero_padding_array[i:,seq_len[i]:,:]=0
            
        hidden_feature=hidden_feature*torch.from_numpy(zero_padding_array).float().to(DEVICE) # 318 * 2
        return hidden_feature
        
    def forward(self,x,sig_size):
        with torch.inference_mode():
            encoder_x,encoder_len = self.model_wav2vec2.extract_features(x,sig_size)
        x = encoder_x
        x = self.zero_padding(x,encoder_len)
        x = self.merge(x)
        #x = torch.stack(x,dim=1)
        #x = x.view(-1,1024)
        x= self.fc(x)
    
        return x

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.


bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model_wav2vec = bundle.get_model().to(DEVICE)

print(model_wav2vec.__class__)

        
class wav_path_Net(nn.Module):
    def __init__(self,):
        super(wav_path_Net,self).__init__()
        
        bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
        self.model_wav2vec = bundle.get_model().to(DEVICE)
        self.res_18 = models.resnet18(pretrained=True)
        self.conv_model1=nn.Conv2d(12,3,(3,3))
        
        #input_dim =101951
        
        self.fc = nn.Sequential(nn.Linear(1000,512),
                                nn.BatchNorm1d(512),
                                nn.ReLU(),
                                nn.Linear(512,256),
                                nn.BatchNorm1d(256),
                                nn.ReLU(),
                                nn.Linear(256,50),
                                nn.Linear(50,2),)
        
        
    def merge(self,hidden_feature):
        hidden_feature=[ feat.mean(axis=1) for feat  in  hidden_feature]
        return hidden_feature
        
        
    def forward(self,x):
        with torch.inference_mode():
            x,_ = self.model_wav2vec.extract_features(x)
        x = torch.stack(x,axis=1)
        x = self.conv_model1(x)
        x = self.res_18(x)
        x= self.fc(x)
    
        return x

# %%
#7. Optimizer, Objective Function
def model_initialize(num):
    model = wav_path_Net(num).to(DEVICE)
    #원핫 인코딩값의 loss는 crossEntropyLoss로 비교
    #print(model)
    return model

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label,sig_len) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        sig_len = sig_len.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image,sig_len) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label,sig_len in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            sig_len = sig_len.to(DEVICE)
            output = model(image,sig_len)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def test_evaluate(model,test_loader):
    model.eval()
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label,sig_len in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            sig_len = sig_len.to(DEVICE)
            output = model(image)
            output = F.softmax(output, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
        return predictions,answers

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score



def test_grid():
    cf = np.zeros((2,2))
    cf_list = []
    average_accuracy = 0
    average_fscore = 0
    
    
    for grid_num in range(0,24):
        for data_ind in range(1,2):
            model=model_initialize(grid_num)
            check_path = '../checkpoint/checkpoint_w2v_large_model60k_'+str(grid_num)+'-'+str(data_ind)+'.pt'
            model.load_state_dict(torch.load(check_path))

            predictions,answers = test_evaluate(model, test_loader)
            predictions=[ dat.cpu().numpy() for dat in predictions]
            answers=[ dat.cpu().numpy() for dat in answers]


            cf = confusion_matrix(answers, predictions)
            cf_list.append(cf)

            acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
            average_accuracy+=acc
            precision=cf[0,0]/(cf[0,0]+cf[1,0])
            recall=cf[0,0]/(cf[0,0]+cf[0,1])
            #fscore=2*precision*recall/(precision+recall)

            #fscroe macro추가
            fscore = f1_score(answers,predictions,average='macro')
            average_fscore+=fscore

            print('{}번 모델'.format(grid_num+1))
            print("Accuracy : {:.4f}% ".format(acc*100))
            print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
            print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
            print("f score : {:.4f} ".format(fscore))
            print(cf)
            print("-----")

# %%
#10. 학습 및 평가.
# kfold 적용
train_accs = []
valid_accs = []
for num in range(24):
    print("{}-번 레이어".format(num))


    for data_ind in range(1,2):

        check_path = '../checkpoint/checkpoint_w2v_large_model60k_'+str(num)+'-'+str(data_ind)+'.pt'
        print(check_path)
        early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
        train_loader,validation_loader = load_data(data_ind-1)

        best_train_acc=0 # accuracy 기록용
        best_valid_acc=0

        model=model_initialize(num)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(),lr=0.001)


        print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
        for Epoch in range(1,EPOCHS+1):
            train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
            valid_loss,valid_accuracy = evaluate(model, validation_loader)


            print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
                  format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
            

            early_stopping(valid_loss, model)
            if -early_stopping.best_score == valid_loss:
                best_train_acc, best_valid_acc = train_accuracy,valid_accuracy

            if early_stopping.early_stop:
                    train_accs.append(best_train_acc)
                    valid_accs.append(best_valid_acc)
                    print("[{} 교차검증] Early stopping".format(data_ind))
                    break

            if Epoch==EPOCHS:
                #만약 early stop 없이 40 epoch라서 중지 된 경우.
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
# Out:
# 0-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_0-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0167	 Train Acc:74.77 %  | 	Valid Loss:0.0132 	Valid Acc: 83.62 %
#
# Validation loss decreased (inf --> 0.013155).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0141	 Train Acc:79.69 %  | 	Valid Loss:0.0143 	Valid Acc: 79.86 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0128	 Train Acc:82.57 %  | 	Valid Loss:0.0145 	Valid Acc: 77.47 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0125	 Train Acc:81.59 %  | 	Valid Loss:0.0105 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.013155 --> 0.010509).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0121	 Train Acc:83.29 %  | 	Valid Loss:0.0121 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0118	 Train Acc:84.21 %  | 	Valid Loss:0.0119 	Valid Acc: 82.25 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0112	 Train Acc:84.67 %  | 	Valid Loss:0.0159 	Valid Acc: 74.74 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:8]	 Train Loss:0.0107	 Train Acc:85.98 %  | 	Valid Loss:0.0127 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:9]	 Train Loss:0.0105	 Train Acc:84.40 %  | 	Valid Loss:0.0105 	Valid Acc: 87.71 %
#
# Validation loss decreased (0.010509 --> 0.010469).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0107	 Train Acc:84.86 %  | 	Valid Loss:0.0121 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0101	 Train Acc:87.22 %  | 	Valid Loss:0.0112 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0102	 Train Acc:85.45 %  | 	Valid Loss:0.0138 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0097	 Train Acc:86.30 %  | 	Valid Loss:0.0122 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0092	 Train Acc:87.29 %  | 	Valid Loss:0.0113 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 1-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_1-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0168	 Train Acc:74.97 %  | 	Valid Loss:0.0132 	Valid Acc: 82.94 %
#
# Validation loss decreased (inf --> 0.013192).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0132	 Train Acc:81.32 %  | 	Valid Loss:0.0120 	Valid Acc: 82.25 %
#
# Validation loss decreased (0.013192 --> 0.012020).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0121	 Train Acc:83.29 %  | 	Valid Loss:0.0107 	Valid Acc: 87.03 %
#
# Validation loss decreased (0.012020 --> 0.010672).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0116	 Train Acc:83.22 %  | 	Valid Loss:0.0117 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0113	 Train Acc:84.67 %  | 	Valid Loss:0.0112 	Valid Acc: 87.71 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0108	 Train Acc:84.73 %  | 	Valid Loss:0.0102 	Valid Acc: 87.37 %
#
# Validation loss decreased (0.010672 --> 0.010229).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0100	 Train Acc:86.96 %  | 	Valid Loss:0.0108 	Valid Acc: 86.35 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0097	 Train Acc:86.50 %  | 	Valid Loss:0.0134 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0093	 Train Acc:87.68 %  | 	Valid Loss:0.0108 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:10]	 Train Loss:0.0096	 Train Acc:86.63 %  | 	Valid Loss:0.0109 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:11]	 Train Loss:0.0093	 Train Acc:87.29 %  | 	Valid Loss:0.0110 	Valid Acc: 88.05 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 2-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_2-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0161	 Train Acc:75.43 %  | 	Valid Loss:0.0134 	Valid Acc: 83.28 %
#
# Validation loss decreased (inf --> 0.013412).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0131	 Train Acc:81.13 %  | 	Valid Loss:0.0132 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.013412 --> 0.013218).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0117	 Train Acc:84.08 %  | 	Valid Loss:0.0119 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.013218 --> 0.011875).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0111	 Train Acc:85.12 %  | 	Valid Loss:0.0116 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.011875 --> 0.011641).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0105	 Train Acc:86.57 %  | 	Valid Loss:0.0111 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.011641 --> 0.011104).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0104	 Train Acc:86.17 %  | 	Valid Loss:0.0100 	Valid Acc: 88.40 %
#
# Validation loss decreased (0.011104 --> 0.009968).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0093	 Train Acc:87.48 %  | 	Valid Loss:0.0131 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0089	 Train Acc:87.42 %  | 	Valid Loss:0.0114 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0085	 Train Acc:88.99 %  | 	Valid Loss:0.0134 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:10]	 Train Loss:0.0085	 Train Acc:89.12 %  | 	Valid Loss:0.0107 	Valid Acc: 88.05 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:11]	 Train Loss:0.0084	 Train Acc:88.60 %  | 	Valid Loss:0.0108 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 3-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_3-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0162	 Train Acc:75.36 %  | 	Valid Loss:0.0143 	Valid Acc: 83.28 %
#
# Validation loss decreased (inf --> 0.014297).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0128	 Train Acc:82.11 %  | 	Valid Loss:0.0135 	Valid Acc: 83.62 %
#
# Validation loss decreased (0.014297 --> 0.013513).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0121	 Train Acc:83.16 %  | 	Valid Loss:0.0174 	Valid Acc: 74.06 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0110	 Train Acc:85.12 %  | 	Valid Loss:0.0131 	Valid Acc: 83.62 %
#
# Validation loss decreased (0.013513 --> 0.013086).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0108	 Train Acc:84.53 %  | 	Valid Loss:0.0134 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0102	 Train Acc:86.50 %  | 	Valid Loss:0.0108 	Valid Acc: 84.64 %
#
# Validation loss decreased (0.013086 --> 0.010830).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0099	 Train Acc:86.30 %  | 	Valid Loss:0.0106 	Valid Acc: 87.03 %
#
# Validation loss decreased (0.010830 --> 0.010594).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0089	 Train Acc:88.07 %  | 	Valid Loss:0.0135 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0095	 Train Acc:87.09 %  | 	Valid Loss:0.0108 	Valid Acc: 86.69 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0083	 Train Acc:88.73 %  | 	Valid Loss:0.0101 	Valid Acc: 87.03 %
#
# Validation loss decreased (0.010594 --> 0.010139).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0082	 Train Acc:87.75 %  | 	Valid Loss:0.0107 	Valid Acc: 87.71 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0083	 Train Acc:89.45 %  | 	Valid Loss:0.0111 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:13]	 Train Loss:0.0076	 Train Acc:90.69 %  | 	Valid Loss:0.0113 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:14]	 Train Loss:0.0077	 Train Acc:89.91 %  | 	Valid Loss:0.0115 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:15]	 Train Loss:0.0069	 Train Acc:91.28 %  | 	Valid Loss:0.0126 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 4-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_4-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0158	 Train Acc:76.02 %  | 	Valid Loss:0.0169 	Valid Acc: 72.01 %
#
# Validation loss decreased (inf --> 0.016894).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0120	 Train Acc:82.96 %  | 	Valid Loss:0.0119 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.016894 --> 0.011903).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0118	 Train Acc:84.53 %  | 	Valid Loss:0.0130 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0113	 Train Acc:84.60 %  | 	Valid Loss:0.0130 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0107	 Train Acc:84.73 %  | 	Valid Loss:0.0119 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 3 out of 5
# [EPOCH:6]	 Train Loss:0.0102	 Train Acc:86.83 %  | 	Valid Loss:0.0133 	Valid Acc: 79.52 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:7]	 Train Loss:0.0096	 Train Acc:87.75 %  | 	Valid Loss:0.0148 	Valid Acc: 78.84 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 5-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_5-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0159	 Train Acc:75.95 %  | 	Valid Loss:0.0182 	Valid Acc: 71.33 %
#
# Validation loss decreased (inf --> 0.018213).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0129	 Train Acc:81.26 %  | 	Valid Loss:0.0111 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.018213 --> 0.011054).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0122	 Train Acc:83.75 %  | 	Valid Loss:0.0131 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0112	 Train Acc:85.45 %  | 	Valid Loss:0.0106 	Valid Acc: 88.05 %
#
# Validation loss decreased (0.011054 --> 0.010606).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0106	 Train Acc:85.65 %  | 	Valid Loss:0.0135 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0101	 Train Acc:86.37 %  | 	Valid Loss:0.0188 	Valid Acc: 73.72 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0100	 Train Acc:86.44 %  | 	Valid Loss:0.0099 	Valid Acc: 86.35 %
#
# Validation loss decreased (0.010606 --> 0.009858).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0089	 Train Acc:88.99 %  | 	Valid Loss:0.0105 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0083	 Train Acc:88.66 %  | 	Valid Loss:0.0122 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0091	 Train Acc:87.35 %  | 	Valid Loss:0.0103 	Valid Acc: 88.74 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0084	 Train Acc:89.38 %  | 	Valid Loss:0.0131 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0078	 Train Acc:89.91 %  | 	Valid Loss:0.0105 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 6-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_6-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0158	 Train Acc:75.43 %  | 	Valid Loss:0.0159 	Valid Acc: 78.84 %
#
# Validation loss decreased (inf --> 0.015902).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0128	 Train Acc:83.03 %  | 	Valid Loss:0.0192 	Valid Acc: 69.97 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0117	 Train Acc:83.81 %  | 	Valid Loss:0.0137 	Valid Acc: 81.57 %
#
# Validation loss decreased (0.015902 --> 0.013733).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0109	 Train Acc:85.65 %  | 	Valid Loss:0.0124 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.013733 --> 0.012359).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0105	 Train Acc:86.37 %  | 	Valid Loss:0.0137 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0099	 Train Acc:86.70 %  | 	Valid Loss:0.0111 	Valid Acc: 85.67 %
#
# Validation loss decreased (0.012359 --> 0.011082).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0103	 Train Acc:86.57 %  | 	Valid Loss:0.0106 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.011082 --> 0.010580).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0096	 Train Acc:86.30 %  | 	Valid Loss:0.0153 	Valid Acc: 79.52 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0094	 Train Acc:86.63 %  | 	Valid Loss:0.0105 	Valid Acc: 87.37 %
#
# Validation loss decreased (0.010580 --> 0.010544).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0089	 Train Acc:88.86 %  | 	Valid Loss:0.0115 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0080	 Train Acc:89.58 %  | 	Valid Loss:0.0115 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0081	 Train Acc:89.12 %  | 	Valid Loss:0.0122 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0075	 Train Acc:90.63 %  | 	Valid Loss:0.0195 	Valid Acc: 78.84 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0082	 Train Acc:88.60 %  | 	Valid Loss:0.0130 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 7-번 레이어
# ../checkpoint/checkpoint_w2v_large_model60k_7-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0171	 Train Acc:73.20 %  | 	Valid Loss:0.0155 	Valid Acc: 78.16 %
#
# Validation loss decreased (inf --> 0.015474).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0138	 Train Acc:82.04 %  | 	Valid Loss:0.0141 	Valid Acc: 77.13 %
#
# Validation loss decreased (0.015474 --> 0.014091).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0124	 Train Acc:84.21 %  | 	Valid Loss:0.0135 	Valid Acc: 82.25 %
#
# Validation loss decreased (0.014091 --> 0.013495).  Saving model ...

# %%
for num,valid in enumerate(valid_accs):
    print("{}번 모델. train :{:.4f}/ valid: {:.4f}".format(num+1,train_accs[num],valid) )
# Out:
# 1번 모델. train :84.4037/ valid: 83.6177
# 2번 모델. train :86.8938/ valid: 87.0307
# 3번 모델. train :88.2700/ valid: 86.0068
# 4번 모델. train :80.3408/ valid: 82.5939
# 5번 모델. train :83.8794/ valid: 82.9352
# 6번 모델. train :91.5465/ valid: 87.0307
# 7번 모델. train :87.8768/ valid: 86.0068
# 8번 모델. train :83.1586/ valid: 83.9590
# 9번 모델. train :86.3041/ valid: 86.6894
# 10번 모델. train :84.5347/ valid: 87.0307
# 11번 모델. train :68.7418/ valid: 81.2287
# 12번 모델. train :88.9908/ valid: 88.3959
# 13번 모델. train :81.7169/ valid: 82.9352
# 14번 모델. train :87.2870/ valid: 84.3003
# 15번 모델. train :86.9594/ valid: 79.8635
# 16번 모델. train :87.8768/ valid: 80.8874

# %%
pd.DataFrame({'train':train_accs,'vaild':valid_accs},).to_csv("./result_transformer.csv")

# %%
pd.DataFrame({'train':train_accs,'vaild':valid_accs},).to_csv("./result_encoder.csv")

# %%
#encoder layer
test_grid()

# %%
# 24 레이어
test_grid()
# Out:
# 1번 모델
# Accuracy : 84.1530%
# Precision (pathology 예측한 것중 맞는 것) : 0.8884
# recall (실제 pathology 중  예측이 맞는 것) : 0.8661
# f score : 0.8270
# [[207  32]
#  [ 26 101]]
# -----
# 2번 모델
# Accuracy : 86.3388%
# Precision (pathology 예측한 것중 맞는 것) : 0.9021
# recall (실제 pathology 중  예측이 맞는 것) : 0.8870
# f score : 0.8504
# [[212  27]
#  [ 23 104]]
# -----
# 3번 모델
# Accuracy : 85.2459%
# Precision (pathology 예측한 것중 맞는 것) : 0.8936
# recall (실제 pathology 중  예측이 맞는 것) : 0.8787
# f score : 0.8384
# [[210  29]
#  [ 25 102]]
# -----
# 4번 모델
# Accuracy : 81.4208%
# Precision (pathology 예측한 것중 맞는 것) : 0.9014
# recall (실제 pathology 중  예측이 맞는 것) : 0.8033
# f score : 0.8034
# [[192  47]
#  [ 21 106]]
# -----
# 5번 모델
# Accuracy : 81.9672%
# Precision (pathology 예측한 것중 맞는 것) : 0.9220
# recall (실제 pathology 중  예측이 맞는 것) : 0.7908
# f score : 0.8111
# [[189  50]
#  [ 16 111]]
# -----
# 6번 모델
# Accuracy : 84.6995%
# Precision (pathology 예측한 것중 맞는 것) : 0.8927
# recall (실제 pathology 중  예측이 맞는 것) : 0.8703
# f score : 0.8330
# [[208  31]
#  [ 25 102]]
# -----
# 7번 모델
# Accuracy : 83.3333%
# Precision (pathology 예측한 것중 맞는 것) : 0.9083
# recall (실제 pathology 중  예측이 맞는 것) : 0.8285
# f score : 0.8224
# [[198  41]
#  [ 20 107]]
# -----
# 8번 모델
# Accuracy : 81.4208%
# Precision (pathology 예측한 것중 맞는 것) : 0.9171
# recall (실제 pathology 중  예측이 맞는 것) : 0.7866
# f score : 0.8054
# [[188  51]
#  [ 17 110]]
# -----
# 9번 모델
# Accuracy : 83.8798%
# Precision (pathology 예측한 것중 맞는 것) : 0.8814
# recall (실제 pathology 중  예측이 맞는 것) : 0.8703
# f score : 0.8231
# [[208  31]
#  [ 28  99]]
# -----
# 10번 모델
# Accuracy : 84.4262%
# Precision (pathology 예측한 것중 맞는 것) : 0.8669
# recall (실제 pathology 중  예측이 맞는 것) : 0.8996
# f score : 0.8252
# [[215  24]
#  [ 33  94]]
# -----
# 11번 모델
# Accuracy : 79.7814%
# Precision (pathology 예측한 것중 맞는 것) : 0.8603
# recall (실제 pathology 중  예측이 맞는 것) : 0.8243
# f score : 0.7808
# [[197  42]
#  [ 32  95]]
# -----
# 12번 모델
# Accuracy : 83.0601%
# Precision (pathology 예측한 것중 맞는 것) : 0.8933
# recall (실제 pathology 중  예측이 맞는 것) : 0.8410
# f score : 0.8175
# [[201  38]
#  [ 24 103]]
# -----
# 13번 모델
# Accuracy : 81.1475%
# Precision (pathology 예측한 것중 맞는 것) : 0.9126
# recall (실제 pathology 중  예측이 맞는 것) : 0.7866
# f score : 0.8023
# [[188  51]
#  [ 18 109]]
# -----
# 14번 모델
# Accuracy : 81.9672%
# Precision (pathology 예측한 것중 맞는 것) : 0.8986
# recall (실제 pathology 중  예측이 맞는 것) : 0.8159
# f score : 0.8081
# [[195  44]
#  [ 22 105]]
# -----
# 15번 모델
# Accuracy : 81.6940%
# Precision (pathology 예측한 것중 맞는 것) : 0.9388
# recall (실제 pathology 중  예측이 맞는 것) : 0.7699
# f score : 0.8102
# [[184  55]
#  [ 12 115]]
# -----
# 16번 모델
# Accuracy : 80.8743%
# Precision (pathology 예측한 것중 맞는 것) : 0.9204
# recall (실제 pathology 중  예측이 맞는 것) : 0.7741
# f score : 0.8006
# [[185  54]
#  [ 16 111]]
# -----
# 17번 모델
# Accuracy : 68.0328%
# Precision (pathology 예측한 것중 맞는 것) : 0.9420
# recall (실제 pathology 중  예측이 맞는 것) : 0.5439
# f score : 0.6800
# [[130 109]
#  [  8 119]]
# -----
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17524/641572437.py in <module>
# ----> 1 test_grid()
#
# ~\AppData\Local\Temp/ipykernel_17524/1780486567.py in test_grid()
#      19             model=model_initialize(grid_num)
#      20             check_path = '../checkpoint/checkpoint_w2v_large_960ft_'+str(grid_num)+'-'+str(data_ind)+'.pt'
# ---> 21             model.load_state_dict(torch.load(check_path))
#      22
#      23             predictions,answers = test_evaluate(model, test_loader)
#
# ~\anaconda3\envs\local_torch\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592         pickle_load_args['encoding'] = 'utf-8'
#     593
# --> 594     with _open_file_like(f, 'rb') as opened_file:
#     595         if _is_zipfile(opened_file):
#     596             # The zipfile reader is going to advance the current file position.
#
# ~\anaconda3\envs\local_torch\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# ~\anaconda3\envs\local_torch\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../checkpoint/checkpoint_w2v_large_960ft_17-1.pt'

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_w2v_'+str(data_ind)+'.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
