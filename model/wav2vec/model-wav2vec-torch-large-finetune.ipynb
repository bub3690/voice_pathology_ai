# %% [markdown]
# # lv60k Fine-tuning
#
# classifier를 변경하고 모델 전체를 fine-tuning한다.

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys
import math



p = os.path.abspath('../') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %% [markdown]
# # data 분류

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('../../voice_data/fusion/pathology/phrase/*.wav')
healthy = glob('../../voice_data/fusion/healthy/phrase/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))


pathology= [ path.split("\\")[-1] for path in pathology] # path 데이터 변환.
healthy= [ path.split("\\")[-1] for path in healthy] # path 데이터 변환.
 # path 데이터 변환


X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1193:
        Y.append("pathology")
    else:
        Y.append("healthy")

X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1193
# Healthy:  634
# 총 데이터수 :  1827
# ---
# 훈련 셋 :  1461 Counter({'pathology': 954, 'healthy': 507})
# 테스트 셋 :  366 Counter({'pathology': 239, 'healthy': 127})
# ---

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 190}

# %%
#2. random over sampling
for i in range(5):
    X_temp = np.array(X_train_list[i]).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
    #Y = np.array(Y)
    ros = RandomOverSampler(random_state = 123)
    X_res,Y_res = ros.fit_resample(X_temp,Y_train_list[i])
    
    print("\n fold{} ".format(i))
    print('before dataset shape {}'.format(Counter(Y_train_list[i])) )
    print('Resampled dataset shape {}'.format(Counter(Y_res)) )
    
    #원래대로 돌리기
    X_res=X_res.reshape(1, -1)
    X_train_list[i]=X_res[0].tolist()
    Y_train_list[i]=Y_res
# Out:
#  fold0
# before dataset shape Counter({'pathology': 763, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold1
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold2
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold3
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold4
# before dataset shape Counter({'pathology': 764, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 764, 'healthy': 764})

# %%
import pickle

 
#load
with open("../../voice_data/fusion/phrase_sig_dict.pickle","rb") as fr:
    phrase_dict = pickle.load(fr)

# %% [markdown]
# # data set

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        sig_length = sig.size #sig length 리턴에 사용. feature 추출및 학습에 사용.
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        
        
        
        return sig, self.classes.index(self.label[idx]),sig_length

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes

        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        sig_length = sig.size #sig length 리턴에 사용. feature 추출및 학습에 사용.
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        return sig, self.classes.index(self.label[idx]),sig_length

# %% [markdown]
# # data loader

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  12 #한 배치당 32개 음성데이터
EPOCHS = 50 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인



train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                                   classes,
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # model
#
# https://pytorch.org/audio/main/tutorials/speech_recognition_pipeline_tutorial.html

# %% [markdown]
# dat1=torch.randn((32,12,318,768))
# model1=nn.Conv2d(12,3,(3,3))
# dat2=model1(dat1)
# print(dat2.size())
# #torch.Size([32, 3, 316, 766])
# res_18_sample = models.resnet18(pretrained=True)
# dat3=res_18_sample(dat2)
# print(dat3.size())

# %%
#https://pytorch.org/audio/0.9.0/models.html#baevski2020wav2vec
from torchaudio.models.wav2vec2.utils import import_huggingface_model
from transformers import Wav2Vec2ForCTC

# %%
#7. Optimizer, Objective Function
class classifier_model(nn.Module):
    def __init__(self,):
        super(classifier_model,self).__init__()
        
        self.model_wav2vec2 = torchaudio.models.wav2vec2_large_lv60k(aux_num_out=32)
        self.model_wav2vec2.load_state_dict(torch.load("../checkpoint/wav2vec2-large-lv60.pt"))
        self.model_wav2vec2.aux = nn.Sequential(nn.Linear(1024,2,bias=True),)
        
        self.padded_frame=318
        
        self.fc = nn.Linear(self.padded_frame*2,2)
        
        
    def forward(self,x,sig_size):
        x,seq_len = self.model_wav2vec2(x,sig_size)
        zero_padding_array=np.ones((len(seq_len),self.padded_frame,2))
        for i in range(len(seq_len)):
            zero_padding_array[i:,seq_len[i]:,:]=0
        x=x*torch.from_numpy(zero_padding_array).float().to(DEVICE) # 318 * 2
        x=x.view(-1,self.padded_frame*2)
        x=self.fc(x)
        
        return x 


def model_initialize():
    model = classifier_model()
    #원핫 인코딩값의 loss는 crossEntropyLoss로 비교
    #print(model)
    return model.to(DEVICE)

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label,sig_size) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        sig_size = sig_size.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image,sig_size) # model로 output을 계산 #WAV2VEC2 학습시 SIG_SIZE 필요,
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
        del output
        del image
        torch.cuda.empty_cache()

    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label,sig_size in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            sig_size = sig_size.to(DEVICE)
            
            output = model(image,sig_size) #WAV2VEC2 학습시 SIG_SIZE 필요,
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
            del output
            del image
            torch.cuda.empty_cache()
            
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_w2v_large_finetune_'+str(data_ind)+'.pt'
    print(check_path)
    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break

        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# ../checkpoint/checkpoint_w2v_large_finetune_1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0576	 Train Acc:54.52 %  | 	Valid Loss:0.0572 	Valid Acc: 53.24 %
#
# Validation loss decreased (inf --> 0.057199).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0547	 Train Acc:61.14 %  | 	Valid Loss:0.0549 	Valid Acc: 65.87 %
#
# Validation loss decreased (0.057199 --> 0.054877).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0565	 Train Acc:55.37 %  | 	Valid Loss:0.0549 	Valid Acc: 64.85 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0574	 Train Acc:54.13 %  | 	Valid Loss:0.0581 	Valid Acc: 47.44 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0568	 Train Acc:55.83 %  | 	Valid Loss:0.0584 	Valid Acc: 62.46 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:6]	 Train Loss:0.0509	 Train Acc:68.09 %  | 	Valid Loss:0.0517 	Valid Acc: 73.72 %
#
# Validation loss decreased (0.054877 --> 0.051749).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0533	 Train Acc:61.53 %  | 	Valid Loss:0.0570 	Valid Acc: 51.19 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0516	 Train Acc:65.86 %  | 	Valid Loss:0.0554 	Valid Acc: 73.38 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0565	 Train Acc:56.42 %  | 	Valid Loss:0.0483 	Valid Acc: 71.67 %
#
# Validation loss decreased (0.051749 --> 0.048269).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0527	 Train Acc:63.83 %  | 	Valid Loss:0.0521 	Valid Acc: 76.11 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0489	 Train Acc:70.25 %  | 	Valid Loss:0.0464 	Valid Acc: 74.40 %
#
# Validation loss decreased (0.048269 --> 0.046397).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0463	 Train Acc:73.53 %  | 	Valid Loss:0.0490 	Valid Acc: 72.35 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0452	 Train Acc:74.77 %  | 	Valid Loss:0.0483 	Valid Acc: 70.65 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0451	 Train Acc:74.38 %  | 	Valid Loss:0.0410 	Valid Acc: 76.11 %
#
# Validation loss decreased (0.046397 --> 0.040994).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0441	 Train Acc:75.62 %  | 	Valid Loss:0.0444 	Valid Acc: 74.74 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0425	 Train Acc:76.02 %  | 	Valid Loss:0.0456 	Valid Acc: 75.09 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:17]	 Train Loss:0.0416	 Train Acc:77.72 %  | 	Valid Loss:0.0418 	Valid Acc: 77.47 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:18]	 Train Loss:0.0419	 Train Acc:76.67 %  | 	Valid Loss:0.0407 	Valid Acc: 75.43 %
#
# Validation loss decreased (0.040994 --> 0.040714).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0400	 Train Acc:79.36 %  | 	Valid Loss:0.0464 	Valid Acc: 73.72 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0382	 Train Acc:79.49 %  | 	Valid Loss:0.0452 	Valid Acc: 74.74 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0346	 Train Acc:82.04 %  | 	Valid Loss:0.0375 	Valid Acc: 79.52 %
#
# Validation loss decreased (0.040714 --> 0.037494).  Saving model ...
#
# [EPOCH:22]	 Train Loss:0.0383	 Train Acc:79.16 %  | 	Valid Loss:0.0398 	Valid Acc: 77.47 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:23]	 Train Loss:0.0321	 Train Acc:84.60 %  | 	Valid Loss:0.0461 	Valid Acc: 74.74 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:24]	 Train Loss:0.0258	 Train Acc:88.60 %  | 	Valid Loss:0.0474 	Valid Acc: 72.35 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:25]	 Train Loss:0.0206	 Train Acc:90.56 %  | 	Valid Loss:0.0597 	Valid Acc: 72.70 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:26]	 Train Loss:0.0143	 Train Acc:93.77 %  | 	Valid Loss:0.0646 	Valid Acc: 70.65 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_large_finetune_2.pt
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0579	 Train Acc:52.36 %  | 	Valid Loss:0.0588 	Valid Acc: 47.60 %
#
# Validation loss decreased (inf --> 0.058841).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0563	 Train Acc:58.39 %  | 	Valid Loss:0.0652 	Valid Acc: 36.99 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0575	 Train Acc:53.28 %  | 	Valid Loss:0.0566 	Valid Acc: 63.01 %
#
# Validation loss decreased (0.058841 --> 0.056650).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0577	 Train Acc:52.56 %  | 	Valid Loss:0.0549 	Valid Acc: 68.49 %
#
# Validation loss decreased (0.056650 --> 0.054874).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0577	 Train Acc:52.95 %  | 	Valid Loss:0.0579 	Valid Acc: 53.77 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0519	 Train Acc:67.17 %  | 	Valid Loss:0.0565 	Valid Acc: 50.00 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0504	 Train Acc:69.53 %  | 	Valid Loss:0.0446 	Valid Acc: 77.74 %
#
# Validation loss decreased (0.054874 --> 0.044569).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0510	 Train Acc:66.06 %  | 	Valid Loss:0.0579 	Valid Acc: 49.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0546	 Train Acc:61.93 %  | 	Valid Loss:0.0509 	Valid Acc: 73.63 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0549	 Train Acc:63.17 %  | 	Valid Loss:0.0596 	Valid Acc: 65.75 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0544	 Train Acc:64.35 %  | 	Valid Loss:0.0560 	Valid Acc: 56.51 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0550	 Train Acc:61.93 %  | 	Valid Loss:0.0519 	Valid Acc: 69.52 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_large_finetune_3.pt
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0584	 Train Acc:50.66 %  | 	Valid Loss:0.0598 	Valid Acc: 34.59 %
#
# Validation loss decreased (inf --> 0.059842).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0581	 Train Acc:55.83 %  | 	Valid Loss:0.0552 	Valid Acc: 65.41 %
#
# Validation loss decreased (0.059842 --> 0.055201).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0579	 Train Acc:53.21 %  | 	Valid Loss:0.0586 	Valid Acc: 46.58 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0576	 Train Acc:53.93 %  | 	Valid Loss:0.0588 	Valid Acc: 48.29 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0575	 Train Acc:53.08 %  | 	Valid Loss:0.0604 	Valid Acc: 48.29 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:6]	 Train Loss:0.0579	 Train Acc:53.80 %  | 	Valid Loss:0.0562 	Valid Acc: 65.41 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:7]	 Train Loss:0.0569	 Train Acc:54.85 %  | 	Valid Loss:0.0557 	Valid Acc: 59.25 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_large_finetune_4.pt
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0568	 Train Acc:55.96 %  | 	Valid Loss:0.0603 	Valid Acc: 44.18 %
#
# Validation loss decreased (inf --> 0.060319).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0560	 Train Acc:58.45 %  | 	Valid Loss:0.0569 	Valid Acc: 57.19 %
#
# Validation loss decreased (0.060319 --> 0.056870).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0563	 Train Acc:57.80 %  | 	Valid Loss:0.0585 	Valid Acc: 56.16 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0505	 Train Acc:71.49 %  | 	Valid Loss:0.0536 	Valid Acc: 71.92 %
#
# Validation loss decreased (0.056870 --> 0.053552).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0538	 Train Acc:62.71 %  | 	Valid Loss:0.0579 	Valid Acc: 65.41 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0573	 Train Acc:52.36 %  | 	Valid Loss:0.0585 	Valid Acc: 44.18 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0573	 Train Acc:53.60 %  | 	Valid Loss:0.0576 	Valid Acc: 48.97 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:8]	 Train Loss:0.0575	 Train Acc:54.00 %  | 	Valid Loss:0.0608 	Valid Acc: 51.37 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:9]	 Train Loss:0.0563	 Train Acc:58.45 %  | 	Valid Loss:0.0614 	Valid Acc: 45.89 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# ../checkpoint/checkpoint_w2v_large_finetune_5.pt
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0576	 Train Acc:52.95 %  | 	Valid Loss:0.0587 	Valid Acc: 47.26 %
#
# Validation loss decreased (inf --> 0.058670).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0571	 Train Acc:55.24 %  | 	Valid Loss:0.0624 	Valid Acc: 55.82 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0572	 Train Acc:57.46 %  | 	Valid Loss:0.0565 	Valid Acc: 53.77 %
#
# Validation loss decreased (0.058670 --> 0.056506).  Saving model ...
# [EPOCH:4]	 Train Loss:0.0569	 Train Acc:57.40 %  | 	Valid Loss:0.0588 	Valid Acc: 48.29 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0571	 Train Acc:52.88 %  | 	Valid Loss:0.0582 	Valid Acc: 50.68 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0569	 Train Acc:54.45 %  | 	Valid Loss:0.0582 	Valid Acc: 44.86 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0574	 Train Acc:53.01 %  | 	Valid Loss:0.0567 	Valid Acc: 54.11 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:8]	 Train Loss:0.0574	 Train Acc:53.53 %  | 	Valid Loss:0.0556 	Valid Acc: 66.78 %
#
# Validation loss decreased (0.056506 --> 0.055599).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0562	 Train Acc:59.16 %  | 	Valid Loss:0.0465 	Valid Acc: 73.29 %
#
# Validation loss decreased (0.055599 --> 0.046470).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0552	 Train Acc:61.32 %  | 	Valid Loss:0.0499 	Valid Acc: 68.84 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0524	 Train Acc:65.58 %  | 	Valid Loss:0.0510 	Valid Acc: 71.23 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0487	 Train Acc:71.66 %  | 	Valid Loss:0.0522 	Valid Acc: 66.78 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0459	 Train Acc:72.77 %  | 	Valid Loss:0.0464 	Valid Acc: 71.58 %
#
# Validation loss decreased (0.046470 --> 0.046430).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0458	 Train Acc:72.71 %  | 	Valid Loss:0.0473 	Valid Acc: 75.00 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0422	 Train Acc:76.77 %  | 	Valid Loss:0.0528 	Valid Acc: 69.18 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:16]	 Train Loss:0.0418	 Train Acc:77.23 %  | 	Valid Loss:0.0439 	Valid Acc: 73.97 %
#
# Validation loss decreased (0.046430 --> 0.043949).  Saving model ...
#
# [EPOCH:17]	 Train Loss:0.0398	 Train Acc:78.99 %  | 	Valid Loss:0.0441 	Valid Acc: 75.68 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:18]	 Train Loss:0.0409	 Train Acc:78.14 %  | 	Valid Loss:0.0503 	Valid Acc: 70.21 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:19]	 Train Loss:0.0377	 Train Acc:80.30 %  | 	Valid Loss:0.0443 	Valid Acc: 72.95 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:20]	 Train Loss:0.0341	 Train Acc:82.26 %  | 	Valid Loss:0.0460 	Valid Acc: 72.26 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:21]	 Train Loss:0.0306	 Train Acc:85.01 %  | 	Valid Loss:0.0464 	Valid Acc: 71.58 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 82.0446 |	 valid ACC: 79.5222
# [2 교차검증] train ACC : 69.5282 |	 valid ACC: 77.7397
# [3 교차검증] train ACC : 55.8322 |	 valid ACC: 65.4110
# [4 교차검증] train ACC : 71.4941 |	 valid ACC: 71.9178
# [5 교차검증] train ACC : 77.2251 |	 valid ACC: 73.9726
# 평균 검증 정확도 73.71265603815046 %

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def test_evaluate(model,test_loader):
    model.eval()
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label,sig_len in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            sig_len = sig_len.to(DEVICE)
            output = model(image,sig_len)
            output = F.softmax(output, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
        return predictions,answers

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_w2v_large_finetune_'+str(data_ind)+'.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
# Out:
# 1번 모델
# Accuracy : 78.1421%
# Precision (pathology 예측한 것중 맞는 것) : 0.8193
# recall (실제 pathology 중  예측이 맞는 것) : 0.8536
# f score : 0.7541
# [[204  35]
#  [ 45  82]]
# -----
# 2번 모델
# Accuracy : 78.1421%
# Precision (pathology 예측한 것중 맞는 것) : 0.8354
# recall (실제 pathology 중  예측이 맞는 것) : 0.8285
# f score : 0.7597
# [[198  41]
#  [ 39  88]]
# -----
# 3번 모델
# Accuracy : 65.3005%
# Precision (pathology 예측한 것중 맞는 것) : 0.6530
# recall (실제 pathology 중  예측이 맞는 것) : 1.0000
# f score : 0.3950
# [[239   0]
#  [127   0]]
# -----
# 4번 모델
# Accuracy : 75.1366%
# Precision (pathology 예측한 것중 맞는 것) : 0.7681
# recall (실제 pathology 중  예측이 맞는 것) : 0.8870
# f score : 0.7020
# [[212  27]
#  [ 64  63]]
# -----
# 5번 모델
# Accuracy : 79.2350%
# Precision (pathology 예측한 것중 맞는 것) : 0.8196
# recall (실제 pathology 중  예측이 맞는 것) : 0.8745
# f score : 0.7634
# [[209  30]
#  [ 46  81]]
# -----
# 평균 acc : 0.7519
# 평균 f1score : 0.6748
