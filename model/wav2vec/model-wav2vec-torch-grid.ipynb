# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys
import math



p = os.path.abspath('../') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %% [markdown]
# # data 분류

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('../../voice_data/fusion/pathology/phrase/*.wav')
healthy = glob('../../voice_data/fusion/healthy/phrase/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))


pathology= [ path.split("\\")[-1] for path in pathology] # path 데이터 변환.
healthy= [ path.split("\\")[-1] for path in healthy] # path 데이터 변환.
 # path 데이터 변환


X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1193:
        Y.append("pathology")
    else:
        Y.append("healthy")

X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1193
# Healthy:  634
# 총 데이터수 :  1827
# ---
# 훈련 셋 :  1461 Counter({'pathology': 954, 'healthy': 507})
# 테스트 셋 :  366 Counter({'pathology': 239, 'healthy': 127})
# ---

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 190}

# %%
#2. random over sampling
for i in range(5):
    X_temp = np.array(X_train_list[i]).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
    #Y = np.array(Y)
    ros = RandomOverSampler(random_state = 123)
    X_res,Y_res = ros.fit_resample(X_temp,Y_train_list[i])
    
    print("\n fold{} ".format(i))
    print('before dataset shape {}'.format(Counter(Y_train_list[i])) )
    print('Resampled dataset shape {}'.format(Counter(Y_res)) )
    
    #원래대로 돌리기
    X_res=X_res.reshape(1, -1)
    X_train_list[i]=X_res[0].tolist()
    Y_train_list[i]=Y_res
# Out:
#  fold0
# before dataset shape Counter({'pathology': 763, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold1
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold2
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold3
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold4
# before dataset shape Counter({'pathology': 764, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 764, 'healthy': 764})

# %%
import pickle

 
#load
with open("../../voice_data/fusion/phrase_sig_dict.pickle","rb") as fr:
    phrase_dict = pickle.load(fr)

# %% [markdown]
# # data set

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        return sig, self.classes.index(self.label[idx])

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes

        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, signal 변환
        2. raw 데이터 바로 출력.
        
        """

        sig = phrase_dict[self.path_list[idx]]
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))
        length = 101951
        sig=pad1d(sig,length)
        sig=torch.from_numpy(sig).type(torch.float32)# 타입 변화
        
        return sig, self.classes.index(self.label[idx])

# %% [markdown]
# # data loader

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 50 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인



train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                                   classes,
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # model
#
# https://pytorch.org/audio/main/tutorials/speech_recognition_pipeline_tutorial.html

# %% [markdown]
# dat1=torch.randn((32,12,318,768))
# model1=nn.Conv2d(12,3,(3,3))
# dat2=model1(dat1)
# print(dat2.size())
# #torch.Size([32, 3, 316, 766])
# res_18_sample = models.resnet18(pretrained=True)
# dat3=res_18_sample(dat2)
# print(dat3.size())

# %%
for x_train,_ in train_loader:
    break

bundle = torchaudio.pipelines.WAV2VEC2_LARGE_LV60K
model_wav2vec = bundle.get_model().to(DEVICE)
with torch.inference_mode():
    x,_ = model_wav2vec.extract_features(x_train.cuda())
    
x[0].size()
# Out:
# torch.Size([32, 318, 1024])

# %%
len(x)
# Out:
# 24

# %%
x[3].mean(axis=1).size()
# Out:
# torch.Size([32, 1024])

# %% [markdown]
# ----

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.


        
class wav_path_Net(nn.Module):
    def __init__(self,):
        super(wav_path_Net,self).__init__()
        
        bundle = torchaudio.pipelines.WAV2VEC2_BASE
        self.model_wav2vec = bundle.get_model().to(DEVICE)
        
        
        input_dim =101951
        
        self.fc = nn.Sequential(nn.Linear(24*1024,1024),
                                nn.BatchNorm1d(1024),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(1024,256),
                                nn.BatchNorm1d(256),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(256,2),)
        
        
    def merge(self,hidden_feature):
        hidden_feature=[ feat.mean(axis=1) for feat  in  hidden_feature]
        return hidden_feature
        
        
    def forward(self,x):
        with torch.inference_mode():
            x,_ = self.model_wav2vec.extract_features(x)
        x = self.merge(x)
        x = torch.stack(x,dim=1)
        x = x.view(-1,24*1024)
        x= self.fc(x)
    
        return x

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



        
class wav_path_Net(nn.Module):
    def __init__(self,num):
        super(wav_path_Net,self).__init__()
        
        bundle = torchaudio.pipelines.WAV2VEC2_LARGE_LV60K
        self.model_wav2vec = bundle.get_model().to(DEVICE)
        self.num = num
        
        #input_dim =101951
        
        self.fc = nn.Sequential(
                                nn.Linear(1024,256),
                                nn.BatchNorm1d(256),
                                nn.ReLU(),
                                nn.Dropout(p=0.7),
                                nn.Linear(256,2),)
        
        
    def merge(self,hidden_feature):
        hidden_feature=hidden_feature.mean(axis=1)
        return hidden_feature
        
        
    def forward(self,x):
        with torch.inference_mode():
            x,_ = self.model_wav2vec.extract_features(x)
        x = x[self.num]
        x = self.merge(x)
        #x = torch.stack(x,dim=1)
        #x = x.view(-1,1024)
        x= self.fc(x)
    
        return x

# %%
###
sr=16000
win_length =  np.int64(sr/40) #
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.


bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model_wav2vec = bundle.get_model().to(DEVICE)

print(model_wav2vec.__class__)

        
class wav_path_Net(nn.Module):
    def __init__(self,):
        super(wav_path_Net,self).__init__()
        
        bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
        self.model_wav2vec = bundle.get_model().to(DEVICE)
        self.res_18 = models.resnet18(pretrained=True)
        self.conv_model1=nn.Conv2d(12,3,(3,3))
        
        #input_dim =101951
        
        self.fc = nn.Sequential(nn.Linear(1000,512),
                                nn.BatchNorm1d(512),
                                nn.ReLU(),
                                nn.Linear(512,256),
                                nn.BatchNorm1d(256),
                                nn.ReLU(),
                                nn.Linear(256,50),
                                nn.Linear(50,2),)
        
        
    def merge(self,hidden_feature):
        hidden_feature=[ feat.mean(axis=1) for feat  in  hidden_feature]
        return hidden_feature
        
        
    def forward(self,x):
        with torch.inference_mode():
            x,_ = self.model_wav2vec.extract_features(x)
        x = torch.stack(x,axis=1)
        x = self.conv_model1(x)
        x = self.res_18(x)
        x= self.fc(x)
    
        return x

# %%
#7. Optimizer, Objective Function
def model_initialize(num):
    model = wav_path_Net(num).to(DEVICE)
    #원핫 인코딩값의 loss는 crossEntropyLoss로 비교
    #print(model)
    return model

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def test_evaluate(model,test_loader):
    model.eval()
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            output = F.softmax(output, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
        return predictions,answers

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score



def test_grid():
    cf = np.zeros((2,2))
    cf_list = []
    average_accuracy = 0
    average_fscore = 0
    
    
    for grid_num in range(0,24):
        for data_ind in range(1,2):
            model=model_initialize(grid_num)
            check_path = '../checkpoint/checkpoint_w2v_large_'+str(grid_num)+'-'+str(data_ind)+'.pt'
            model.load_state_dict(torch.load(check_path))

            predictions,answers = test_evaluate(model, test_loader)
            predictions=[ dat.cpu().numpy() for dat in predictions]
            answers=[ dat.cpu().numpy() for dat in answers]


            cf = confusion_matrix(answers, predictions)
            cf_list.append(cf)

            acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
            average_accuracy+=acc
            precision=cf[0,0]/(cf[0,0]+cf[1,0])
            recall=cf[0,0]/(cf[0,0]+cf[0,1])
            #fscore=2*precision*recall/(precision+recall)

            #fscroe macro추가
            fscore = f1_score(answers,predictions,average='macro')
            average_fscore+=fscore

            print('{}번 모델'.format(grid_num+1))
            print("Accuracy : {:.4f}% ".format(acc*100))
            print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
            print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
            print("f score : {:.4f} ".format(fscore))
            print(cf)
            print("-----")

# %%
#10. 학습 및 평가.
# kfold 적용
train_accs = []
valid_accs = []
for num in range(24):
    print("{}-번 레이어".format(num))


    for data_ind in range(1,2):

        check_path = '../checkpoint/checkpoint_w2v_large_'+str(num)+'-'+str(data_ind)+'.pt'
        print(check_path)
        early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
        train_loader,validation_loader = load_data(data_ind-1)

        best_train_acc=0 # accuracy 기록용
        best_valid_acc=0

        model=model_initialize(num)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)


        print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
        for Epoch in range(1,EPOCHS+1):
            train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
            valid_loss,valid_accuracy = evaluate(model, validation_loader)


            print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
                  format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
            

            early_stopping(valid_loss, model)
            if -early_stopping.best_score == valid_loss:
                best_train_acc, best_valid_acc = train_accuracy,valid_accuracy

            if early_stopping.early_stop:
                    train_accs.append(best_train_acc)
                    valid_accs.append(best_valid_acc)
                    print("[{} 교차검증] Early stopping".format(data_ind))
                    break

            if Epoch==EPOCHS:
                #만약 early stop 없이 40 epoch라서 중지 된 경우.
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
# Out:
# 0-번 레이어
# ../checkpoint/checkpoint_w2v_large_0-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0178	 Train Acc:72.21 %  | 	Valid Loss:0.0151 	Valid Acc: 74.74 %
#
# Validation loss decreased (inf --> 0.015072).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0146	 Train Acc:77.39 %  | 	Valid Loss:0.0147 	Valid Acc: 81.57 %
#
# Validation loss decreased (0.015072 --> 0.014695).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0130	 Train Acc:82.04 %  | 	Valid Loss:0.0120 	Valid Acc: 81.91 %
#
# Validation loss decreased (0.014695 --> 0.012045).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0127	 Train Acc:81.98 %  | 	Valid Loss:0.0127 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0118	 Train Acc:83.62 %  | 	Valid Loss:0.0126 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0113	 Train Acc:82.63 %  | 	Valid Loss:0.0150 	Valid Acc: 79.52 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0110	 Train Acc:84.99 %  | 	Valid Loss:0.0124 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:8]	 Train Loss:0.0107	 Train Acc:84.80 %  | 	Valid Loss:0.0123 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 1-번 레이어
# ../checkpoint/checkpoint_w2v_large_1-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0183	 Train Acc:69.40 %  | 	Valid Loss:0.0180 	Valid Acc: 76.79 %
#
# Validation loss decreased (inf --> 0.018013).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0143	 Train Acc:79.10 %  | 	Valid Loss:0.0146 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.018013 --> 0.014598).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0129	 Train Acc:81.06 %  | 	Valid Loss:0.0136 	Valid Acc: 81.91 %
#
# Validation loss decreased (0.014598 --> 0.013554).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0120	 Train Acc:82.77 %  | 	Valid Loss:0.0129 	Valid Acc: 82.25 %
#
# Validation loss decreased (0.013554 --> 0.012881).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0118	 Train Acc:82.70 %  | 	Valid Loss:0.0118 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.012881 --> 0.011767).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0111	 Train Acc:83.94 %  | 	Valid Loss:0.0134 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0107	 Train Acc:84.93 %  | 	Valid Loss:0.0118 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0100	 Train Acc:86.37 %  | 	Valid Loss:0.0127 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0101	 Train Acc:86.44 %  | 	Valid Loss:0.0129 	Valid Acc: 82.25 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:10]	 Train Loss:0.0096	 Train Acc:86.89 %  | 	Valid Loss:0.0134 	Valid Acc: 87.71 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 2-번 레이어
# ../checkpoint/checkpoint_w2v_large_2-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0179	 Train Acc:70.77 %  | 	Valid Loss:0.0167 	Valid Acc: 77.47 %
#
# Validation loss decreased (inf --> 0.016747).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0140	 Train Acc:79.55 %  | 	Valid Loss:0.0161 	Valid Acc: 77.82 %
#
# Validation loss decreased (0.016747 --> 0.016116).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0131	 Train Acc:81.39 %  | 	Valid Loss:0.0146 	Valid Acc: 81.57 %
#
# Validation loss decreased (0.016116 --> 0.014563).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0119	 Train Acc:82.50 %  | 	Valid Loss:0.0131 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.014563 --> 0.013111).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0116	 Train Acc:83.94 %  | 	Valid Loss:0.0133 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0108	 Train Acc:85.91 %  | 	Valid Loss:0.0117 	Valid Acc: 87.03 %
#
# Validation loss decreased (0.013111 --> 0.011738).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0104	 Train Acc:85.39 %  | 	Valid Loss:0.0113 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.011738 --> 0.011304).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0099	 Train Acc:86.76 %  | 	Valid Loss:0.0106 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.011304 --> 0.010612).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0095	 Train Acc:87.35 %  | 	Valid Loss:0.0118 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0087	 Train Acc:89.12 %  | 	Valid Loss:0.0109 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0085	 Train Acc:89.38 %  | 	Valid Loss:0.0108 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:12]	 Train Loss:0.0085	 Train Acc:88.93 %  | 	Valid Loss:0.0100 	Valid Acc: 87.37 %
#
# Validation loss decreased (0.010612 --> 0.010006).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0077	 Train Acc:90.83 %  | 	Valid Loss:0.0102 	Valid Acc: 86.69 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0078	 Train Acc:90.89 %  | 	Valid Loss:0.0108 	Valid Acc: 88.40 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:15]	 Train Loss:0.0074	 Train Acc:90.69 %  | 	Valid Loss:0.0101 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:16]	 Train Loss:0.0074	 Train Acc:91.61 %  | 	Valid Loss:0.0103 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:17]	 Train Loss:0.0068	 Train Acc:91.87 %  | 	Valid Loss:0.0114 	Valid Acc: 86.69 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 3-번 레이어
# ../checkpoint/checkpoint_w2v_large_3-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0183	 Train Acc:70.64 %  | 	Valid Loss:0.0180 	Valid Acc: 74.74 %
#
# Validation loss decreased (inf --> 0.018021).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0150	 Train Acc:78.37 %  | 	Valid Loss:0.0173 	Valid Acc: 79.52 %
#
# Validation loss decreased (0.018021 --> 0.017304).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0131	 Train Acc:80.73 %  | 	Valid Loss:0.0129 	Valid Acc: 81.91 %
#
# Validation loss decreased (0.017304 --> 0.012868).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0126	 Train Acc:82.18 %  | 	Valid Loss:0.0143 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0111	 Train Acc:84.99 %  | 	Valid Loss:0.0113 	Valid Acc: 85.67 %
#
# Validation loss decreased (0.012868 --> 0.011252).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0112	 Train Acc:84.99 %  | 	Valid Loss:0.0119 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0106	 Train Acc:86.57 %  | 	Valid Loss:0.0114 	Valid Acc: 86.35 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0100	 Train Acc:86.37 %  | 	Valid Loss:0.0136 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0091	 Train Acc:88.73 %  | 	Valid Loss:0.0107 	Valid Acc: 85.67 %
#
# Validation loss decreased (0.011252 --> 0.010749).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0090	 Train Acc:88.01 %  | 	Valid Loss:0.0108 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0090	 Train Acc:88.73 %  | 	Valid Loss:0.0101 	Valid Acc: 87.37 %
#
# Validation loss decreased (0.010749 --> 0.010141).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0084	 Train Acc:88.60 %  | 	Valid Loss:0.0110 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0081	 Train Acc:89.45 %  | 	Valid Loss:0.0121 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0077	 Train Acc:90.37 %  | 	Valid Loss:0.0109 	Valid Acc: 86.35 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0078	 Train Acc:89.84 %  | 	Valid Loss:0.0099 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.010141 --> 0.009896).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0074	 Train Acc:91.02 %  | 	Valid Loss:0.0111 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0065	 Train Acc:92.46 %  | 	Valid Loss:0.0110 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0070	 Train Acc:91.61 %  | 	Valid Loss:0.0102 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:19]	 Train Loss:0.0065	 Train Acc:92.40 %  | 	Valid Loss:0.0105 	Valid Acc: 86.01 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:20]	 Train Loss:0.0063	 Train Acc:92.99 %  | 	Valid Loss:0.0100 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 4-번 레이어
# ../checkpoint/checkpoint_w2v_large_4-1.pt
# [1 교차검증] 학습 시작
#  -----
# [EPOCH:1]	 Train Loss:0.0186	 Train Acc:69.07 %  | 	Valid Loss:0.0165 	Valid Acc: 77.82 %
#
# Validation loss decreased (inf --> 0.016542).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0149	 Train Acc:78.96 %  | 	Valid Loss:0.0150 	Valid Acc: 80.55 %
#
# Validation loss decreased (0.016542 --> 0.014955).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0129	 Train Acc:81.65 %  | 	Valid Loss:0.0127 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.014955 --> 0.012727).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0121	 Train Acc:82.18 %  | 	Valid Loss:0.0151 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0116	 Train Acc:83.09 %  | 	Valid Loss:0.0128 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0107	 Train Acc:85.19 %  | 	Valid Loss:0.0171 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0106	 Train Acc:85.32 %  | 	Valid Loss:0.0106 	Valid Acc: 86.01 %
#
# Validation loss decreased (0.012727 --> 0.010633).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0101	 Train Acc:86.50 %  | 	Valid Loss:0.0122 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0092	 Train Acc:88.27 %  | 	Valid Loss:0.0121 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0087	 Train Acc:89.06 %  | 	Valid Loss:0.0105 	Valid Acc: 86.01 %
#
# Validation loss decreased (0.010633 --> 0.010452).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0087	 Train Acc:89.38 %  | 	Valid Loss:0.0108 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0082	 Train Acc:89.32 %  | 	Valid Loss:0.0112 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:13]	 Train Loss:0.0079	 Train Acc:91.15 %  | 	Valid Loss:0.0116 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:14]	 Train Loss:0.0074	 Train Acc:90.96 %  | 	Valid Loss:0.0111 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:15]	 Train Loss:0.0073	 Train Acc:91.15 %  | 	Valid Loss:0.0103 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.010452 --> 0.010295).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0070	 Train Acc:91.61 %  | 	Valid Loss:0.0112 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0064	 Train Acc:92.66 %  | 	Valid Loss:0.0110 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0064	 Train Acc:92.92 %  | 	Valid Loss:0.0103 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:19]	 Train Loss:0.0066	 Train Acc:92.14 %  | 	Valid Loss:0.0110 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:20]	 Train Loss:0.0060	 Train Acc:92.86 %  | 	Valid Loss:0.0132 	Valid Acc: 86.01 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 5-번 레이어
# ../checkpoint/checkpoint_w2v_large_5-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0196	 Train Acc:67.50 %  | 	Valid Loss:0.0269 	Valid Acc: 65.87 %
#
# Validation loss decreased (inf --> 0.026902).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0146	 Train Acc:78.64 %  | 	Valid Loss:0.0142 	Valid Acc: 81.23 %
#
# Validation loss decreased (0.026902 --> 0.014220).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0135	 Train Acc:80.80 %  | 	Valid Loss:0.0145 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0123	 Train Acc:81.91 %  | 	Valid Loss:0.0136 	Valid Acc: 81.91 %
#
# Validation loss decreased (0.014220 --> 0.013620).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0113	 Train Acc:84.67 %  | 	Valid Loss:0.0126 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.013620 --> 0.012565).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0110	 Train Acc:85.12 %  | 	Valid Loss:0.0142 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0107	 Train Acc:84.67 %  | 	Valid Loss:0.0123 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.012565 --> 0.012337).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0100	 Train Acc:87.09 %  | 	Valid Loss:0.0180 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0097	 Train Acc:87.48 %  | 	Valid Loss:0.0136 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0091	 Train Acc:89.12 %  | 	Valid Loss:0.0128 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0088	 Train Acc:89.12 %  | 	Valid Loss:0.0137 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0088	 Train Acc:88.53 %  | 	Valid Loss:0.0111 	Valid Acc: 86.01 %
#
# Validation loss decreased (0.012337 --> 0.011064).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0075	 Train Acc:91.02 %  | 	Valid Loss:0.0144 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0078	 Train Acc:89.65 %  | 	Valid Loss:0.0108 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.011064 --> 0.010849).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0074	 Train Acc:90.96 %  | 	Valid Loss:0.0117 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0073	 Train Acc:91.74 %  | 	Valid Loss:0.0105 	Valid Acc: 85.67 %
#
# Validation loss decreased (0.010849 --> 0.010546).  Saving model ...
#
# [EPOCH:17]	 Train Loss:0.0069	 Train Acc:91.55 %  | 	Valid Loss:0.0136 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:18]	 Train Loss:0.0064	 Train Acc:94.04 %  | 	Valid Loss:0.0122 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:19]	 Train Loss:0.0067	 Train Acc:93.18 %  | 	Valid Loss:0.0111 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:20]	 Train Loss:0.0062	 Train Acc:92.86 %  | 	Valid Loss:0.0122 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:21]	 Train Loss:0.0058	 Train Acc:93.51 %  | 	Valid Loss:0.0122 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 6-번 레이어
# ../checkpoint/checkpoint_w2v_large_6-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0179	 Train Acc:71.69 %  | 	Valid Loss:0.0134 	Valid Acc: 80.89 %
#
# Validation loss decreased (inf --> 0.013445).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0145	 Train Acc:78.05 %  | 	Valid Loss:0.0129 	Valid Acc: 80.55 %
#
# Validation loss decreased (0.013445 --> 0.012902).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0130	 Train Acc:82.11 %  | 	Valid Loss:0.0123 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.012902 --> 0.012312).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0118	 Train Acc:83.42 %  | 	Valid Loss:0.0121 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.012312 --> 0.012077).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0114	 Train Acc:85.26 %  | 	Valid Loss:0.0116 	Valid Acc: 84.30 %
#
# Validation loss decreased (0.012077 --> 0.011616).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0115	 Train Acc:84.93 %  | 	Valid Loss:0.0126 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0103	 Train Acc:85.71 %  | 	Valid Loss:0.0115 	Valid Acc: 84.30 %
#
# Validation loss decreased (0.011616 --> 0.011468).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0100	 Train Acc:87.55 %  | 	Valid Loss:0.0113 	Valid Acc: 83.96 %
#
# Validation loss decreased (0.011468 --> 0.011312).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0095	 Train Acc:87.61 %  | 	Valid Loss:0.0116 	Valid Acc: 86.35 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0084	 Train Acc:89.06 %  | 	Valid Loss:0.0121 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0084	 Train Acc:89.65 %  | 	Valid Loss:0.0121 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:12]	 Train Loss:0.0084	 Train Acc:89.71 %  | 	Valid Loss:0.0114 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:13]	 Train Loss:0.0085	 Train Acc:89.12 %  | 	Valid Loss:0.0134 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 7-번 레이어
# ../checkpoint/checkpoint_w2v_large_7-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0198	 Train Acc:69.27 %  | 	Valid Loss:0.0193 	Valid Acc: 69.97 %
#
# Validation loss decreased (inf --> 0.019297).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0150	 Train Acc:78.51 %  | 	Valid Loss:0.0128 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.019297 --> 0.012812).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0139	 Train Acc:79.16 %  | 	Valid Loss:0.0229 	Valid Acc: 68.94 %
#
# EarlyStopping counter: 1 out of 5
# [EPOCH:4]	 Train Loss:0.0130	 Train Acc:81.39 %  | 	Valid Loss:0.0142 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0117	 Train Acc:83.16 %  | 	Valid Loss:0.0148 	Valid Acc: 79.86 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:6]	 Train Loss:0.0114	 Train Acc:84.01 %  | 	Valid Loss:0.0124 	Valid Acc: 84.64 %
#
# Validation loss decreased (0.012812 --> 0.012432).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0109	 Train Acc:85.91 %  | 	Valid Loss:0.0180 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0099	 Train Acc:87.09 %  | 	Valid Loss:0.0149 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0098	 Train Acc:87.22 %  | 	Valid Loss:0.0122 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.012432 --> 0.012194).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0090	 Train Acc:87.75 %  | 	Valid Loss:0.0109 	Valid Acc: 86.01 %
#
# Validation loss decreased (0.012194 --> 0.010857).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0095	 Train Acc:87.68 %  | 	Valid Loss:0.0108 	Valid Acc: 87.03 %
#
# Validation loss decreased (0.010857 --> 0.010763).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0089	 Train Acc:88.79 %  | 	Valid Loss:0.0132 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0088	 Train Acc:88.27 %  | 	Valid Loss:0.0151 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0085	 Train Acc:89.38 %  | 	Valid Loss:0.0108 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0073	 Train Acc:91.68 %  | 	Valid Loss:0.0152 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:16]	 Train Loss:0.0082	 Train Acc:89.38 %  | 	Valid Loss:0.0140 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 8-번 레이어
# ../checkpoint/checkpoint_w2v_large_8-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0196	 Train Acc:67.76 %  | 	Valid Loss:0.0146 	Valid Acc: 81.91 %
#
# Validation loss decreased (inf --> 0.014586).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0156	 Train Acc:77.26 %  | 	Valid Loss:0.0197 	Valid Acc: 74.40 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0139	 Train Acc:79.62 %  | 	Valid Loss:0.0206 	Valid Acc: 75.43 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0135	 Train Acc:80.21 %  | 	Valid Loss:0.0163 	Valid Acc: 78.16 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:5]	 Train Loss:0.0123	 Train Acc:82.37 %  | 	Valid Loss:0.0151 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:6]	 Train Loss:0.0119	 Train Acc:83.68 %  | 	Valid Loss:0.0117 	Valid Acc: 84.30 %
#
# Validation loss decreased (0.014586 --> 0.011658).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0114	 Train Acc:84.40 %  | 	Valid Loss:0.0121 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0110	 Train Acc:85.65 %  | 	Valid Loss:0.0128 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0106	 Train Acc:86.76 %  | 	Valid Loss:0.0110 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.011658 --> 0.010963).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0105	 Train Acc:85.85 %  | 	Valid Loss:0.0112 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0096	 Train Acc:87.94 %  | 	Valid Loss:0.0114 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0096	 Train Acc:87.75 %  | 	Valid Loss:0.0119 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0094	 Train Acc:87.94 %  | 	Valid Loss:0.0126 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0090	 Train Acc:88.53 %  | 	Valid Loss:0.0138 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 9-번 레이어
# ../checkpoint/checkpoint_w2v_large_9-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0190	 Train Acc:68.74 %  | 	Valid Loss:0.0140 	Valid Acc: 79.86 %
#
# Validation loss decreased (inf --> 0.013985).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0157	 Train Acc:77.00 %  | 	Valid Loss:0.0145 	Valid Acc: 78.84 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0140	 Train Acc:79.75 %  | 	Valid Loss:0.0152 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0133	 Train Acc:80.21 %  | 	Valid Loss:0.0128 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.013985 --> 0.012789).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0129	 Train Acc:82.24 %  | 	Valid Loss:0.0135 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0118	 Train Acc:84.08 %  | 	Valid Loss:0.0141 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0114	 Train Acc:84.80 %  | 	Valid Loss:0.0147 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:8]	 Train Loss:0.0108	 Train Acc:85.71 %  | 	Valid Loss:0.0198 	Valid Acc: 72.70 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:9]	 Train Loss:0.0109	 Train Acc:85.65 %  | 	Valid Loss:0.0136 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 10-번 레이어
# ../checkpoint/checkpoint_w2v_large_10-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0196	 Train Acc:67.50 %  | 	Valid Loss:0.0224 	Valid Acc: 70.65 %
#
# Validation loss decreased (inf --> 0.022422).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0156	 Train Acc:78.05 %  | 	Valid Loss:0.0188 	Valid Acc: 78.50 %
#
# Validation loss decreased (0.022422 --> 0.018774).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0145	 Train Acc:78.77 %  | 	Valid Loss:0.0148 	Valid Acc: 82.25 %
#
# Validation loss decreased (0.018774 --> 0.014815).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0136	 Train Acc:81.45 %  | 	Valid Loss:0.0140 	Valid Acc: 79.52 %
#
# Validation loss decreased (0.014815 --> 0.014012).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0130	 Train Acc:81.72 %  | 	Valid Loss:0.0141 	Valid Acc: 78.50 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0118	 Train Acc:82.96 %  | 	Valid Loss:0.0126 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.014012 --> 0.012572).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0118	 Train Acc:82.83 %  | 	Valid Loss:0.0172 	Valid Acc: 76.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0109	 Train Acc:84.73 %  | 	Valid Loss:0.0121 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.012572 --> 0.012145).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0106	 Train Acc:85.32 %  | 	Valid Loss:0.0222 	Valid Acc: 71.33 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0111	 Train Acc:84.47 %  | 	Valid Loss:0.0121 	Valid Acc: 83.62 %
#
# Validation loss decreased (0.012145 --> 0.012132).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0104	 Train Acc:86.57 %  | 	Valid Loss:0.0133 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0101	 Train Acc:86.63 %  | 	Valid Loss:0.0106 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.012132 --> 0.010601).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0097	 Train Acc:88.01 %  | 	Valid Loss:0.0146 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0094	 Train Acc:87.55 %  | 	Valid Loss:0.0114 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:15]	 Train Loss:0.0092	 Train Acc:87.02 %  | 	Valid Loss:0.0208 	Valid Acc: 72.70 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:16]	 Train Loss:0.0088	 Train Acc:88.47 %  | 	Valid Loss:0.0119 	Valid Acc: 83.96 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:17]	 Train Loss:0.0086	 Train Acc:89.52 %  | 	Valid Loss:0.0153 	Valid Acc: 79.52 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 11-번 레이어
# ../checkpoint/checkpoint_w2v_large_11-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0188	 Train Acc:70.12 %  | 	Valid Loss:0.0163 	Valid Acc: 78.16 %
#
# Validation loss decreased (inf --> 0.016264).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0153	 Train Acc:76.47 %  | 	Valid Loss:0.0174 	Valid Acc: 76.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0141	 Train Acc:79.29 %  | 	Valid Loss:0.0165 	Valid Acc: 78.50 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0138	 Train Acc:79.95 %  | 	Valid Loss:0.0124 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.016264 --> 0.012442).  Saving model ...
# [EPOCH:5]	 Train Loss:0.0123	 Train Acc:83.22 %  | 	Valid Loss:0.0167 	Valid Acc: 79.18 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0120	 Train Acc:82.96 %  | 	Valid Loss:0.0126 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0121	 Train Acc:83.29 %  | 	Valid Loss:0.0169 	Valid Acc: 77.47 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:8]	 Train Loss:0.0113	 Train Acc:85.45 %  | 	Valid Loss:0.0127 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:9]	 Train Loss:0.0109	 Train Acc:85.39 %  | 	Valid Loss:0.0143 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 12-번 레이어
# ../checkpoint/checkpoint_w2v_large_12-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0193	 Train Acc:68.68 %  | 	Valid Loss:0.0142 	Valid Acc: 78.84 %
#
# Validation loss decreased (inf --> 0.014207).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0158	 Train Acc:75.95 %  | 	Valid Loss:0.0138 	Valid Acc: 80.55 %
#
# Validation loss decreased (0.014207 --> 0.013845).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0146	 Train Acc:78.24 %  | 	Valid Loss:0.0137 	Valid Acc: 82.25 %
#
# Validation loss decreased (0.013845 --> 0.013688).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0135	 Train Acc:80.01 %  | 	Valid Loss:0.0180 	Valid Acc: 76.79 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0128	 Train Acc:82.11 %  | 	Valid Loss:0.0169 	Valid Acc: 78.84 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0124	 Train Acc:82.44 %  | 	Valid Loss:0.0124 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.013688 --> 0.012423).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0121	 Train Acc:82.63 %  | 	Valid Loss:0.0132 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0114	 Train Acc:84.01 %  | 	Valid Loss:0.0122 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.012423 --> 0.012228).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0108	 Train Acc:86.63 %  | 	Valid Loss:0.0117 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.012228 --> 0.011683).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0105	 Train Acc:86.11 %  | 	Valid Loss:0.0131 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0102	 Train Acc:86.24 %  | 	Valid Loss:0.0140 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0099	 Train Acc:86.04 %  | 	Valid Loss:0.0110 	Valid Acc: 86.35 %
#
# Validation loss decreased (0.011683 --> 0.010966).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0100	 Train Acc:87.68 %  | 	Valid Loss:0.0115 	Valid Acc: 86.01 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0099	 Train Acc:86.17 %  | 	Valid Loss:0.0131 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:15]	 Train Loss:0.0090	 Train Acc:87.29 %  | 	Valid Loss:0.0122 	Valid Acc: 86.35 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:16]	 Train Loss:0.0090	 Train Acc:87.88 %  | 	Valid Loss:0.0114 	Valid Acc: 86.69 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:17]	 Train Loss:0.0092	 Train Acc:88.07 %  | 	Valid Loss:0.0104 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.010966 --> 0.010448).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0088	 Train Acc:87.35 %  | 	Valid Loss:0.0165 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:19]	 Train Loss:0.0086	 Train Acc:89.19 %  | 	Valid Loss:0.0135 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:20]	 Train Loss:0.0083	 Train Acc:89.25 %  | 	Valid Loss:0.0109 	Valid Acc: 87.71 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:21]	 Train Loss:0.0081	 Train Acc:89.45 %  | 	Valid Loss:0.0118 	Valid Acc: 86.69 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:22]	 Train Loss:0.0086	 Train Acc:88.34 %  | 	Valid Loss:0.0117 	Valid Acc: 87.71 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 13-번 레이어
# ../checkpoint/checkpoint_w2v_large_13-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0183	 Train Acc:70.97 %  | 	Valid Loss:0.0156 	Valid Acc: 78.50 %
#
# Validation loss decreased (inf --> 0.015615).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0154	 Train Acc:77.33 %  | 	Valid Loss:0.0211 	Valid Acc: 67.24 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0143	 Train Acc:79.23 %  | 	Valid Loss:0.0150 	Valid Acc: 79.18 %
#
# Validation loss decreased (0.015615 --> 0.014968).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0129	 Train Acc:81.13 %  | 	Valid Loss:0.0179 	Valid Acc: 75.77 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0132	 Train Acc:81.26 %  | 	Valid Loss:0.0196 	Valid Acc: 71.67 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0120	 Train Acc:82.63 %  | 	Valid Loss:0.0151 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0123	 Train Acc:82.83 %  | 	Valid Loss:0.0144 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.014968 --> 0.014428).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0115	 Train Acc:84.60 %  | 	Valid Loss:0.0117 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.014428 --> 0.011710).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0109	 Train Acc:84.99 %  | 	Valid Loss:0.0130 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0110	 Train Acc:84.14 %  | 	Valid Loss:0.0187 	Valid Acc: 73.72 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0104	 Train Acc:85.32 %  | 	Valid Loss:0.0119 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:12]	 Train Loss:0.0106	 Train Acc:84.99 %  | 	Valid Loss:0.0139 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:13]	 Train Loss:0.0097	 Train Acc:87.29 %  | 	Valid Loss:0.0140 	Valid Acc: 79.86 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 14-번 레이어
# ../checkpoint/checkpoint_w2v_large_14-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0190	 Train Acc:68.48 %  | 	Valid Loss:0.0160 	Valid Acc: 79.18 %
#
# Validation loss decreased (inf --> 0.016050).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0156	 Train Acc:76.61 %  | 	Valid Loss:0.0177 	Valid Acc: 73.72 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0145	 Train Acc:78.18 %  | 	Valid Loss:0.0167 	Valid Acc: 76.79 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0133	 Train Acc:81.78 %  | 	Valid Loss:0.0157 	Valid Acc: 81.91 %
#
# Validation loss decreased (0.016050 --> 0.015711).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0128	 Train Acc:81.06 %  | 	Valid Loss:0.0187 	Valid Acc: 76.79 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0122	 Train Acc:83.49 %  | 	Valid Loss:0.0131 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.015711 --> 0.013150).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0119	 Train Acc:83.68 %  | 	Valid Loss:0.0163 	Valid Acc: 76.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0111	 Train Acc:84.67 %  | 	Valid Loss:0.0152 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0114	 Train Acc:84.21 %  | 	Valid Loss:0.0121 	Valid Acc: 84.98 %
#
# Validation loss decreased (0.013150 --> 0.012058).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0105	 Train Acc:85.12 %  | 	Valid Loss:0.0174 	Valid Acc: 75.43 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0105	 Train Acc:85.85 %  | 	Valid Loss:0.0150 	Valid Acc: 78.84 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0110	 Train Acc:85.52 %  | 	Valid Loss:0.0139 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0096	 Train Acc:88.01 %  | 	Valid Loss:0.0128 	Valid Acc: 84.98 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0102	 Train Acc:85.91 %  | 	Valid Loss:0.0131 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 15-번 레이어
# ../checkpoint/checkpoint_w2v_large_15-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0184	 Train Acc:69.66 %  | 	Valid Loss:0.0160 	Valid Acc: 75.43 %
#
# Validation loss decreased (inf --> 0.016046).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0161	 Train Acc:76.02 %  | 	Valid Loss:0.0157 	Valid Acc: 77.47 %
#
# Validation loss decreased (0.016046 --> 0.015734).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0145	 Train Acc:78.57 %  | 	Valid Loss:0.0134 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.015734 --> 0.013442).  Saving model ...
# [EPOCH:4]	 Train Loss:0.0134	 Train Acc:79.62 %  | 	Valid Loss:0.0174 	Valid Acc: 77.13 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0129	 Train Acc:81.98 %  | 	Valid Loss:0.0140 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0122	 Train Acc:82.57 %  | 	Valid Loss:0.0136 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0119	 Train Acc:83.81 %  | 	Valid Loss:0.0143 	Valid Acc: 79.86 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:8]	 Train Loss:0.0113	 Train Acc:84.67 %  | 	Valid Loss:0.0202 	Valid Acc: 74.06 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 16-번 레이어
# ../checkpoint/checkpoint_w2v_large_16-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0188	 Train Acc:70.18 %  | 	Valid Loss:0.0163 	Valid Acc: 75.77 %
#
# Validation loss decreased (inf --> 0.016350).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0153	 Train Acc:76.80 %  | 	Valid Loss:0.0165 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0144	 Train Acc:78.05 %  | 	Valid Loss:0.0140 	Valid Acc: 83.96 %
#
# Validation loss decreased (0.016350 --> 0.013989).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0133	 Train Acc:81.85 %  | 	Valid Loss:0.0157 	Valid Acc: 77.47 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0127	 Train Acc:82.77 %  | 	Valid Loss:0.0132 	Valid Acc: 83.62 %
#
# Validation loss decreased (0.013989 --> 0.013247).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0124	 Train Acc:82.96 %  | 	Valid Loss:0.0159 	Valid Acc: 78.16 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0117	 Train Acc:83.29 %  | 	Valid Loss:0.0135 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0118	 Train Acc:83.55 %  | 	Valid Loss:0.0152 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0114	 Train Acc:84.21 %  | 	Valid Loss:0.0118 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.013247 --> 0.011846).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0109	 Train Acc:84.27 %  | 	Valid Loss:0.0146 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0106	 Train Acc:85.45 %  | 	Valid Loss:0.0126 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0104	 Train Acc:85.26 %  | 	Valid Loss:0.0158 	Valid Acc: 79.52 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0098	 Train Acc:86.17 %  | 	Valid Loss:0.0138 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0095	 Train Acc:86.63 %  | 	Valid Loss:0.0135 	Valid Acc: 83.62 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 17-번 레이어
# ../checkpoint/checkpoint_w2v_large_17-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0192	 Train Acc:69.07 %  | 	Valid Loss:0.0183 	Valid Acc: 72.01 %
#
# Validation loss decreased (inf --> 0.018329).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0151	 Train Acc:77.13 %  | 	Valid Loss:0.0183 	Valid Acc: 76.11 %
#
# Validation loss decreased (0.018329 --> 0.018303).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0139	 Train Acc:79.82 %  | 	Valid Loss:0.0184 	Valid Acc: 75.09 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0127	 Train Acc:82.50 %  | 	Valid Loss:0.0181 	Valid Acc: 74.74 %
#
# Validation loss decreased (0.018303 --> 0.018103).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0122	 Train Acc:82.96 %  | 	Valid Loss:0.0139 	Valid Acc: 81.57 %
#
# Validation loss decreased (0.018103 --> 0.013936).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0119	 Train Acc:83.42 %  | 	Valid Loss:0.0172 	Valid Acc: 75.77 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0116	 Train Acc:82.90 %  | 	Valid Loss:0.0180 	Valid Acc: 76.79 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0110	 Train Acc:85.06 %  | 	Valid Loss:0.0149 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0106	 Train Acc:85.39 %  | 	Valid Loss:0.0128 	Valid Acc: 82.59 %
#
# Validation loss decreased (0.013936 --> 0.012753).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0110	 Train Acc:85.52 %  | 	Valid Loss:0.0150 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0101	 Train Acc:86.24 %  | 	Valid Loss:0.0141 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0103	 Train Acc:86.57 %  | 	Valid Loss:0.0159 	Valid Acc: 76.79 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0101	 Train Acc:86.50 %  | 	Valid Loss:0.0152 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:14]	 Train Loss:0.0096	 Train Acc:88.07 %  | 	Valid Loss:0.0140 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 18-번 레이어
# ../checkpoint/checkpoint_w2v_large_18-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0201	 Train Acc:67.69 %  | 	Valid Loss:0.0172 	Valid Acc: 76.45 %
#
# Validation loss decreased (inf --> 0.017208).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0152	 Train Acc:77.46 %  | 	Valid Loss:0.0163 	Valid Acc: 76.11 %
#
# Validation loss decreased (0.017208 --> 0.016309).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0148	 Train Acc:78.11 %  | 	Valid Loss:0.0176 	Valid Acc: 75.43 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0132	 Train Acc:80.80 %  | 	Valid Loss:0.0154 	Valid Acc: 79.18 %
#
# Validation loss decreased (0.016309 --> 0.015385).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0126	 Train Acc:81.52 %  | 	Valid Loss:0.0143 	Valid Acc: 78.84 %
#
# Validation loss decreased (0.015385 --> 0.014340).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0120	 Train Acc:83.62 %  | 	Valid Loss:0.0138 	Valid Acc: 81.91 %
#
# Validation loss decreased (0.014340 --> 0.013827).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0117	 Train Acc:82.96 %  | 	Valid Loss:0.0156 	Valid Acc: 79.52 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0120	 Train Acc:83.29 %  | 	Valid Loss:0.0130 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.013827 --> 0.012966).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0106	 Train Acc:85.58 %  | 	Valid Loss:0.0149 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0109	 Train Acc:84.53 %  | 	Valid Loss:0.0161 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0106	 Train Acc:85.98 %  | 	Valid Loss:0.0126 	Valid Acc: 83.96 %
#
# Validation loss decreased (0.012966 --> 0.012625).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0101	 Train Acc:86.70 %  | 	Valid Loss:0.0150 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0103	 Train Acc:86.17 %  | 	Valid Loss:0.0199 	Valid Acc: 73.72 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0099	 Train Acc:86.50 %  | 	Valid Loss:0.0135 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0099	 Train Acc:87.68 %  | 	Valid Loss:0.0177 	Valid Acc: 78.50 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:16]	 Train Loss:0.0091	 Train Acc:87.94 %  | 	Valid Loss:0.0142 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 19-번 레이어
# ../checkpoint/checkpoint_w2v_large_19-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0185	 Train Acc:68.35 %  | 	Valid Loss:0.0218 	Valid Acc: 66.21 %
#
# Validation loss decreased (inf --> 0.021842).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0154	 Train Acc:77.79 %  | 	Valid Loss:0.0141 	Valid Acc: 80.89 %
#
# Validation loss decreased (0.021842 --> 0.014085).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0142	 Train Acc:79.29 %  | 	Valid Loss:0.0138 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.014085 --> 0.013801).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0129	 Train Acc:81.59 %  | 	Valid Loss:0.0165 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0127	 Train Acc:82.83 %  | 	Valid Loss:0.0143 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0116	 Train Acc:83.29 %  | 	Valid Loss:0.0146 	Valid Acc: 81.23 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0111	 Train Acc:84.93 %  | 	Valid Loss:0.0146 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:8]	 Train Loss:0.0111	 Train Acc:85.58 %  | 	Valid Loss:0.0140 	Valid Acc: 81.91 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 20-번 레이어
# ../checkpoint/checkpoint_w2v_large_20-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0182	 Train Acc:69.66 %  | 	Valid Loss:0.0209 	Valid Acc: 70.31 %
#
# Validation loss decreased (inf --> 0.020874).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0146	 Train Acc:77.33 %  | 	Valid Loss:0.0140 	Valid Acc: 80.20 %
#
# Validation loss decreased (0.020874 --> 0.014049).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0139	 Train Acc:80.14 %  | 	Valid Loss:0.0145 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0128	 Train Acc:82.04 %  | 	Valid Loss:0.0159 	Valid Acc: 80.20 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0122	 Train Acc:82.44 %  | 	Valid Loss:0.0138 	Valid Acc: 82.94 %
#
# Validation loss decreased (0.014049 --> 0.013787).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0119	 Train Acc:82.77 %  | 	Valid Loss:0.0142 	Valid Acc: 84.30 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0116	 Train Acc:83.09 %  | 	Valid Loss:0.0130 	Valid Acc: 84.30 %
#
# Validation loss decreased (0.013787 --> 0.012983).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0115	 Train Acc:84.40 %  | 	Valid Loss:0.0134 	Valid Acc: 84.64 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0110	 Train Acc:84.08 %  | 	Valid Loss:0.0131 	Valid Acc: 86.01 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0106	 Train Acc:85.26 %  | 	Valid Loss:0.0115 	Valid Acc: 85.32 %
#
# Validation loss decreased (0.012983 --> 0.011525).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0104	 Train Acc:86.17 %  | 	Valid Loss:0.0133 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0099	 Train Acc:87.22 %  | 	Valid Loss:0.0110 	Valid Acc: 87.37 %
#
# Validation loss decreased (0.011525 --> 0.010979).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0101	 Train Acc:86.76 %  | 	Valid Loss:0.0126 	Valid Acc: 85.67 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0089	 Train Acc:88.93 %  | 	Valid Loss:0.0113 	Valid Acc: 87.37 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:15]	 Train Loss:0.0093	 Train Acc:87.42 %  | 	Valid Loss:0.0106 	Valid Acc: 86.01 %
#
# Validation loss decreased (0.010979 --> 0.010612).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0088	 Train Acc:87.94 %  | 	Valid Loss:0.0112 	Valid Acc: 86.01 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0088	 Train Acc:88.60 %  | 	Valid Loss:0.0124 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0088	 Train Acc:87.81 %  | 	Valid Loss:0.0107 	Valid Acc: 87.71 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:19]	 Train Loss:0.0085	 Train Acc:89.25 %  | 	Valid Loss:0.0107 	Valid Acc: 87.03 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:20]	 Train Loss:0.0089	 Train Acc:88.66 %  | 	Valid Loss:0.0127 	Valid Acc: 85.32 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 21-번 레이어
# ../checkpoint/checkpoint_w2v_large_21-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0218	 Train Acc:62.45 %  | 	Valid Loss:0.0193 	Valid Acc: 76.11 %
#
# Validation loss decreased (inf --> 0.019306).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0200	 Train Acc:66.78 %  | 	Valid Loss:0.0200 	Valid Acc: 67.24 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0197	 Train Acc:68.68 %  | 	Valid Loss:0.0349 	Valid Acc: 37.88 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:4]	 Train Loss:0.0200	 Train Acc:67.82 %  | 	Valid Loss:0.0190 	Valid Acc: 74.74 %
#
# Validation loss decreased (0.019306 --> 0.019000).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0193	 Train Acc:68.94 %  | 	Valid Loss:0.0228 	Valid Acc: 59.73 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0187	 Train Acc:70.18 %  | 	Valid Loss:0.0183 	Valid Acc: 68.94 %
#
# Validation loss decreased (0.019000 --> 0.018284).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0191	 Train Acc:69.27 %  | 	Valid Loss:0.0175 	Valid Acc: 70.99 %
#
# Validation loss decreased (0.018284 --> 0.017521).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0181	 Train Acc:71.04 %  | 	Valid Loss:0.0309 	Valid Acc: 47.10 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0180	 Train Acc:71.30 %  | 	Valid Loss:0.0542 	Valid Acc: 37.54 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0189	 Train Acc:69.46 %  | 	Valid Loss:0.0179 	Valid Acc: 75.09 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0181	 Train Acc:70.51 %  | 	Valid Loss:0.0230 	Valid Acc: 57.00 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0182	 Train Acc:72.28 %  | 	Valid Loss:0.0185 	Valid Acc: 72.35 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 22-번 레이어
# ../checkpoint/checkpoint_w2v_large_22-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0238	 Train Acc:57.40 %  | 	Valid Loss:0.0393 	Valid Acc: 42.32 %
#
# Validation loss decreased (inf --> 0.039311).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0205	 Train Acc:63.50 %  | 	Valid Loss:0.0206 	Valid Acc: 72.01 %
#
# Validation loss decreased (0.039311 --> 0.020575).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0205	 Train Acc:65.01 %  | 	Valid Loss:0.0304 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0191	 Train Acc:68.48 %  | 	Valid Loss:0.0447 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:5]	 Train Loss:0.0201	 Train Acc:65.20 %  | 	Valid Loss:0.0248 	Valid Acc: 53.92 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:6]	 Train Loss:0.0197	 Train Acc:66.12 %  | 	Valid Loss:0.1208 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:7]	 Train Loss:0.0200	 Train Acc:68.55 %  | 	Valid Loss:0.0504 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# 23-번 레이어
# ../checkpoint/checkpoint_w2v_large_23-1.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0222	 Train Acc:58.26 %  | 	Valid Loss:0.0610 	Valid Acc: 35.15 %
#
# Validation loss decreased (inf --> 0.061032).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0211	 Train Acc:63.96 %  | 	Valid Loss:0.0280 	Valid Acc: 62.80 %
#
# Validation loss decreased (0.061032 --> 0.027991).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0209	 Train Acc:64.09 %  | 	Valid Loss:0.0193 	Valid Acc: 67.58 %
#
# Validation loss decreased (0.027991 --> 0.019317).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0204	 Train Acc:64.94 %  | 	Valid Loss:0.0335 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0195	 Train Acc:66.71 %  | 	Valid Loss:0.0191 	Valid Acc: 65.19 %
#
# Validation loss decreased (0.019317 --> 0.019118).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0194	 Train Acc:68.87 %  | 	Valid Loss:0.0405 	Valid Acc: 53.92 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0201	 Train Acc:67.76 %  | 	Valid Loss:0.1385 	Valid Acc: 34.81 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:8]	 Train Loss:0.0195	 Train Acc:66.91 %  | 	Valid Loss:0.1009 	Valid Acc: 34.81 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:9]	 Train Loss:0.0190	 Train Acc:68.74 %  | 	Valid Loss:0.0312 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:10]	 Train Loss:0.0192	 Train Acc:69.79 %  | 	Valid Loss:0.0237 	Valid Acc: 65.19 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping

# %%
for num,valid in enumerate(valid_accs):
    print("{}번 모델. train :{:.4f}/ valid: {:.4f}".format(num+1,train_accs[num],valid) )
# Out:
# 1번 모델. train :82.0446/ valid: 81.9113
# 2번 모델. train :82.6999/ valid: 83.2765
# 3번 모델. train :88.9253/ valid: 87.3720
# 4번 모델. train :89.8427/ valid: 86.6894
# 5번 모델. train :91.1533/ valid: 84.9829
# 6번 모델. train :91.7431/ valid: 85.6655
# 7번 모델. train :87.5491/ valid: 83.9590
# 8번 모델. train :87.6802/ valid: 87.0307
# 9번 모델. train :86.7628/ valid: 84.9829
# 10번 모델. train :80.2097/ valid: 83.2765
# 11번 모델. train :86.6317/ valid: 84.9829
# 12번 모델. train :79.9476/ valid: 82.9352
# 13번 모델. train :88.0734/ valid: 86.6894
# 14번 모델. train :84.6003/ valid: 84.9829
# 15번 모델. train :84.2071/ valid: 84.9829
# 16번 모델. train :78.5714/ valid: 82.9352
# 17번 모델. train :84.2071/ valid: 86.6894
# 18번 모델. train :85.3866/ valid: 82.5939
# 19번 모델. train :85.9764/ valid: 83.9590
# 20번 모델. train :79.2923/ valid: 83.2765
# 21번 모델. train :87.4181/ valid: 86.0068
# 22번 모델. train :69.2661/ valid: 70.9898
# 23번 모델. train :63.4993/ valid: 72.0137
# 24번 모델. train :66.7104/ valid: 65.1877

# %%
test_grid()
# Out:
# 1번 모델
# Accuracy : 83.3333%
# Precision (pathology 예측한 것중 맞는 것) : 0.8371
# recall (실제 pathology 중  예측이 맞는 것) : 0.9247
# f score : 0.8062
# [[221  18]
#  [ 43  84]]
# -----
# 2번 모델
# Accuracy : 83.6066%
# Precision (pathology 예측한 것중 맞는 것) : 0.8714
# recall (실제 pathology 중  예측이 맞는 것) : 0.8787
# f score : 0.8185
# [[210  29]
#  [ 31  96]]
# -----
# 3번 모델
# Accuracy : 85.7923%
# Precision (pathology 예측한 것중 맞는 것) : 0.8848
# recall (실제 pathology 중  예측이 맞는 것) : 0.8996
# f score : 0.8421
# [[215  24]
#  [ 28  99]]
# -----
# 4번 모델
# Accuracy : 83.8798%
# Precision (pathology 예측한 것중 맞는 것) : 0.8982
# recall (실제 pathology 중  예측이 맞는 것) : 0.8494
# f score : 0.8261
# [[203  36]
#  [ 23 104]]
# -----
# 5번 모델
# Accuracy : 83.3333%
# Precision (pathology 예측한 것중 맞는 것) : 0.8836
# recall (실제 pathology 중  예측이 맞는 것) : 0.8577
# f score : 0.8184
# [[205  34]
#  [ 27 100]]
# -----
# 6번 모델
# Accuracy : 82.5137%
# Precision (pathology 예측한 것중 맞는 것) : 0.9070
# recall (실제 pathology 중  예측이 맞는 것) : 0.8159
# f score : 0.8144
# [[195  44]
#  [ 20 107]]
# -----
# 7번 모델
# Accuracy : 85.2459%
# Precision (pathology 예측한 것중 맞는 것) : 0.8715
# recall (실제 pathology 중  예측이 맞는 것) : 0.9079
# f score : 0.8340
# [[217  22]
#  [ 32  95]]
# -----
# 8번 모델
# Accuracy : 84.9727%
# Precision (pathology 예측한 것중 맞는 것) : 0.8833
# recall (실제 pathology 중  예측이 맞는 것) : 0.8870
# f score : 0.8339
# [[212  27]
#  [ 28  99]]
# -----
# 9번 모델
# Accuracy : 84.4262%
# Precision (pathology 예측한 것중 맞는 것) : 0.8640
# recall (실제 pathology 중  예측이 맞는 것) : 0.9038
# f score : 0.8244
# [[216  23]
#  [ 34  93]]
# -----
# 10번 모델
# Accuracy : 82.7869%
# Precision (pathology 예측한 것중 맞는 것) : 0.8964
# recall (실제 pathology 중  예측이 맞는 것) : 0.8326
# f score : 0.8154
# [[199  40]
#  [ 23 104]]
# -----
# 11번 모델
# Accuracy : 84.6995%
# Precision (pathology 예측한 것중 맞는 것) : 0.8617
# recall (실제 pathology 중  예측이 맞는 것) : 0.9121
# f score : 0.8264
# [[218  21]
#  [ 35  92]]
# -----
# 12번 모델
# Accuracy : 84.1530%
# Precision (pathology 예측한 것중 맞는 것) : 0.8664
# recall (실제 pathology 중  예측이 맞는 것) : 0.8954
# f score : 0.8224
# [[214  25]
#  [ 33  94]]
# -----
# 13번 모델
# Accuracy : 83.8798%
# Precision (pathology 예측한 것중 맞는 것) : 0.8719
# recall (실제 pathology 중  예측이 맞는 것) : 0.8828
# f score : 0.8211
# [[211  28]
#  [ 31  96]]
# -----
# 14번 모델
# Accuracy : 84.1530%
# Precision (pathology 예측한 것중 맞는 것) : 0.8635
# recall (실제 pathology 중  예측이 맞는 것) : 0.8996
# f score : 0.8217
# [[215  24]
#  [ 34  93]]
# -----
# 15번 모델
# Accuracy : 83.3333%
# Precision (pathology 예측한 것중 맞는 것) : 0.8708
# recall (실제 pathology 중  예측이 맞는 것) : 0.8745
# f score : 0.8158
# [[209  30]
#  [ 31  96]]
# -----
# 16번 모델
# Accuracy : 83.6066%
# Precision (pathology 예측한 것중 맞는 것) : 0.8978
# recall (실제 pathology 중  예측이 맞는 것) : 0.8452
# f score : 0.8234
# [[202  37]
#  [ 23 104]]
# -----
# 17번 모델
# Accuracy : 82.2404%
# Precision (pathology 예측한 것중 맞는 것) : 0.8850
# recall (실제 pathology 중  예측이 맞는 것) : 0.8368
# f score : 0.8084
# [[200  39]
#  [ 26 101]]
# -----
# 18번 모델
# Accuracy : 80.8743%
# Precision (pathology 예측한 것중 맞는 것) : 0.9043
# recall (실제 pathology 중  예측이 맞는 것) : 0.7908
# f score : 0.7986
# [[189  50]
#  [ 20 107]]
# -----
# 19번 모델
# Accuracy : 83.0601%
# Precision (pathology 예측한 것중 맞는 것) : 0.9078
# recall (실제 pathology 중  예측이 맞는 것) : 0.8243
# f score : 0.8197
# [[197  42]
#  [ 20 107]]
# -----
# 20번 모델
# Accuracy : 81.9672%
# Precision (pathology 예측한 것중 맞는 것) : 0.8986
# recall (실제 pathology 중  예측이 맞는 것) : 0.8159
# f score : 0.8081
# [[195  44]
#  [ 22 105]]
# -----
# 21번 모델
# Accuracy : 83.8798%
# Precision (pathology 예측한 것중 맞는 것) : 0.8719
# recall (실제 pathology 중  예측이 맞는 것) : 0.8828
# f score : 0.8211
# [[211  28]
#  [ 31  96]]
# -----
# 22번 모델
# Accuracy : 72.1311%
# Precision (pathology 예측한 것중 맞는 것) : 0.7069
# recall (실제 pathology 중  예측이 맞는 것) : 0.9791
# f score : 0.5957
# [[234   5]
#  [ 97  30]]
# -----
# 23번 모델
# Accuracy : 70.4918%
# Precision (pathology 예측한 것중 맞는 것) : 0.7529
# recall (실제 pathology 중  예측이 맞는 것) : 0.8159
# f score : 0.6608
# [[195  44]
#  [ 64  63]]
# -----
# 24번 모델
# Accuracy : 65.5738%
# Precision (pathology 예측한 것중 맞는 것) : 0.6548
# recall (실제 pathology 중  예측이 맞는 것) : 1.0000
# f score : 0.4035
# [[239   0]
#  [126   1]]
# -----

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_w2v_'+str(data_ind)+'.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
