# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.0  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../voice_data/pathology_a/export/'):
    sig, sr = librosa.load('../voice_data/pathology_a/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
    pathology.append(MFCCs)
    

#Healthy data
for audio_path in os.listdir('../voice_data/healthy_a/export/'):
    sig, sr = librosa.load('../voice_data/healthy_a/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
    healthy.append(MFCCs)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  1354
# healthy data 수 :  687
# 가장 긴 path sample : 131655
# 가장 긴 healthy sample : 219501

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 2.6331 초
# 4.39002 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
pd.DataFrame(healthy[1].T,columns=headers)
# Out:
#           mfcc1       mfcc2      mfcc3      mfcc4      mfcc5      mfcc6  \
# 0   -214.176651  207.977264   1.462625  13.944162 -63.319916  -2.144712
# 1   -222.949982  209.148163   2.133819  17.240515 -52.081551   2.385664
# 2   -248.733551  195.559235  -2.844307   7.977224 -52.356590  -1.202414
# 3   -246.802917  198.915344  -3.477466   8.681169 -53.547142  -5.144975
# 4   -245.827591  200.687988   0.568132   6.174569 -51.041344  -1.792537
# ..          ...         ...        ...        ...        ...        ...
# 333 -242.007767  200.297760   3.961174  14.153851 -52.725536   7.545429
# 334 -245.131500  196.616119   2.222031  15.436684 -56.961128   6.723224
# 335 -247.851624  198.925278   2.341530  14.167100 -54.980747  11.598038
# 336 -232.978348  215.946442  14.133223  16.482494 -50.424297  13.806274
# 337 -218.726624  225.969635  17.963581  17.724133 -46.865860   8.419164
#
#          mfcc7      mfcc8     mfcc9     mfcc10     mfcc11     mfcc12  \
# 0   -16.828245 -21.429878  7.964348  -0.085761  -1.125562 -21.268238
# 1   -18.650604 -24.606426  3.663574  -1.903811  -8.280209 -16.000689
# 2   -16.476841 -20.510300  5.527544  -0.318386 -15.725111  -8.803049
# 3   -17.089766 -22.173811  4.114779  -1.155015 -14.204550  -9.640966
# 4   -17.918312 -18.034185  5.677939  -2.018642 -12.768702 -11.336535
# ..         ...        ...       ...        ...        ...        ...
# 333  -5.822221 -22.547153  6.216630   7.461223 -12.434643 -15.016934
# 334  -5.488671 -19.845875  7.457106   2.931230 -13.481985 -15.816978
# 335  -2.436407 -18.352262  8.678156   8.914279  -9.958929 -16.050816
# 336  -4.241011 -16.475407  5.775840   7.153922 -11.623649 -19.136692
# 337  -2.978050 -13.858909  9.973724  11.311474 -11.353134 -16.323940
#
#         mfcc13
# 0   -16.084270
# 1   -12.138484
# 2    -4.176742
# 3    -2.181946
# 4    -1.299195
# ..         ...
# 333  12.251122
# 334  13.508206
# 335  15.700717
# 336  15.453394
# 337  12.591789
#
# [338 rows x 13 columns]

# %%
healthy[0].shape[1]
# Out:
# 312

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기
# - pathology : 852 ,  healthy 수 :  632  총 1484
# - train :  1187 , test : 297

# %%
#1. train, test 나누기
import os
import random #데이터 shuffle 사용
from glob import glob


pathology = glob('../voice_data/pathology_a/export/*.wav')
healthy = glob('../voice_data/healthy_a/export/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))


X = pathology+healthy # mfcc 데이터 합
print("총 데이터수 : ",len(X))
Y = {} # 라벨
for idx,x in enumerate(X):
    if idx<852:
        Y[x]="pathology"
    else:
        Y[x]="healthy"

#train 1187   test: 297
random.shuffle(X)
DATA_TRAINING_PATH = X[:1186]
DATA_TEST_PATH = X[1187:]

print("훈련 셋 : ",len(DATA_TRAINING_PATH))
print("테스트 셋 : ",len(DATA_TEST_PATH))
# Out:
# Pathology :  1354
# Healthy:  687
# 총 데이터수 :  2041
# 훈련 셋 :  1186
# 테스트 셋 :  854

# %%
Y
# Out:
# {'../voice_data/pathology_a/export\\101-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1037-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1038-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1039-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1040-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1041-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1042-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1043-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1044-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1045-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1046-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1047-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1048-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1049-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\105-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1050-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1051-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1052-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1053-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1054-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1055-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1056-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1057-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1058-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\106-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\107-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\108-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1083-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1084-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1085-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1086-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1087-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1088-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1089-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\109-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1090-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\110-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\111-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1113-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1115-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1116-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1117-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1118-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1119-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1120-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1156-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1157-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1158-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1159-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1160-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1161-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1162-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1163-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1164-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1165-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1166-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\118-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1186-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1187-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1188-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1189-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\119-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1190-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1191-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1192-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1193-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1194-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1195-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1196-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1197-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1198-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1199-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\120-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1200-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1201-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1202-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1203-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1204-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1205-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1206-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1217-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1218-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1219-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1220-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1221-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1222-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1223-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1224-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1225-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1227-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1228-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1229-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1230-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1231-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1232-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1233-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1234-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1235-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1237-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1238-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1239-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1240-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1241-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1242-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1243-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1244-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1245-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1246-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1247-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1248-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1249-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1250-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1251-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1252-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1253-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1254-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1255-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1256-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1257-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1258-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1259-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1260-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1261-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1262-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1263-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1264-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1265-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1266-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1267-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1268-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1269-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\127-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1270-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1271-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1272-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1273-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1274-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1275-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1276-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1277-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1279-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\128-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1280-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1281-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1282-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1283-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1284-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1285-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1286-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1289-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\129-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1290-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1291-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1292-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1293-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1294-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1295-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1296-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1297-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1298-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1299-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\130-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1300-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1301-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1302-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1303-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1304-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1305-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1306-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1307-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1309-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\131-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1310-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1311-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1312-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1313-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1314-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1315-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1316-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1317-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1318-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1319-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1321-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1322-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1323-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1324-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1325-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1326-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1327-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1328-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1329-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1330-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1331-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1332-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1333-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1334-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1335-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1337-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1338-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1339-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1340-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1341-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1376-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1378-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1379-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\138-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1380-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1381-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1382-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1383-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1384-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1385-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1386-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1387-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1388-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1389-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\139-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1390-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1391-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1392-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1393-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1394-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1395-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1396-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1397-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1398-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1399-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\140-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1400-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1401-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1402-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1403-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1404-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1405-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1406-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1407-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1408-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1409-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\141-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1410-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1411-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1412-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1414-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1415-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1416-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1417-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1418-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\142-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1421-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1422-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1424-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1425-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1426-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1428-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1429-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\143-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1430-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1431-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1432-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1433-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1434-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1435-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1436-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1437-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1438-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1439-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\144-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1440-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1441-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1442-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1443-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1444-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1445-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1446-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1447-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1448-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1449-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1450-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1451-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1452-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1453-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1454-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1455-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1456-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1457-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1458-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1459-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\146-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1461-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1462-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1463-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1464-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1465-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1466-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1467-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1468-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1469-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\147-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1470-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1471-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1472-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1476-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1477-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1478-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1479-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\148-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1481-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1482-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1483-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1484-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1485-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1486-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1487-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1488-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1489-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\149-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1490-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1491-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1492-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\150-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1500-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1501-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1502-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1503-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\151-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\152-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1525-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\154-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1545-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1546-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1547-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1548-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1549-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\155-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1550-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1551-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1552-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1553-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1554-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1555-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1556-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1557-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1558-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1559-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1560-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1561-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1562-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1563-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1564-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1565-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1566-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1567-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1568-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1569-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1570-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1571-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1572-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1574-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1575-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1576-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1578-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1580-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1581-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1588-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1589-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\159-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1590-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1591-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1592-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1593-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1594-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1595-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1596-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1597-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1599-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\160-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1600-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1601-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1602-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1603-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1604-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1606-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1607-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1608-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1609-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1610-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1611-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1613-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1614-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1615-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1616-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1617-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1620-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1621-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1622-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1624-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1625-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1626-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1627-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1628-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1629-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1630-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1631-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1632-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1633-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1634-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1635-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1636-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1637-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1638-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1639-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1640-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1641-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1642-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1643-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1644-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1645-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1646-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1647-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1648-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1649-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1650-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1651-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1652-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1653-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1654-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1655-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1656-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1657-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1658-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1659-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1660-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1661-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1662-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1663-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1664-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1665-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1666-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1667-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1668-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1669-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1670-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1671-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1672-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1673-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1674-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1675-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1676-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1677-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1678-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1679-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1680-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1681-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1682-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1683-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1684-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1685-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1686-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1687-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1688-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1689-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1690-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1691-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1692-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1693-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1694-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1713-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1714-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1715-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1716-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1717-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1718-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1719-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1720-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1721-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1722-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1723-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1741-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1742-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1743-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1744-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1745-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1746-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1747-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1748-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1749-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1750-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1751-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1752-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1753-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1754-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1755-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1756-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1757-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1758-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1759-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1760-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1761-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1762-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1763-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1764-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1766-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1767-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1768-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1769-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1770-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1771-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1772-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1773-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1774-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1776-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1777-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1778-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1779-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1780-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1781-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1782-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1783-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1784-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1785-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1786-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1787-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1788-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1789-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1790-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1791-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1792-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1793-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1794-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1795-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1796-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1797-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1798-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1799-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1800-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1801-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1802-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1803-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1804-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1806-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1807-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1808-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1809-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1810-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1811-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1812-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1813-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1814-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1816-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1817-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1818-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1819-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1820-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1821-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1822-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1823-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1824-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1825-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1826-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1827-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1828-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1829-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1830-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1831-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1832-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1833-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1834-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1835-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1836-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1861-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1862-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1863-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1864-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1866-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1867-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1868-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1869-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1887-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1888-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1889-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1890-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1891-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1892-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1894-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1895-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1896-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1897-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1898-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1899-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1900-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1901-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1902-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1903-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1904-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1905-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1906-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1907-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1908-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1909-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1910-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1911-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1912-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1913-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1914-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1927-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1928-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1929-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1930-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1931-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1932-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1933-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1934-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1935-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1936-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1937-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1938-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1939-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1940-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1941-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1942-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1943-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1944-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1945-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1946-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1948-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1949-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1950-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1951-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1952-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1953-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1955-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1957-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1958-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1959-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1960-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1961-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1962-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1963-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1964-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1965-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1966-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1967-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1968-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1970-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1971-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1972-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1973-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1976-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1977-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1978-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1980-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1981-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1982-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1983-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1984-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1986-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1987-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1988-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1989-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1990-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1991-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1992-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1993-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1994-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1998-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\1999-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2000-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2001-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2002-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2003-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2004-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2005-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2006-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2007-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2008-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2009-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2010-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2011-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2012-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2013-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2014-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2015-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2016-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2017-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2019-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2020-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2021-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2022-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2023-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2024-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2025-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2027-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2028-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2029-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2030-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2031-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2032-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2033-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2034-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2055-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2056-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2057-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2058-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2061-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2062-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2063-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2064-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2066-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2067-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2068-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2069-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2070-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2071-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2072-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2073-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2074-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2075-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2077-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2078-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2079-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2080-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2081-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2082-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2083-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2085-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2086-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2087-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2088-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2089-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2090-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2091-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2092-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2093-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2094-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2095-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2096-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2097-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2098-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2099-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2100-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2101-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2102-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2103-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2104-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2105-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2106-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2107-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2109-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2110-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2112-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2113-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2114-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2115-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2116-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2117-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2118-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2119-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2120-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2121-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2122-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2123-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2124-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2125-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2126-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2127-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2128-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2129-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2130-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2131-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2133-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2134-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2135-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2136-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2137-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2138-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2139-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2140-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2141-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2143-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2144-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2145-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2146-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2147-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2148-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2149-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2150-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2151-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2152-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2153-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2154-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2155-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2156-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2157-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2158-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2159-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2160-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2161-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2182-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2183-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2184-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2185-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2186-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2187-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2188-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2189-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2190-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2191-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2192-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2193-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2194-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2211-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2212-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2213-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2214-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2215-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2216-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2217-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2218-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2219-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2220-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2221-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2222-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2223-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2224-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2225-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2226-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2227-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2228-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2229-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2230-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2231-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2232-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2233-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2234-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2235-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2236-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2237-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2238-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2239-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2240-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2241-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2242-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2243-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2245-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2246-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2247-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2265-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2266-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2267-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2268-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2269-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2270-a_n.wav': 'pathology',
#  '../voice_data/pathology_a/export\\2271-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2272-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2273-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2274-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2275-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2276-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2288-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2289-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2290-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2291-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2292-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2293-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2294-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2295-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2296-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2297-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2298-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2299-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2300-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2301-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2302-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2303-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2304-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2305-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2306-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2307-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2308-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2309-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2310-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2311-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2312-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2313-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2314-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2315-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2316-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2317-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2318-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2319-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2320-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2321-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2322-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2323-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2325-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2326-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2327-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2328-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2329-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2330-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2331-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2332-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2333-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2334-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2335-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2336-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2337-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2338-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2339-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2340-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2341-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2342-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2343-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2344-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2345-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2346-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2347-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2348-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2349-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2350-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2351-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2352-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2353-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2354-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2355-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2356-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2357-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2358-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2359-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2360-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2361-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2362-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2363-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2364-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2365-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2366-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2367-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2368-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2369-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2370-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2371-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2372-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2373-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2374-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2375-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2376-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2377-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2378-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2380-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2381-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2382-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2383-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2384-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2385-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2386-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2387-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2388-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2389-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2390-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2391-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2392-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2393-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2394-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2395-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2396-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2397-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2398-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2399-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2400-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2401-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2402-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2403-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2404-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2405-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2406-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2408-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2410-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2411-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2412-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2413-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2414-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2415-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2416-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2417-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2418-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2419-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2420-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2421-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2422-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2423-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2424-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2425-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2426-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2427-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2428-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2429-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2430-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2431-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2432-a_n.wav': 'healthy',
#  '../voice_data/pathology_a/export\\2433-a_n.wav': 'healthy',
#  ...}

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        self.path_list = data_path_list
        self.label = svd_dataset.get_label(data_path_list)
        self.classes=classes
        self.transform=transform
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        for idx in data_path_list:
            label_list.append(Y[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        학습에 사용할 이미지를 반환하면 된다. 이 함수는 인풋으로 index를 받는다. 
        path_list에서 index에 해당하는 이미지를 읽으면 된다. 
        이때 텐서형태의 인풋이 들어오기때문에 리스트로 변환하여준다.(굳이 안해도됨)
        반환값으로는 경로로부터 읽어들여 transform을 적용한 이미지 파일과 정답에 해당하는 클래스를 반환하면 된다.
        이때, 클래스를 숫자로 반환하여야 한다. 
        예를들면 Good: 0 Bad:1. 클래스 리스트의 index로 반환하게 구현하였다.
        """
        #mfcc = X[self.path_list[idx]].T
        #print(self.path_list[idx])
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        

        
        MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=100)
        #mfcc 400 FRAME이 되도록 패딩.
        length = 400
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        MFCCs = pad2d(MFCCs, length)
        MFCCs=MFCCs.T
        
        
        
        if self.transform:
            #print('transform')
            MFCCs=self.transform(MFCCs).type(torch.float32)# 데이터 0~1 정규화
        else:
            #print("else")
            MFCCs = torch.from_numpy(MFCCs).type(torch.float32)# 이미지 0~1 정규화
            MFCCs=MFCCs.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MFCCs, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 30 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.
train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               DATA_TRAINING_PATH,
                                               classes,
                                               transform = transforms.ToTensor()#이걸 composed로 고쳐서 전처리 하도록 수정.
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.


test_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               DATA_TEST_PATH,
                                               classes,
                                               transform = transforms.ToTensor()
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = False,) # 순서가 암기되는것을 막기위해.

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
X_train[0]
print(Y_train[0])
librosa.display.specshow(X_train[0].numpy().squeeze(0).T, sr=50000, x_axis='time')
#batch: 32 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([32, 1, 400, 100]) type: torch.FloatTensor
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(1)

# %%
print(Y_train[1])
librosa.display.specshow(X_train[1].numpy().squeeze(0).T, sr=50000, x_axis='time')
# Out:
# tensor(0)

# %%
print(Y_train[2])
librosa.display.specshow(X_train[2].numpy().squeeze(0).T, sr=50000, x_axis='time')
# Out:
# tensor(1)

# %%
print(Y_train[3])
librosa.display.specshow(X_train[3].numpy().squeeze(0).T, sr=50000, x_axis='time')
# Out:
# tensor(0)

# %%
print(Y_train[5])
librosa.display.specshow(X_train[5].numpy().squeeze(0).T, sr=50000, x_axis='time')
# Out:
# tensor(0)

# %% [markdown]
# # CNN

# %%
#6 -3. CNN 모델
# 6-2. 모델. drop out 추가.
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__() # 상속받기
        #컨볼루션 커널 정의 및 컨볼루션 레이어
        self.conv1 = nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 4,# FeatureMap 수,커널 수
            kernel_size = 3,#3x3
            padding=1,#제로패딩.크기 유지
        )
        #결과로 1개의 평면이 -> 8개의 피처맵으로.
        self.conv2 = nn.Conv2d(
            in_channels = 4,# featureMap 8개
            out_channels = 8,# FeatureMap 수,커널 수
            kernel_size = 3,#3x3
            padding=1,#제로패딩.크기 유지
        )
        #8개의 피처맵 -> 16개 피처맵
        self.pool = nn.MaxPool2d(
            kernel_size = 4,
            stride = 2
        )
        #이미지의 크기가 4분의 1줄어든다.
        
        #Fully-connected layer
        self.fc1 = nn.Linear(98*23*8,500)# pooling두번해서 125*3
        self.fc2 = nn.Linear(500,250)
        self.fc3 = nn.Linear(250,100)
        self.fc4 = nn.Linear(100,1)#1개 클래스
    
    def forward(self,x):
        x = self.conv1(x)#flatten 없어도 된다.
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = x.view(-1,98*23*8)#피처맵을 flatten
        x = self.fc1(x)
        x = F.relu(x)

        x = self.fc2(x)
        x = F.relu(x)
        
        x = self.fc3(x)
        x = F.relu(x)
        
        x = self.fc4(x)
        x = x.squeeze()
        #x = F.log_softmax(x,dim=1)#2개 클래스
        #print(x)
        return x

# %%
#7. Optimizer, Objective Function
model = Net().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
criterion = nn.BCEWithLogitsLoss()
#원핫 인코딩값의 loss는 crossEntropyLoss로 비교
print(model)
# Out:
# Net(
#   (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=18032, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=250, bias=True)
#   (fc3): Linear(in_features=250, out_features=100, bias=True)
#   (fc4): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.type(torch.FloatTensor).to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.

# %%
#9. 학습 진행하며, test 데이터로 모델 성능확인
def evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    threshold=torch.FloatTensor([0.5]).cuda()
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.type(torch.FloatTensor).to(DEVICE)
            output = model(image)
            #print(output)
            #label.type(torch.FloatTensor).to(DEVICE)
            test_loss += criterion(output, label).item()
            prediction = output >= threshold
            #prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            #print(output.max(1,keepdim=True))
            #print(prediction)
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        test_loss /= len(test_loader.dataset)
        test_accuracy = 100. * correct / len(test_loader.dataset)
        return test_loss,test_accuracy

# %%
#10. 학습 및 평가.
for Epoch in range(1,EPOCHS+1):
    train(model,train_loader,optimizer,log_interval=200)
    test_loss,test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH:{}], \tTest Loss:{:.4f} \tTest Accuracy: {:.2f} %\n".
          format(Epoch,test_loss,test_accuracy))
# Out:
# [EPOCH:1], 	Test Loss:0.0223 	Test Accuracy: 56.79 %
#
#
# [EPOCH:2], 	Test Loss:0.0214 	Test Accuracy: 47.19 %
#
#
# [EPOCH:3], 	Test Loss:0.0217 	Test Accuracy: 56.32 %
#
#
# [EPOCH:4], 	Test Loss:0.0213 	Test Accuracy: 58.20 %
#
#
# [EPOCH:5], 	Test Loss:0.0215 	Test Accuracy: 58.55 %
#
#
# [EPOCH:6], 	Test Loss:0.0215 	Test Accuracy: 59.60 %
#
#
# [EPOCH:7], 	Test Loss:0.0211 	Test Accuracy: 56.09 %
#
#
# [EPOCH:8], 	Test Loss:0.0221 	Test Accuracy: 57.38 %
#
#
# [EPOCH:9], 	Test Loss:0.0227 	Test Accuracy: 59.72 %
#
#
# [EPOCH:10], 	Test Loss:0.0239 	Test Accuracy: 57.14 %
#
#
# [EPOCH:11], 	Test Loss:0.0329 	Test Accuracy: 59.72 %
#
#
# [EPOCH:12], 	Test Loss:0.0305 	Test Accuracy: 58.08 %
#
#
# [EPOCH:13], 	Test Loss:0.0434 	Test Accuracy: 52.22 %
#
#
# [EPOCH:14], 	Test Loss:0.0362 	Test Accuracy: 57.38 %
#
#
# [EPOCH:15], 	Test Loss:0.0512 	Test Accuracy: 56.44 %
#
#
# [EPOCH:16], 	Test Loss:0.0496 	Test Accuracy: 55.97 %
#
#
# [EPOCH:17], 	Test Loss:0.0496 	Test Accuracy: 54.68 %
#
#
# [EPOCH:18], 	Test Loss:0.0525 	Test Accuracy: 56.09 %
#
#
# [EPOCH:19], 	Test Loss:0.0631 	Test Accuracy: 55.97 %
#
#
# [EPOCH:20], 	Test Loss:0.0809 	Test Accuracy: 56.91 %
#
#
# [EPOCH:21], 	Test Loss:0.0858 	Test Accuracy: 57.26 %
#
#
# [EPOCH:22], 	Test Loss:0.0982 	Test Accuracy: 57.38 %
#
#
# [EPOCH:23], 	Test Loss:0.1051 	Test Accuracy: 57.03 %
#
#
# [EPOCH:24], 	Test Loss:0.1090 	Test Accuracy: 57.14 %
#
#
# [EPOCH:25], 	Test Loss:0.1129 	Test Accuracy: 57.14 %
#
#
# [EPOCH:26], 	Test Loss:0.1169 	Test Accuracy: 57.03 %
#
#
# [EPOCH:27], 	Test Loss:0.1197 	Test Accuracy: 57.03 %
#
#
# [EPOCH:28], 	Test Loss:0.1221 	Test Accuracy: 57.14 %
#
#
# [EPOCH:29], 	Test Loss:0.1242 	Test Accuracy: 57.03 %
#
#
# [EPOCH:30], 	Test Loss:0.1260 	Test Accuracy: 57.26 %

# %%
#크기 알아보기
m = nn.MaxPool2d(4, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 400, 100)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 400, 100])
# torch.Size([32, 1, 199, 49])
# torch.Size([32, 1, 98, 23])
