# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.9.0  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../voice_data/disorder/export/'):
    sig, sr = librosa.load('../voice_data/disorder/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
    pathology.append(MFCCs)
    

#Healthy data
for audio_path in os.listdir('../voice_data/healthy/export/'):
    sig, sr = librosa.load('../voice_data/healthy/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
    healthy.append(MFCCs)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  852
# healthy data 수 :  632
# 가장 긴 path sample : 317967
# 가장 긴 healthy sample : 207017

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 6.35934 초
# 4.14034 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
pd.DataFrame(healthy[0].T,columns=headers)
# Out:
#           mfcc1       mfcc2      mfcc3      mfcc4      mfcc5      mfcc6  \
# 0   -664.554626   42.987347  19.686474  17.893703   5.439661  15.109371
# 1   -661.093262   49.232384  25.329205  19.615353   3.622412  11.143848
# 2   -648.416748   59.700802  29.251112  24.551905   5.502740   8.653681
# 3   -641.470398   64.023300  33.875042  33.504829  10.996720  10.126940
# 4   -640.913208   65.740158  37.212051  34.325729  11.286431  10.338777
# ..          ...         ...        ...        ...        ...        ...
# 321 -583.004944  103.957191  27.952499  24.078373  17.805784  23.063253
# 322 -586.246582  101.427971  23.151981  18.545017  17.543690  25.053160
# 323 -583.195374  100.612839  25.392967  22.381254  10.108490  20.151932
# 324 -591.548950   96.951584  27.558010  26.244709   9.731691  15.010460
# 325 -598.023804   90.819595  32.691036  40.272263  18.734198  16.876379
#
#          mfcc7      mfcc8      mfcc9     mfcc10     mfcc11     mfcc12  \
# 0    25.698231  15.588242  12.777233  12.864212   5.049675   9.790856
# 1    20.681862  11.148173  10.953643  11.828960   5.742882  12.660656
# 2    17.301186   9.595350  11.883837  13.102000   3.480697   4.985497
# 3    20.400213  15.367504  13.606176  16.794329   5.960305   6.227929
# 4    17.450600  13.628424  13.935904  19.616440   8.325340  10.149255
# ..         ...        ...        ...        ...        ...        ...
# 321   9.110998   1.523905   4.881299  12.015347  11.527961  -1.548047
# 322  12.090671   5.663185  11.320033  20.145441  22.497692  10.250481
# 323  11.551888   2.375783   9.401663  18.179150  18.509977   5.336875
# 324  17.244743   8.297909  10.048749  12.094749   5.907953   2.231759
# 325  19.807566   8.091202   6.432929  13.209663   8.640621   4.569102
#
#         mfcc13
# 0    18.775772
# 1    19.052067
# 2     9.246387
# 3    16.133617
# 4    23.181538
# ..         ...
# 321   1.509847
# 322   8.224429
# 323   2.377341
# 324   2.409741
# 325  10.659433
#
# [326 rows x 13 columns]

# %%
healthy[0].shape[1]
# Out:
# 326

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기
# - pathology : 852 ,  healthy 수 :  632  총 1484
# - train :  1187 , test : 297

# %%
#1. train, test 나누기
import os
import random #데이터 shuffle 사용
from glob import glob


pathology = glob('../voice_data/disorder/export/*.wav')
healthy = glob('../voice_data/healthy/export/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))


X = pathology+healthy # mfcc 데이터 합
print("총 데이터수 : ",len(X))
Y = {} # 라벨
for idx,x in enumerate(X):
    if idx<852:
        Y[x]="pathology"
    else:
        Y[x]="healthy"

#train 1187   test: 297
random.shuffle(X)
DATA_TRAINING_PATH = X[:1186]
DATA_TEST_PATH = X[1187:]

print("훈련 셋 : ",len(DATA_TRAINING_PATH))
print("테스트 셋 : ",len(DATA_TEST_PATH))
# Out:
# Pathology :  852
# Healthy:  632
# 총 데이터수 :  1484
# 훈련 셋 :  1186
# 테스트 셋 :  297

# %%
Y
# Out:
# {'../voice_data/disorder/export\\101-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1037-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1038-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1039-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1040-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1041-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1042-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1043-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1044-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1045-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1046-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1047-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1048-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1049-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\105-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1050-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1051-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1052-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1053-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1054-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1055-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1056-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1057-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1058-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\106-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\107-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\108-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1083-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1084-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1085-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1086-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1087-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1088-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1089-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\109-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1090-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\110-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\111-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1113-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1115-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1116-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1117-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1118-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1119-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1120-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1156-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1157-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1158-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1159-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1160-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1161-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1162-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1163-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1164-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1165-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1166-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\118-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1186-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1187-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1188-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1189-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\119-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1190-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1191-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1192-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1193-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1194-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1195-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1196-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1197-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1198-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1199-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\120-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1200-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1201-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1202-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1203-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1204-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1205-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1206-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1217-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1218-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1219-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1220-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1221-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1222-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1223-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1224-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1225-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1227-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1228-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1229-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1230-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1231-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1232-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1233-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1234-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1235-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1237-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1238-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1239-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1240-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1241-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1242-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1243-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1244-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1245-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1246-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1247-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1248-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1249-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1250-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1251-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1252-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1253-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1254-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1255-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1256-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1257-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1258-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1259-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1260-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1261-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1262-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1263-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1264-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1265-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1266-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1267-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1268-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1269-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\127-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1270-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1271-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1272-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1273-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1274-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1275-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1277-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1279-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\128-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1280-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1281-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1282-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1283-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1284-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1285-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1286-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1289-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\129-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1290-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1291-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1292-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1293-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1294-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1295-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1296-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1297-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1298-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1299-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\130-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1300-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1301-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1302-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1303-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1304-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1305-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1306-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1307-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1309-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\131-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1310-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1311-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1312-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1313-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1314-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1315-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1316-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1317-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1318-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1319-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1321-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1322-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1323-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1324-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1325-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1326-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1327-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1328-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1329-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1330-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1331-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1332-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1333-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1334-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1335-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1337-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1338-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1339-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1340-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1341-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1376-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1378-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1379-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\138-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1380-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1381-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1382-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1383-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1384-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1385-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1386-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1387-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1388-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1389-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\139-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1390-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1391-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1392-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1393-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1394-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1395-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1396-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1397-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1398-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1399-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\140-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1400-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1401-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1402-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1403-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1404-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1405-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1406-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1407-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1408-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1409-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\141-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1410-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1411-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1412-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1414-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1415-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1416-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1417-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1418-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\142-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1421-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1422-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1424-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1425-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1426-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1428-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1429-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\143-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1430-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1431-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1432-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1433-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1434-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1435-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1436-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1437-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1438-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1439-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\144-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1440-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1441-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1442-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1443-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1444-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1445-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1446-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1447-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1448-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1449-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1450-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1451-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1452-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1453-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1454-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1455-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1456-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1457-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1458-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1459-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\146-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1461-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1462-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1463-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1464-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1465-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1466-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1467-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1468-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1469-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\147-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1470-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1471-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1472-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1476-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1477-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1478-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1479-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\148-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1481-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1482-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1483-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1484-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1485-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1486-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1487-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1488-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1489-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\149-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1490-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1491-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1492-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\150-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1500-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1501-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1502-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1503-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\151-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\152-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1525-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\154-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1545-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1546-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1547-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1548-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1549-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\155-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1550-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1551-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1552-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1553-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1554-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1555-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1556-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1557-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1558-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1559-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1560-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1561-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1562-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1563-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1564-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1565-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1566-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1567-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1568-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1569-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1570-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1571-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1572-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1574-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1575-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1576-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1578-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1580-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1581-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1588-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1589-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\159-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1590-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1591-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1592-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1593-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1594-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1595-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1596-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1597-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1599-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\160-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1600-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1601-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1602-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1603-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1604-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1606-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1607-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1608-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1609-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1610-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1611-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1613-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1614-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1615-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1616-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1617-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1620-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1621-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1622-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1624-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1625-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1626-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1627-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1628-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1629-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1630-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1631-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1632-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1633-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1634-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1635-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1636-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1637-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1638-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1639-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1640-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1641-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1642-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1643-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1644-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1645-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1646-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1647-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1648-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1649-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1650-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1651-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1652-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1653-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1654-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1655-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1656-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1657-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1658-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1659-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1660-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1661-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1662-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1663-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1664-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1665-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1666-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1667-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1668-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1670-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1671-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1672-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1673-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1674-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1675-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1676-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1677-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1678-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1679-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1680-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1681-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1682-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1683-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1684-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1685-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1686-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1687-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1688-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1689-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1690-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1691-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1692-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1693-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1694-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1713-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1714-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1715-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1716-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1717-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1718-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1719-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1720-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1721-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1722-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1723-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1741-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1742-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1743-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1744-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1745-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1746-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1747-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1748-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1749-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1750-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1751-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1752-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1753-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1754-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1755-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1756-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1757-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1758-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1759-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1760-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1761-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1762-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1763-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1764-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1766-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1767-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1768-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1769-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1770-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1771-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1772-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1773-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1774-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1776-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1777-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1778-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1779-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1780-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1781-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1782-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1783-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1784-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1785-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1786-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1787-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1788-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1789-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1790-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1791-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1792-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1793-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1794-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1795-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1796-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1797-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1798-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1799-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1800-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1801-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1802-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1803-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1804-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1806-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1807-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1808-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1809-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1810-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1811-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1812-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1813-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1814-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1816-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1817-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1818-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1819-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1820-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1821-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1822-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1823-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1824-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1825-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1826-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1827-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1828-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1829-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1830-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1831-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1832-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1833-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1834-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1835-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1836-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1861-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1862-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1863-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1864-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1866-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1867-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1868-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1869-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1887-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1888-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1889-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1890-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1892-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1894-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1895-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1901-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1902-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1908-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1909-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1913-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1914-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1929-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1930-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1931-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1932-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1938-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1942-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1944-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1945-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1946-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1949-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1951-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1955-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1960-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1961-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1970-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1972-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1991-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1993-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1994-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\1998-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2004-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2011-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2022-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2029-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2030-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2031-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2061-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2064-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2077-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2078-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2083-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2088-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2109-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2120-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2131-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2136-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2150-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2151-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2159-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2189-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2190-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2227-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2234-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2243-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2246-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2268-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2271-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2296-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2304-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2311-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2320-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2326-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2334-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2351-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2352-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2355-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2360-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2361-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2362-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2363-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2366-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2373-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2383-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2384-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2395-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2397-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2412-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2413-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2453-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2455-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2458-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2469-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2477-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2482-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2485-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2490-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2491-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2503-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2512-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2536-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2548-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2558-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2564-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\2599-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\348-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\349-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\350-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\351-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\352-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\355-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\356-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\357-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\358-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\359-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\360-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\362-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\363-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\364-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\365-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\366-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\367-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\368-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\445-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\446-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\447-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\448-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\449-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\450-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\451-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\491-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\492-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\493-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\495-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\503-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\504-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\562-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\563-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\564-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\565-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\567-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\568-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\612-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\627-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\628-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\629-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\630-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\631-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\632-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\633-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\634-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\665-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\666-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\667-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\668-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\669-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\670-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\671-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\672-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\673-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\674-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\692-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\693-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\712-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\714-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\715-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\716-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\718-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\719-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\720-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\721-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\722-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\723-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\724-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\725-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\726-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\727-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\728-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\729-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\730-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\731-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\741-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\742-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\814-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\815-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\816-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\817-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\818-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\819-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\820-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\821-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\822-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\823-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\824-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\825-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\826-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\827-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\828-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\829-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\830-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\844-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\845-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\846-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\847-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\848-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\849-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\850-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\851-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\853-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\854-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\855-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\857-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\859-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\863-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\864-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\868-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\869-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\870-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\871-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\872-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\873-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\874-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\875-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\876-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\877-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\878-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\879-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\880-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\881-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\883-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\884-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\885-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\886-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\887-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\888-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\889-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\890-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\891-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\892-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\893-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\894-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\895-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\896-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\897-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\898-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\899-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\900-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\901-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\902-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\903-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\904-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\907-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\908-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\909-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\910-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\911-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\912-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\913-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\914-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\915-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\916-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\917-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\918-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\919-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\920-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\921-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\922-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\923-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\924-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\925-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\926-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\927-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\928-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\929-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\930-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\931-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\932-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\933-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\934-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\935-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\936-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\937-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\938-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\939-phrase.wav': 'pathology',
#  '../voice_data/disorder/export\\940-phrase.wav': 'pathology',
#  '../voice_data/healthy/export\\1-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\10-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\100-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1000-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1002-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1003-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1004-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1005-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1006-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1007-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1008-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1009-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1010-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1011-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1012-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1013-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1014-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1015-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1016-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1017-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1018-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1019-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\102-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1020-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1021-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1022-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1023-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1024-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1025-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1026-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1027-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1028-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1029-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\103-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1030-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1031-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1032-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1033-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1034-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1035-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1036-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\104-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1059-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1060-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1061-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1062-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1063-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1064-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1065-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1066-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1067-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1068-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1069-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1070-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1071-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1072-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1073-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1074-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1075-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1076-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1077-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1078-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1079-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1080-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1081-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1082-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1091-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1092-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1093-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1094-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1095-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1096-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1097-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1098-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1099-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\11-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1100-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1101-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1102-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1103-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1104-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1105-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1106-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1107-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1108-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1109-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1110-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1111-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1112-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\112-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1121-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1122-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1123-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1124-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1125-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1126-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1127-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1128-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1129-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\113-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1130-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1131-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1132-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1133-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1134-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1135-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1136-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1137-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1138-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1139-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\114-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1140-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1141-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1142-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1143-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1144-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1145-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1146-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1147-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1148-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1149-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\115-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1150-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1151-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1153-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1155-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\116-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1167-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1168-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1169-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\117-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1170-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1171-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1172-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1173-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1174-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1175-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1176-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1177-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1178-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1179-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1180-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1181-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1182-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1183-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1184-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\1185-phrase.wav': 'healthy',
#  '../voice_data/healthy/export\\12-phrase.wav': 'healthy',
#  ...}

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        self.path_list = data_path_list
        self.label = svd_dataset.get_label(data_path_list)
        self.classes=classes
        self.transform=transform
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        for idx in data_path_list:
            label_list.append(Y[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        학습에 사용할 이미지를 반환하면 된다. 이 함수는 인풋으로 index를 받는다. 
        path_list에서 index에 해당하는 이미지를 읽으면 된다. 
        이때 텐서형태의 인풋이 들어오기때문에 리스트로 변환하여준다.(굳이 안해도됨)
        반환값으로는 경로로부터 읽어들여 transform을 적용한 이미지 파일과 정답에 해당하는 클래스를 반환하면 된다.
        이때, 클래스를 숫자로 반환하여야 한다. 
        예를들면 Good: 0 Bad:1. 클래스 리스트의 index로 반환하게 구현하였다.
        """
        #mfcc = X[self.path_list[idx]].T
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        #mfcc 500 FRAME이 되도록 패딩.
        length = 156400 #100 낮춤.
        if length < len(sig):
            data = sig[:length]
        elif length > len(sig):
            data = np.pad(sig, (0, length - len(sig)), "constant")
        
        MFCCs = librosa.feature.mfcc(data, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
        MFCCs=MFCCs.T
        
        
        
        if self.transform:
            #print('transform')
            MFCCs=self.transform(MFCCs).type(torch.float32)# 데이터 0~1 정규화
        else:
            #print("else")
            MFCCs = torch.from_numpy(MFCCs).type(torch.float32)# 이미지 0~1 정규화
            MFCCs=MFCCs.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MFCCs, self.classes.index(self.label[idx])

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        self.path_list = data_path_list
        self.label = svd_dataset.get_label(data_path_list)
        self.classes=classes
        self.transform=transform
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        for idx in data_path_list:
            label_list.append(Y[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        학습에 사용할 이미지를 반환하면 된다. 이 함수는 인풋으로 index를 받는다. 
        path_list에서 index에 해당하는 이미지를 읽으면 된다. 
        이때 텐서형태의 인풋이 들어오기때문에 리스트로 변환하여준다.(굳이 안해도됨)
        반환값으로는 경로로부터 읽어들여 transform을 적용한 이미지 파일과 정답에 해당하는 클래스를 반환하면 된다.
        이때, 클래스를 숫자로 반환하여야 한다. 
        예를들면 Good: 0 Bad:1. 클래스 리스트의 index로 반환하게 구현하였다.
        """
        #mfcc = X[self.path_list[idx]].T
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        

        
        MFCCs = librosa.feature.mfcc(sig, sr, win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
        #mfcc 500 FRAME이 되도록 패딩.
        length = 500
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        MFCCs = pad2d(MFCCs, 500)
        MFCCs=MFCCs.T
        
        
        
        if self.transform:
            #print('transform')
            MFCCs=self.transform(MFCCs).type(torch.float32)# 데이터 0~1 정규화
        else:
            #print("else")
            MFCCs = torch.from_numpy(MFCCs).type(torch.float32)# 이미지 0~1 정규화
            MFCCs=MFCCs.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MFCCs, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 10 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.
train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               DATA_TRAINING_PATH,
                                               classes,
                                               transform = transforms.ToTensor()#이걸 composed로 고쳐서 전처리 하도록 수정.
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.


test_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               DATA_TEST_PATH,
                                               classes,
                                               transform = transforms.ToTensor()
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = False,) # 순서가 암기되는것을 막기위해.

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
X_train[0]
print(Y_train[0])
librosa.display.specshow(X_train[0].numpy().squeeze(0).T, sr=50000, x_axis='time')
#batch: 32 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([32, 1, 500, 13]) type: torch.FloatTensor
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(1)

# %%
print(Y_train[1])
librosa.display.specshow(X_train[1].numpy().squeeze(0).T, sr=50000, x_axis='time')
# Out:
# tensor(0)

# %%
print(Y_train[2])
librosa.display.specshow(X_train[2].numpy().squeeze(0).T, sr=50000, x_axis='time')
# Out:
# tensor(0)

# %% [markdown]
# # CNN

# %%
#6 -3. CNN 모델
# 6-2. 모델. drop out 추가.
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__() # 상속받기
        #컨볼루션 커널 정의 및 컨볼루션 레이어
        self.conv1 = nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 4,# FeatureMap 수,커널 수
            kernel_size = 3,#3x3
            padding=1,#제로패딩.크기 유지
        )
        #결과로 1개의 평면이 -> 8개의 피처맵으로.
        self.conv2 = nn.Conv2d(
            in_channels = 4,# featureMap 8개
            out_channels = 8,# FeatureMap 수,커널 수
            kernel_size = 3,#3x3
            padding=1,#제로패딩.크기 유지
        )
        #8개의 피처맵 -> 16개 피처맵
        self.pool = nn.MaxPool2d(
            kernel_size = 2,
            stride = 2
        )
        #이미지의 크기가 4분의 1줄어든다.
        
        #Fully-connected layer
        self.fc1 = nn.Linear(125*3*8,1500)# pooling두번해서 125*3
        self.fc2 = nn.Linear(1500,750)
        self.fc3 = nn.Linear(750,325)
        self.fc4 = nn.Linear(325,2)#2개 클래스
    
    def forward(self,x):
        x = self.conv1(x)#flatten 없어도 된다.
        x = F.relu(x)
        x = self.pool(x)
        
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = x.view(-1,125*3*8)#피처맵을 flatten
        x = self.fc1(x)
        x = F.relu(x)

        x = self.fc2(x)
        x = F.relu(x)
        
        x = self.fc3(x)
        x = F.relu(x)
        
        x = self.fc4(x)
        x = F.log_softmax(x,dim=1)#2개 클래스
        return x

# %%
#7. Optimizer, Objective Function
model = Net().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
criterion = nn.CrossEntropyLoss()
#원핫 인코딩값의 loss는 crossEntropyLoss로 비교
print(model)
# Out:
# Net(
#   (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=3000, out_features=1500, bias=True)
#   (fc2): Linear(in_features=1500, out_features=750, bias=True)
#   (fc3): Linear(in_features=750, out_features=325, bias=True)
#   (fc4): Linear(in_features=325, out_features=2, bias=True)
# )

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.

# %%
#9. 학습 진행하며, test 데이터로 모델 성능확인
def evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            #print(output.max(1,keepdim=True))
            #print(prediction)
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        test_loss /= len(test_loader.dataset)
        test_accuracy = 100. * correct / len(test_loader.dataset)
        return test_loss,test_accuracy

# %%
#10. 학습 및 평가.
for Epoch in range(1,EPOCHS+1):
    train(model,train_loader,optimizer,log_interval=200)
    test_loss,test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH:{}], \tTest Loss:{:.4f} \tTest Accuracy: {:.2f} %\n".
          format(Epoch,test_loss,test_accuracy))
# Out:
# C:\Users\dlwhd\miniconda3\envs\localtorch\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [EPOCH:1], 	Test Loss:0.0203 	Test Accuracy: 72.73 %
#
#
# [EPOCH:2], 	Test Loss:0.0197 	Test Accuracy: 71.04 %
#
#
# [EPOCH:3], 	Test Loss:0.0225 	Test Accuracy: 66.67 %
#
#
# [EPOCH:4], 	Test Loss:0.0180 	Test Accuracy: 71.38 %
#
#
# [EPOCH:5], 	Test Loss:0.0211 	Test Accuracy: 67.34 %

# %%
#크기 알아보기
m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 500, 13])
# torch.Size([32, 1, 250, 6])
# torch.Size([32, 1, 125, 3])
