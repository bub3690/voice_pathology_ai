# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5
# - https://quokkas.tistory.com/37 : early stopping
# - https://continuous-development.tistory.com/166 : stratified kfold
# - https://deep-learning-study.tistory.com/476 fiter 시각화
# - https://wyatt37.tistory.com/10 : random over sampling

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp38-cp38-win_amd64.whl (7.2 MB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp38-cp38-win_amd64.whl (52 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.29.1 kiwisolver-1.3.2 matplotlib-3.5.1

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys

p = os.path.abspath('../..') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../../../voice_data/fusion/pathology/phrase/'):
    sig, sr = librosa.load('../../../voice_data/fusion/pathology/phrase/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    pathology.append(log_spectrogram)
    

#Healthy data
for audio_path in os.listdir('../../../voice_data/fusion/healthy/phrase/'):
    sig, sr = librosa.load('../../../voice_data/fusion/healthy/phrase/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    stft = librosa.stft(sig,win_length=win_length ,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    healthy.append(log_spectrogram)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  1193
# healthy data 수 :  634
# 가장 긴 path sample : 318596
# 가장 긴 healthy sample : 207017

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 6.37192 초
# 4.14034 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
#headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
#pd.DataFrame(healthy[0].T,columns=headers)

print(healthy[0])
# Out:
# [[ -8.41268    -7.705823   -9.314145  ...  -3.2875543  -9.481657
#   -14.334839 ]
#  [ -9.690009   -7.0746346  -5.761348  ...  -5.3182898  -6.9227552
#    -9.569631 ]
#  [-13.675301  -12.412195  -29.27149   ... -16.410295  -20.021296
#   -10.153454 ]
#  ...
#  [-43.8044    -43.8044    -43.8044    ... -43.8044    -43.8044
#   -43.8044   ]
#  [-43.8044    -43.8044    -43.8044    ... -43.8044    -43.8044
#   -43.8044   ]
#  [-43.8044    -43.8044    -43.8044    ... -43.8044    -43.8044
#   -43.8044   ]]

# %%
print(healthy[0].shape) #1번 주파수 축, 2번 시간축.
print(healthy[1].shape)
# Out:
# (626, 326)
# (626, 338)

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기 - Stratified KFold
#
# - pathology : 1194 / healthy : 634 / 총 1828
# - k = 5

# %% [markdown]
# ## 1. test/ train 나누기

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from imbalanced-learn->imblearn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\user\anaconda3\envs\local_torch\lib\site-packages (from imbalanced-learn->imblearn) (1.8.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.9.0 imblearn-0.0

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('../../../voice_data/fusion/pathology/phrase/*.wav')
healthy = glob('../../../voice_data/fusion/healthy/phrase/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))

X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1193:
        Y.append("pathology")
    else:
        Y.append("healthy")

X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1193
# Healthy:  634
# 총 데이터수 :  1827
# ---
# 훈련 셋 :  1461 Counter({'pathology': 954, 'healthy': 507})
# 테스트 셋 :  366 Counter({'pathology': 239, 'healthy': 127})
# ---

# %% [markdown]
# ## 2. stratified k-fold

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 763}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 190}

# %% [markdown]
# ## 3. random over sampling

# %%
#2. random over sampling
for i in range(5):
    X_temp = np.array(X_train_list[i]).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
    #Y = np.array(Y)
    ros = RandomOverSampler(random_state = 123)
    X_res,Y_res = ros.fit_resample(X_temp,Y_train_list[i])
    
    print("\n fold{} ".format(i))
    print('before dataset shape {}'.format(Counter(Y_train_list[i])) )
    print('Resampled dataset shape {}'.format(Counter(Y_res)) )
    
    #원래대로 돌리기
    X_res=X_res.reshape(1, -1)
    X_train_list[i]=X_res[0].tolist()
    Y_train_list[i]=Y_res
# Out:
#  fold0
# before dataset shape Counter({'pathology': 763, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold1
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold2
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold3
# before dataset shape Counter({'pathology': 763, 'healthy': 406})
# Resampled dataset shape Counter({'pathology': 763, 'healthy': 763})
#
#  fold4
# before dataset shape Counter({'pathology': 764, 'healthy': 405})
# Resampled dataset shape Counter({'pathology': 764, 'healthy': 764})

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.(여기서는 500frame)
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
    
       
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. mfcc를 300프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        kind=self.path_list[idx].split('/')[-2]
        number=self.path_list[idx].split('\\')[-1].split('-')[0]
        path_a="../../../voice_data/fusion/"+kind+"/a\\"+number+"-a_n.wav"
        path_i="../../../voice_data/fusion/"+kind+"/i\\"+number+"-i_n.wav"
        path_u="../../../voice_data/fusion/"+kind+"/u\\"+number+"-u_n.wav"

        sig_phrase, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        sig_a, sr = librosa.load(path_a, sr=50000)# 논문에서 f_s = 50 000HZ
        sig_i, sr = librosa.load(path_i, sr=50000)# 논문에서 f_s = 50 000HZ
        sig_u, sr = librosa.load(path_u, sr=50000)# 논문에서 f_s = 50 000HZ        

        
        stft_phrase = librosa.stft(sig_phrase, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        stft_a = librosa.stft(sig_a, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        stft_i = librosa.stft(sig_i, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        stft_u = librosa.stft(sig_u, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        #stft 300 FRAME이 되도록 패딩.
        length = 300

        magnitude_phrase = np.abs(stft_phrase)
        magnitude_a = np.abs(stft_a)
        magnitude_i = np.abs(stft_i)
        magnitude_u = np.abs(stft_u)
        
        log_spectrogram_phrase = librosa.amplitude_to_db(magnitude_phrase)
        log_spectrogram_a = librosa.amplitude_to_db(magnitude_a)
        log_spectrogram_i = librosa.amplitude_to_db(magnitude_i)
        log_spectrogram_u = librosa.amplitude_to_db(magnitude_u)
        
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram_phrase = pad2d(log_spectrogram_phrase, length)
        log_spectrogram_a = pad2d(log_spectrogram_a, length)
        log_spectrogram_i = pad2d(log_spectrogram_i, length)
        log_spectrogram_u = pad2d(log_spectrogram_u, length)        
        
        
        
        if self.transform:
            #print('transform')
            log_spectrogram_phrase=self.transform(log_spectrogram_phrase).type(torch.float32)# 데이터 타입 변화
            log_spectrogram_a=self.transform(log_spectrogram_a).type(torch.float32)# 데이터 타입 변화
            log_spectrogram_i=self.transform(log_spectrogram_i).type(torch.float32)# 데이터 타입 변화
            log_spectrogram_u=self.transform(log_spectrogram_u).type(torch.float32)# 데이터 타입 변화 
            
            log_spectrogram_phrase=torch.stack([log_spectrogram_phrase,log_spectrogram_phrase,log_spectrogram_phrase])# 3채널로 복사.
            log_spectrogram_a=torch.stack([log_spectrogram_a,log_spectrogram_a,log_spectrogram_a])# 3채널로 복사.
            log_spectrogram_i=torch.stack([log_spectrogram_i,log_spectrogram_i,log_spectrogram_i])# 3채널로 복사.
            log_spectrogram_u=torch.stack([log_spectrogram_u,log_spectrogram_u,log_spectrogram_u])# 3채널로 복사.
            
            log_spectrogram_phrase = log_spectrogram_phrase.squeeze(dim=1)
            log_spectrogram_a = log_spectrogram_a.squeeze(dim=1)
            log_spectrogram_i = log_spectrogram_i.squeeze(dim=1)
            log_spectrogram_u = log_spectrogram_u.squeeze(dim=1)
        else:
            ## 사용안하는 곳##########
            #print("else")
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return log_spectrogram_phrase,log_spectrogram_a,log_spectrogram_i,log_spectrogram_u,self.classes.index(self.label[idx])

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. mfcc를 300프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        kind=self.path_list[idx].split('/')[-2]
        number=self.path_list[idx].split('\\')[-1].split('-')[0]
        path_a="../../../voice_data/fusion/"+kind+"/a\\"+number+"-a_n.wav"
        path_i="../../../voice_data/fusion/"+kind+"/i\\"+number+"-i_n.wav"
        path_u="../../../voice_data/fusion/"+kind+"/u\\"+number+"-u_n.wav"

        sig_phrase, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        sig_a, sr = librosa.load(path_a, sr=50000)# 논문에서 f_s = 50 000HZ
        sig_i, sr = librosa.load(path_i, sr=50000)# 논문에서 f_s = 50 000HZ
        sig_u, sr = librosa.load(path_u, sr=50000)# 논문에서 f_s = 50 000HZ        

        
        stft_phrase = librosa.stft(sig_phrase, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        stft_a = librosa.stft(sig_a, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        stft_i = librosa.stft(sig_i, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        stft_u = librosa.stft(sig_u, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        #stft 300 FRAME이 되도록 패딩.
        length = 300

        magnitude_phrase = np.abs(stft_phrase)
        magnitude_a = np.abs(stft_a)
        magnitude_i = np.abs(stft_i)
        magnitude_u = np.abs(stft_u)
        
        log_spectrogram_phrase = librosa.amplitude_to_db(magnitude_phrase)
        log_spectrogram_a = librosa.amplitude_to_db(magnitude_a)
        log_spectrogram_i = librosa.amplitude_to_db(magnitude_i)
        log_spectrogram_u = librosa.amplitude_to_db(magnitude_u)
        
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram_phrase = pad2d(log_spectrogram_phrase, length)
        log_spectrogram_a = pad2d(log_spectrogram_a, length)
        log_spectrogram_i = pad2d(log_spectrogram_i, length)
        log_spectrogram_u = pad2d(log_spectrogram_u, length)        
        
        
        
        if self.transform:
            #print('transform')
            log_spectrogram_phrase=self.transform(log_spectrogram_phrase).type(torch.float32)# 데이터 타입 변화
            log_spectrogram_a=self.transform(log_spectrogram_a).type(torch.float32)# 데이터 타입 변화
            log_spectrogram_i=self.transform(log_spectrogram_i).type(torch.float32)# 데이터 타입 변화
            log_spectrogram_u=self.transform(log_spectrogram_u).type(torch.float32)# 데이터 타입 변화 

            log_spectrogram_phrase=torch.stack([log_spectrogram_phrase,log_spectrogram_phrase,log_spectrogram_phrase])# 3채널로 복사.
            log_spectrogram_a=torch.stack([log_spectrogram_a,log_spectrogram_a,log_spectrogram_a])# 3채널로 복사.
            log_spectrogram_i=torch.stack([log_spectrogram_i,log_spectrogram_i,log_spectrogram_i])# 3채널로 복사.
            log_spectrogram_u=torch.stack([log_spectrogram_u,log_spectrogram_u,log_spectrogram_u])# 3채널로 복사.
            
            log_spectrogram_phrase = log_spectrogram_phrase.squeeze(dim=1)
            log_spectrogram_a = log_spectrogram_a.squeeze(dim=1)
            log_spectrogram_i = log_spectrogram_i.squeeze(dim=1)
            log_spectrogram_u = log_spectrogram_u.squeeze(dim=1)
        else:
            ## 사용안하는 곳##########
            #print("else")
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return log_spectrogram_phrase,log_spectrogram_a,log_spectrogram_i,log_spectrogram_u,self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 40 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인


train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                               classes,
                                               transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               transform = transforms.ToTensor(),
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,a,i,u,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'\na : ',a.size(),'\ni : ',i.size(),'\nu : ',u.size())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])
plt.figure(figsize=(15,5))
plt.subplot(141)
librosa.display.specshow(X_train[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')


plt.subplot(142)
librosa.display.specshow(a[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(143)
librosa.display.specshow(i[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(144)
librosa.display.specshow(u[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')



#plt.xlabel("Time")
#plt.ylabel("Frequency")
#plt.colorbar(format='%+2.0f dB')
#plt.title("Spectrogram (dB)")
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([32, 3, 626, 300])
# a :  torch.Size([32, 3, 626, 300])
# i :  torch.Size([32, 3, 626, 300])
# u :  torch.Size([32, 3, 626, 300])
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(1)

# %%
#valiation set 확인
for (X_valid,a_valid,i_valid,u_valid,Y_valid) in validation_loader:
    print("X_train : ",X_valid.size(),'\na : ',a_valid.size(),'\ni : ',i_valid.size(),'\nu : ',u_valid.size())
    print("Y_train : ",Y_valid.size(),'type:',Y_valid.type())
    break
print(Y_valid[0])
plt.figure(figsize=(15,5))
plt.subplot(141)
librosa.display.specshow(X_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(142)
librosa.display.specshow(a_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(143)
librosa.display.specshow(i_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(144)
librosa.display.specshow(u_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')


#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([32, 3, 626, 300])
# a :  torch.Size([32, 3, 626, 300])
# i :  torch.Size([32, 3, 626, 300])
# u :  torch.Size([32, 3, 626, 300])
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(0)

# %%
#Test set 확인
for (X_test,a_test,i_test,u_test,Y_test) in test_loader:
    print("X_test : ",X_test.size(),'\na : ',a_test.size(),'\ni : ',i_test.size(),'\nu : ',u_test.size())
    print("Y_test : ",Y_test.size(),'type:',Y_test.type())
    break
    


print(X_test[0])
plt.figure(figsize=(15,5))
plt.subplot(141)
librosa.display.specshow(X_test[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(142)
librosa.display.specshow(a_test[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(143)
librosa.display.specshow(i_test[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

plt.subplot(144)
librosa.display.specshow(u_test[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')

#batch: 32 / 3채널 / feature수: 128/ frame수: 300
# Out:
# X_test :  torch.Size([32, 3, 626, 300])
# a :  torch.Size([32, 3, 626, 300])
# i :  torch.Size([32, 3, 626, 300])
# u :  torch.Size([32, 3, 626, 300])
# Y_test :  torch.Size([32]) type: torch.LongTensor
# tensor([[[ -0.9459,   5.8354,  10.7393,  ...,  22.4064,  15.2266,  10.7946],
#          [ -2.8497,   0.1081,   5.5408,  ...,  18.4980,  15.0981,  13.1419],
#          [ -8.4342, -15.1902,  -7.7991,  ...,   4.4085,   3.2438,  -0.2163],
#          ...,
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -40.5010],
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -38.7866],
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -36.6411]],
#
#         [[ -0.9459,   5.8354,  10.7393,  ...,  22.4064,  15.2266,  10.7946],
#          [ -2.8497,   0.1081,   5.5408,  ...,  18.4980,  15.0981,  13.1419],
#          [ -8.4342, -15.1902,  -7.7991,  ...,   4.4085,   3.2438,  -0.2163],
#          ...,
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -40.5010],
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -38.7866],
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -36.6411]],
#
#         [[ -0.9459,   5.8354,  10.7393,  ...,  22.4064,  15.2266,  10.7946],
#          [ -2.8497,   0.1081,   5.5408,  ...,  18.4980,  15.0981,  13.1419],
#          [ -8.4342, -15.1902,  -7.7991,  ...,   4.4085,   3.2438,  -0.2163],
#          ...,
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -40.5010],
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -38.7866],
#          [-40.5010, -40.5010, -40.5010,  ..., -40.5010, -40.5010, -36.6411]]])

# %% [markdown]
# # RESNET

# %%
class resnet18_feature(nn.Module):
    def __init__(self, embedding_dimension=128, pretrained=True):
        super().__init__()
        self.model = models.resnet18(pretrained=pretrained)
        
        # embedding
        input_features_fc_layer = self.model.fc.in_features # fc layer 채널 수 얻기
        self.model.fc = nn.Linear(input_features_fc_layer, embedding_dimension, bias=True) # fc layer 수정
        
    def forward(self, images):
        embedding = self.model(images) # embedding 생성
        return embedding

    
class resnet18_fusion(nn.Module):
    """Model modified.
    The architecture of our model is the same as standard DenseNet121
    except the classifier layer which has an additional sigmoid function.
    """

    def __init__(self, n_class=2):
        super(resnet18_fusion, self).__init__()


        model1 = resnet18_feature()
        self.phrase_model = model1
        in_features = self.phrase_model.model.fc.out_features
        

        model2 = resnet18_feature()
        self.a_model = model2

        model3 = resnet18_feature()
        self.i_model = model3

        model4 = resnet18_feature()
        self.u_model = model4
        

        self.combine = nn.Sequential(
            nn.Linear(in_features * 4, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128,64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(64,50),
            nn.BatchNorm1d(50),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(50,n_class)
        )



    def forward(self, phrase,a,i,u):
        phrase_feature = self.phrase_model(phrase)
        a_feature = self.a_model(a)
        i_feature = self.i_model(i)
        u_feature = self.u_model(u)      
        
        #0204 여기부터 수정.

        combine = torch.cat((phrase_feature,
                             a_feature,
                             i_feature,
                             u_feature), 1)
        combine = self.combine(combine)

        return combine

# %%
# 모델 
# pretrained


def model_initialize():
    model = resnet18_fusion(n_class=2).cuda()

    return model

model= model_initialize()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\USER/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 52.5%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
print(model)
# Out:
# resnet18_fusion(
#   (phrase_model): resnet18_feature(
#     (model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=512, out_features=128, bias=True)
#     )
#   )
#   (a_model): resnet18_feature(
#     (model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=512, out_features=128, bias=True)
#     )
#   )
#   (i_model): resnet18_feature(
#     (model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=512, out_features=128, bias=True)
#     )
#   )
#   (u_model): resnet18_feature(
#     (model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=512, out_features=128, bias=True)
#     )
#   )
#   (combine): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=64, out_features=50, bias=True)
#     (13): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Linear(in_features=50, out_features=2, bias=True)
#   )
# )

# %%
# get the model summary
from torchsummary import summary
#summary(model, input_size=(3, 128, 300), device=DEVICE.type)

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(phrase,a,i,u,label) in enumerate(train_loader):
        phrase = phrase.to(DEVICE)
        a = a.to(DEVICE)
        i = i.to(DEVICE)        
        u = u.to(DEVICE)
        label = label.to(DEVICE)
        
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(phrase,a,i,u) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for phrase,a,i,u,label in valid_loader:
            phrase = phrase.to(DEVICE)
            a = a.to(DEVICE)
            i = i.to(DEVICE)        
            u = u.to(DEVICE)
            label = label.to(DEVICE)
            output = model(phrase,a,i,u)
            
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# resnet34 pretrained true
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = '../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_fusion.pt'
    print(check_path)
    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break

        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# ../../checkpoint/checkpoint_spectro_resnet18_true_ros_1_300_fusion.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0233	 Train Acc:52.23 %  | 	Valid Loss:0.0236 	Valid Acc: 45.05 %
#
# Validation loss decreased (inf --> 0.023624).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0218	 Train Acc:54.98 %  | 	Valid Loss:0.0224 	Valid Acc: 60.41 %
#
# Validation loss decreased (0.023624 --> 0.022419).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0209	 Train Acc:59.04 %  | 	Valid Loss:0.0211 	Valid Acc: 73.38 %
#
# Validation loss decreased (0.022419 --> 0.021079).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0194	 Train Acc:65.60 %  | 	Valid Loss:0.0203 	Valid Acc: 78.84 %
#
# Validation loss decreased (0.021079 --> 0.020318).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0179	 Train Acc:68.74 %  | 	Valid Loss:0.0186 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.020318 --> 0.018592).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0170	 Train Acc:73.92 %  | 	Valid Loss:0.0176 	Valid Acc: 77.47 %
#
# Validation loss decreased (0.018592 --> 0.017639).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0154	 Train Acc:79.03 %  | 	Valid Loss:0.0161 	Valid Acc: 84.64 %
#
# Validation loss decreased (0.017639 --> 0.016092).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0136	 Train Acc:83.29 %  | 	Valid Loss:0.0163 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0116	 Train Acc:90.37 %  | 	Valid Loss:0.0166 	Valid Acc: 74.40 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0099	 Train Acc:94.36 %  | 	Valid Loss:0.0161 	Valid Acc: 75.09 %
#
# Validation loss decreased (0.016092 --> 0.016054).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0091	 Train Acc:95.28 %  | 	Valid Loss:0.0151 	Valid Acc: 75.09 %
#
# Validation loss decreased (0.016054 --> 0.015126).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0078	 Train Acc:96.79 %  | 	Valid Loss:0.0141 	Valid Acc: 79.86 %
#
# Validation loss decreased (0.015126 --> 0.014106).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0068	 Train Acc:97.84 %  | 	Valid Loss:0.0168 	Valid Acc: 73.38 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0061	 Train Acc:98.49 %  | 	Valid Loss:0.0132 	Valid Acc: 83.28 %
#
# Validation loss decreased (0.014106 --> 0.013220).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0054	 Train Acc:98.69 %  | 	Valid Loss:0.0119 	Valid Acc: 86.69 %
#
# Validation loss decreased (0.013220 --> 0.011949).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0045	 Train Acc:99.15 %  | 	Valid Loss:0.0139 	Valid Acc: 81.57 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0039	 Train Acc:99.80 %  | 	Valid Loss:0.0115 	Valid Acc: 84.64 %
#
# Validation loss decreased (0.011949 --> 0.011540).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0035	 Train Acc:99.61 %  | 	Valid Loss:0.0155 	Valid Acc: 77.82 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:19]	 Train Loss:0.0037	 Train Acc:98.89 %  | 	Valid Loss:0.0150 	Valid Acc: 83.28 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:20]	 Train Loss:0.0041	 Train Acc:97.38 %  | 	Valid Loss:0.0238 	Valid Acc: 67.24 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:21]	 Train Loss:0.0031	 Train Acc:99.54 %  | 	Valid Loss:0.0133 	Valid Acc: 82.94 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:22]	 Train Loss:0.0030	 Train Acc:99.02 %  | 	Valid Loss:0.0140 	Valid Acc: 82.59 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# ../../checkpoint/checkpoint_spectro_resnet18_true_ros_2_300_fusion.pt
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0236	 Train Acc:52.49 %  | 	Valid Loss:0.0216 	Valid Acc: 67.81 %
#
# Validation loss decreased (inf --> 0.021607).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0229	 Train Acc:54.65 %  | 	Valid Loss:0.0213 	Valid Acc: 74.32 %
#
# Validation loss decreased (0.021607 --> 0.021253).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0210	 Train Acc:59.17 %  | 	Valid Loss:0.0202 	Valid Acc: 75.34 %
#
# Validation loss decreased (0.021253 --> 0.020237).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0205	 Train Acc:62.12 %  | 	Valid Loss:0.0191 	Valid Acc: 77.40 %
#
# Validation loss decreased (0.020237 --> 0.019137).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0187	 Train Acc:67.56 %  | 	Valid Loss:0.0187 	Valid Acc: 80.82 %
#
# Validation loss decreased (0.019137 --> 0.018664).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0177	 Train Acc:70.05 %  | 	Valid Loss:0.0170 	Valid Acc: 81.85 %
#
# Validation loss decreased (0.018664 --> 0.016971).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0164	 Train Acc:75.49 %  | 	Valid Loss:0.0163 	Valid Acc: 81.51 %
#
# Validation loss decreased (0.016971 --> 0.016341).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0144	 Train Acc:81.39 %  | 	Valid Loss:0.0150 	Valid Acc: 81.51 %
#
# Validation loss decreased (0.016341 --> 0.015040).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0127	 Train Acc:86.04 %  | 	Valid Loss:0.0152 	Valid Acc: 81.51 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0110	 Train Acc:89.78 %  | 	Valid Loss:0.0142 	Valid Acc: 85.62 %
#
# Validation loss decreased (0.015040 --> 0.014183).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0098	 Train Acc:92.46 %  | 	Valid Loss:0.0144 	Valid Acc: 79.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0085	 Train Acc:94.76 %  | 	Valid Loss:0.0135 	Valid Acc: 84.25 %
#
# Validation loss decreased (0.014183 --> 0.013514).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0076	 Train Acc:96.72 %  | 	Valid Loss:0.0126 	Valid Acc: 84.93 %
#
# Validation loss decreased (0.013514 --> 0.012631).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0067	 Train Acc:97.84 %  | 	Valid Loss:0.0134 	Valid Acc: 85.27 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0058	 Train Acc:98.62 %  | 	Valid Loss:0.0132 	Valid Acc: 83.90 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:16]	 Train Loss:0.0054	 Train Acc:98.82 %  | 	Valid Loss:0.0128 	Valid Acc: 86.30 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:17]	 Train Loss:0.0043	 Train Acc:99.08 %  | 	Valid Loss:0.0127 	Valid Acc: 83.56 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:18]	 Train Loss:0.0040	 Train Acc:99.15 %  | 	Valid Loss:0.0125 	Valid Acc: 84.59 %
#
# Validation loss decreased (0.012631 --> 0.012468).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0037	 Train Acc:99.54 %  | 	Valid Loss:0.0130 	Valid Acc: 82.19 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0034	 Train Acc:99.61 %  | 	Valid Loss:0.0128 	Valid Acc: 82.19 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0032	 Train Acc:99.02 %  | 	Valid Loss:0.0154 	Valid Acc: 81.16 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0031	 Train Acc:98.89 %  | 	Valid Loss:0.0120 	Valid Acc: 83.90 %
#
# Validation loss decreased (0.012468 --> 0.012008).  Saving model ...
#
# [EPOCH:23]	 Train Loss:0.0031	 Train Acc:98.89 %  | 	Valid Loss:0.0144 	Valid Acc: 82.19 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:24]	 Train Loss:0.0037	 Train Acc:97.31 %  | 	Valid Loss:0.0167 	Valid Acc: 76.37 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:25]	 Train Loss:0.0031	 Train Acc:98.82 %  | 	Valid Loss:0.0151 	Valid Acc: 81.85 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:26]	 Train Loss:0.0023	 Train Acc:99.21 %  | 	Valid Loss:0.0129 	Valid Acc: 84.25 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:27]	 Train Loss:0.0025	 Train Acc:98.75 %  | 	Valid Loss:0.0134 	Valid Acc: 83.22 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# ../../checkpoint/checkpoint_spectro_resnet18_true_ros_3_300_fusion.pt
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0234	 Train Acc:51.90 %  | 	Valid Loss:0.0214 	Valid Acc: 70.21 %
#
# Validation loss decreased (inf --> 0.021415).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0217	 Train Acc:57.47 %  | 	Valid Loss:0.0202 	Valid Acc: 78.08 %
#
# Validation loss decreased (0.021415 --> 0.020163).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0203	 Train Acc:60.55 %  | 	Valid Loss:0.0191 	Valid Acc: 77.40 %
#
# Validation loss decreased (0.020163 --> 0.019113).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0196	 Train Acc:64.22 %  | 	Valid Loss:0.0182 	Valid Acc: 81.16 %
#
# Validation loss decreased (0.019113 --> 0.018184).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0183	 Train Acc:68.09 %  | 	Valid Loss:0.0175 	Valid Acc: 81.85 %
#
# Validation loss decreased (0.018184 --> 0.017537).  Saving model ...
# [EPOCH:6]	 Train Loss:0.0170	 Train Acc:74.71 %  | 	Valid Loss:0.0172 	Valid Acc: 81.16 %
#
# Validation loss decreased (0.017537 --> 0.017224).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0152	 Train Acc:78.44 %  | 	Valid Loss:0.0161 	Valid Acc: 82.19 %
#
# Validation loss decreased (0.017224 --> 0.016088).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0137	 Train Acc:82.50 %  | 	Valid Loss:0.0159 	Valid Acc: 79.79 %
#
# Validation loss decreased (0.016088 --> 0.015868).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0115	 Train Acc:90.37 %  | 	Valid Loss:0.0145 	Valid Acc: 81.85 %
#
# Validation loss decreased (0.015868 --> 0.014464).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0098	 Train Acc:92.33 %  | 	Valid Loss:0.0142 	Valid Acc: 80.82 %
#
# Validation loss decreased (0.014464 --> 0.014248).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0086	 Train Acc:95.15 %  | 	Valid Loss:0.0140 	Valid Acc: 82.53 %
#
# Validation loss decreased (0.014248 --> 0.013968).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0077	 Train Acc:95.87 %  | 	Valid Loss:0.0142 	Valid Acc: 80.82 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0065	 Train Acc:97.90 %  | 	Valid Loss:0.0129 	Valid Acc: 82.88 %
#
# Validation loss decreased (0.013968 --> 0.012882).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0053	 Train Acc:99.21 %  | 	Valid Loss:0.0120 	Valid Acc: 84.25 %
#
# Validation loss decreased (0.012882 --> 0.012050).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0051	 Train Acc:98.75 %  | 	Valid Loss:0.0116 	Valid Acc: 84.93 %
#
# Validation loss decreased (0.012050 --> 0.011604).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0043	 Train Acc:99.28 %  | 	Valid Loss:0.0155 	Valid Acc: 79.11 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0038	 Train Acc:99.41 %  | 	Valid Loss:0.0129 	Valid Acc: 84.59 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0034	 Train Acc:99.80 %  | 	Valid Loss:0.0114 	Valid Acc: 85.96 %
#
# Validation loss decreased (0.011604 --> 0.011388).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0031	 Train Acc:99.67 %  | 	Valid Loss:0.0120 	Valid Acc: 84.25 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0031	 Train Acc:99.61 %  | 	Valid Loss:0.0122 	Valid Acc: 84.25 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0026	 Train Acc:100.00 %  | 	Valid Loss:0.0132 	Valid Acc: 84.59 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0024	 Train Acc:99.80 %  | 	Valid Loss:0.0142 	Valid Acc: 83.56 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:23]	 Train Loss:0.0021	 Train Acc:99.87 %  | 	Valid Loss:0.0121 	Valid Acc: 84.25 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# ../../checkpoint/checkpoint_spectro_resnet18_true_ros_4_300_fusion.pt
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0237	 Train Acc:51.64 %  | 	Valid Loss:0.0205 	Valid Acc: 69.86 %
#
# Validation loss decreased (inf --> 0.020537).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0212	 Train Acc:58.45 %  | 	Valid Loss:0.0194 	Valid Acc: 76.71 %
#
# Validation loss decreased (0.020537 --> 0.019418).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0198	 Train Acc:63.63 %  | 	Valid Loss:0.0170 	Valid Acc: 78.08 %
#
# Validation loss decreased (0.019418 --> 0.017013).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0187	 Train Acc:67.82 %  | 	Valid Loss:0.0172 	Valid Acc: 78.77 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0167	 Train Acc:72.08 %  | 	Valid Loss:0.0173 	Valid Acc: 77.74 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:6]	 Train Loss:0.0151	 Train Acc:79.49 %  | 	Valid Loss:0.0173 	Valid Acc: 77.05 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:7]	 Train Loss:0.0138	 Train Acc:82.50 %  | 	Valid Loss:0.0157 	Valid Acc: 81.51 %
#
# Validation loss decreased (0.017013 --> 0.015707).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0119	 Train Acc:89.58 %  | 	Valid Loss:0.0171 	Valid Acc: 76.03 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0106	 Train Acc:91.28 %  | 	Valid Loss:0.0162 	Valid Acc: 81.51 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0091	 Train Acc:94.30 %  | 	Valid Loss:0.0182 	Valid Acc: 71.58 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0077	 Train Acc:96.99 %  | 	Valid Loss:0.0146 	Valid Acc: 83.90 %
#
# Validation loss decreased (0.015707 --> 0.014638).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0066	 Train Acc:98.03 %  | 	Valid Loss:0.0148 	Valid Acc: 76.71 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0060	 Train Acc:97.84 %  | 	Valid Loss:0.0129 	Valid Acc: 82.19 %
#
# Validation loss decreased (0.014638 --> 0.012857).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0047	 Train Acc:99.41 %  | 	Valid Loss:0.0135 	Valid Acc: 80.48 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0046	 Train Acc:99.15 %  | 	Valid Loss:0.0126 	Valid Acc: 82.53 %
#
# Validation loss decreased (0.012857 --> 0.012593).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0038	 Train Acc:99.80 %  | 	Valid Loss:0.0127 	Valid Acc: 82.88 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0035	 Train Acc:99.80 %  | 	Valid Loss:0.0150 	Valid Acc: 82.19 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0032	 Train Acc:99.61 %  | 	Valid Loss:0.0139 	Valid Acc: 80.14 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:19]	 Train Loss:0.0033	 Train Acc:98.95 %  | 	Valid Loss:0.0136 	Valid Acc: 82.19 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:20]	 Train Loss:0.0037	 Train Acc:98.30 %  | 	Valid Loss:0.0174 	Valid Acc: 79.45 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# ../../checkpoint/checkpoint_spectro_resnet18_true_ros_5_300_fusion.pt
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0239	 Train Acc:52.29 %  | 	Valid Loss:0.0225 	Valid Acc: 61.99 %
#
# Validation loss decreased (inf --> 0.022481).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0219	 Train Acc:55.37 %  | 	Valid Loss:0.0207 	Valid Acc: 76.03 %
#
# Validation loss decreased (0.022481 --> 0.020711).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0206	 Train Acc:59.82 %  | 	Valid Loss:0.0199 	Valid Acc: 74.32 %
#
# Validation loss decreased (0.020711 --> 0.019859).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0191	 Train Acc:64.53 %  | 	Valid Loss:0.0195 	Valid Acc: 73.97 %
#
# Validation loss decreased (0.019859 --> 0.019456).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0176	 Train Acc:71.20 %  | 	Valid Loss:0.0187 	Valid Acc: 75.68 %
#
# Validation loss decreased (0.019456 --> 0.018729).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0157	 Train Acc:77.36 %  | 	Valid Loss:0.0190 	Valid Acc: 75.00 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0147	 Train Acc:80.76 %  | 	Valid Loss:0.0163 	Valid Acc: 79.11 %
#
# Validation loss decreased (0.018729 --> 0.016286).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0127	 Train Acc:86.71 %  | 	Valid Loss:0.0164 	Valid Acc: 79.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0111	 Train Acc:89.73 %  | 	Valid Loss:0.0205 	Valid Acc: 66.10 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0094	 Train Acc:93.52 %  | 	Valid Loss:0.0177 	Valid Acc: 78.08 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0088	 Train Acc:94.18 %  | 	Valid Loss:0.0190 	Valid Acc: 74.32 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0077	 Train Acc:95.88 %  | 	Valid Loss:0.0163 	Valid Acc: 77.05 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %% [markdown]
# # Model 결과 확인

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 99.8034 |	 valid ACC: 84.6416
# [2 교차검증] train ACC : 98.8860 |	 valid ACC: 83.9041
# [3 교차검증] train ACC : 99.8034 |	 valid ACC: 85.9589
# [4 교차검증] train ACC : 99.1481 |	 valid ACC: 82.5342
# [5 교차검증] train ACC : 80.7592 |	 valid ACC: 79.1096
# 평균 검증 정확도 83.2296975080649 %

# %% [markdown]
# # Model Test
#
# - test set
# - confusion matrix

# %%
#confusion matrix 계산
#test set 계산.
def test_evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_fusion.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers,test_loss = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8696/4070680189.py in <module>
#      16     model.load_state_dict(torch.load(check_path))
#      17
# ---> 18     predictions,answers,test_loss = test_evaluate(model, test_loader)
#      19     predictions=[ dat.cpu().numpy() for dat in predictions]
#      20     answers=[ dat.cpu().numpy() for dat in answers]
#
# ~\AppData\Local\Temp/ipykernel_8696/2041524167.py in test_evaluate(model, test_loader)
#       8     #no_grad : 그래디언트 값 계산 막기.
#       9     with torch.no_grad():
# ---> 10         for image, label in test_loader:
#      11             image = image.to(DEVICE)
#      12             label = label.to(DEVICE)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # 기타

# %%
#크기 알아보기
#일반 CNN

m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 500, 13])
# torch.Size([32, 1, 250, 6])
# torch.Size([32, 1, 125, 3])

# %%
#크기 알아보기
#주파수 영역 CNN

input = torch.randn(32, 1, 500, 13)
m=nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 32,# FeatureMap 수,커널 수
            kernel_size = (1,13),#1x13  no padding
        )
output=m(input)
print(output.size())
m=nn.Conv2d(
            in_channels = 32,# 채널이 1개
            out_channels = 64,# FeatureMap 수,커널 수
            kernel_size = (27,1),#9 x 1 no padding
        )
output=m(output)
print(output.size())
# Out:
# torch.Size([32, 32, 500, 1])
# torch.Size([32, 64, 474, 1])

# %%
input = torch.randn(500, 13)

out=torch.stack([input,input,input])
out.size()
# Out:
# torch.Size([3, 500, 13])
