# %% [markdown]
# # MSF 모델
#
# - mfcc, spectrogram , mel-spectrogram 3채널을 엮어서 학습을 해본다.
# - 이미지는 300 x 300 으로 고정하고, mfcc 100을 interpolate 한다.
# - fusion 실시 x
# - grad-cam 포함
#
#
#
# ## normalize
#
#
#
# 먼저 수행해볼것
# 1. signal normalize
# 2. spectrogram global normalize
#
#
# 따로 확인해볼것
# 1. layer normalize (channel 별로 noramlize로 변경?)
#
#
# 참고
#
# https://enzokro.dev/spectrogram_normalizations/2020/09/10/Normalizing-spectrograms-for-deep-learning.html

# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5
# - https://quokkas.tistory.com/37 : early stopping
# - https://continuous-development.tistory.com/166 : stratified kfold
# - https://deep-learning-study.tistory.com/476 fiter 시각화
# - https://wyatt37.tistory.com/10 : random over sampling

# %%
import wandb

wandb.init(project="SVD-voice-disorder", entity="bub3690")
wandb.run.name = 'MSF-organic-baseline-normalize-minmax'
wandb.run.save()
# Out:
# wandb: Currently logged in as: bub3690. Use `wandb login --relogin` to force relogin
# wandb version 0.12.19 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>D:\project\voice_pathology_ai\model\spectrogram\ros\MSFnet\wandb\run-20220624_121956-167wqhum</code>
# Syncing run <strong><a href="https://wandb.ai/bub3690/SVD-voice-disorder/runs/167wqhum" target="_blank">silvery-energy-99</a></strong> to <a href="https://wandb.ai/bub3690/SVD-voice-disorder" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# True

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys
import librosa, librosa.display 

p = os.path.abspath('../../..') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.2  Device :  cuda

# %%
import torchaudio
import torchaudio.transforms as T

# %% [markdown]
# # 데이터 나누기 - Stratified KFold
#
# - pathology : 1194 / healthy : 634 / 총 1828
# - k = 5

# %% [markdown]
# ## 1. test/ train 나누기

# %%
#1. train, test 나누기

import os
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('D:/project/voice_pathology_ai/voice_data/organics/pathology/phrase/*.wav')
healthy = glob('D:/project/voice_pathology_ai/voice_data/organics/healthy/phrase/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))

pathology= [ path.split("\\")[-1] for path in pathology] # path 데이터 변환.
healthy= [ path.split("\\")[-1] for path in healthy] # path 데이터 변환.
 # path 데이터 변환 #외부데이터로 가져오기위해서, 번호만 남긴다

    
X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<597:
        Y.append("pathology")
    else:
        Y.append("healthy")

X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  597
# Healthy:  634
# 총 데이터수 :  1231
# ---
# 훈련 셋 :  984 Counter({'healthy': 507, 'pathology': 477})
# 테스트 셋 :  247 Counter({'healthy': 127, 'pathology': 120})
# ---

# %% [markdown]
# ## 2. stratified k-fold

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter



skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 381}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 96}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 381}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 96}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 382}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 95}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 405, 'pathology': 382}
# 검증 레이블 데이터 분포 :
#  {'healthy': 102, 'pathology': 95}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 406, 'pathology': 382}
# 검증 레이블 데이터 분포 :
#  {'healthy': 101, 'pathology': 95}

# %% [markdown]
# ## 3. random over sampling

# %%
#2. random over sampling
for i in range(5):
    X_temp = np.array(X_train_list[i]).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
    #Y = np.array(Y)
    ros = RandomOverSampler(random_state = 123)
    X_res,Y_res = ros.fit_resample(X_temp,Y_train_list[i])
    
    print("\n fold{} ".format(i))
    print('before dataset shape {}'.format(Counter(Y_train_list[i])) )
    print('Resampled dataset shape {}'.format(Counter(Y_res)) )   
    
    #원래대로 돌리기
    X_res=X_res.reshape(1, -1)
    X_train_list[i]=X_res[0].tolist()
    Y_train_list[i]=Y_res
# Out:
#  fold0
# before dataset shape Counter({'healthy': 406, 'pathology': 381})
# Resampled dataset shape Counter({'pathology': 406, 'healthy': 406})
#
#  fold1
# before dataset shape Counter({'healthy': 406, 'pathology': 381})
# Resampled dataset shape Counter({'healthy': 406, 'pathology': 406})
#
#  fold2
# before dataset shape Counter({'healthy': 405, 'pathology': 382})
# Resampled dataset shape Counter({'pathology': 405, 'healthy': 405})
#
#  fold3
# before dataset shape Counter({'healthy': 405, 'pathology': 382})
# Resampled dataset shape Counter({'pathology': 405, 'healthy': 405})
#
#  fold4
# before dataset shape Counter({'healthy': 406, 'pathology': 382})
# Resampled dataset shape Counter({'pathology': 406, 'healthy': 406})

# %%
import pickle

 
#load
with open("D:/project/voice_pathology_ai/voice_data/organics/phrase_sig_dict.pickle","rb") as fr:
    phrase_dict = pickle.load(fr)

#load min-max scaler
with open("D:/project/voice_pathology_ai/voice_data/organics/phrase_scaler.pickle","rb") as fr:
    phrase_scaler = pickle.load(fr)

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.(여기서는 300frame)
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler



classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None,augment=None,normalize=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        self.augment=augment
        self.normalize=normalize
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
    
       
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc, spectro, mel-spectro를 추출
        2. mfcc를 224프레임으로 패딩. 또한 세로축은 224으로 interpolate
        3. resnet에 사용되기 위해 3채널로 쌓기.
        4. 미정. 0~1 정규화
        
        """
        sig =  phrase_dict[self.path_list[idx]] # 16000hz 실시
        length=29990 #300 padding을 위한 파라미터
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))        
        sig = pad1d(sig,length)        
        
        ###signal norm
        sig = (sig-sig.mean())/sig.std()
        ###
        
        
        
        
        
        MFCCs = librosa.feature.mfcc(y=sig, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=128)
        #MFCCs = librosa.util.normalize(MFCCs) # l-infinity norm
        #MFCCs=cv2.resize(MFCCs,(MFCCs.shape[1],128),interpolation=cv2.INTER_LINEAR)# interpolate 적용해서 128 사이즈로
        
        
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        
        
        mel_feature = librosa.feature.melspectrogram(y=sig,sr=sr,hop_length=hop_length,n_fft=n_fft)
        mel_feature = librosa.core.power_to_db(mel_feature,ref=np.max)
        #mel_feature=librosa.util.normalize(mel_feature) # l-infinity norm
        
        #stft 300 FRAME이 되도록 패딩.
        #length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        #log_spectrogram = librosa.util.normalize(log_spectrogram) # l-infinity norm
        
        
        #padding
        #pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        #log_spectrogram = pad2d(log_spectrogram, length)
        #mel_feature = pad2d(mel_feature, length)
        
        #MFCCs = pad2d(MFCCs, length) # mfcc 대신 encoder를 가져와서 해보자.
        log_spectrogram=log_spectrogram[:128,:]# 224 x 300 으로 사이즈 조절
        
        log_spectrogram = phrase_scaler[0].transform(log_spectrogram.reshape(1,-1)).reshape(128,300)
        mel_feature=phrase_scaler[1].transform(mel_feature.reshape(1,-1)).reshape(128,300)
        MFCCs=phrase_scaler[2].transform(MFCCs.reshape(1,-1)).reshape(128,300)        
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 타입 변화
            mel_feature=self.transform(mel_feature).type(torch.float32)# 타입 변화
            MFCCs=self.transform(MFCCs).type(torch.float32)# 타입 변화            
            
            MSF = torch.stack([log_spectrogram,mel_feature,MFCCs])# 3채널로 복사.
            MSF = MSF.squeeze(dim=1)
            # global normalize
            if self.normalize:
                #MSF=self.normalize(MSF)
                pass
            
            #augmentation
            if self.training and self.augment:
                MSF=self.augment(MSF)
                
            

        else:
            #print("else")
            ##################안쓰는 곳
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MSF, self.classes.index(self.label[idx])

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes,transform=None,normalize=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes
        self.transform=transform
        self.normalize=normalize
        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc, spectro, mel-spectro를 추출
        2. mfcc를 300프레임으로 패딩. 또한 세로축은 128으로 interpolate
        3. resnet에 사용되기 위해 3채널로 쌓기.
        4. 미정. 0~1 정규화
        
        """
        sig =  phrase_dict[self.path_list[idx]] # 16000hz 실시
        length=29990 #300 padding을 위한 파라미터
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))        
        sig = pad1d(sig,length)
        ###signal norm
        sig = (sig-sig.mean())/sig.std()
        ###        
        
        
        
        MFCCs = librosa.feature.mfcc(y=sig, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=128)
        #MFCCs = librosa.util.normalize(MFCCs) # l-infinity norm
        #MFCCs=cv2.resize(MFCCs,(MFCCs.shape[1],128),interpolation=cv2.INTER_LINEAR)# interpolate 적용해서 128 사이즈로
        
        
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        
        
        mel_feature = librosa.feature.melspectrogram(y=sig,sr=sr,hop_length=hop_length,n_fft=n_fft)
        mel_feature = librosa.core.power_to_db(mel_feature,ref=np.max)
        #mel_feature=librosa.util.normalize(mel_feature) # l-infinity norm
        
        #stft 300 FRAME이 되도록 패딩.
        #length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        #log_spectrogram = librosa.util.normalize(log_spectrogram) # l-infinity norm
        
        
        #padding
        #pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        #log_spectrogram = pad2d(log_spectrogram, length)

        
        #MFCCs = pad2d(MFCCs, length) # mfcc 대신 encoder를 가져와서 해보자.
        log_spectrogram=log_spectrogram[:128,:]# 128 x 300 으로 사이즈 조절
        
        log_spectrogram = phrase_scaler[0].transform(log_spectrogram.reshape(1,-1)).reshape(128,300)
        mel_feature=phrase_scaler[1].transform(mel_feature.reshape(1,-1)).reshape(128,300)
        MFCCs=phrase_scaler[2].transform(MFCCs.reshape(1,-1)).reshape(128,300)
        
        
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 타입 변화
            mel_feature=self.transform(mel_feature).type(torch.float32)# 타입 변화
            MFCCs=self.transform(MFCCs).type(torch.float32)# 타입 변화
            
            
            MSF = torch.stack([log_spectrogram,mel_feature,MFCCs])# 3채널로 복사.
            MSF = MSF.squeeze(dim=1)
            
            # global normalize
            if self.normalize:
                pass
                #MSF=self.normalize(MSF)
     
        else:
            #print("else")
            ##################안쓰는 곳
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MSF, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  32 #한 배치당 32개 음성데이터
EPOCHS = 40 # 전체 데이터 셋을 50번 반복
lr=0.0001

# %%
wandb.config.update({
    "learning_rate": lr,
    "epochs": EPOCHS,
    "batch_size": BATCH_SIZE,
    "augment":"No",
})

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인
#transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])

train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                               classes,
                                               transform=transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                               normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),                                               
                                               transform=transforms.ToTensor(),
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                                   normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),
                                                   transform = transforms.ToTensor(),
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])
plt.figure(figsize=(15,5))
plt.imshow(X_train[0].view(128,300,3).numpy())
plt.xlabel("Time")
plt.ylim((0,128))
plt.ylabel("Frequency")
#plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# X_train :  torch.Size([32, 3, 128, 300]) type: torch.FloatTensor
# Y_train :  torch.Size([32]) type: torch.LongTensor
# tensor(0)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
X_train.size()
# Out:
# torch.Size([32, 3, 128, 300])

# %%
X_train[0][0].shape
# Out:
# torch.Size([128, 300])

# %%
librosa.display.specshow(X_train[0][0].view(128,300).numpy(),sr=16000)

# %%
librosa.display.specshow(X_train[0][1].view(128,300).numpy(),sr=16000)

# %%
X_train[0].size()
# Out:
# torch.Size([3, 128, 300])

# %%
librosa.display.specshow(X_train[0][2].view(128,300).numpy(),sr=16000)

# %%
#valiation set 확인
for (X_valid,Y_valid) in validation_loader:
    print("X_valid : ",X_valid.size(),'type:',X_valid.type())
    print("Y_valid : ",Y_valid.size(),'type:',Y_valid.type())
    break

print(Y_valid[0])
plt.figure(figsize=(15,5))
plt.imshow(X_valid[0].view(128,300,3).numpy())
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.ylim((0,120))
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")

#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# X_valid :  torch.Size([32, 3, 128, 300]) type: torch.FloatTensor
# Y_valid :  torch.Size([32]) type: torch.LongTensor
# tensor(1)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
#test set 확인
for (test_data,test_label) in test_loader:
    print("X_valid : ",test_data.size(),'type:',test_data.type())
    print("Y_valid : ",test_label.size(),'type:',test_label.type())
    break

print(test_label[0])
plt.figure(figsize=(15,5))
plt.imshow(test_data[0].view(128,300,3).numpy())
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.ylim((0,128))
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")

#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# X_valid :  torch.Size([32, 3, 128, 300]) type: torch.FloatTensor
# Y_valid :  torch.Size([32]) type: torch.LongTensor
# tensor(1)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %% [markdown]
# # RESNET

# %%
class ResLayer(nn.Module):
    def __init__(self):
        super(ResLayer, self).__init__()
        self.model = models.resnet18(pretrained=True).cuda()
        
        self.model.ftrs = self.model.fc.in_features # in_features : fully connected의 입력수.
        self.num_ftrs = self.model.fc.in_features
        self.model.fc = nn.Sequential(nn.Linear(self.num_ftrs, 64),
                             nn.BatchNorm1d(64),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(64,50),
                             nn.BatchNorm1d(50),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(50,2)
                            )
        

    def forward(self, x):
        res_feature=self.model(x)
        return res_feature



def model_initialize():
    model = ResLayer().cuda()
    #model=se_resnet18().cuda()
    return model

model=model_initialize()

# %%
class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self):
        super(LabelSmoothingCrossEntropy,self).__init__()
    def forward(self,x,target,smoothing=0.1):
        confidence =1.-smoothing
        logprobs = F.log_softmax(x,dim=-1)
        nll_loss = -logprobs.gather(dim=-1,index=target.unsqueeze(1))
        nll_loss = nll_loss.squeeze(1)
        smooth_loss = -logprobs.mean(dim=-1)
        loss = confidence * nll_loss + smoothing*smooth_loss
        return loss.mean()

# %%
criterion = nn.CrossEntropyLoss()
#criterion = LabelSmoothingCrossEntropy()


optimizer = torch.optim.Adam(model.parameters(),lr=lr)
print(model)
# Out:
# ResLayer(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=64, out_features=50, bias=True)
#       (5): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )

# %%
# get the model summary
from torchsummary import summary
#summary(model, input_size=(3, 128, 300), device=DEVICE.type)

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        #loss = softXEnt(output,label)
        
        train_loss += loss.item()
        
        
        output = F.softmax(output, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            
            valid_loss += criterion(output, label).item()
            #valid_loss +=softXEnt(output,label).item()
            
            output = F.softmax(output, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만

            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                                   normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),
                                                   transform = transforms.ToTensor(),
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# resnet34 pretrained true
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_msf_organic_base_minmax.pt'
    print(check_path)
    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)
        wandb.log({
                "valid {}fold Accuracy".format(data_ind) : valid_accuracy,
                "valid {}fold loss".format(data_ind) : valid_loss})

        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
            wandb.run.summary.update({"best_valid_{}fold_acc".format(data_ind) : best_valid_acc})
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break

        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_1_300_msf_organic_base_minmax.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0221	 Train Acc:60.22 %  | 	Valid Loss:0.0213 	Valid Acc: 73.60 %
#
# Validation loss decreased (inf --> 0.021320).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0164	 Train Acc:74.75 %  | 	Valid Loss:0.0164 	Valid Acc: 82.23 %
#
# Validation loss decreased (0.021320 --> 0.016419).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0132	 Train Acc:84.11 %  | 	Valid Loss:0.0161 	Valid Acc: 80.20 %
#
# Validation loss decreased (0.016419 --> 0.016134).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0114	 Train Acc:90.27 %  | 	Valid Loss:0.0160 	Valid Acc: 80.71 %
#
# Validation loss decreased (0.016134 --> 0.015985).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0095	 Train Acc:95.07 %  | 	Valid Loss:0.0154 	Valid Acc: 81.22 %
#
# Validation loss decreased (0.015985 --> 0.015448).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0078	 Train Acc:96.31 %  | 	Valid Loss:0.0154 	Valid Acc: 82.23 %
#
# Validation loss decreased (0.015448 --> 0.015426).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0068	 Train Acc:97.91 %  | 	Valid Loss:0.0146 	Valid Acc: 81.22 %
#
# Validation loss decreased (0.015426 --> 0.014569).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0057	 Train Acc:99.38 %  | 	Valid Loss:0.0139 	Valid Acc: 83.25 %
#
# Validation loss decreased (0.014569 --> 0.013934).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0054	 Train Acc:99.26 %  | 	Valid Loss:0.0153 	Valid Acc: 83.76 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0049	 Train Acc:99.63 %  | 	Valid Loss:0.0149 	Valid Acc: 84.77 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0047	 Train Acc:99.75 %  | 	Valid Loss:0.0132 	Valid Acc: 81.22 %
#
# Validation loss decreased (0.013934 --> 0.013245).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0040	 Train Acc:99.88 %  | 	Valid Loss:0.0143 	Valid Acc: 81.73 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0037	 Train Acc:99.88 %  | 	Valid Loss:0.0148 	Valid Acc: 81.73 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0035	 Train Acc:100.00 %  | 	Valid Loss:0.0135 	Valid Acc: 82.74 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0032	 Train Acc:99.88 %  | 	Valid Loss:0.0138 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:16]	 Train Loss:0.0029	 Train Acc:100.00 %  | 	Valid Loss:0.0131 	Valid Acc: 84.26 %
#
# Validation loss decreased (0.013245 --> 0.013122).  Saving model ...
#
# [EPOCH:17]	 Train Loss:0.0030	 Train Acc:100.00 %  | 	Valid Loss:0.0156 	Valid Acc: 82.23 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:18]	 Train Loss:0.0026	 Train Acc:100.00 %  | 	Valid Loss:0.0131 	Valid Acc: 82.23 %
#
# Validation loss decreased (0.013122 --> 0.013076).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0027	 Train Acc:100.00 %  | 	Valid Loss:0.0161 	Valid Acc: 82.74 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0024	 Train Acc:100.00 %  | 	Valid Loss:0.0141 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0023	 Train Acc:100.00 %  | 	Valid Loss:0.0140 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0023	 Train Acc:99.88 %  | 	Valid Loss:0.0147 	Valid Acc: 83.76 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:23]	 Train Loss:0.0022	 Train Acc:99.75 %  | 	Valid Loss:0.0157 	Valid Acc: 80.71 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_2_300_msf_organic_base_minmax.pt
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0197	 Train Acc:63.79 %  | 	Valid Loss:0.0192 	Valid Acc: 75.63 %
#
# Validation loss decreased (inf --> 0.019179).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0146	 Train Acc:82.51 %  | 	Valid Loss:0.0159 	Valid Acc: 84.26 %
#
# Validation loss decreased (0.019179 --> 0.015947).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0128	 Train Acc:86.82 %  | 	Valid Loss:0.0160 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0109	 Train Acc:91.87 %  | 	Valid Loss:0.0144 	Valid Acc: 81.73 %
#
# Validation loss decreased (0.015947 --> 0.014385).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0095	 Train Acc:95.20 %  | 	Valid Loss:0.0143 	Valid Acc: 82.74 %
#
# Validation loss decreased (0.014385 --> 0.014317).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0081	 Train Acc:97.91 %  | 	Valid Loss:0.0137 	Valid Acc: 84.77 %
#
# Validation loss decreased (0.014317 --> 0.013657).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0070	 Train Acc:99.26 %  | 	Valid Loss:0.0141 	Valid Acc: 84.77 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0062	 Train Acc:99.38 %  | 	Valid Loss:0.0122 	Valid Acc: 84.77 %
#
# Validation loss decreased (0.013657 --> 0.012211).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0055	 Train Acc:99.88 %  | 	Valid Loss:0.0117 	Valid Acc: 83.76 %
#
# Validation loss decreased (0.012211 --> 0.011731).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0050	 Train Acc:99.63 %  | 	Valid Loss:0.0116 	Valid Acc: 83.25 %
#
# Validation loss decreased (0.011731 --> 0.011609).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0044	 Train Acc:99.75 %  | 	Valid Loss:0.0113 	Valid Acc: 82.74 %
#
# Validation loss decreased (0.011609 --> 0.011334).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0042	 Train Acc:99.75 %  | 	Valid Loss:0.0124 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0039	 Train Acc:99.88 %  | 	Valid Loss:0.0146 	Valid Acc: 82.74 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0037	 Train Acc:100.00 %  | 	Valid Loss:0.0120 	Valid Acc: 84.77 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0035	 Train Acc:100.00 %  | 	Valid Loss:0.0104 	Valid Acc: 85.28 %
#
# Validation loss decreased (0.011334 --> 0.010369).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0030	 Train Acc:100.00 %  | 	Valid Loss:0.0128 	Valid Acc: 83.76 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0030	 Train Acc:100.00 %  | 	Valid Loss:0.0110 	Valid Acc: 82.74 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0030	 Train Acc:99.75 %  | 	Valid Loss:0.0131 	Valid Acc: 83.76 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:19]	 Train Loss:0.0028	 Train Acc:100.00 %  | 	Valid Loss:0.0111 	Valid Acc: 83.76 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:20]	 Train Loss:0.0026	 Train Acc:99.75 %  | 	Valid Loss:0.0130 	Valid Acc: 83.76 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_3_300_msf_organic_base_minmax.pt
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0206	 Train Acc:60.74 %  | 	Valid Loss:0.0220 	Valid Acc: 69.04 %
#
# Validation loss decreased (inf --> 0.022050).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0166	 Train Acc:76.30 %  | 	Valid Loss:0.0170 	Valid Acc: 81.73 %
#
# Validation loss decreased (0.022050 --> 0.016986).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0143	 Train Acc:83.21 %  | 	Valid Loss:0.0162 	Valid Acc: 82.23 %
#
# Validation loss decreased (0.016986 --> 0.016216).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0128	 Train Acc:88.52 %  | 	Valid Loss:0.0155 	Valid Acc: 85.79 %
#
# Validation loss decreased (0.016216 --> 0.015515).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0116	 Train Acc:93.21 %  | 	Valid Loss:0.0150 	Valid Acc: 86.29 %
#
# Validation loss decreased (0.015515 --> 0.014962).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0101	 Train Acc:95.06 %  | 	Valid Loss:0.0140 	Valid Acc: 87.82 %
#
# Validation loss decreased (0.014962 --> 0.013957).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0092	 Train Acc:96.54 %  | 	Valid Loss:0.0140 	Valid Acc: 87.31 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0079	 Train Acc:98.27 %  | 	Valid Loss:0.0131 	Valid Acc: 87.82 %
#
# Validation loss decreased (0.013957 --> 0.013125).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0069	 Train Acc:98.64 %  | 	Valid Loss:0.0134 	Valid Acc: 88.83 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0063	 Train Acc:99.51 %  | 	Valid Loss:0.0117 	Valid Acc: 90.36 %
#
# Validation loss decreased (0.013125 --> 0.011671).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0058	 Train Acc:99.63 %  | 	Valid Loss:0.0128 	Valid Acc: 89.34 %
#
# EarlyStopping counter: 1 out of 5
# [EPOCH:12]	 Train Loss:0.0051	 Train Acc:100.00 %  | 	Valid Loss:0.0108 	Valid Acc: 88.83 %
#
# Validation loss decreased (0.011671 --> 0.010780).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0047	 Train Acc:99.88 %  | 	Valid Loss:0.0115 	Valid Acc: 90.36 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0043	 Train Acc:99.88 %  | 	Valid Loss:0.0099 	Valid Acc: 87.82 %
#
# Validation loss decreased (0.010780 --> 0.009874).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0038	 Train Acc:100.00 %  | 	Valid Loss:0.0107 	Valid Acc: 88.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0036	 Train Acc:100.00 %  | 	Valid Loss:0.0100 	Valid Acc: 88.83 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:17]	 Train Loss:0.0035	 Train Acc:100.00 %  | 	Valid Loss:0.0100 	Valid Acc: 88.32 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:18]	 Train Loss:0.0032	 Train Acc:100.00 %  | 	Valid Loss:0.0094 	Valid Acc: 88.32 %
#
# Validation loss decreased (0.009874 --> 0.009375).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0032	 Train Acc:100.00 %  | 	Valid Loss:0.0092 	Valid Acc: 88.83 %
#
# Validation loss decreased (0.009375 --> 0.009156).  Saving model ...
#
# [EPOCH:20]	 Train Loss:0.0030	 Train Acc:99.88 %  | 	Valid Loss:0.0109 	Valid Acc: 87.82 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:21]	 Train Loss:0.0025	 Train Acc:99.88 %  | 	Valid Loss:0.0098 	Valid Acc: 87.82 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:22]	 Train Loss:0.0034	 Train Acc:99.38 %  | 	Valid Loss:0.0100 	Valid Acc: 88.83 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:23]	 Train Loss:0.0034	 Train Acc:98.89 %  | 	Valid Loss:0.0141 	Valid Acc: 82.23 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:24]	 Train Loss:0.0028	 Train Acc:99.63 %  | 	Valid Loss:0.0099 	Valid Acc: 88.32 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_4_300_msf_organic_base_minmax.pt
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0208	 Train Acc:60.62 %  | 	Valid Loss:0.0209 	Valid Acc: 77.66 %
#
# Validation loss decreased (inf --> 0.020909).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0164	 Train Acc:77.16 %  | 	Valid Loss:0.0167 	Valid Acc: 79.70 %
#
# Validation loss decreased (0.020909 --> 0.016669).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0141	 Train Acc:82.59 %  | 	Valid Loss:0.0157 	Valid Acc: 83.25 %
#
# Validation loss decreased (0.016669 --> 0.015730).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0126	 Train Acc:88.15 %  | 	Valid Loss:0.0155 	Valid Acc: 86.80 %
#
# Validation loss decreased (0.015730 --> 0.015540).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0110	 Train Acc:92.47 %  | 	Valid Loss:0.0146 	Valid Acc: 88.32 %
#
# Validation loss decreased (0.015540 --> 0.014565).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0096	 Train Acc:95.19 %  | 	Valid Loss:0.0145 	Valid Acc: 87.82 %
#
# Validation loss decreased (0.014565 --> 0.014540).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0085	 Train Acc:97.53 %  | 	Valid Loss:0.0144 	Valid Acc: 88.32 %
#
# Validation loss decreased (0.014540 --> 0.014376).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0073	 Train Acc:99.38 %  | 	Valid Loss:0.0139 	Valid Acc: 89.34 %
#
# Validation loss decreased (0.014376 --> 0.013890).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0065	 Train Acc:99.38 %  | 	Valid Loss:0.0125 	Valid Acc: 88.32 %
#
# Validation loss decreased (0.013890 --> 0.012526).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0063	 Train Acc:99.63 %  | 	Valid Loss:0.0127 	Valid Acc: 89.34 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0056	 Train Acc:99.51 %  | 	Valid Loss:0.0113 	Valid Acc: 87.31 %
#
# Validation loss decreased (0.012526 --> 0.011312).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0051	 Train Acc:99.63 %  | 	Valid Loss:0.0124 	Valid Acc: 87.31 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0045	 Train Acc:99.88 %  | 	Valid Loss:0.0117 	Valid Acc: 88.32 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0042	 Train Acc:99.88 %  | 	Valid Loss:0.0115 	Valid Acc: 88.32 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0040	 Train Acc:100.00 %  | 	Valid Loss:0.0110 	Valid Acc: 88.32 %
#
# Validation loss decreased (0.011312 --> 0.011038).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0037	 Train Acc:99.88 %  | 	Valid Loss:0.0127 	Valid Acc: 86.80 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0036	 Train Acc:100.00 %  | 	Valid Loss:0.0126 	Valid Acc: 87.31 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0036	 Train Acc:99.88 %  | 	Valid Loss:0.0102 	Valid Acc: 87.31 %
#
# Validation loss decreased (0.011038 --> 0.010189).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0028	 Train Acc:100.00 %  | 	Valid Loss:0.0103 	Valid Acc: 88.83 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0028	 Train Acc:100.00 %  | 	Valid Loss:0.0106 	Valid Acc: 88.83 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0026	 Train Acc:100.00 %  | 	Valid Loss:0.0118 	Valid Acc: 86.80 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0026	 Train Acc:100.00 %  | 	Valid Loss:0.0105 	Valid Acc: 88.32 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:23]	 Train Loss:0.0036	 Train Acc:99.14 %  | 	Valid Loss:0.0113 	Valid Acc: 89.34 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_5_300_msf_organic_base_minmax.pt
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0201	 Train Acc:63.42 %  | 	Valid Loss:0.0205 	Valid Acc: 76.02 %
#
# Validation loss decreased (inf --> 0.020536).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0159	 Train Acc:77.96 %  | 	Valid Loss:0.0159 	Valid Acc: 84.69 %
#
# Validation loss decreased (0.020536 --> 0.015869).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0131	 Train Acc:83.87 %  | 	Valid Loss:0.0148 	Valid Acc: 86.22 %
#
# Validation loss decreased (0.015869 --> 0.014783).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0115	 Train Acc:90.15 %  | 	Valid Loss:0.0142 	Valid Acc: 86.73 %
#
# Validation loss decreased (0.014783 --> 0.014249).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0098	 Train Acc:92.73 %  | 	Valid Loss:0.0133 	Valid Acc: 88.78 %
#
# Validation loss decreased (0.014249 --> 0.013325).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0090	 Train Acc:95.57 %  | 	Valid Loss:0.0123 	Valid Acc: 88.27 %
#
# Validation loss decreased (0.013325 --> 0.012349).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0076	 Train Acc:98.40 %  | 	Valid Loss:0.0144 	Valid Acc: 85.71 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0059	 Train Acc:98.77 %  | 	Valid Loss:0.0122 	Valid Acc: 87.24 %
#
# Validation loss decreased (0.012349 --> 0.012241).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0057	 Train Acc:99.38 %  | 	Valid Loss:0.0124 	Valid Acc: 88.27 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0051	 Train Acc:99.63 %  | 	Valid Loss:0.0115 	Valid Acc: 88.78 %
#
# Validation loss decreased (0.012241 --> 0.011508).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0049	 Train Acc:99.75 %  | 	Valid Loss:0.0113 	Valid Acc: 88.27 %
#
# Validation loss decreased (0.011508 --> 0.011254).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0042	 Train Acc:99.75 %  | 	Valid Loss:0.0107 	Valid Acc: 87.24 %
#
# Validation loss decreased (0.011254 --> 0.010737).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0037	 Train Acc:99.88 %  | 	Valid Loss:0.0104 	Valid Acc: 87.76 %
#
# Validation loss decreased (0.010737 --> 0.010428).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0038	 Train Acc:100.00 %  | 	Valid Loss:0.0109 	Valid Acc: 88.78 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0033	 Train Acc:99.88 %  | 	Valid Loss:0.0126 	Valid Acc: 89.29 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:16]	 Train Loss:0.0032	 Train Acc:100.00 %  | 	Valid Loss:0.0106 	Valid Acc: 88.78 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:17]	 Train Loss:0.0029	 Train Acc:100.00 %  | 	Valid Loss:0.0097 	Valid Acc: 88.78 %
#
# Validation loss decreased (0.010428 --> 0.009658).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0027	 Train Acc:100.00 %  | 	Valid Loss:0.0093 	Valid Acc: 88.78 %
#
# Validation loss decreased (0.009658 --> 0.009260).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0024	 Train Acc:100.00 %  | 	Valid Loss:0.0102 	Valid Acc: 88.78 %
#
# EarlyStopping counter: 1 out of 5
# [EPOCH:20]	 Train Loss:0.0023	 Train Acc:100.00 %  | 	Valid Loss:0.0101 	Valid Acc: 89.29 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0023	 Train Acc:100.00 %  | 	Valid Loss:0.0099 	Valid Acc: 89.29 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0023	 Train Acc:99.88 %  | 	Valid Loss:0.0096 	Valid Acc: 88.78 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:23]	 Train Loss:0.0020	 Train Acc:100.00 %  | 	Valid Loss:0.0121 	Valid Acc: 88.27 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %% [markdown]
# # Model 결과 확인

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 100.0000 |	 valid ACC: 82.2335
# [2 교차검증] train ACC : 100.0000 |	 valid ACC: 85.2792
# [3 교차검증] train ACC : 100.0000 |	 valid ACC: 88.8325
# [4 교차검증] train ACC : 99.8765 |	 valid ACC: 87.3096
# [5 교차검증] train ACC : 100.0000 |	 valid ACC: 88.7755
# 평균 검증 정확도 86.48606650782139 %

# %% [markdown]
# # Model Test
#
# - test set
# - confusion matrix

# %%
#confusion matrix 계산
#test set 계산.
def test_evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0
average_uar = 0

for data_ind in range(1,6):

    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_msf_organic_base_minmax.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers,test_loss = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[1,0])
    
    specificity=cf[1,1]/(cf[0,1]+cf[1,1])
    average_uar += (specificity+recall)/2
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    #print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("specificity : {:.4f}%".format(specificity))
    print("UAR : {:.4f}%".format( (specificity+recall)/2 ))
    
    
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")
    #### wandb
    
    wandb.run.summary.update({"test_{}fold_acc".format(data_ind) : acc*100})
    wandb.run.summary.update({"test_{}fold_f1".format(data_ind) : fscore})
    wandb.run.summary.update({"test_{}fold_UAR".format(data_ind) : (specificity+recall)/2})
    wandb.log({"{}fold Confusion Matrix".format(data_ind) :wandb.sklearn.plot_confusion_matrix(answers, predictions, labels=classes)})
    
    ####
    
    
    

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 UAR : {:.4f}".format(average_uar/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
wandb.run.summary.update({"test 평균 acc" : average_accuracy/5})
wandb.run.summary.update({"test 평균 f1" : average_fscore/5})
wandb.run.summary.update({"test 평균 UAR" : average_uar/5})
# Out:
# 1번 모델
# Accuracy : 89.0688%
# recall (실제 pathology 중  예측이 맞는 것) : 0.8720
# specificity : 0.9098%
# UAR : 0.8909%
# f score : 0.8907
# [[109  11]
#  [ 16 111]]
# -----
# 2번 모델
# Accuracy : 87.0445%
# recall (실제 pathology 중  예측이 맞는 것) : 0.8860
# specificity : 0.8571%
# UAR : 0.8716%
# f score : 0.8701
# [[101  19]
#  [ 13 114]]
# -----
# 3번 모델
# Accuracy : 87.8543%
# recall (실제 pathology 중  예측이 맞는 것) : 0.8814
# specificity : 0.8760%
# UAR : 0.8787%
# f score : 0.8784
# [[104  16]
#  [ 14 113]]
# -----
# 4번 모델
# Accuracy : 86.2348%
# recall (실제 pathology 중  예측이 맞는 것) : 0.8707
# specificity : 0.8550%
# UAR : 0.8628%
# f score : 0.8621
# [[101  19]
#  [ 15 112]]
# -----
# 5번 모델
# Accuracy : 85.8300%
# recall (실제 pathology 중  예측이 맞는 것) : 0.8972
# specificity : 0.8286%
# UAR : 0.8629%
# f score : 0.8574
# [[ 96  24]
#  [ 11 116]]
# -----
# 평균 acc : 0.8721
# 평균 UAR : 0.8734
# 평균 f1score : 0.8717

# %% [markdown]
# ## validation set 답 정리
# - 분포 확인

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler



classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None,augment=None,normalize=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        self.augment=augment
        self.normalize=normalize
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
    
       
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc, spectro, mel-spectro를 추출
        2. mfcc를 224프레임으로 패딩. 또한 세로축은 224으로 interpolate
        3. resnet에 사용되기 위해 3채널로 쌓기.
        4. 미정. 0~1 정규화
        
        """
        sig =  phrase_dict[self.path_list[idx]] # 16000hz 실시
        length=29990 #300 padding을 위한 파라미터
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))        
        sig = pad1d(sig,length)        
        
        ###signal norm
        sig = (sig-sig.mean())/sig.std()
        ###
        
        
        
        
        
        MFCCs = librosa.feature.mfcc(y=sig, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=128)
        #MFCCs = librosa.util.normalize(MFCCs) # l-infinity norm
        #MFCCs=cv2.resize(MFCCs,(MFCCs.shape[1],128),interpolation=cv2.INTER_LINEAR)# interpolate 적용해서 128 사이즈로
        
        
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        
        
        mel_feature = librosa.feature.melspectrogram(y=sig,sr=sr,hop_length=hop_length,n_fft=n_fft)
        mel_feature = librosa.core.power_to_db(mel_feature,ref=np.max)
        #mel_feature=librosa.util.normalize(mel_feature) # l-infinity norm
        
        #stft 300 FRAME이 되도록 패딩.
        #length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        #log_spectrogram = librosa.util.normalize(log_spectrogram) # l-infinity norm
        
        
        #padding
        #pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        #log_spectrogram = pad2d(log_spectrogram, length)
        #mel_feature = pad2d(mel_feature, length)
        
        #MFCCs = pad2d(MFCCs, length) # mfcc 대신 encoder를 가져와서 해보자.
        log_spectrogram=log_spectrogram[:128,:]# 224 x 300 으로 사이즈 조절
        
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 타입 변화
            mel_feature=self.transform(mel_feature).type(torch.float32)# 타입 변화
            MFCCs=self.transform(MFCCs).type(torch.float32)# 타입 변화            
            
            MSF = torch.stack([log_spectrogram,mel_feature,MFCCs])# 3채널로 복사.
            
            #augmentation
            if self.training and self.augment:
                MSF = MSF.squeeze(dim=1)
                MSF=self.augment(MSF)
            else:
                MSF = MSF.squeeze(dim=1)
            
            # global normalize
            if self.normalize:
                MSF=self.normalize(MSF)
        else:
            #print("else")
            ##################안쓰는 곳
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MSF, self.classes.index(self.label[idx]),self.path_list[idx]

# %%
#confusion matrix 계산
#valid set 계산.
all_filename=[]
all_prediction=[]
all_answers=[]


def valid_evaluate(model,data_ind):
    model.eval()
    test_loss = 0
    file_name = []
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   transform=transforms.ToTensor(),
                                                   data_num=data_ind-1,
                                                   normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    
    with torch.no_grad():
        for image, label,path_list in validation_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            file_name+=(path_list)            
        all_filename.append(file_name)
        all_prediction.append(predictions)
        all_answers.append(answers)
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_msf_organic_base_global_norm2.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers, valid_loss = valid_evaluate(model,data_ind)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
# Out:
# 1번 모델
# Accuracy : 84.7716%
# Precision (pathology 예측한 것중 맞는 것) : 0.8511
# recall (실제 pathology 중  예측이 맞는 것) : 0.8333
# f score : 0.8475
# [[80 16]
#  [14 87]]
# -----
# 2번 모델
# Accuracy : 85.7868%
# Precision (pathology 예측한 것중 맞는 것) : 0.8400
# recall (실제 pathology 중  예측이 맞는 것) : 0.8750
# f score : 0.8579
# [[84 12]
#  [16 85]]
# -----
# 3번 모델
# Accuracy : 85.7868%
# Precision (pathology 예측한 것중 맞는 것) : 0.8526
# recall (실제 pathology 중  예측이 맞는 것) : 0.8526
# f score : 0.8577
# [[81 14]
#  [14 88]]
# -----
# 4번 모델
# Accuracy : 86.8020%
# Precision (pathology 예측한 것중 맞는 것) : 0.8632
# recall (실제 pathology 중  예측이 맞는 것) : 0.8632
# f score : 0.8679
# [[82 13]
#  [13 89]]
# -----
# 5번 모델
# Accuracy : 90.8163%
# Precision (pathology 예측한 것중 맞는 것) : 0.9425
# recall (실제 pathology 중  예측이 맞는 것) : 0.8632
# f score : 0.9077
# [[82 13]
#  [ 5 96]]
# -----
# 평균 acc : 0.8679
# 평균 f1score : 0.8677

# %%
len(all_filename)
# Out:
# 5

# %%
fold_excel = []
for i in range(5):
    fold_excel.append(pd.DataFrame({'filename':all_filename[i],
                  'prediction':[data.cpu().numpy().item() for data in all_prediction[i]],
                  'answer':[ data.cpu().numpy().item() for data in all_answers[i]],
                  'fold':i+1}))

# %%
fold_excel_all=pd.concat(fold_excel,axis=0)

# %%
answer_paper=pd.read_excel('D:/project/voice_pathology_ai/voice_data/only_organics_healthy.xlsx')
answer_paper.head()
# Out:
#    RECORDING PATHOLOGY        DATE  SPEAKER GENDER  AGE  \
# 0        715         p  20.05.1998     1407      w   63
# 1       1303         p  21.04.1999     1407      w   64
# 2       1557         p  08.12.1999     1407      w   65
# 3       1559         p  15.12.1999     1407      w   65
# 4       1864         p  29.11.2000     1407      w   66
#
#                     DETAIL        DIAG
# 0  Laryngitis; Leukoplakie  structural
# 1              Leukoplakie  structural
# 2              Leukoplakie  structural
# 3              Leukoplakie  structural
# 4              Leukoplakie  structural

# %%
answer_paper['RECORDING']=answer_paper['RECORDING'].values.astype(str)

# %%
answer_paper['RECORDING']=answer_paper['RECORDING']+'-phrase.wav'

# %%
answer_paper[['RECORDING','DETAIL','AGE']]
# Out:
#             RECORDING                   DETAIL  AGE
# 0      715-phrase.wav  Laryngitis; Leukoplakie   63
# 1     1303-phrase.wav              Leukoplakie   64
# 2     1557-phrase.wav              Leukoplakie   65
# 3     1559-phrase.wav              Leukoplakie   65
# 4     1864-phrase.wav              Leukoplakie   66
# ...               ...                      ...  ...
# 1461    80-phrase.wav                  control   49
# 1462    81-phrase.wav                  control   42
# 1463    82-phrase.wav                  control   49
# 1464    83-phrase.wav                  control   46
# 1465   153-phrase.wav                  control   60
#
# [1466 rows x 3 columns]

# %%
merge_left = pd.merge(fold_excel_all,answer_paper[['RECORDING','DETAIL','AGE','SPEAKER']], how='left', left_on='filename', right_on='RECORDING')
merge_left
# Out:
#             filename  prediction  answer  fold        RECORDING  \
# 0    1105-phrase.wav           1       1     1  1105-phrase.wav
# 1     122-phrase.wav           1       1     1   122-phrase.wav
# 2    1817-phrase.wav           0       0     1  1817-phrase.wav
# 3    1553-phrase.wav           1       0     1  1553-phrase.wav
# 4    1749-phrase.wav           0       0     1  1749-phrase.wav
# ..               ...         ...     ...   ...              ...
# 979  1100-phrase.wav           1       1     5  1100-phrase.wav
# 980  1638-phrase.wav           0       0     5  1638-phrase.wav
# 981  1237-phrase.wav           0       0     5  1237-phrase.wav
# 982  1583-phrase.wav           1       1     5  1583-phrase.wav
# 983  1167-phrase.wav           1       1     5  1167-phrase.wav
#
#                                              DETAIL  AGE  SPEAKER
# 0                                           control   37      878
# 1                                           control   19      129
# 2                            Spasmodische Dysphonie   36     2027
# 3                                   Rekurrensparese   51     1863
# 4    Frontolaterale Teilresektion; Stimmlippenpolyp   57     2000
# ..                                              ...  ...      ...
# 979                                         control   19      871
# 980                                 Rekurrensparese   56     1932
# 981                                      Laryngitis   45     1623
# 982                                         control   20     1030
# 983                                         control   18      920
#
# [984 rows x 8 columns]

# %%
merge_left.drop(['RECORDING'],axis=1,inplace=True)

# %%
merge_left['result']=merge_left['prediction']==merge_left['answer']

# %%
merge_left
# Out:
#             filename  prediction  answer  fold  \
# 0    1105-phrase.wav           1       1     1
# 1     122-phrase.wav           1       1     1
# 2    1817-phrase.wav           0       0     1
# 3    1553-phrase.wav           1       0     1
# 4    1749-phrase.wav           0       0     1
# ..               ...         ...     ...   ...
# 979  1100-phrase.wav           1       1     5
# 980  1638-phrase.wav           0       0     5
# 981  1237-phrase.wav           0       0     5
# 982  1583-phrase.wav           1       1     5
# 983  1167-phrase.wav           1       1     5
#
#                                              DETAIL  AGE  SPEAKER  result
# 0                                           control   37      878    True
# 1                                           control   19      129    True
# 2                            Spasmodische Dysphonie   36     2027    True
# 3                                   Rekurrensparese   51     1863   False
# 4    Frontolaterale Teilresektion; Stimmlippenpolyp   57     2000    True
# ..                                              ...  ...      ...     ...
# 979                                         control   19      871    True
# 980                                 Rekurrensparese   56     1932    True
# 981                                      Laryngitis   45     1623    True
# 982                                         control   20     1030    True
# 983                                         control   18      920    True
#
# [984 rows x 8 columns]

# %%
merge_left.to_excel('D:/project/voice_pathology_ai/voice_data/result_valid_organics_0622_globalNorm.xlsx',index=False)

# %% [markdown]
# ## validation cam

# %%
# final conv layer name 
finalconv_name = 'layer4'

# activations
feature_blobs = []

# gradient를 가져올 hook 함수
backward_feature = []

transform_norm = transforms.ToTensor()

# output으로 나오는 feature를 feature_blobs에 append하도록
def hook_feature(module, input, output):
    feature_blobs.append(output.cpu().data.numpy()) # 레이어의 마지막 output(피처맵)을 구하는 함수
    

# Grad-CAM
def backward_hook(module, input, output):
    backward_feature.append(output[0])  #backward시에 그래디언트 저장.

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler



classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None,augment=None,normalize=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        self.augment=augment
        self.normalize=normalize
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
    
       
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc, spectro, mel-spectro를 추출
        2. mfcc를 224프레임으로 패딩. 또한 세로축은 224으로 interpolate
        3. resnet에 사용되기 위해 3채널로 쌓기.
        4. 미정. 0~1 정규화
        
        """
        sig =  phrase_dict[self.path_list[idx]] # 16000hz 실시
        length=29990 #300 padding을 위한 파라미터
        pad1d=lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))        
        sig = pad1d(sig,length)        
        
        ###signal norm
        sig = (sig-sig.mean())/sig.std()
        ###
        
        
        
        
        
        MFCCs = librosa.feature.mfcc(y=sig, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=128)
        #MFCCs = librosa.util.normalize(MFCCs) # l-infinity norm
        #MFCCs=cv2.resize(MFCCs,(MFCCs.shape[1],128),interpolation=cv2.INTER_LINEAR)# interpolate 적용해서 128 사이즈로
        
        
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        
        
        mel_feature = librosa.feature.melspectrogram(y=sig,sr=sr,hop_length=hop_length,n_fft=n_fft)
        mel_feature = librosa.core.power_to_db(mel_feature,ref=np.max)
        #mel_feature=librosa.util.normalize(mel_feature) # l-infinity norm
        
        #stft 300 FRAME이 되도록 패딩.
        #length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        #log_spectrogram = librosa.util.normalize(log_spectrogram) # l-infinity norm
        
        
        #padding
        #pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        #log_spectrogram = pad2d(log_spectrogram, length)
        #mel_feature = pad2d(mel_feature, length)
        
        #MFCCs = pad2d(MFCCs, length) # mfcc 대신 encoder를 가져와서 해보자.
        log_spectrogram=log_spectrogram[:128,:]# 224 x 300 으로 사이즈 조절
        
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 타입 변화
            mel_feature=self.transform(mel_feature).type(torch.float32)# 타입 변화
            MFCCs=self.transform(MFCCs).type(torch.float32)# 타입 변화            
            
            MSF = torch.stack([log_spectrogram,mel_feature,MFCCs])# 3채널로 복사.
            
            #augmentation
            if self.training and self.augment:
                MSF = MSF.squeeze(dim=1)
                MSF=self.augment(MSF)
            else:
                MSF = MSF.squeeze(dim=1)
            
            # global normalize
            if self.normalize:
                MSF=self.normalize(MSF)
        else:
            #print("else")
            ##################안쓰는 곳
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MSF, self.classes.index(self.label[idx]),self.path_list[idx]

# %%
CAM_BATCH_SIZE=1
finalconv_name
# Out:
# 'layer4'

# %%
check_path
# Out:
# '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_2_300_msf_organic_base_global_norm2.pt'

# %%
from torch.autograd import Variable
from torchvision.utils import make_grid, save_image



#pathology 음성 파일 가져오기

length=300
image_list=[]

label_list=[]
prob_list=[] #valid set의 확률값
name_list=[] #파일명
predict_label_list=[] #예측 라벨
res = []



mel_list=[]#정규 mel-spectrogram 모은 리스트
fallout_list=[] # cam - mel . 음수는 0 처리.
cam_list=[]# cam list



mel_sample=None


for data_ind in  range(1,6):
    print("----------------")
    print(data_ind,'fold')
    print("----------------")
    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   transform=transforms.ToTensor(),
                                                   data_num=data_ind-1,
                                                   normalize=transforms.Normalize((-9.27142, -56.4917,-0.87598), (16.8772,17.9446,28.5648)),
                                                   training=False
                                               ),
                                               batch_size = CAM_BATCH_SIZE,
                                               shuffle = True,) 
    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_msf_organic_base_global_norm2.pt'
    model.load_state_dict(torch.load(check_path))
    model.eval()
    
    
    for image, label, path in validation_loader:

        name = path[0].split('\\')[-1]
        name = name.replace('.wav', '')
        name_list.append(name)
        label_list.append(classes[label])

        # activations
        feature_blobs = []
        # gradient를 가져올 hook 함수
        backward_feature = []

        mel_sample = image
        mel_sample = mel_sample.to(DEVICE).float()

        
        model._modules.get('model')._modules.get(finalconv_name).register_forward_hook(hook_feature)
        model._modules.get('model')._modules.get(finalconv_name).register_backward_hook(backward_hook)
        


        # Prediction
        logit = model(mel_sample) # 예측값 구하기.
        out = F.softmax(logit, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
        probs, idx = out.sort(0, True)
        print("Predicted label : %d, Probability : %.2f" % (idx[0].item(), probs[0].item()))
        predict_label_list.append(classes[idx[0].item()])
        prob_list.append(probs[0].item())
        res.append(classes[label]==classes[idx[0].item()])


        ###########
        # Grad - cam
        ###########

        score = logit[:, idx[0]].squeeze() # 예측값 y^c.
        score.backward(retain_graph = True) # 예측값 y^c에 대해서 backprop 진행

        activations = torch.Tensor(feature_blobs[0]).to(DEVICE) # (1, 512, 7, 7), forward activations. append라서 0번이 마지막
        gradients = backward_feature[0] # (1, 512, 4, 10), backward gradients. 마지막 conv layer의 gradient
        b, k, u, v = gradients.size()  # batch, 피처맵 수,  상, 하
        #print(gradients.size())

        alpha = gradients.view(b, k, -1).mean(2) # (1, 512, 7*7) => (1, 512), feature map k의 'importance'
        weights = alpha.view(b, k, 1, 1) # (1, 512, 1, 1)

        grad_cam_map = (weights*activations).sum(1, keepdim = True) # alpha * A^k = (1, 512, 7, 7) => (1, 1, 7, 7)
        grad_cam_map = F.relu(grad_cam_map) # Apply R e L U
        grad_cam_map = F.interpolate(grad_cam_map, size=(128, 300), mode='bilinear', align_corners=False) # (1, 1, 128, 300)
        map_min, map_max = grad_cam_map.min(), grad_cam_map.max()
        grad_cam_map = (grad_cam_map - map_min).div(map_max - map_min).data # (1, 1, 128, 300), min-max scaling

        grad_heatmap=grad_cam_map.squeeze().cpu()
        cam_list.append(grad_heatmap)
        # grad_cam_map.squeeze() : (128, 300)

        #save_image(grad_heatmap, os.path.join("./", "Grad_CAM.jpg"))

        # mel-spectorgram min-max normalization

        mel_min,mel_max = mel_sample.squeeze()[1].min(),mel_sample.squeeze()[1].max()
        mel_sample = (mel_sample.squeeze()[1]- mel_min).div(mel_max-mel_min)
        mel_sample = mel_sample.cpu().numpy()
        mel_list.append(mel_sample)


        #mel_sample = librosa.util.normalize(mel_sample.cpu().squeeze().numpy()[0]) #수정 필요. min-max normalization

        grad_result = grad_heatmap.numpy() + mel_sample # (1, 3, 244, 244)

        fallout_list.append(grad_heatmap.numpy() - mel_sample)


        plt.figure(figsize=(10,5))
        plt.ion()
        plt.subplot(131)
        librosa.display.specshow(mel_sample, sr=sr, hop_length=hop_length)
        plt.xlabel("Time")
        plt.ylabel("Frequency")
        plt.colorbar(format='%+2.0f dB')
        plt.title("Spectrogram (dB)")

        plt.subplot(132)
        librosa.display.specshow(grad_heatmap.numpy(), sr=sr, hop_length=hop_length)
        plt.xlabel("Time")
        plt.ylabel("Frequency")
        plt.colorbar(format='%+2.0f dB')
        plt.title("Spectrogram (dB)")

        plt.subplot(133)
        librosa.display.specshow(grad_result, sr=sr, hop_length=hop_length)
        plt.xlabel("Time")
        plt.ylabel("Frequency")
        plt.colorbar(format='%+2.0f dB')
        plt.title("Spectrogram (dB)")


        
        folder_path='D:/project/voice_pathology_ai/voice_data/organics_globalnorm_cam_fold/'+str(data_ind)+'fold/'
        plt.savefig(folder_path+name)
        plt.close()
    

#result_excel=pd.concat( [pd.DataFrame(name_list),
#            pd.DataFrame(label_list),
#            pd.DataFrame(predict_label_list),
#            pd.DataFrame(prob_list),
#            pd.DataFrame(res)],axis=1)
#result_excel.columns=['name','class','predict','probability','result']
#result_excel.to_excel("D:/project/voice_pathology_ai/voice_data/result_excel_fallout_valid.xlsx",index=False)
# Out:
# ----------------
# 1 fold
# ----------------
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.86
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.91
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.73
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.74
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.77
# Predicted label : 1, Probability : 0.80
# Predicted label : 0, Probability : 0.81
# Predicted label : 0, Probability : 0.74
# Predicted label : 0, Probability : 0.66
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.88
# Predicted label : 1, Probability : 0.51
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.73
# Predicted label : 1, Probability : 0.79
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.83
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.77
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.73
# Predicted label : 0, Probability : 0.50
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.73
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.81
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.52
# Predicted label : 0, Probability : 0.83
# Predicted label : 1, Probability : 0.61
# Predicted label : 0, Probability : 0.73
# Predicted label : 1, Probability : 0.72
# Predicted label : 0, Probability : 0.86
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.77
# Predicted label : 1, Probability : 0.64
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.76
# Predicted label : 0, Probability : 0.50
# Predicted label : 1, Probability : 0.70
# Predicted label : 0, Probability : 0.81
# Predicted label : 0, Probability : 0.54
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.75
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.65
# Predicted label : 0, Probability : 0.77
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.60
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.61
# Predicted label : 0, Probability : 0.84
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.71
# Predicted label : 0, Probability : 0.75
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.54
# Predicted label : 0, Probability : 0.67
# Predicted label : 1, Probability : 0.77
# Predicted label : 1, Probability : 0.63
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.80
# Predicted label : 1, Probability : 0.76
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.70
# Predicted label : 0, Probability : 0.68
# Predicted label : 1, Probability : 0.80
# Predicted label : 0, Probability : 0.71
# Predicted label : 1, Probability : 0.85
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.73
# Predicted label : 1, Probability : 0.52
# Predicted label : 1, Probability : 0.75
# Predicted label : 1, Probability : 0.69
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.67
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.77
# Predicted label : 0, Probability : 0.63
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.81
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.80
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.71
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.66
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.91
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.71
# Predicted label : 1, Probability : 0.75
# Predicted label : 0, Probability : 0.68
# Predicted label : 0, Probability : 0.75
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.91
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.65
# Predicted label : 0, Probability : 0.84
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.85
# Predicted label : 1, Probability : 0.69
# Predicted label : 1, Probability : 0.62
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.68
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.56
# Predicted label : 1, Probability : 0.73
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.88
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.56
# Predicted label : 0, Probability : 0.88
# Predicted label : 0, Probability : 0.76
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.68
# Predicted label : 1, Probability : 0.69
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.80
# Predicted label : 0, Probability : 0.78
# Predicted label : 1, Probability : 0.76
# Predicted label : 1, Probability : 0.84
# Predicted label : 1, Probability : 0.61
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.64
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.52
# Predicted label : 0, Probability : 0.80
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.86
# Predicted label : 0, Probability : 0.52
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.63
# Predicted label : 0, Probability : 0.75
# Predicted label : 0, Probability : 0.83
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.86
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.60
# Predicted label : 1, Probability : 0.70
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.60
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.73
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.60
# ----------------
# 2 fold
# ----------------
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.62
# Predicted label : 0, Probability : 0.78
# Predicted label : 1, Probability : 0.70
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.66
# Predicted label : 0, Probability : 0.76
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.65
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.86
# Predicted label : 0, Probability : 0.63
# Predicted label : 1, Probability : 0.65
# Predicted label : 1, Probability : 0.52
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.80
# Predicted label : 1, Probability : 0.58
# Predicted label : 0, Probability : 0.61
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.58
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.84
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.54
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.98
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.72
# Predicted label : 0, Probability : 0.98
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.63
# Predicted label : 1, Probability : 0.62
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.61
# Predicted label : 0, Probability : 0.98
# Predicted label : 0, Probability : 0.88
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.57
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.86
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.51
# Predicted label : 0, Probability : 0.68
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.62
# Predicted label : 0, Probability : 0.82
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.72
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.75
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.99
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.74
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.89
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.98
# Predicted label : 0, Probability : 0.75
# Predicted label : 1, Probability : 0.79
# Predicted label : 0, Probability : 0.86
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.81
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.61
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.89
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.56
# Predicted label : 0, Probability : 0.72
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.77
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.72
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.61
# Predicted label : 0, Probability : 0.98
# Predicted label : 0, Probability : 0.91
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.82
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.75
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.89
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.54
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.84
# Predicted label : 1, Probability : 0.51
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.86
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.65
# Predicted label : 1, Probability : 0.75
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.55
# Predicted label : 0, Probability : 0.69
# Predicted label : 0, Probability : 0.71
# Predicted label : 0, Probability : 0.76
# Predicted label : 0, Probability : 0.75
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.73
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.76
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.72
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.53
# Predicted label : 1, Probability : 0.88
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.89
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.57
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.80
# Predicted label : 0, Probability : 0.51
# Predicted label : 0, Probability : 0.56
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.78
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.77
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.87
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.58
# Predicted label : 0, Probability : 0.74
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.70
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.57
# Predicted label : 1, Probability : 0.57
# ----------------
# 3 fold
# ----------------
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.99
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.68
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.77
# Predicted label : 0, Probability : 0.64
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.56
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.99
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.77
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.63
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.89
# Predicted label : 1, Probability : 0.74
# Predicted label : 1, Probability : 0.98
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.54
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.84
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.75
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.62
# Predicted label : 1, Probability : 0.99
# Predicted label : 0, Probability : 0.73
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.73
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.58
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.78
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.99
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.79
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.76
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.84
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.98
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.87
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.66
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.65
# Predicted label : 0, Probability : 0.88
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.85
# Predicted label : 1, Probability : 0.77
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.70
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.98
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.78
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.99
# Predicted label : 0, Probability : 0.84
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.88
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.99
# Predicted label : 0, Probability : 0.74
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.52
# Predicted label : 0, Probability : 0.78
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.82
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.77
# Predicted label : 0, Probability : 0.83
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.87
# Predicted label : 0, Probability : 0.87
# Predicted label : 0, Probability : 0.71
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.78
# Predicted label : 0, Probability : 0.53
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.69
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.81
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.80
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.85
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.75
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.51
# Predicted label : 1, Probability : 0.53
# Predicted label : 1, Probability : 0.57
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.72
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.78
# Predicted label : 1, Probability : 0.68
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.79
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.78
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.79
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.92
# ----------------
# 4 fold
# ----------------
# Predicted label : 0, Probability : 0.79
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.98
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.81
# Predicted label : 0, Probability : 0.84
# Predicted label : 0, Probability : 0.83
# Predicted label : 0, Probability : 0.62
# Predicted label : 0, Probability : 0.67
# Predicted label : 0, Probability : 0.66
# Predicted label : 1, Probability : 0.63
# Predicted label : 0, Probability : 0.84
# Predicted label : 0, Probability : 0.79
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.62
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.72
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.67
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.60
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.76
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.67
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.67
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.72
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.69
# Predicted label : 1, Probability : 0.81
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.56
# Predicted label : 0, Probability : 0.73
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.64
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.84
# Predicted label : 0, Probability : 0.62
# Predicted label : 0, Probability : 0.67
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.73
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.85
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.80
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.61
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.63
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.76
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.59
# Predicted label : 1, Probability : 0.77
# Predicted label : 1, Probability : 0.58
# Predicted label : 1, Probability : 0.53
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.79
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.86
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.72
# Predicted label : 1, Probability : 0.73
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.83
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.68
# Predicted label : 0, Probability : 0.69
# Predicted label : 1, Probability : 0.79
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.88
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.74
# Predicted label : 1, Probability : 0.84
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.81
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.56
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.88
# Predicted label : 1, Probability : 0.74
# Predicted label : 1, Probability : 0.78
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.60
# Predicted label : 1, Probability : 0.71
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.58
# Predicted label : 1, Probability : 0.72
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.85
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.81
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.73
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.77
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.73
# Predicted label : 0, Probability : 0.72
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.68
# Predicted label : 0, Probability : 0.83
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.50
# Predicted label : 1, Probability : 0.92
# Predicted label : 0, Probability : 0.83
# Predicted label : 1, Probability : 0.59
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.86
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.88
# Predicted label : 1, Probability : 0.85
# Predicted label : 0, Probability : 0.65
# Predicted label : 0, Probability : 0.87
# Predicted label : 1, Probability : 0.90
# ----------------
# 5 fold
# ----------------
# Predicted label : 0, Probability : 0.74
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.81
# Predicted label : 1, Probability : 0.97
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.83
# Predicted label : 0, Probability : 0.80
# Predicted label : 0, Probability : 0.77
# Predicted label : 0, Probability : 0.59
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.76
# Predicted label : 0, Probability : 0.63
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.68
# Predicted label : 0, Probability : 0.81
# Predicted label : 0, Probability : 0.58
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.57
# Predicted label : 0, Probability : 0.67
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.98
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.74
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.75
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.73
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.69
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.79
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.53
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.90
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.82
# Predicted label : 0, Probability : 0.98
# Predicted label : 1, Probability : 0.65
# Predicted label : 0, Probability : 0.82
# Predicted label : 1, Probability : 0.96
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.75
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.81
# Predicted label : 0, Probability : 0.63
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.70
# Predicted label : 0, Probability : 0.53
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.87
# Predicted label : 1, Probability : 0.97
# Predicted label : 1, Probability : 0.90
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.70
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.72
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.73
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.89
# Predicted label : 0, Probability : 0.54
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.76
# Predicted label : 1, Probability : 0.76
# Predicted label : 1, Probability : 0.52
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.96
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.86
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.54
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.84
# Predicted label : 0, Probability : 0.71
# Predicted label : 1, Probability : 0.93
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.76
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.73
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.72
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.87
# Predicted label : 0, Probability : 0.94
# Predicted label : 0, Probability : 0.79
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.83
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.98
# Predicted label : 0, Probability : 0.95
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.91
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.86
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.82
# Predicted label : 0, Probability : 0.79
# Predicted label : 0, Probability : 0.79
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.91
# Predicted label : 0, Probability : 0.89
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.90
# Predicted label : 1, Probability : 0.82
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.94
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.95
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.89
# Predicted label : 0, Probability : 0.92
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.74
# Predicted label : 0, Probability : 0.62
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.91
# Predicted label : 1, Probability : 0.56
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.96
# Predicted label : 1, Probability : 0.86
# Predicted label : 0, Probability : 0.85
# Predicted label : 1, Probability : 0.89
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.97
# Predicted label : 0, Probability : 0.87
# Predicted label : 0, Probability : 0.97
# Predicted label : 1, Probability : 0.98
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.84
# Predicted label : 1, Probability : 0.91
# Predicted label : 1, Probability : 0.84
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.93
# Predicted label : 0, Probability : 0.64
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.76
# Predicted label : 1, Probability : 0.95
# Predicted label : 1, Probability : 0.96
# Predicted label : 0, Probability : 0.53
# Predicted label : 0, Probability : 0.56
# Predicted label : 1, Probability : 0.94
# Predicted label : 0, Probability : 0.90
# Predicted label : 0, Probability : 0.93
# Predicted label : 1, Probability : 0.95
# Predicted label : 0, Probability : 0.92
# Predicted label : 1, Probability : 0.93
# Predicted label : 0, Probability : 0.94
# Predicted label : 1, Probability : 0.92
# Predicted label : 1, Probability : 0.85
# Predicted label : 0, Probability : 0.88
# Predicted label : 0, Probability : 0.93

# %%
from numpy import unravel_index

max_Freq_list = []

for tmp in cam_list:
    #tmp = grad_cam_map.cpu().numpy()
    print(unravel_index(np.argmax(tmp),tmp.shape ))
    max_Freq_list.append(unravel_index(np.argmax(tmp),tmp.shape )[0])
# Out:
# (79, 44)
# (47, 74)
# (47, 45)
# (79, 44)
# (47, 44)
# (47, 45)
# (48, 44)
# (0, 44)
# (79, 44)
# (0, 44)
# (48, 255)
# (79, 194)
# (80, 0)
# (79, 44)
# (47, 44)
# (79, 44)
# (47, 225)
# (47, 165)
# (47, 75)
# (79, 44)
# (79, 45)
# (80, 44)
# (47, 44)
# (79, 44)
# (79, 134)
# (47, 44)
# (48, 44)
# (48, 44)
# (48, 164)
# (47, 45)
# (47, 44)
# (79, 45)
# (48, 44)
# (47, 44)
# (47, 44)
# (80, 75)
# (47, 134)
# (47, 44)
# (47, 44)
# (79, 255)
# (80, 45)
# (47, 44)
# (79, 255)
# (79, 44)
# (80, 0)
# (47, 44)
# (79, 45)
# (47, 44)
# (48, 0)
# (47, 44)
# (79, 0)
# (79, 0)
# (79, 0)
# (47, 44)
# (47, 45)
# (80, 45)
# (47, 44)
# (80, 195)
# (48, 254)
# (47, 44)
# (47, 194)
# (79, 194)
# (79, 74)
# (47, 0)
# (47, 164)
# (47, 44)
# (80, 44)
# (47, 44)
# (47, 255)
# (47, 44)
# (79, 44)
# (47, 45)
# (48, 44)
# (47, 44)
# (47, 164)
# (79, 44)
# (80, 0)
# (79, 44)
# (47, 254)
# (79, 255)
# (47, 0)
# (48, 44)
# (80, 45)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (48, 194)
# (0, 0)
# (80, 165)
# (47, 164)
# (47, 195)
# (80, 0)
# (47, 104)
# (0, 195)
# (79, 44)
# (79, 195)
# (47, 44)
# (47, 44)
# (79, 105)
# (79, 44)
# (47, 44)
# (0, 164)
# (48, 0)
# (79, 134)
# (48, 45)
# (47, 254)
# (79, 0)
# (47, 44)
# (79, 165)
# (79, 45)
# (48, 0)
# (47, 134)
# (80, 194)
# (48, 44)
# (47, 44)
# (47, 44)
# (80, 74)
# (48, 224)
# (47, 44)
# (47, 45)
# (79, 44)
# (48, 0)
# (47, 75)
# (47, 255)
# (47, 44)
# (79, 44)
# (48, 45)
# (47, 45)
# (47, 44)
# (80, 44)
# (47, 74)
# (48, 44)
# (79, 44)
# (79, 225)
# (0, 75)
# (47, 45)
# (79, 44)
# (80, 44)
# (47, 44)
# (79, 45)
# (47, 104)
# (79, 134)
# (79, 165)
# (47, 44)
# (48, 255)
# (47, 44)
# (47, 104)
# (47, 135)
# (79, 44)
# (47, 75)
# (80, 44)
# (47, 75)
# (47, 45)
# (0, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (48, 254)
# (79, 74)
# (79, 0)
# (79, 44)
# (47, 44)
# (79, 164)
# (47, 44)
# (79, 44)
# (80, 44)
# (79, 44)
# (79, 44)
# (79, 135)
# (79, 134)
# (47, 44)
# (79, 255)
# (47, 44)
# (47, 225)
# (48, 164)
# (79, 44)
# (47, 254)
# (79, 44)
# (47, 44)
# (80, 0)
# (47, 44)
# (47, 165)
# (47, 45)
# (47, 44)
# (47, 44)
# (47, 255)
# (47, 44)
# (79, 45)
# (47, 255)
# (79, 74)
# (79, 44)
# (79, 75)
# (79, 44)
# (48, 0)
# (48, 44)
# (47, 254)
# (0, 0)
# (79, 134)
# (47, 44)
# (0, 44)
# (0, 44)
# (80, 44)
# (80, 134)
# (112, 45)
# (79, 105)
# (48, 135)
# (47, 44)
# (47, 44)
# (48, 225)
# (48, 194)
# (79, 44)
# (47, 0)
# (47, 44)
# (47, 224)
# (79, 164)
# (0, 0)
# (79, 165)
# (79, 255)
# (47, 0)
# (0, 105)
# (47, 0)
# (48, 195)
# (48, 44)
# (112, 224)
# (48, 194)
# (0, 0)
# (47, 0)
# (47, 44)
# (0, 45)
# (80, 164)
# (47, 44)
# (47, 45)
# (48, 225)
# (48, 44)
# (48, 164)
# (79, 195)
# (47, 0)
# (47, 0)
# (47, 0)
# (47, 224)
# (79, 44)
# (79, 165)
# (47, 0)
# (48, 44)
# (79, 165)
# (48, 165)
# (79, 165)
# (79, 164)
# (48, 105)
# (47, 165)
# (47, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (48, 195)
# (47, 135)
# (80, 195)
# (0, 44)
# (48, 165)
# (0, 0)
# (47, 44)
# (0, 45)
# (79, 135)
# (47, 44)
# (47, 44)
# (47, 0)
# (47, 0)
# (47, 44)
# (79, 44)
# (80, 44)
# (47, 254)
# (48, 195)
# (47, 0)
# (48, 44)
# (47, 44)
# (48, 0)
# (48, 164)
# (47, 0)
# (47, 44)
# (47, 0)
# (79, 44)
# (79, 165)
# (80, 224)
# (48, 164)
# (47, 45)
# (48, 44)
# (0, 44)
# (48, 164)
# (0, 0)
# (79, 165)
# (79, 0)
# (80, 165)
# (48, 44)
# (0, 44)
# (79, 195)
# (80, 254)
# (79, 105)
# (47, 45)
# (79, 224)
# (80, 194)
# (79, 255)
# (47, 45)
# (80, 255)
# (47, 44)
# (79, 135)
# (0, 44)
# (79, 45)
# (79, 165)
# (47, 45)
# (0, 0)
# (79, 74)
# (80, 254)
# (80, 194)
# (79, 195)
# (80, 255)
# (47, 44)
# (80, 134)
# (47, 0)
# (48, 194)
# (0, 45)
# (48, 164)
# (47, 44)
# (80, 254)
# (47, 44)
# (0, 0)
# (79, 225)
# (47, 0)
# (47, 0)
# (47, 44)
# (112, 255)
# (48, 164)
# (80, 135)
# (47, 0)
# (48, 164)
# (80, 0)
# (80, 105)
# (47, 0)
# (0, 44)
# (0, 0)
# (79, 164)
# (47, 44)
# (48, 255)
# (48, 164)
# (79, 194)
# (0, 45)
# (47, 0)
# (79, 254)
# (48, 44)
# (47, 44)
# (80, 135)
# (79, 195)
# (80, 165)
# (80, 134)
# (48, 165)
# (47, 164)
# (47, 44)
# (79, 165)
# (48, 135)
# (47, 0)
# (47, 0)
# (79, 45)
# (47, 44)
# (47, 45)
# (48, 165)
# (79, 164)
# (80, 74)
# (80, 254)
# (48, 194)
# (79, 165)
# (48, 44)
# (80, 0)
# (48, 195)
# (0, 255)
# (47, 0)
# (47, 105)
# (79, 44)
# (0, 44)
# (47, 44)
# (79, 44)
# (79, 135)
# (48, 44)
# (47, 0)
# (47, 44)
# (79, 255)
# (0, 0)
# (47, 0)
# (79, 0)
# (79, 194)
# (0, 44)
# (47, 44)
# (47, 0)
# (79, 44)
# (0, 74)
# (48, 44)
# (79, 44)
# (112, 134)
# (48, 44)
# (48, 165)
# (80, 224)
# (48, 44)
# (0, 0)
# (80, 104)
# (47, 74)
# (80, 74)
# (48, 44)
# (0, 75)
# (80, 44)
# (48, 225)
# (47, 164)
# (48, 44)
# (79, 105)
# (79, 45)
# (80, 44)
# (48, 44)
# (80, 135)
# (47, 134)
# (80, 45)
# (112, 105)
# (47, 255)
# (79, 44)
# (79, 44)
# (112, 194)
# (80, 135)
# (79, 105)
# (112, 45)
# (80, 164)
# (48, 44)
# (47, 44)
# (79, 44)
# (48, 164)
# (80, 44)
# (112, 105)
# (80, 164)
# (48, 44)
# (79, 255)
# (79, 44)
# (112, 135)
# (80, 254)
# (112, 194)
# (48, 134)
# (80, 105)
# (80, 134)
# (48, 44)
# (80, 164)
# (80, 44)
# (48, 44)
# (48, 44)
# (79, 44)
# (112, 285)
# (48, 44)
# (112, 74)
# (48, 44)
# (112, 165)
# (48, 194)
# (80, 44)
# (112, 135)
# (47, 44)
# (112, 165)
# (79, 44)
# (48, 165)
# (79, 45)
# (112, 194)
# (47, 0)
# (112, 164)
# (48, 44)
# (80, 135)
# (48, 45)
# (79, 44)
# (48, 254)
# (112, 164)
# (79, 44)
# (47, 44)
# (79, 254)
# (47, 194)
# (48, 45)
# (47, 45)
# (79, 44)
# (48, 44)
# (0, 105)
# (48, 164)
# (80, 195)
# (0, 104)
# (48, 224)
# (79, 44)
# (79, 44)
# (48, 45)
# (48, 105)
# (79, 44)
# (79, 44)
# (79, 164)
# (47, 75)
# (112, 254)
# (112, 254)
# (48, 44)
# (79, 44)
# (79, 45)
# (112, 225)
# (112, 165)
# (79, 44)
# (48, 44)
# (47, 44)
# (112, 165)
# (80, 255)
# (48, 194)
# (79, 44)
# (48, 44)
# (112, 75)
# (47, 164)
# (48, 44)
# (79, 44)
# (48, 44)
# (80, 45)
# (79, 44)
# (48, 44)
# (112, 195)
# (48, 74)
# (48, 44)
# (112, 75)
# (80, 224)
# (48, 45)
# (47, 165)
# (112, 75)
# (79, 45)
# (48, 44)
# (80, 44)
# (48, 45)
# (112, 194)
# (48, 44)
# (80, 255)
# (80, 105)
# (79, 45)
# (80, 105)
# (79, 104)
# (47, 195)
# (0, 224)
# (79, 44)
# (47, 0)
# (79, 44)
# (112, 195)
# (112, 74)
# (112, 224)
# (47, 44)
# (80, 164)
# (79, 44)
# (80, 45)
# (80, 105)
# (0, 105)
# (112, 225)
# (48, 44)
# (79, 135)
# (48, 225)
# (112, 105)
# (80, 44)
# (48, 254)
# (48, 135)
# (79, 44)
# (112, 285)
# (80, 45)
# (47, 45)
# (48, 255)
# (112, 195)
# (80, 255)
# (112, 104)
# (80, 45)
# (47, 0)
# (47, 194)
# (79, 44)
# (80, 44)
# (48, 44)
# (47, 134)
# (112, 45)
# (112, 225)
# (79, 44)
# (48, 44)
# (80, 135)
# (80, 44)
# (112, 105)
# (79, 44)
# (112, 164)
# (48, 194)
# (80, 105)
# (47, 165)
# (80, 105)
# (47, 75)
# (112, 164)
# (48, 44)
# (79, 44)
# (79, 44)
# (79, 44)
# (112, 254)
# (48, 45)
# (79, 44)
# (48, 105)
# (80, 44)
# (80, 45)
# (48, 44)
# (79, 45)
# (48, 255)
# (79, 74)
# (47, 255)
# (47, 44)
# (47, 255)
# (47, 224)
# (47, 194)
# (80, 255)
# (48, 164)
# (80, 225)
# (80, 225)
# (48, 254)
# (79, 44)
# (80, 45)
# (79, 75)
# (79, 134)
# (48, 195)
# (80, 74)
# (79, 44)
# (80, 104)
# (47, 255)
# (48, 194)
# (47, 45)
# (48, 45)
# (48, 44)
# (80, 75)
# (48, 44)
# (80, 105)
# (80, 74)
# (80, 45)
# (79, 45)
# (80, 104)
# (79, 44)
# (79, 44)
# (48, 104)
# (79, 44)
# (48, 135)
# (79, 254)
# (48, 44)
# (80, 254)
# (112, 74)
# (48, 194)
# (80, 44)
# (80, 45)
# (80, 164)
# (80, 75)
# (80, 254)
# (79, 45)
# (47, 45)
# (80, 195)
# (79, 44)
# (47, 44)
# (79, 44)
# (79, 44)
# (48, 194)
# (80, 44)
# (48, 194)
# (48, 44)
# (79, 44)
# (79, 255)
# (79, 45)
# (47, 255)
# (48, 194)
# (112, 194)
# (79, 45)
# (47, 254)
# (48, 0)
# (80, 225)
# (47, 44)
# (80, 254)
# (80, 45)
# (48, 45)
# (48, 44)
# (80, 164)
# (47, 44)
# (47, 225)
# (80, 164)
# (79, 44)
# (80, 164)
# (79, 134)
# (79, 255)
# (48, 255)
# (48, 254)
# (48, 45)
# (79, 44)
# (48, 194)
# (47, 45)
# (47, 224)
# (48, 164)
# (47, 254)
# (79, 44)
# (80, 134)
# (48, 44)
# (48, 224)
# (80, 104)
# (79, 44)
# (48, 255)
# (48, 255)
# (79, 44)
# (47, 104)
# (48, 44)
# (48, 44)
# (80, 255)
# (80, 74)
# (80, 44)
# (80, 44)
# (48, 44)
# (80, 254)
# (80, 74)
# (79, 44)
# (48, 45)
# (48, 44)
# (47, 44)
# (47, 255)
# (48, 255)
# (48, 44)
# (79, 45)
# (48, 194)
# (80, 45)
# (47, 135)
# (48, 44)
# (48, 255)
# (79, 194)
# (80, 135)
# (48, 44)
# (79, 135)
# (79, 45)
# (48, 44)
# (79, 44)
# (48, 45)
# (80, 254)
# (48, 74)
# (48, 44)
# (47, 195)
# (47, 44)
# (48, 194)
# (48, 255)
# (79, 75)
# (79, 44)
# (48, 45)
# (48, 224)
# (80, 45)
# (48, 254)
# (80, 194)
# (48, 44)
# (79, 134)
# (79, 44)
# (48, 45)
# (112, 254)
# (80, 165)
# (48, 44)
# (47, 45)
# (80, 254)
# (48, 195)
# (79, 105)
# (79, 194)
# (79, 45)
# (79, 44)
# (79, 45)
# (48, 44)
# (48, 45)
# (79, 164)
# (80, 135)
# (47, 44)
# (79, 104)
# (79, 45)
# (48, 44)
# (47, 44)
# (47, 255)
# (79, 44)
# (48, 255)
# (47, 224)
# (48, 134)
# (80, 44)
# (79, 165)
# (48, 105)
# (48, 44)
# (47, 134)
# (80, 44)
# (47, 44)
# (48, 44)
# (48, 45)
# (48, 45)
# (79, 44)
# (79, 224)
# (79, 45)
# (47, 254)
# (80, 105)
# (48, 164)
# (47, 0)
# (47, 44)
# (48, 44)
# (79, 44)
# (47, 44)
# (47, 44)
# (48, 44)
# (47, 44)
# (80, 44)
# (79, 44)
# (47, 44)
# (80, 194)
# (47, 44)
# (47, 105)
# (47, 44)
# (47, 45)
# (48, 164)
# (47, 255)
# (47, 44)
# (79, 44)
# (80, 44)
# (79, 44)
# (112, 44)
# (47, 45)
# (47, 44)
# (79, 44)
# (47, 44)
# (79, 44)
# (112, 45)
# (47, 194)
# (80, 135)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (80, 44)
# (80, 0)
# (48, 195)
# (80, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (47, 45)
# (80, 44)
# (47, 45)
# (48, 44)
# (48, 194)
# (47, 45)
# (47, 44)
# (47, 44)
# (48, 44)
# (79, 44)
# (80, 44)
# (112, 45)
# (47, 75)
# (47, 44)
# (47, 44)
# (48, 44)
# (48, 135)
# (48, 45)
# (80, 0)
# (47, 44)
# (79, 44)
# (48, 44)
# (48, 44)
# (47, 44)
# (79, 44)
# (112, 0)
# (48, 44)
# (48, 44)
# (47, 224)
# (48, 44)
# (47, 44)
# (47, 44)
# (0, 45)
# (47, 165)
# (80, 0)
# (79, 44)
# (79, 44)
# (79, 44)
# (47, 44)
# (112, 44)
# (47, 44)
# (47, 0)
# (79, 44)
# (48, 44)
# (79, 195)
# (47, 44)
# (79, 44)
# (47, 44)
# (47, 0)
# (79, 44)
# (48, 44)
# (79, 255)
# (80, 285)
# (79, 44)
# (48, 45)
# (80, 194)
# (47, 44)
# (79, 44)
# (0, 44)
# (47, 44)
# (47, 44)
# (79, 0)
# (80, 44)
# (79, 44)
# (48, 44)
# (47, 45)
# (79, 44)
# (48, 44)
# (112, 255)
# (47, 44)
# (79, 44)
# (48, 224)
# (48, 44)
# (112, 165)
# (79, 44)
# (80, 44)
# (47, 44)
# (79, 44)
# (80, 165)
# (47, 44)
# (79, 194)
# (47, 44)
# (112, 45)
# (47, 104)
# (79, 165)
# (79, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (48, 44)
# (47, 44)
# (48, 134)
# (47, 44)
# (47, 44)
# (48, 195)
# (112, 44)
# (47, 44)
# (47, 74)
# (48, 165)
# (48, 44)
# (47, 44)
# (79, 44)
# (80, 44)
# (79, 44)
# (48, 44)
# (48, 44)
# (80, 44)
# (47, 45)
# (47, 44)
# (80, 0)
# (47, 44)
# (47, 44)
# (48, 44)
# (47, 44)
# (47, 45)
# (47, 45)
# (47, 44)
# (80, 0)
# (79, 44)
# (47, 45)
# (79, 44)
# (79, 195)
# (79, 134)
# (48, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (48, 44)
# (48, 44)
# (47, 225)
# (48, 44)
# (79, 165)
# (48, 44)
# (79, 254)
# (47, 194)
# (47, 44)
# (112, 44)
# (48, 44)
# (79, 44)
# (79, 254)
# (47, 44)
# (48, 44)
# (47, 44)
# (48, 254)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (48, 44)
# (79, 44)
# (47, 44)
# (47, 45)

# %%
len(max_Freq_list)
# Out:
# 984

# %%
for ind in np.where( np.array(res) == False)[0].tolist():
    print(max_Freq_list[ind])
# Out:
# 48
# 47
# 47
# 80
# 47
# 79
# 79
# 79
# 47
# 80
# 80
# 47
# 47
# 47
# 0
# 80
# 47
# 79
# 79
# 79
# 80
# 80
# 80
# 48
# 0
# 47
# 48
# 47
# 47
# 47
# 48
# 47
# 79
# 0
# 79
# 47
# 79
# 79
# 47
# 80
# 47
# 48
# 0
# 79
# 80
# 0
# 48
# 48
# 80
# 0
# 79
# 80
# 0
# 47
# 79
# 0
# 0
# 79
# 0
# 80
# 48
# 47
# 80
# 48
# 79
# 112
# 48
# 112
# 112
# 47
# 48
# 0
# 48
# 112
# 80
# 80
# 0
# 112
# 0
# 80
# 112
# 47
# 112
# 79
# 112
# 80
# 48
# 80
# 80
# 80
# 79
# 48
# 80
# 79
# 79
# 48
# 79
# 79
# 47
# 47
# 48
# 48
# 79
# 48
# 79
# 79
# 79
# 48
# 48
# 47
# 48
# 79
# 47
# 112
# 47
# 80
# 47
# 112
# 80
# 48
# 48
# 47
# 48
# 47
# 112
# 0
# 47
# 48
# 79
# 48

# %%
plt.scatter(x=np.arange(len(max_Freq_list)),y=max_Freq_list)

# %%
from numpy import unravel_index

max_time_list = []

for tmp in cam_list:
    #tmp = grad_cam_map.cpu().numpy()
    print(unravel_index(np.argmax(tmp),tmp.shape ))
    max_time_list.append(unravel_index(np.argmax(tmp),tmp.shape )[1])
# Out:
# (79, 44)
# (47, 74)
# (47, 45)
# (79, 44)
# (47, 44)
# (47, 45)
# (48, 44)
# (0, 44)
# (79, 44)
# (0, 44)
# (48, 255)
# (79, 194)
# (80, 0)
# (79, 44)
# (47, 44)
# (79, 44)
# (47, 225)
# (47, 165)
# (47, 75)
# (79, 44)
# (79, 45)
# (80, 44)
# (47, 44)
# (79, 44)
# (79, 134)
# (47, 44)
# (48, 44)
# (48, 44)
# (48, 164)
# (47, 45)
# (47, 44)
# (79, 45)
# (48, 44)
# (47, 44)
# (47, 44)
# (80, 75)
# (47, 134)
# (47, 44)
# (47, 44)
# (79, 255)
# (80, 45)
# (47, 44)
# (79, 255)
# (79, 44)
# (80, 0)
# (47, 44)
# (79, 45)
# (47, 44)
# (48, 0)
# (47, 44)
# (79, 0)
# (79, 0)
# (79, 0)
# (47, 44)
# (47, 45)
# (80, 45)
# (47, 44)
# (80, 195)
# (48, 254)
# (47, 44)
# (47, 194)
# (79, 194)
# (79, 74)
# (47, 0)
# (47, 164)
# (47, 44)
# (80, 44)
# (47, 44)
# (47, 255)
# (47, 44)
# (79, 44)
# (47, 45)
# (48, 44)
# (47, 44)
# (47, 164)
# (79, 44)
# (80, 0)
# (79, 44)
# (47, 254)
# (79, 255)
# (47, 0)
# (48, 44)
# (80, 45)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (48, 194)
# (0, 0)
# (80, 165)
# (47, 164)
# (47, 195)
# (80, 0)
# (47, 104)
# (0, 195)
# (79, 44)
# (79, 195)
# (47, 44)
# (47, 44)
# (79, 105)
# (79, 44)
# (47, 44)
# (0, 164)
# (48, 0)
# (79, 134)
# (48, 45)
# (47, 254)
# (79, 0)
# (47, 44)
# (79, 165)
# (79, 45)
# (48, 0)
# (47, 134)
# (80, 194)
# (48, 44)
# (47, 44)
# (47, 44)
# (80, 74)
# (48, 224)
# (47, 44)
# (47, 45)
# (79, 44)
# (48, 0)
# (47, 75)
# (47, 255)
# (47, 44)
# (79, 44)
# (48, 45)
# (47, 45)
# (47, 44)
# (80, 44)
# (47, 74)
# (48, 44)
# (79, 44)
# (79, 225)
# (0, 75)
# (47, 45)
# (79, 44)
# (80, 44)
# (47, 44)
# (79, 45)
# (47, 104)
# (79, 134)
# (79, 165)
# (47, 44)
# (48, 255)
# (47, 44)
# (47, 104)
# (47, 135)
# (79, 44)
# (47, 75)
# (80, 44)
# (47, 75)
# (47, 45)
# (0, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (48, 254)
# (79, 74)
# (79, 0)
# (79, 44)
# (47, 44)
# (79, 164)
# (47, 44)
# (79, 44)
# (80, 44)
# (79, 44)
# (79, 44)
# (79, 135)
# (79, 134)
# (47, 44)
# (79, 255)
# (47, 44)
# (47, 225)
# (48, 164)
# (79, 44)
# (47, 254)
# (79, 44)
# (47, 44)
# (80, 0)
# (47, 44)
# (47, 165)
# (47, 45)
# (47, 44)
# (47, 44)
# (47, 255)
# (47, 44)
# (79, 45)
# (47, 255)
# (79, 74)
# (79, 44)
# (79, 75)
# (79, 44)
# (48, 0)
# (48, 44)
# (47, 254)
# (0, 0)
# (79, 134)
# (47, 44)
# (0, 44)
# (0, 44)
# (80, 44)
# (80, 134)
# (112, 45)
# (79, 105)
# (48, 135)
# (47, 44)
# (47, 44)
# (48, 225)
# (48, 194)
# (79, 44)
# (47, 0)
# (47, 44)
# (47, 224)
# (79, 164)
# (0, 0)
# (79, 165)
# (79, 255)
# (47, 0)
# (0, 105)
# (47, 0)
# (48, 195)
# (48, 44)
# (112, 224)
# (48, 194)
# (0, 0)
# (47, 0)
# (47, 44)
# (0, 45)
# (80, 164)
# (47, 44)
# (47, 45)
# (48, 225)
# (48, 44)
# (48, 164)
# (79, 195)
# (47, 0)
# (47, 0)
# (47, 0)
# (47, 224)
# (79, 44)
# (79, 165)
# (47, 0)
# (48, 44)
# (79, 165)
# (48, 165)
# (79, 165)
# (79, 164)
# (48, 105)
# (47, 165)
# (47, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (48, 195)
# (47, 135)
# (80, 195)
# (0, 44)
# (48, 165)
# (0, 0)
# (47, 44)
# (0, 45)
# (79, 135)
# (47, 44)
# (47, 44)
# (47, 0)
# (47, 0)
# (47, 44)
# (79, 44)
# (80, 44)
# (47, 254)
# (48, 195)
# (47, 0)
# (48, 44)
# (47, 44)
# (48, 0)
# (48, 164)
# (47, 0)
# (47, 44)
# (47, 0)
# (79, 44)
# (79, 165)
# (80, 224)
# (48, 164)
# (47, 45)
# (48, 44)
# (0, 44)
# (48, 164)
# (0, 0)
# (79, 165)
# (79, 0)
# (80, 165)
# (48, 44)
# (0, 44)
# (79, 195)
# (80, 254)
# (79, 105)
# (47, 45)
# (79, 224)
# (80, 194)
# (79, 255)
# (47, 45)
# (80, 255)
# (47, 44)
# (79, 135)
# (0, 44)
# (79, 45)
# (79, 165)
# (47, 45)
# (0, 0)
# (79, 74)
# (80, 254)
# (80, 194)
# (79, 195)
# (80, 255)
# (47, 44)
# (80, 134)
# (47, 0)
# (48, 194)
# (0, 45)
# (48, 164)
# (47, 44)
# (80, 254)
# (47, 44)
# (0, 0)
# (79, 225)
# (47, 0)
# (47, 0)
# (47, 44)
# (112, 255)
# (48, 164)
# (80, 135)
# (47, 0)
# (48, 164)
# (80, 0)
# (80, 105)
# (47, 0)
# (0, 44)
# (0, 0)
# (79, 164)
# (47, 44)
# (48, 255)
# (48, 164)
# (79, 194)
# (0, 45)
# (47, 0)
# (79, 254)
# (48, 44)
# (47, 44)
# (80, 135)
# (79, 195)
# (80, 165)
# (80, 134)
# (48, 165)
# (47, 164)
# (47, 44)
# (79, 165)
# (48, 135)
# (47, 0)
# (47, 0)
# (79, 45)
# (47, 44)
# (47, 45)
# (48, 165)
# (79, 164)
# (80, 74)
# (80, 254)
# (48, 194)
# (79, 165)
# (48, 44)
# (80, 0)
# (48, 195)
# (0, 255)
# (47, 0)
# (47, 105)
# (79, 44)
# (0, 44)
# (47, 44)
# (79, 44)
# (79, 135)
# (48, 44)
# (47, 0)
# (47, 44)
# (79, 255)
# (0, 0)
# (47, 0)
# (79, 0)
# (79, 194)
# (0, 44)
# (47, 44)
# (47, 0)
# (79, 44)
# (0, 74)
# (48, 44)
# (79, 44)
# (112, 134)
# (48, 44)
# (48, 165)
# (80, 224)
# (48, 44)
# (0, 0)
# (80, 104)
# (47, 74)
# (80, 74)
# (48, 44)
# (0, 75)
# (80, 44)
# (48, 225)
# (47, 164)
# (48, 44)
# (79, 105)
# (79, 45)
# (80, 44)
# (48, 44)
# (80, 135)
# (47, 134)
# (80, 45)
# (112, 105)
# (47, 255)
# (79, 44)
# (79, 44)
# (112, 194)
# (80, 135)
# (79, 105)
# (112, 45)
# (80, 164)
# (48, 44)
# (47, 44)
# (79, 44)
# (48, 164)
# (80, 44)
# (112, 105)
# (80, 164)
# (48, 44)
# (79, 255)
# (79, 44)
# (112, 135)
# (80, 254)
# (112, 194)
# (48, 134)
# (80, 105)
# (80, 134)
# (48, 44)
# (80, 164)
# (80, 44)
# (48, 44)
# (48, 44)
# (79, 44)
# (112, 285)
# (48, 44)
# (112, 74)
# (48, 44)
# (112, 165)
# (48, 194)
# (80, 44)
# (112, 135)
# (47, 44)
# (112, 165)
# (79, 44)
# (48, 165)
# (79, 45)
# (112, 194)
# (47, 0)
# (112, 164)
# (48, 44)
# (80, 135)
# (48, 45)
# (79, 44)
# (48, 254)
# (112, 164)
# (79, 44)
# (47, 44)
# (79, 254)
# (47, 194)
# (48, 45)
# (47, 45)
# (79, 44)
# (48, 44)
# (0, 105)
# (48, 164)
# (80, 195)
# (0, 104)
# (48, 224)
# (79, 44)
# (79, 44)
# (48, 45)
# (48, 105)
# (79, 44)
# (79, 44)
# (79, 164)
# (47, 75)
# (112, 254)
# (112, 254)
# (48, 44)
# (79, 44)
# (79, 45)
# (112, 225)
# (112, 165)
# (79, 44)
# (48, 44)
# (47, 44)
# (112, 165)
# (80, 255)
# (48, 194)
# (79, 44)
# (48, 44)
# (112, 75)
# (47, 164)
# (48, 44)
# (79, 44)
# (48, 44)
# (80, 45)
# (79, 44)
# (48, 44)
# (112, 195)
# (48, 74)
# (48, 44)
# (112, 75)
# (80, 224)
# (48, 45)
# (47, 165)
# (112, 75)
# (79, 45)
# (48, 44)
# (80, 44)
# (48, 45)
# (112, 194)
# (48, 44)
# (80, 255)
# (80, 105)
# (79, 45)
# (80, 105)
# (79, 104)
# (47, 195)
# (0, 224)
# (79, 44)
# (47, 0)
# (79, 44)
# (112, 195)
# (112, 74)
# (112, 224)
# (47, 44)
# (80, 164)
# (79, 44)
# (80, 45)
# (80, 105)
# (0, 105)
# (112, 225)
# (48, 44)
# (79, 135)
# (48, 225)
# (112, 105)
# (80, 44)
# (48, 254)
# (48, 135)
# (79, 44)
# (112, 285)
# (80, 45)
# (47, 45)
# (48, 255)
# (112, 195)
# (80, 255)
# (112, 104)
# (80, 45)
# (47, 0)
# (47, 194)
# (79, 44)
# (80, 44)
# (48, 44)
# (47, 134)
# (112, 45)
# (112, 225)
# (79, 44)
# (48, 44)
# (80, 135)
# (80, 44)
# (112, 105)
# (79, 44)
# (112, 164)
# (48, 194)
# (80, 105)
# (47, 165)
# (80, 105)
# (47, 75)
# (112, 164)
# (48, 44)
# (79, 44)
# (79, 44)
# (79, 44)
# (112, 254)
# (48, 45)
# (79, 44)
# (48, 105)
# (80, 44)
# (80, 45)
# (48, 44)
# (79, 45)
# (48, 255)
# (79, 74)
# (47, 255)
# (47, 44)
# (47, 255)
# (47, 224)
# (47, 194)
# (80, 255)
# (48, 164)
# (80, 225)
# (80, 225)
# (48, 254)
# (79, 44)
# (80, 45)
# (79, 75)
# (79, 134)
# (48, 195)
# (80, 74)
# (79, 44)
# (80, 104)
# (47, 255)
# (48, 194)
# (47, 45)
# (48, 45)
# (48, 44)
# (80, 75)
# (48, 44)
# (80, 105)
# (80, 74)
# (80, 45)
# (79, 45)
# (80, 104)
# (79, 44)
# (79, 44)
# (48, 104)
# (79, 44)
# (48, 135)
# (79, 254)
# (48, 44)
# (80, 254)
# (112, 74)
# (48, 194)
# (80, 44)
# (80, 45)
# (80, 164)
# (80, 75)
# (80, 254)
# (79, 45)
# (47, 45)
# (80, 195)
# (79, 44)
# (47, 44)
# (79, 44)
# (79, 44)
# (48, 194)
# (80, 44)
# (48, 194)
# (48, 44)
# (79, 44)
# (79, 255)
# (79, 45)
# (47, 255)
# (48, 194)
# (112, 194)
# (79, 45)
# (47, 254)
# (48, 0)
# (80, 225)
# (47, 44)
# (80, 254)
# (80, 45)
# (48, 45)
# (48, 44)
# (80, 164)
# (47, 44)
# (47, 225)
# (80, 164)
# (79, 44)
# (80, 164)
# (79, 134)
# (79, 255)
# (48, 255)
# (48, 254)
# (48, 45)
# (79, 44)
# (48, 194)
# (47, 45)
# (47, 224)
# (48, 164)
# (47, 254)
# (79, 44)
# (80, 134)
# (48, 44)
# (48, 224)
# (80, 104)
# (79, 44)
# (48, 255)
# (48, 255)
# (79, 44)
# (47, 104)
# (48, 44)
# (48, 44)
# (80, 255)
# (80, 74)
# (80, 44)
# (80, 44)
# (48, 44)
# (80, 254)
# (80, 74)
# (79, 44)
# (48, 45)
# (48, 44)
# (47, 44)
# (47, 255)
# (48, 255)
# (48, 44)
# (79, 45)
# (48, 194)
# (80, 45)
# (47, 135)
# (48, 44)
# (48, 255)
# (79, 194)
# (80, 135)
# (48, 44)
# (79, 135)
# (79, 45)
# (48, 44)
# (79, 44)
# (48, 45)
# (80, 254)
# (48, 74)
# (48, 44)
# (47, 195)
# (47, 44)
# (48, 194)
# (48, 255)
# (79, 75)
# (79, 44)
# (48, 45)
# (48, 224)
# (80, 45)
# (48, 254)
# (80, 194)
# (48, 44)
# (79, 134)
# (79, 44)
# (48, 45)
# (112, 254)
# (80, 165)
# (48, 44)
# (47, 45)
# (80, 254)
# (48, 195)
# (79, 105)
# (79, 194)
# (79, 45)
# (79, 44)
# (79, 45)
# (48, 44)
# (48, 45)
# (79, 164)
# (80, 135)
# (47, 44)
# (79, 104)
# (79, 45)
# (48, 44)
# (47, 44)
# (47, 255)
# (79, 44)
# (48, 255)
# (47, 224)
# (48, 134)
# (80, 44)
# (79, 165)
# (48, 105)
# (48, 44)
# (47, 134)
# (80, 44)
# (47, 44)
# (48, 44)
# (48, 45)
# (48, 45)
# (79, 44)
# (79, 224)
# (79, 45)
# (47, 254)
# (80, 105)
# (48, 164)
# (47, 0)
# (47, 44)
# (48, 44)
# (79, 44)
# (47, 44)
# (47, 44)
# (48, 44)
# (47, 44)
# (80, 44)
# (79, 44)
# (47, 44)
# (80, 194)
# (47, 44)
# (47, 105)
# (47, 44)
# (47, 45)
# (48, 164)
# (47, 255)
# (47, 44)
# (79, 44)
# (80, 44)
# (79, 44)
# (112, 44)
# (47, 45)
# (47, 44)
# (79, 44)
# (47, 44)
# (79, 44)
# (112, 45)
# (47, 194)
# (80, 135)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (80, 44)
# (80, 0)
# (48, 195)
# (80, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (47, 45)
# (80, 44)
# (47, 45)
# (48, 44)
# (48, 194)
# (47, 45)
# (47, 44)
# (47, 44)
# (48, 44)
# (79, 44)
# (80, 44)
# (112, 45)
# (47, 75)
# (47, 44)
# (47, 44)
# (48, 44)
# (48, 135)
# (48, 45)
# (80, 0)
# (47, 44)
# (79, 44)
# (48, 44)
# (48, 44)
# (47, 44)
# (79, 44)
# (112, 0)
# (48, 44)
# (48, 44)
# (47, 224)
# (48, 44)
# (47, 44)
# (47, 44)
# (0, 45)
# (47, 165)
# (80, 0)
# (79, 44)
# (79, 44)
# (79, 44)
# (47, 44)
# (112, 44)
# (47, 44)
# (47, 0)
# (79, 44)
# (48, 44)
# (79, 195)
# (47, 44)
# (79, 44)
# (47, 44)
# (47, 0)
# (79, 44)
# (48, 44)
# (79, 255)
# (80, 285)
# (79, 44)
# (48, 45)
# (80, 194)
# (47, 44)
# (79, 44)
# (0, 44)
# (47, 44)
# (47, 44)
# (79, 0)
# (80, 44)
# (79, 44)
# (48, 44)
# (47, 45)
# (79, 44)
# (48, 44)
# (112, 255)
# (47, 44)
# (79, 44)
# (48, 224)
# (48, 44)
# (112, 165)
# (79, 44)
# (80, 44)
# (47, 44)
# (79, 44)
# (80, 165)
# (47, 44)
# (79, 194)
# (47, 44)
# (112, 45)
# (47, 104)
# (79, 165)
# (79, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (48, 44)
# (47, 44)
# (48, 134)
# (47, 44)
# (47, 44)
# (48, 195)
# (112, 44)
# (47, 44)
# (47, 74)
# (48, 165)
# (48, 44)
# (47, 44)
# (79, 44)
# (80, 44)
# (79, 44)
# (48, 44)
# (48, 44)
# (80, 44)
# (47, 45)
# (47, 44)
# (80, 0)
# (47, 44)
# (47, 44)
# (48, 44)
# (47, 44)
# (47, 45)
# (47, 45)
# (47, 44)
# (80, 0)
# (79, 44)
# (47, 45)
# (79, 44)
# (79, 195)
# (79, 134)
# (48, 44)
# (47, 44)
# (47, 44)
# (47, 44)
# (48, 44)
# (48, 44)
# (47, 225)
# (48, 44)
# (79, 165)
# (48, 44)
# (79, 254)
# (47, 194)
# (47, 44)
# (112, 44)
# (48, 44)
# (79, 44)
# (79, 254)
# (47, 44)
# (48, 44)
# (47, 44)
# (48, 254)
# (47, 44)
# (47, 44)
# (79, 44)
# (47, 44)
# (48, 44)
# (79, 44)
# (47, 44)
# (47, 45)

# %%
max_time_list
# Out:
# [44,
#  74,
#  45,
#  44,
#  44,
#  45,
#  44,
#  44,
#  44,
#  44,
#  255,
#  194,
#  0,
#  44,
#  44,
#  44,
#  225,
#  165,
#  75,
#  44,
#  45,
#  44,
#  44,
#  44,
#  134,
#  44,
#  44,
#  44,
#  164,
#  45,
#  44,
#  45,
#  44,
#  44,
#  44,
#  75,
#  134,
#  44,
#  44,
#  255,
#  45,
#  44,
#  255,
#  44,
#  0,
#  44,
#  45,
#  44,
#  0,
#  44,
#  0,
#  0,
#  0,
#  44,
#  45,
#  45,
#  44,
#  195,
#  254,
#  44,
#  194,
#  194,
#  74,
#  0,
#  164,
#  44,
#  44,
#  44,
#  255,
#  44,
#  44,
#  45,
#  44,
#  44,
#  164,
#  44,
#  0,
#  44,
#  254,
#  255,
#  0,
#  44,
#  45,
#  44,
#  44,
#  44,
#  44,
#  194,
#  0,
#  165,
#  164,
#  195,
#  0,
#  104,
#  195,
#  44,
#  195,
#  44,
#  44,
#  105,
#  44,
#  44,
#  164,
#  0,
#  134,
#  45,
#  254,
#  0,
#  44,
#  165,
#  45,
#  0,
#  134,
#  194,
#  44,
#  44,
#  44,
#  74,
#  224,
#  44,
#  45,
#  44,
#  0,
#  75,
#  255,
#  44,
#  44,
#  45,
#  45,
#  44,
#  44,
#  74,
#  44,
#  44,
#  225,
#  75,
#  45,
#  44,
#  44,
#  44,
#  45,
#  104,
#  134,
#  165,
#  44,
#  255,
#  44,
#  104,
#  135,
#  44,
#  75,
#  44,
#  75,
#  45,
#  44,
#  44,
#  44,
#  44,
#  254,
#  74,
#  0,
#  44,
#  44,
#  164,
#  44,
#  44,
#  44,
#  44,
#  44,
#  135,
#  134,
#  44,
#  255,
#  44,
#  225,
#  164,
#  44,
#  254,
#  44,
#  44,
#  0,
#  44,
#  165,
#  45,
#  44,
#  44,
#  255,
#  44,
#  45,
#  255,
#  74,
#  44,
#  75,
#  44,
#  0,
#  44,
#  254,
#  0,
#  134,
#  44,
#  44,
#  44,
#  44,
#  134,
#  45,
#  105,
#  135,
#  44,
#  44,
#  225,
#  194,
#  44,
#  0,
#  44,
#  224,
#  164,
#  0,
#  165,
#  255,
#  0,
#  105,
#  0,
#  195,
#  44,
#  224,
#  194,
#  0,
#  0,
#  44,
#  45,
#  164,
#  44,
#  45,
#  225,
#  44,
#  164,
#  195,
#  0,
#  0,
#  0,
#  224,
#  44,
#  165,
#  0,
#  44,
#  165,
#  165,
#  165,
#  164,
#  105,
#  165,
#  44,
#  44,
#  44,
#  44,
#  44,
#  195,
#  135,
#  195,
#  44,
#  165,
#  0,
#  44,
#  45,
#  135,
#  44,
#  44,
#  0,
#  0,
#  44,
#  44,
#  44,
#  254,
#  195,
#  0,
#  44,
#  44,
#  0,
#  164,
#  0,
#  44,
#  0,
#  44,
#  165,
#  224,
#  164,
#  45,
#  44,
#  44,
#  164,
#  0,
#  165,
#  0,
#  165,
#  44,
#  44,
#  195,
#  254,
#  105,
#  45,
#  224,
#  194,
#  255,
#  45,
#  255,
#  44,
#  135,
#  44,
#  45,
#  165,
#  45,
#  0,
#  74,
#  254,
#  194,
#  195,
#  255,
#  44,
#  134,
#  0,
#  194,
#  45,
#  164,
#  44,
#  254,
#  44,
#  0,
#  225,
#  0,
#  0,
#  44,
#  255,
#  164,
#  135,
#  0,
#  164,
#  0,
#  105,
#  0,
#  44,
#  0,
#  164,
#  44,
#  255,
#  164,
#  194,
#  45,
#  0,
#  254,
#  44,
#  44,
#  135,
#  195,
#  165,
#  134,
#  165,
#  164,
#  44,
#  165,
#  135,
#  0,
#  0,
#  45,
#  44,
#  45,
#  165,
#  164,
#  74,
#  254,
#  194,
#  165,
#  44,
#  0,
#  195,
#  255,
#  0,
#  105,
#  44,
#  44,
#  44,
#  44,
#  135,
#  44,
#  0,
#  44,
#  255,
#  0,
#  0,
#  0,
#  194,
#  44,
#  44,
#  0,
#  44,
#  74,
#  44,
#  44,
#  134,
#  44,
#  165,
#  224,
#  44,
#  0,
#  104,
#  74,
#  74,
#  44,
#  75,
#  44,
#  225,
#  164,
#  44,
#  105,
#  45,
#  44,
#  44,
#  135,
#  134,
#  45,
#  105,
#  255,
#  44,
#  44,
#  194,
#  135,
#  105,
#  45,
#  164,
#  44,
#  44,
#  44,
#  164,
#  44,
#  105,
#  164,
#  44,
#  255,
#  44,
#  135,
#  254,
#  194,
#  134,
#  105,
#  134,
#  44,
#  164,
#  44,
#  44,
#  44,
#  44,
#  285,
#  44,
#  74,
#  44,
#  165,
#  194,
#  44,
#  135,
#  44,
#  165,
#  44,
#  165,
#  45,
#  194,
#  0,
#  164,
#  44,
#  135,
#  45,
#  44,
#  254,
#  164,
#  44,
#  44,
#  254,
#  194,
#  45,
#  45,
#  44,
#  44,
#  105,
#  164,
#  195,
#  104,
#  224,
#  44,
#  44,
#  45,
#  105,
#  44,
#  44,
#  164,
#  75,
#  254,
#  254,
#  44,
#  44,
#  45,
#  225,
#  165,
#  44,
#  44,
#  44,
#  165,
#  255,
#  194,
#  44,
#  44,
#  75,
#  164,
#  44,
#  44,
#  44,
#  45,
#  44,
#  44,
#  195,
#  74,
#  44,
#  75,
#  224,
#  45,
#  165,
#  75,
#  45,
#  44,
#  44,
#  45,
#  194,
#  44,
#  255,
#  105,
#  45,
#  105,
#  104,
#  195,
#  224,
#  44,
#  0,
#  44,
#  195,
#  74,
#  224,
#  44,
#  164,
#  44,
#  45,
#  105,
#  105,
#  225,
#  44,
#  135,
#  225,
#  105,
#  44,
#  254,
#  135,
#  44,
#  285,
#  45,
#  45,
#  255,
#  195,
#  255,
#  104,
#  45,
#  0,
#  194,
#  44,
#  44,
#  44,
#  134,
#  45,
#  225,
#  44,
#  44,
#  135,
#  44,
#  105,
#  44,
#  164,
#  194,
#  105,
#  165,
#  105,
#  75,
#  164,
#  44,
#  44,
#  44,
#  44,
#  254,
#  45,
#  44,
#  105,
#  44,
#  45,
#  44,
#  45,
#  255,
#  74,
#  255,
#  44,
#  255,
#  224,
#  194,
#  255,
#  164,
#  225,
#  225,
#  254,
#  44,
#  45,
#  75,
#  134,
#  195,
#  74,
#  44,
#  104,
#  255,
#  194,
#  45,
#  45,
#  44,
#  75,
#  44,
#  105,
#  74,
#  45,
#  45,
#  104,
#  44,
#  44,
#  104,
#  44,
#  135,
#  254,
#  44,
#  254,
#  74,
#  194,
#  44,
#  45,
#  164,
#  75,
#  254,
#  45,
#  45,
#  195,
#  44,
#  44,
#  44,
#  44,
#  194,
#  44,
#  194,
#  44,
#  44,
#  255,
#  45,
#  255,
#  194,
#  194,
#  45,
#  254,
#  0,
#  225,
#  44,
#  254,
#  45,
#  45,
#  44,
#  164,
#  44,
#  225,
#  164,
#  44,
#  164,
#  134,
#  255,
#  255,
#  254,
#  45,
#  44,
#  194,
#  45,
#  224,
#  164,
#  254,
#  44,
#  134,
#  44,
#  224,
#  104,
#  44,
#  255,
#  255,
#  44,
#  104,
#  44,
#  44,
#  255,
#  74,
#  44,
#  44,
#  44,
#  254,
#  74,
#  44,
#  45,
#  44,
#  44,
#  255,
#  255,
#  44,
#  45,
#  194,
#  45,
#  135,
#  44,
#  255,
#  194,
#  135,
#  44,
#  135,
#  45,
#  44,
#  44,
#  45,
#  254,
#  74,
#  44,
#  195,
#  44,
#  194,
#  255,
#  75,
#  44,
#  45,
#  224,
#  45,
#  254,
#  194,
#  44,
#  134,
#  44,
#  45,
#  254,
#  165,
#  44,
#  45,
#  254,
#  195,
#  105,
#  194,
#  45,
#  44,
#  45,
#  44,
#  45,
#  164,
#  135,
#  44,
#  104,
#  45,
#  44,
#  44,
#  255,
#  44,
#  255,
#  224,
#  134,
#  44,
#  165,
#  105,
#  44,
#  134,
#  44,
#  44,
#  44,
#  45,
#  45,
#  44,
#  224,
#  45,
#  254,
#  105,
#  164,
#  0,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  194,
#  44,
#  105,
#  44,
#  45,
#  164,
#  255,
#  44,
#  44,
#  44,
#  44,
#  44,
#  45,
#  44,
#  44,
#  44,
#  44,
#  45,
#  194,
#  135,
#  44,
#  44,
#  44,
#  44,
#  44,
#  0,
#  195,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  45,
#  44,
#  45,
#  44,
#  194,
#  45,
#  44,
#  44,
#  44,
#  44,
#  44,
#  45,
#  75,
#  44,
#  44,
#  44,
#  135,
#  45,
#  0,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  0,
#  44,
#  44,
#  224,
#  44,
#  44,
#  44,
#  45,
#  165,
#  0,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  0,
#  44,
#  44,
#  195,
#  44,
#  44,
#  44,
#  0,
#  44,
#  44,
#  255,
#  285,
#  44,
#  45,
#  194,
#  44,
#  44,
#  44,
#  44,
#  44,
#  0,
#  44,
#  44,
#  44,
#  45,
#  44,
#  44,
#  255,
#  44,
#  44,
#  224,
#  44,
#  165,
#  44,
#  44,
#  44,
#  44,
#  165,
#  44,
#  194,
#  44,
#  45,
#  104,
#  165,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  134,
#  44,
#  44,
#  195,
#  44,
#  44,
#  74,
#  165,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  45,
#  44,
#  0,
#  44,
#  44,
#  44,
#  44,
#  45,
#  45,
#  44,
#  0,
#  44,
#  45,
#  44,
#  195,
#  134,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  225,
#  44,
#  165,
#  44,
#  254,
#  194,
#  44,
#  44,
#  44,
#  44,
#  254,
#  44,
#  44,
#  44,
#  254,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  45]

# %%
plt.scatter(x=np.arange(len(max_time_list)),y=max_time_list)

# %%
from numpy import unravel_index

max_fallout_list = []

for tmp in fallout_list:
    #tmp = grad_cam_map.cpu().numpy()
    print(unravel_index(np.argmax(tmp),tmp.shape ))
    max_fallout_list.append(unravel_index(np.argmax(tmp),tmp.shape )[0])
# Out:
# (57, 47)
# (40, 52)
# (49, 100)
# (53, 35)
# (47, 46)
# (47, 45)
# (48, 3)
# (19, 41)
# (79, 26)
# (24, 39)
# (48, 255)
# (77, 197)
# (80, 1)
# (80, 25)
# (47, 39)
# (77, 33)
# (46, 226)
# (47, 177)
# (43, 78)
# (61, 47)
# (79, 31)
# (80, 44)
# (47, 44)
# (77, 45)
# (74, 138)
# (47, 45)
# (48, 44)
# (60, 30)
# (52, 164)
# (45, 36)
# (47, 49)
# (79, 38)
# (57, 45)
# (35, 43)
# (44, 41)
# (80, 91)
# (46, 118)
# (47, 40)
# (47, 45)
# (58, 255)
# (114, 135)
# (47, 51)
# (79, 255)
# (60, 40)
# (80, 2)
# (43, 28)
# (80, 46)
# (47, 37)
# (48, 3)
# (47, 28)
# (79, 6)
# (79, 2)
# (79, 2)
# (47, 2)
# (39, 50)
# (81, 38)
# (44, 38)
# (83, 189)
# (46, 255)
# (46, 42)
# (53, 199)
# (77, 180)
# (73, 53)
# (47, 4)
# (47, 142)
# (47, 46)
# (80, 34)
# (46, 43)
# (52, 264)
# (43, 51)
# (79, 35)
# (46, 251)
# (51, 23)
# (47, 37)
# (46, 162)
# (78, 41)
# (80, 3)
# (83, 47)
# (47, 254)
# (55, 255)
# (47, 4)
# (48, 32)
# (80, 40)
# (36, 42)
# (46, 36)
# (77, 44)
# (39, 40)
# (48, 172)
# (6, 5)
# (82, 164)
# (47, 164)
# (45, 193)
# (80, 2)
# (45, 107)
# (19, 189)
# (78, 30)
# (78, 203)
# (45, 26)
# (46, 43)
# (77, 110)
# (79, 31)
# (49, 43)
# (46, 160)
# (48, 4)
# (79, 135)
# (56, 50)
# (48, 254)
# (79, 4)
# (47, 46)
# (79, 167)
# (65, 46)
# (48, 2)
# (39, 112)
# (80, 185)
# (49, 30)
# (46, 45)
# (49, 0)
# (80, 39)
# (47, 205)
# (48, 38)
# (47, 45)
# (79, 38)
# (52, 6)
# (47, 97)
# (47, 255)
# (46, 36)
# (70, 38)
# (52, 40)
# (47, 51)
# (46, 32)
# (80, 24)
# (53, 68)
# (49, 36)
# (79, 32)
# (79, 233)
# (11, 162)
# (49, 49)
# (79, 23)
# (80, 41)
# (45, 34)
# (77, 48)
# (49, 101)
# (79, 123)
# (75, 163)
# (53, 39)
# (49, 258)
# (44, 41)
# (46, 75)
# (43, 134)
# (79, 28)
# (49, 71)
# (80, 31)
# (47, 103)
# (49, 46)
# (14, 15)
# (47, 39)
# (47, 37)
# (47, 36)
# (48, 169)
# (80, 39)
# (79, 0)
# (79, 33)
# (48, 39)
# (88, 165)
# (47, 36)
# (52, 31)
# (93, 45)
# (46, 41)
# (79, 31)
# (78, 131)
# (80, 119)
# (49, 43)
# (79, 260)
# (47, 38)
# (47, 232)
# (48, 156)
# (78, 24)
# (48, 251)
# (79, 30)
# (47, 0)
# (80, 0)
# (46, 37)
# (47, 159)
# (49, 38)
# (47, 48)
# (48, 42)
# (47, 256)
# (43, 43)
# (71, 52)
# (47, 255)
# (80, 43)
# (79, 31)
# (87, 76)
# (79, 34)
# (48, 5)
# (57, 44)
# (49, 247)
# (7, 3)
# (79, 117)
# (47, 24)
# (18, 45)
# (14, 35)
# (80, 41)
# (83, 127)
# (122, 50)
# (79, 106)
# (49, 135)
# (47, 3)
# (49, 41)
# (48, 215)
# (39, 194)
# (79, 25)
# (47, 0)
# (49, 44)
# (44, 220)
# (68, 163)
# (7, 34)
# (81, 156)
# (63, 256)
# (47, 4)
# (16, 103)
# (47, 5)
# (48, 195)
# (48, 32)
# (125, 224)
# (47, 189)
# (4, 3)
# (47, 1)
# (47, 44)
# (12, 45)
# (79, 163)
# (47, 41)
# (80, 167)
# (40, 223)
# (68, 40)
# (48, 155)
# (79, 206)
# (47, 0)
# (47, 1)
# (47, 2)
# (47, 212)
# (66, 44)
# (79, 164)
# (46, 16)
# (48, 28)
# (79, 168)
# (48, 164)
# (53, 163)
# (78, 164)
# (53, 108)
# (47, 165)
# (42, 41)
# (46, 1)
# (47, 42)
# (47, 2)
# (44, 45)
# (48, 195)
# (47, 137)
# (80, 223)
# (31, 34)
# (49, 168)
# (7, 2)
# (48, 36)
# (16, 48)
# (79, 135)
# (48, 44)
# (47, 2)
# (47, 0)
# (47, 9)
# (47, 41)
# (80, 165)
# (80, 32)
# (48, 159)
# (49, 195)
# (47, 0)
# (46, 41)
# (47, 2)
# (48, 0)
# (47, 164)
# (47, 3)
# (43, 26)
# (47, 0)
# (78, 31)
# (61, 165)
# (86, 224)
# (49, 156)
# (48, 44)
# (53, 44)
# (19, 32)
# (47, 170)
# (3, 7)
# (75, 174)
# (79, 1)
# (80, 154)
# (46, 44)
# (26, 45)
# (81, 197)
# (83, 254)
# (79, 105)
# (36, 48)
# (79, 215)
# (84, 190)
# (69, 258)
# (43, 37)
# (79, 257)
# (44, 41)
# (76, 143)
# (4, 40)
# (80, 30)
# (80, 158)
# (42, 47)
# (7, 3)
# (58, 61)
# (127, 191)
# (78, 0)
# (79, 212)
# (80, 255)
# (39, 50)
# (79, 135)
# (47, 0)
# (51, 190)
# (32, 40)
# (48, 162)
# (47, 42)
# (79, 266)
# (44, 42)
# (9, 2)
# (49, 231)
# (49, 4)
# (47, 3)
# (42, 47)
# (127, 254)
# (51, 163)
# (78, 121)
# (47, 2)
# (46, 160)
# (80, 2)
# (80, 104)
# (47, 2)
# (17, 42)
# (9, 6)
# (78, 171)
# (48, 42)
# (47, 255)
# (49, 152)
# (79, 183)
# (19, 44)
# (47, 3)
# (79, 255)
# (54, 45)
# (45, 44)
# (79, 147)
# (79, 201)
# (80, 178)
# (89, 133)
# (48, 171)
# (53, 164)
# (47, 36)
# (80, 153)
# (48, 136)
# (47, 0)
# (47, 0)
# (53, 85)
# (47, 7)
# (47, 59)
# (47, 167)
# (79, 164)
# (81, 81)
# (85, 254)
# (43, 194)
# (77, 175)
# (39, 44)
# (80, 1)
# (48, 217)
# (43, 253)
# (47, 0)
# (47, 115)
# (69, 44)
# (29, 41)
# (44, 35)
# (74, 44)
# (75, 143)
# (49, 43)
# (47, 1)
# (49, 36)
# (77, 249)
# (5, 6)
# (47, 0)
# (79, 5)
# (53, 199)
# (14, 36)
# (47, 167)
# (47, 2)
# (77, 29)
# (47, 271)
# (51, 48)
# (79, 34)
# (126, 134)
# (47, 43)
# (47, 171)
# (127, 224)
# (49, 34)
# (12, 4)
# (81, 97)
# (126, 0)
# (81, 84)
# (47, 32)
# (34, 69)
# (78, 29)
# (48, 223)
# (48, 159)
# (46, 36)
# (63, 124)
# (79, 33)
# (79, 30)
# (48, 24)
# (85, 135)
# (112, 164)
# (80, 45)
# (127, 105)
# (49, 254)
# (64, 44)
# (57, 41)
# (126, 194)
# (85, 138)
# (81, 105)
# (127, 45)
# (127, 105)
# (49, 35)
# (49, 42)
# (74, 40)
# (49, 163)
# (51, 166)
# (126, 105)
# (79, 159)
# (56, 37)
# (79, 257)
# (46, 221)
# (126, 135)
# (80, 253)
# (127, 194)
# (53, 128)
# (81, 110)
# (90, 104)
# (49, 43)
# (81, 165)
# (80, 32)
# (58, 42)
# (48, 141)
# (79, 43)
# (127, 285)
# (48, 42)
# (127, 74)
# (49, 42)
# (112, 165)
# (48, 194)
# (80, 31)
# (112, 135)
# (48, 35)
# (127, 165)
# (71, 42)
# (49, 166)
# (80, 78)
# (112, 194)
# (47, 4)
# (127, 164)
# (80, 55)
# (85, 135)
# (48, 45)
# (80, 25)
# (47, 236)
# (127, 164)
# (70, 42)
# (44, 42)
# (55, 248)
# (48, 187)
# (45, 49)
# (51, 45)
# (60, 47)
# (58, 42)
# (24, 121)
# (49, 162)
# (81, 195)
# (114, 195)
# (48, 213)
# (69, 44)
# (61, 27)
# (52, 38)
# (81, 270)
# (79, 29)
# (47, 197)
# (80, 160)
# (32, 65)
# (114, 254)
# (126, 254)
# (49, 53)
# (74, 43)
# (81, 43)
# (124, 225)
# (112, 165)
# (77, 45)
# (50, 43)
# (47, 34)
# (112, 165)
# (81, 253)
# (48, 194)
# (69, 31)
# (51, 41)
# (127, 75)
# (45, 168)
# (48, 38)
# (79, 33)
# (48, 40)
# (86, 46)
# (79, 31)
# (47, 45)
# (112, 195)
# (49, 66)
# (50, 30)
# (127, 75)
# (80, 224)
# (49, 48)
# (49, 162)
# (113, 75)
# (81, 45)
# (49, 36)
# (87, 44)
# (46, 40)
# (126, 194)
# (48, 44)
# (90, 255)
# (114, 134)
# (46, 196)
# (126, 105)
# (47, 113)
# (46, 194)
# (12, 226)
# (51, 43)
# (47, 1)
# (69, 46)
# (127, 195)
# (127, 74)
# (127, 204)
# (45, 42)
# (83, 163)
# (85, 28)
# (97, 48)
# (81, 107)
# (42, 133)
# (112, 225)
# (48, 33)
# (126, 195)
# (46, 244)
# (112, 105)
# (93, 42)
# (51, 246)
# (75, 170)
# (53, 42)
# (126, 296)
# (77, 46)
# (41, 30)
# (54, 256)
# (126, 195)
# (80, 292)
# (127, 95)
# (92, 51)
# (47, 0)
# (47, 191)
# (88, 44)
# (79, 38)
# (46, 42)
# (43, 128)
# (127, 46)
# (126, 225)
# (78, 29)
# (57, 43)
# (80, 135)
# (80, 28)
# (127, 108)
# (79, 32)
# (113, 164)
# (48, 194)
# (81, 115)
# (45, 167)
# (79, 120)
# (27, 80)
# (127, 163)
# (45, 47)
# (79, 38)
# (77, 38)
# (81, 32)
# (127, 254)
# (49, 39)
# (79, 33)
# (59, 105)
# (98, 44)
# (92, 44)
# (51, 32)
# (58, 53)
# (49, 254)
# (91, 75)
# (49, 254)
# (47, 40)
# (39, 254)
# (48, 223)
# (47, 175)
# (80, 3)
# (57, 142)
# (127, 216)
# (127, 228)
# (48, 255)
# (74, 47)
# (80, 58)
# (86, 68)
# (79, 134)
# (53, 198)
# (127, 72)
# (74, 45)
# (80, 104)
# (47, 255)
# (48, 194)
# (48, 45)
# (49, 49)
# (49, 2)
# (110, 78)
# (57, 37)
# (126, 105)
# (97, 75)
# (92, 43)
# (77, 35)
# (79, 102)
# (80, 49)
# (57, 45)
# (66, 102)
# (78, 34)
# (46, 140)
# (47, 42)
# (57, 43)
# (127, 254)
# (103, 74)
# (79, 140)
# (80, 44)
# (81, 59)
# (80, 164)
# (92, 73)
# (85, 261)
# (59, 44)
# (47, 38)
# (92, 193)
# (79, 32)
# (47, 52)
# (79, 33)
# (77, 42)
# (49, 185)
# (77, 48)
# (47, 196)
# (48, 45)
# (79, 30)
# (72, 258)
# (77, 54)
# (47, 255)
# (57, 195)
# (127, 194)
# (71, 43)
# (47, 253)
# (48, 1)
# (80, 221)
# (46, 35)
# (127, 252)
# (90, 42)
# (58, 47)
# (49, 1)
# (81, 146)
# (49, 39)
# (45, 226)
# (85, 164)
# (64, 44)
# (49, 48)
# (80, 130)
# (71, 257)
# (52, 260)
# (48, 238)
# (48, 36)
# (53, 44)
# (49, 194)
# (47, 43)
# (49, 222)
# (49, 142)
# (46, 252)
# (80, 35)
# (80, 134)
# (71, 48)
# (48, 218)
# (84, 96)
# (79, 36)
# (46, 259)
# (49, 253)
# (79, 35)
# (46, 107)
# (49, 40)
# (53, 44)
# (78, 254)
# (87, 61)
# (88, 41)
# (79, 44)
# (47, 39)
# (80, 252)
# (127, 75)
# (77, 46)
# (48, 34)
# (46, 45)
# (47, 44)
# (51, 263)
# (47, 255)
# (63, 42)
# (79, 52)
# (49, 185)
# (88, 56)
# (49, 132)
# (49, 44)
# (39, 254)
# (58, 197)
# (85, 152)
# (46, 48)
# (76, 129)
# (51, 165)
# (47, 42)
# (92, 45)
# (48, 44)
# (127, 239)
# (127, 75)
# (47, 32)
# (46, 203)
# (47, 42)
# (51, 187)
# (48, 257)
# (71, 70)
# (79, 38)
# (57, 39)
# (48, 214)
# (75, 44)
# (48, 241)
# (78, 193)
# (46, 42)
# (79, 123)
# (86, 49)
# (47, 33)
# (127, 253)
# (78, 182)
# (46, 39)
# (48, 255)
# (89, 265)
# (51, 198)
# (79, 106)
# (79, 166)
# (97, 45)
# (80, 31)
# (79, 29)
# (45, 43)
# (51, 29)
# (79, 171)
# (80, 134)
# (47, 31)
# (47, 256)
# (79, 38)
# (48, 52)
# (49, 44)
# (47, 254)
# (52, 41)
# (48, 253)
# (47, 215)
# (47, 127)
# (85, 43)
# (80, 186)
# (49, 105)
# (59, 38)
# (46, 133)
# (79, 32)
# (47, 35)
# (79, 37)
# (48, 44)
# (58, 50)
# (76, 46)
# (79, 236)
# (59, 49)
# (49, 250)
# (84, 106)
# (51, 165)
# (47, 0)
# (46, 31)
# (55, 27)
# (79, 3)
# (49, 45)
# (48, 42)
# (46, 45)
# (47, 49)
# (80, 33)
# (79, 32)
# (49, 35)
# (79, 158)
# (46, 43)
# (43, 89)
# (48, 40)
# (48, 48)
# (48, 152)
# (43, 255)
# (48, 44)
# (79, 32)
# (80, 36)
# (80, 30)
# (125, 44)
# (47, 44)
# (46, 44)
# (79, 38)
# (48, 44)
# (79, 0)
# (127, 45)
# (46, 196)
# (81, 145)
# (49, 46)
# (47, 43)
# (80, 0)
# (47, 40)
# (80, 0)
# (80, 0)
# (46, 212)
# (82, 44)
# (47, 43)
# (47, 44)
# (46, 37)
# (79, 29)
# (47, 44)
# (47, 54)
# (82, 24)
# (48, 49)
# (52, 33)
# (47, 194)
# (49, 54)
# (47, 37)
# (47, 50)
# (52, 45)
# (79, 37)
# (80, 39)
# (114, 45)
# (47, 149)
# (47, 44)
# (48, 2)
# (47, 34)
# (52, 140)
# (46, 43)
# (79, 6)
# (47, 39)
# (79, 34)
# (77, 33)
# (49, 41)
# (49, 30)
# (79, 31)
# (112, 0)
# (52, 43)
# (53, 35)
# (47, 210)
# (45, 37)
# (46, 45)
# (48, 3)
# (43, 103)
# (47, 176)
# (80, 0)
# (79, 5)
# (79, 36)
# (79, 34)
# (53, 43)
# (112, 44)
# (47, 38)
# (47, 2)
# (79, 28)
# (48, 33)
# (78, 190)
# (46, 31)
# (78, 31)
# (48, 38)
# (47, 2)
# (79, 33)
# (48, 46)
# (89, 255)
# (80, 285)
# (81, 156)
# (48, 45)
# (79, 249)
# (48, 43)
# (78, 38)
# (36, 33)
# (49, 34)
# (47, 31)
# (79, 11)
# (80, 4)
# (79, 34)
# (53, 33)
# (48, 253)
# (79, 32)
# (60, 42)
# (127, 255)
# (47, 34)
# (67, 44)
# (48, 222)
# (57, 43)
# (112, 165)
# (79, 41)
# (80, 22)
# (49, 31)
# (79, 36)
# (80, 180)
# (49, 43)
# (82, 180)
# (43, 53)
# (116, 45)
# (48, 72)
# (59, 185)
# (73, 41)
# (44, 38)
# (51, 45)
# (47, 1)
# (46, 36)
# (49, 30)
# (52, 134)
# (47, 47)
# (47, 45)
# (48, 199)
# (112, 44)
# (47, 44)
# (42, 66)
# (47, 164)
# (46, 34)
# (47, 45)
# (79, 30)
# (80, 39)
# (79, 33)
# (49, 43)
# (48, 28)
# (80, 28)
# (45, 54)
# (45, 44)
# (80, 5)
# (48, 31)
# (46, 35)
# (51, 39)
# (47, 35)
# (47, 46)
# (47, 43)
# (47, 44)
# (80, 1)
# (79, 31)
# (44, 41)
# (79, 3)
# (52, 188)
# (48, 141)
# (48, 42)
# (48, 42)
# (49, 44)
# (47, 42)
# (56, 35)
# (49, 46)
# (49, 220)
# (48, 4)
# (56, 155)
# (48, 34)
# (52, 215)
# (39, 194)
# (47, 2)
# (112, 44)
# (79, 10)
# (79, 34)
# (80, 257)
# (45, 41)
# (59, 40)
# (47, 38)
# (47, 38)
# (53, 42)
# (44, 39)
# (75, 40)
# (44, 39)
# (127, 135)
# (79, 12)
# (49, 45)
# (46, 43)

# %%
plt.scatter(x=np.arange(len(max_fallout_list)),y=max_fallout_list)

# %% [markdown]
# # train set 확인

# %% [markdown]
# ## 결과 출력

# %%
#confusion matrix 계산
#valid set 계산.
all_filename=[]
all_prediction=[]
all_answers=[]


def train_evaluate(model,data_ind):
    model.eval()
    test_loss = 0
    file_name = []
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform=transforms.ToTensor(),
                                                   data_num=data_ind-1,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    
    with torch.no_grad():
        for image, label,path_list in train_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            file_name+=(path_list)            
        all_filename.append(file_name)
        all_prediction.append(predictions)
        all_answers.append(answers)
        return predictions,answers,test_loss

# %%
#분포 확인 위해 수정
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler



classes = ["pathology","healthy"]
sr=16000
win_length =  np.int64(sr/40) # 
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None,augment=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        self.augment=augment
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        print()
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다.     
    
       
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc, spectro, mel-spectro를 추출
        2. mfcc를 224프레임으로 패딩. 또한 세로축은 224으로 interpolate
        3. resnet에 사용되기 위해 3채널로 쌓기.
        4. 미정. 0~1 정규화
        
        """
        sig =  phrase_dict[self.path_list[idx]] # 16000hz 실시
        
        
        MFCCs = librosa.feature.mfcc(y=sig, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=128)
        #MFCCs = librosa.util.normalize(MFCCs) # l-infinity norm
        #MFCCs=cv2.resize(MFCCs,(MFCCs.shape[1],128),interpolation=cv2.INTER_LINEAR)# interpolate 적용해서 128 사이즈로
        
        
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        
        
        mel_feature = librosa.feature.melspectrogram(y=sig,sr=sr,hop_length=hop_length,n_fft=n_fft)
        mel_feature = librosa.core.power_to_db(mel_feature,ref=np.max)
        #mel_feature=librosa.util.normalize(mel_feature) # l-infinity norm
        
        #stft 300 FRAME이 되도록 패딩.
        length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        #log_spectrogram = librosa.util.normalize(log_spectrogram) # l-infinity norm
        
        
        #padding
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram = pad2d(log_spectrogram, length)
        mel_feature = pad2d(mel_feature, length)
        MFCCs = pad2d(MFCCs, length) # mfcc 대신 encoder를 가져와서 해보자.
        log_spectrogram=log_spectrogram[:128,:]# 224 x 300 으로 사이즈 조절
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 타입 변화
            mel_feature=self.transform(mel_feature).type(torch.float32)# 타입 변화
            MFCCs=self.transform(MFCCs).type(torch.float32)# 타입 변화            
            
            MSF = torch.stack([log_spectrogram,mel_feature,MFCCs])# 3채널로 복사.
            #augmentation
            if self.training and self.augment:
                MSF=self.augment(MSF)     
            MSF = MSF.squeeze(dim=1)
        else:
            #print("else")
            ##################안쓰는 곳
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return MSF, self.classes.index(self.label[idx]), self.path_list[idx]

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_300_msf_organic_aug.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers, valid_loss = train_evaluate(model,data_ind)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))

# %%
len(all_filename)

# %%
fold_excel = []
for i in range(5):
    fold_excel.append(pd.DataFrame({'filename':all_filename[i],
                  'prediction':[data.cpu().numpy().item() for data in all_prediction[i]],
                  'answer':[ data.cpu().numpy().item() for data in all_answers[i]],
                  'fold':i+1}))

# %%
fold_excel_all=pd.concat(fold_excel,axis=0)

# %%
answer_paper=pd.read_excel('D:/project/voice_pathology_ai/voice_data/only_organics_healthy.xlsx')
answer_paper.head()

# %%
answer_paper['RECORDING']=answer_paper['RECORDING'].values.astype(str)
answer_paper['RECORDING']=answer_paper['RECORDING']+'-phrase.wav'
answer_paper[['RECORDING','DETAIL']]
merge_left = pd.merge(fold_excel_all,answer_paper[['RECORDING','DETAIL']], how='left', left_on='filename', right_on='RECORDING')
merge_left.drop(['RECORDING'],axis=1,inplace=True)
merge_left['result']=merge_left['prediction']==merge_left['answer']
merge_left

# %%
merge_left.to_excel('D:/project/voice_pathology_ai/voice_data/result_train_organics_0523_aug.xlsx',index=False)

# %% [markdown]
# ## train cam

# %%
# final conv layer name 
finalconv_name = 'layer4'

# activations
feature_blobs = []

# gradient를 가져올 hook 함수
backward_feature = []

transform_norm = transforms.ToTensor()

# output으로 나오는 feature를 feature_blobs에 append하도록
def hook_feature(module, input, output):
    feature_blobs.append(output.cpu().data.numpy()) # 레이어의 마지막 output(피처맵)을 구하는 함수
    

# Grad-CAM
def backward_hook(module, input, output):
    backward_feature.append(output[0])  #backward시에 그래디언트 저장.

# %%
CAM_BATCH_SIZE=1
finalconv_name

# %%
from torch.autograd import Variable
from torchvision.utils import make_grid, save_image



#pathology 음성 파일 가져오기

length=300
image_list=[]

label_list=[]
prob_list=[] #valid set의 확률값
name_list=[] #파일명
predict_label_list=[] #예측 라벨
res = []



mel_list=[]#정규 mel-spectrogram 모은 리스트
fallout_list=[] # cam - mel . 음수는 0 처리.


model.eval()
mel_sample=None


for data_ind in  range(1,6):
    print("----------------")
    print(data_ind,'fold')
    print("----------------")
    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform=transforms.ToTensor(),
                                                   data_num=data_ind-1,
                                                   training=True
                                               ),
                                               batch_size = CAM_BATCH_SIZE,
                                               shuffle = True,) 
    for image, label, path in train_loader:

        name = path[0].split('\\')[-1]
        name = name.replace('.wav', '')
        name_list.append(name)
        label_list.append(classes[label])

        # activations
        feature_blobs = []
        # gradient를 가져올 hook 함수
        backward_feature = []

        mel_sample = image
        mel_sample = mel_sample.to(DEVICE).float()


        model._modules.get(finalconv_name).register_forward_hook(hook_feature)
        model._modules.get(finalconv_name).register_backward_hook(backward_hook)



        # Prediction
        logit = model(mel_sample) # 예측값 구하기.
        out = F.softmax(logit, dim=1).data.squeeze() # softmax 적용 (모델을 통과는 했지만, criterion는 안통과함.)
        probs, idx = out.sort(0, True)
        print("Predicted label : %d, Probability : %.2f" % (idx[0].item(), probs[0].item()))
        predict_label_list.append(classes[idx[0].item()])
        prob_list.append(probs[0].item())
        res.append(classes[label]==classes[idx[0].item()])


        ###########
        # Grad - cam
        ###########

        score = logit[:, idx[0]].squeeze() # 예측값 y^c.
        score.backward(retain_graph = True) # 예측값 y^c에 대해서 backprop 진행

        activations = torch.Tensor(feature_blobs[0]).to(DEVICE) # (1, 512, 7, 7), forward activations. append라서 0번이 마지막
        gradients = backward_feature[0] # (1, 512, 4, 10), backward gradients. 마지막 conv layer의 gradient
        b, k, u, v = gradients.size()  # batch, 피처맵 수,  상, 하
        #print(gradients.size())

        alpha = gradients.view(b, k, -1).mean(2) # (1, 512, 7*7) => (1, 512), feature map k의 'importance'
        weights = alpha.view(b, k, 1, 1) # (1, 512, 1, 1)

        grad_cam_map = (weights*activations).sum(1, keepdim = True) # alpha * A^k = (1, 512, 7, 7) => (1, 1, 7, 7)
        grad_cam_map = F.relu(grad_cam_map) # Apply R e L U
        grad_cam_map = F.interpolate(grad_cam_map, size=(128, 300), mode='bilinear', align_corners=False) # (1, 1, 128, 300)
        map_min, map_max = grad_cam_map.min(), grad_cam_map.max()
        grad_cam_map = (grad_cam_map - map_min).div(map_max - map_min).data # (1, 1, 128, 300), min-max scaling

        grad_heatmap=grad_cam_map.squeeze().cpu()

        # grad_cam_map.squeeze() : (128, 300)

        #save_image(grad_heatmap, os.path.join("./", "Grad_CAM.jpg"))

        # mel-spectorgram min-max normalization

        mel_min,mel_max = mel_sample.squeeze()[1].min(),mel_sample.squeeze()[1].max()
        mel_sample = (mel_sample.squeeze()[1]- mel_min).div(mel_max-mel_min)
        mel_sample = mel_sample.cpu().numpy()
        mel_list.append(mel_sample)


        #mel_sample = librosa.util.normalize(mel_sample.cpu().squeeze().numpy()[0]) #수정 필요. min-max normalization

        grad_result = grad_heatmap.numpy() + mel_sample # (1, 3, 244, 244)

        fallout_list.append(grad_heatmap.numpy() - mel_sample)


        plt.figure(figsize=(10,5))
        plt.ion()
        plt.subplot(131)
        librosa.display.specshow(mel_sample, sr=sr, hop_length=hop_length)
        plt.xlabel("Time")
        plt.ylabel("Frequency")
        plt.colorbar(format='%+2.0f dB')
        plt.title("Spectrogram (dB)")

        plt.subplot(132)
        librosa.display.specshow(grad_heatmap.numpy(), sr=sr, hop_length=hop_length)
        plt.xlabel("Time")
        plt.ylabel("Frequency")
        plt.colorbar(format='%+2.0f dB')
        plt.title("Spectrogram (dB)")

        plt.subplot(133)
        librosa.display.specshow(grad_result, sr=sr, hop_length=hop_length)
        plt.xlabel("Time")
        plt.ylabel("Frequency")
        plt.colorbar(format='%+2.0f dB')
        plt.title("Spectrogram (dB)")


        
        folder_path='D:/project/voice_pathology_ai/voice_data/aug_organics_cam_fold_train/'+str(data_ind)+'fold/'
        plt.savefig(folder_path+name)
        plt.close() 
        
    

result_excel=pd.concat( [pd.DataFrame(name_list),
            pd.DataFrame(label_list),
            pd.DataFrame(predict_label_list),
            pd.DataFrame(prob_list),
            pd.DataFrame(res)],axis=1)
result_excel.columns=['name','class','predict','probability','result']
#result_excel.to_excel("D:/project/voice_pathology_ai/voice_data/result_excel_fallout_train.xlsx",index=False)

# %% [markdown]
# # 기타

# %%
#크기 알아보기
#일반 CNN

m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())

# %%
#크기 알아보기
#주파수 영역 CNN

input = torch.randn(32, 1, 500, 13)
m=nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 32,# FeatureMap 수,커널 수
            kernel_size = (1,13),#1x13  no padding
        )
output=m(input)
print(output.size())
m=nn.Conv2d(
            in_channels = 32,# 채널이 1개
            out_channels = 64,# FeatureMap 수,커널 수
            kernel_size = (27,1),#9 x 1 no padding
        )
output=m(output)
print(output.size())

# %%
input = torch.randn(500, 13)

out=torch.stack([input,input,input])
out.size()
