# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5
# - https://quokkas.tistory.com/37 : early stopping
# - https://continuous-development.tistory.com/166 : stratified kfold
# - https://deep-learning-study.tistory.com/476 fiter 시각화
# - https://wyatt37.tistory.com/10 : random over sampling

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys

p = os.path.abspath('../..') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.0  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../../../voice_data/pathology_new/i/export'):
    sig, sr = librosa.load('../../../voice_data/pathology_new/i/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    pathology.append(log_spectrogram)
    

#Healthy data
for audio_path in os.listdir('../../../voice_data/healthy_new/i/export'):
    sig, sr = librosa.load('../../../voice_data/healthy_new/i/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    stft = librosa.stft(sig,win_length=win_length ,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    healthy.append(log_spectrogram)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  1194
# healthy data 수 :  687
# 가장 긴 path sample : 126051
# 가장 긴 healthy sample : 226236

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 2.52102 초
# 4.52472 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
#headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
#pd.DataFrame(healthy[0].T,columns=headers)

print(healthy[0])
# Out:
# [[  9.921936     0.42160308   2.2117379  ...   0.7855269   -0.6773767
#    -2.7671578 ]
#  [ 11.065737     6.5034037   -2.5846279  ...  -4.1016107   -5.4213667
#   -10.597058  ]
#  [ 11.889238     5.386593   -19.749138   ... -22.717716   -14.141793
#   -12.514749  ]
#  ...
#  [-43.76186    -43.76186    -43.76186    ... -43.76186    -43.76186
#   -43.76186   ]
#  [-43.76186    -43.76186    -43.76186    ... -43.76186    -43.76186
#   -43.76186   ]
#  [-43.76186    -43.76186    -43.76186    ... -43.76186    -43.76186
#   -43.76186   ]]

# %%
print(healthy[0].shape) #1번 주파수 축, 2번 시간축.
print(healthy[1].shape)
# Out:
# (626, 272)
# (626, 331)

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기 - Stratified KFold
#
# - pathology : 1194 / healthy : 634 / 총 1828
# - k = 5

# %%
#1. train, test 나누기

import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

pathology = glob('../../../voice_data/pathology_new/i/export/*.wav')
healthy = glob('../../../voice_data/healthy_new/i/export/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))

X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1194:
        Y.append("pathology")
    else:
        Y.append("healthy")

skf_iris = StratifiedKFold(n_splits=5)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_test_list = []
Y_test_list = []

for train_idx, test_idx in  skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_test = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_test = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_test_list.append(X_test)
    
    Y_test_list.append(Y_test)
    Y_train_list.append(Y_train)
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_test
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# Pathology :  1194
# Healthy:  687
# 총 데이터수 :  1881
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 549, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 138, 'pathology': 239}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 550, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 137, 'pathology': 239}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 550, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 137, 'pathology': 239}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 550, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 137, 'pathology': 239}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 549, 'pathology': 956}
# 검증 레이블 데이터 분포 :
#  {'healthy': 138, 'pathology': 238}

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.(여기서는 500frame)
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_test_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. 300프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        #stft 500 FRAME이 되도록 패딩.
        length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram = pad2d(log_spectrogram, length)
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 데이터 0~1 정규화
            log_spectrogram=torch.stack([log_spectrogram,log_spectrogram,log_spectrogram])# 3채널로 복사.
            log_spectrogram = log_spectrogram.squeeze(dim=1)
        else:
            #print("else")
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return log_spectrogram, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  18 #한 배치당 18개 음성데이터
EPOCHS = 40 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인


train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                               classes,
                                               transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_test_list,
                                               classes,
                                               transform = transforms.ToTensor(),
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])
librosa.display.specshow(X_train[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([18, 3, 626, 300]) type: torch.FloatTensor
# Y_train :  torch.Size([18]) type: torch.LongTensor
# tensor(1)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
#valiation set 확인
for (X_valid,Y_valid) in validation_loader:
    print("X_valid : ",X_valid.size(),'type:',X_valid.type())
    print("Y_valid : ",Y_valid.size(),'type:',Y_valid.type())
    break

print(Y_valid[0])
librosa.display.specshow(X_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")

#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_valid :  torch.Size([18, 3, 626, 300]) type: torch.FloatTensor
# Y_valid :  torch.Size([18]) type: torch.LongTensor
# tensor(1)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %% [markdown]
# # RESNET

# %%
# 모델 
# pretrained


def model_initialize():
    model = models.resnet34(pretrained=True).cuda()
    model.ftrs = model.fc.in_features # in_features : fully connected의 입력수.
    num_ftrs = model.fc.in_features

    model.fc = nn.Sequential(nn.Linear(num_ftrs, 256),
                             nn.BatchNorm1d(256),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(256,128),
                             nn.BatchNorm1d(128),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(128,64),
                             nn.BatchNorm1d(64),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(64,50),
                             nn.BatchNorm1d(50),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(50,2)
                            )

    model = model.cuda()
    return model
model=model_initialize()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=64, out_features=50, bias=True)
#     (13): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Linear(in_features=50, out_features=2, bias=True)
#   )
# )

# %%
# get the model summary
from torchsummary import summary
summary(model, input_size=(3, 626, 500), device=DEVICE.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 313, 250]           9,408
#        BatchNorm2d-2         [-1, 64, 313, 250]             128
#               ReLU-3         [-1, 64, 313, 250]               0
#          MaxPool2d-4         [-1, 64, 157, 125]               0
#             Conv2d-5         [-1, 64, 157, 125]          36,864
#        BatchNorm2d-6         [-1, 64, 157, 125]             128
#               ReLU-7         [-1, 64, 157, 125]               0
#             Conv2d-8         [-1, 64, 157, 125]          36,864
#        BatchNorm2d-9         [-1, 64, 157, 125]             128
#              ReLU-10         [-1, 64, 157, 125]               0
#        BasicBlock-11         [-1, 64, 157, 125]               0
#            Conv2d-12         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-13         [-1, 64, 157, 125]             128
#              ReLU-14         [-1, 64, 157, 125]               0
#            Conv2d-15         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-16         [-1, 64, 157, 125]             128
#              ReLU-17         [-1, 64, 157, 125]               0
#        BasicBlock-18         [-1, 64, 157, 125]               0
#            Conv2d-19         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-20         [-1, 64, 157, 125]             128
#              ReLU-21         [-1, 64, 157, 125]               0
#            Conv2d-22         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-23         [-1, 64, 157, 125]             128
#              ReLU-24         [-1, 64, 157, 125]               0
#        BasicBlock-25         [-1, 64, 157, 125]               0
#            Conv2d-26          [-1, 128, 79, 63]          73,728
#       BatchNorm2d-27          [-1, 128, 79, 63]             256
#              ReLU-28          [-1, 128, 79, 63]               0
#            Conv2d-29          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-30          [-1, 128, 79, 63]             256
#            Conv2d-31          [-1, 128, 79, 63]           8,192
#       BatchNorm2d-32          [-1, 128, 79, 63]             256
#              ReLU-33          [-1, 128, 79, 63]               0
#        BasicBlock-34          [-1, 128, 79, 63]               0
#            Conv2d-35          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-36          [-1, 128, 79, 63]             256
#              ReLU-37          [-1, 128, 79, 63]               0
#            Conv2d-38          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-39          [-1, 128, 79, 63]             256
#              ReLU-40          [-1, 128, 79, 63]               0
#        BasicBlock-41          [-1, 128, 79, 63]               0
#            Conv2d-42          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-43          [-1, 128, 79, 63]             256
#              ReLU-44          [-1, 128, 79, 63]               0
#            Conv2d-45          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-46          [-1, 128, 79, 63]             256
#              ReLU-47          [-1, 128, 79, 63]               0
#        BasicBlock-48          [-1, 128, 79, 63]               0
#            Conv2d-49          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-50          [-1, 128, 79, 63]             256
#              ReLU-51          [-1, 128, 79, 63]               0
#            Conv2d-52          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-53          [-1, 128, 79, 63]             256
#              ReLU-54          [-1, 128, 79, 63]               0
#        BasicBlock-55          [-1, 128, 79, 63]               0
#            Conv2d-56          [-1, 256, 40, 32]         294,912
#       BatchNorm2d-57          [-1, 256, 40, 32]             512
#              ReLU-58          [-1, 256, 40, 32]               0
#            Conv2d-59          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-60          [-1, 256, 40, 32]             512
#            Conv2d-61          [-1, 256, 40, 32]          32,768
#       BatchNorm2d-62          [-1, 256, 40, 32]             512
#              ReLU-63          [-1, 256, 40, 32]               0
#        BasicBlock-64          [-1, 256, 40, 32]               0
#            Conv2d-65          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-66          [-1, 256, 40, 32]             512
#              ReLU-67          [-1, 256, 40, 32]               0
#            Conv2d-68          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-69          [-1, 256, 40, 32]             512
#              ReLU-70          [-1, 256, 40, 32]               0
#        BasicBlock-71          [-1, 256, 40, 32]               0
#            Conv2d-72          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-73          [-1, 256, 40, 32]             512
#              ReLU-74          [-1, 256, 40, 32]               0
#            Conv2d-75          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-76          [-1, 256, 40, 32]             512
#              ReLU-77          [-1, 256, 40, 32]               0
#        BasicBlock-78          [-1, 256, 40, 32]               0
#            Conv2d-79          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-80          [-1, 256, 40, 32]             512
#              ReLU-81          [-1, 256, 40, 32]               0
#            Conv2d-82          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-83          [-1, 256, 40, 32]             512
#              ReLU-84          [-1, 256, 40, 32]               0
#        BasicBlock-85          [-1, 256, 40, 32]               0
#            Conv2d-86          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-87          [-1, 256, 40, 32]             512
#              ReLU-88          [-1, 256, 40, 32]               0
#            Conv2d-89          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-90          [-1, 256, 40, 32]             512
#              ReLU-91          [-1, 256, 40, 32]               0
#        BasicBlock-92          [-1, 256, 40, 32]               0
#            Conv2d-93          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-94          [-1, 256, 40, 32]             512
#              ReLU-95          [-1, 256, 40, 32]               0
#            Conv2d-96          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-97          [-1, 256, 40, 32]             512
#              ReLU-98          [-1, 256, 40, 32]               0
#        BasicBlock-99          [-1, 256, 40, 32]               0
#           Conv2d-100          [-1, 512, 20, 16]       1,179,648
#      BatchNorm2d-101          [-1, 512, 20, 16]           1,024
#             ReLU-102          [-1, 512, 20, 16]               0
#           Conv2d-103          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-104          [-1, 512, 20, 16]           1,024
#           Conv2d-105          [-1, 512, 20, 16]         131,072
#      BatchNorm2d-106          [-1, 512, 20, 16]           1,024
#             ReLU-107          [-1, 512, 20, 16]               0
#       BasicBlock-108          [-1, 512, 20, 16]               0
#           Conv2d-109          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-110          [-1, 512, 20, 16]           1,024
#             ReLU-111          [-1, 512, 20, 16]               0
#           Conv2d-112          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-113          [-1, 512, 20, 16]           1,024
#             ReLU-114          [-1, 512, 20, 16]               0
#       BasicBlock-115          [-1, 512, 20, 16]               0
#           Conv2d-116          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-117          [-1, 512, 20, 16]           1,024
#             ReLU-118          [-1, 512, 20, 16]               0
#           Conv2d-119          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-120          [-1, 512, 20, 16]           1,024
#             ReLU-121          [-1, 512, 20, 16]               0
#       BasicBlock-122          [-1, 512, 20, 16]               0
# AdaptiveAvgPool2d-123            [-1, 512, 1, 1]               0
#           Linear-124                  [-1, 256]         131,328
#      BatchNorm1d-125                  [-1, 256]             512
#             ReLU-126                  [-1, 256]               0
#          Dropout-127                  [-1, 256]               0
#           Linear-128                  [-1, 128]          32,896
#      BatchNorm1d-129                  [-1, 128]             256
#             ReLU-130                  [-1, 128]               0
#          Dropout-131                  [-1, 128]               0
#           Linear-132                   [-1, 64]           8,256
#      BatchNorm1d-133                   [-1, 64]             128
#             ReLU-134                   [-1, 64]               0
#          Dropout-135                   [-1, 64]               0
#           Linear-136                   [-1, 50]           3,250
#      BatchNorm1d-137                   [-1, 50]             100
#             ReLU-138                   [-1, 50]               0
#          Dropout-139                   [-1, 50]               0
#           Linear-140                    [-1, 2]             102
# ================================================================
# Total params: 21,461,500
# Trainable params: 21,461,500
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.58
# Forward/backward pass size (MB): 610.02
# Params size (MB): 81.87
# Estimated Total Size (MB): 695.47
# ----------------------------------------------------------------

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_test_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# resnet34 pretrained true
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = '../../checkpoint/checkpoint_spectro_resnet18_true_noros_'+str(data_ind)+'_i_300.pt'

    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break
        
        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0445	 Train Acc:46.41 %  | 	Valid Loss:0.0384 	Valid Acc: 54.38 %
#
# Validation loss decreased (inf --> 0.038428).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0419	 Train Acc:51.33 %  | 	Valid Loss:0.0379 	Valid Acc: 57.56 %
#
# Validation loss decreased (0.038428 --> 0.037871).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0406	 Train Acc:53.32 %  | 	Valid Loss:0.0371 	Valid Acc: 61.54 %
#
# Validation loss decreased (0.037871 --> 0.037101).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0395	 Train Acc:54.32 %  | 	Valid Loss:0.0355 	Valid Acc: 61.80 %
#
# Validation loss decreased (0.037101 --> 0.035496).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0369	 Train Acc:62.37 %  | 	Valid Loss:0.0344 	Valid Acc: 63.66 %
#
# Validation loss decreased (0.035496 --> 0.034355).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0365	 Train Acc:61.10 %  | 	Valid Loss:0.0332 	Valid Acc: 65.52 %
#
# Validation loss decreased (0.034355 --> 0.033171).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0346	 Train Acc:63.96 %  | 	Valid Loss:0.0330 	Valid Acc: 64.72 %
#
# Validation loss decreased (0.033171 --> 0.032991).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0339	 Train Acc:65.29 %  | 	Valid Loss:0.0309 	Valid Acc: 71.09 %
#
# Validation loss decreased (0.032991 --> 0.030857).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0328	 Train Acc:67.95 %  | 	Valid Loss:0.0336 	Valid Acc: 64.46 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0319	 Train Acc:69.61 %  | 	Valid Loss:0.0319 	Valid Acc: 68.97 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0315	 Train Acc:69.68 %  | 	Valid Loss:0.0321 	Valid Acc: 66.31 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:12]	 Train Loss:0.0300	 Train Acc:72.14 %  | 	Valid Loss:0.0312 	Valid Acc: 69.23 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:13]	 Train Loss:0.0284	 Train Acc:74.73 %  | 	Valid Loss:0.0382 	Valid Acc: 57.82 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0432	 Train Acc:48.57 %  | 	Valid Loss:0.0376 	Valid Acc: 59.57 %
#
# Validation loss decreased (inf --> 0.037619).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0414	 Train Acc:53.09 %  | 	Valid Loss:0.0381 	Valid Acc: 58.78 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0412	 Train Acc:53.69 %  | 	Valid Loss:0.0369 	Valid Acc: 63.03 %
#
# Validation loss decreased (0.037619 --> 0.036857).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0399	 Train Acc:55.42 %  | 	Valid Loss:0.0356 	Valid Acc: 64.10 %
#
# Validation loss decreased (0.036857 --> 0.035563).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0383	 Train Acc:58.60 %  | 	Valid Loss:0.0362 	Valid Acc: 66.22 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0381	 Train Acc:58.27 %  | 	Valid Loss:0.0348 	Valid Acc: 68.35 %
#
# Validation loss decreased (0.035563 --> 0.034837).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0366	 Train Acc:61.46 %  | 	Valid Loss:0.0341 	Valid Acc: 67.29 %
#
# Validation loss decreased (0.034837 --> 0.034129).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0364	 Train Acc:63.26 %  | 	Valid Loss:0.0347 	Valid Acc: 68.09 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0352	 Train Acc:63.32 %  | 	Valid Loss:0.0342 	Valid Acc: 66.49 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0332	 Train Acc:66.51 %  | 	Valid Loss:0.0356 	Valid Acc: 62.50 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0317	 Train Acc:69.83 %  | 	Valid Loss:0.0355 	Valid Acc: 63.30 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0308	 Train Acc:69.77 %  | 	Valid Loss:0.0311 	Valid Acc: 68.35 %
#
# Validation loss decreased (0.034129 --> 0.031137).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0301	 Train Acc:72.16 %  | 	Valid Loss:0.0301 	Valid Acc: 70.48 %
#
# Validation loss decreased (0.031137 --> 0.030116).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0284	 Train Acc:75.08 %  | 	Valid Loss:0.0333 	Valid Acc: 65.43 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0274	 Train Acc:75.88 %  | 	Valid Loss:0.0328 	Valid Acc: 69.68 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:16]	 Train Loss:0.0258	 Train Acc:79.60 %  | 	Valid Loss:0.0332 	Valid Acc: 60.64 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:17]	 Train Loss:0.0243	 Train Acc:80.40 %  | 	Valid Loss:0.0329 	Valid Acc: 65.96 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:18]	 Train Loss:0.0210	 Train Acc:85.91 %  | 	Valid Loss:0.0371 	Valid Acc: 62.50 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0415	 Train Acc:51.43 %  | 	Valid Loss:0.0369 	Valid Acc: 59.84 %
#
# Validation loss decreased (inf --> 0.036853).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0396	 Train Acc:58.07 %  | 	Valid Loss:0.0375 	Valid Acc: 61.70 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0390	 Train Acc:56.21 %  | 	Valid Loss:0.0356 	Valid Acc: 59.57 %
#
# Validation loss decreased (0.036853 --> 0.035615).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0379	 Train Acc:58.80 %  | 	Valid Loss:0.0359 	Valid Acc: 63.30 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0371	 Train Acc:62.19 %  | 	Valid Loss:0.0350 	Valid Acc: 63.03 %
#
# Validation loss decreased (0.035615 --> 0.034969).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0359	 Train Acc:60.86 %  | 	Valid Loss:0.0351 	Valid Acc: 63.83 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0349	 Train Acc:63.85 %  | 	Valid Loss:0.0334 	Valid Acc: 67.55 %
#
# Validation loss decreased (0.034969 --> 0.033400).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0347	 Train Acc:63.52 %  | 	Valid Loss:0.0329 	Valid Acc: 69.95 %
#
# Validation loss decreased (0.033400 --> 0.032935).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0330	 Train Acc:65.71 %  | 	Valid Loss:0.0327 	Valid Acc: 70.48 %
#
# Validation loss decreased (0.032935 --> 0.032673).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0322	 Train Acc:65.78 %  | 	Valid Loss:0.0302 	Valid Acc: 70.48 %
#
# Validation loss decreased (0.032673 --> 0.030229).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0319	 Train Acc:66.84 %  | 	Valid Loss:0.0308 	Valid Acc: 71.54 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0308	 Train Acc:69.17 %  | 	Valid Loss:0.0295 	Valid Acc: 69.41 %
#
# Validation loss decreased (0.030229 --> 0.029514).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0304	 Train Acc:70.96 %  | 	Valid Loss:0.0304 	Valid Acc: 71.28 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0302	 Train Acc:68.70 %  | 	Valid Loss:0.0278 	Valid Acc: 77.39 %
#
# Validation loss decreased (0.029514 --> 0.027806).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0293	 Train Acc:72.82 %  | 	Valid Loss:0.0309 	Valid Acc: 74.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0270	 Train Acc:75.75 %  | 	Valid Loss:0.0281 	Valid Acc: 75.80 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:17]	 Train Loss:0.0253	 Train Acc:79.00 %  | 	Valid Loss:0.0292 	Valid Acc: 73.94 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:18]	 Train Loss:0.0229	 Train Acc:83.52 %  | 	Valid Loss:0.0309 	Valid Acc: 71.28 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:19]	 Train Loss:0.0211	 Train Acc:85.71 %  | 	Valid Loss:0.0290 	Valid Acc: 71.54 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0472	 Train Acc:44.92 %  | 	Valid Loss:0.0392 	Valid Acc: 48.40 %
#
# Validation loss decreased (inf --> 0.039173).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0433	 Train Acc:50.70 %  | 	Valid Loss:0.0359 	Valid Acc: 66.22 %
#
# Validation loss decreased (0.039173 --> 0.035940).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0402	 Train Acc:55.75 %  | 	Valid Loss:0.0387 	Valid Acc: 58.24 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0385	 Train Acc:59.20 %  | 	Valid Loss:0.0344 	Valid Acc: 67.55 %
#
# Validation loss decreased (0.035940 --> 0.034379).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0381	 Train Acc:60.80 %  | 	Valid Loss:0.0339 	Valid Acc: 67.29 %
#
# Validation loss decreased (0.034379 --> 0.033935).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0366	 Train Acc:62.52 %  | 	Valid Loss:0.0354 	Valid Acc: 63.30 %
#
# EarlyStopping counter: 1 out of 5
# [EPOCH:7]	 Train Loss:0.0361	 Train Acc:64.58 %  | 	Valid Loss:0.0317 	Valid Acc: 71.81 %
#
# Validation loss decreased (0.033935 --> 0.031660).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0347	 Train Acc:63.65 %  | 	Valid Loss:0.0317 	Valid Acc: 72.07 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0335	 Train Acc:68.57 %  | 	Valid Loss:0.0319 	Valid Acc: 71.01 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0327	 Train Acc:67.31 %  | 	Valid Loss:0.0308 	Valid Acc: 71.81 %
#
# Validation loss decreased (0.031660 --> 0.030794).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0315	 Train Acc:71.30 %  | 	Valid Loss:0.0325 	Valid Acc: 69.15 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0302	 Train Acc:72.03 %  | 	Valid Loss:0.0316 	Valid Acc: 69.41 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:13]	 Train Loss:0.0283	 Train Acc:76.08 %  | 	Valid Loss:0.0291 	Valid Acc: 74.73 %
#
# Validation loss decreased (0.030794 --> 0.029067).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0266	 Train Acc:78.34 %  | 	Valid Loss:0.0272 	Valid Acc: 77.39 %
#
# Validation loss decreased (0.029067 --> 0.027236).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0242	 Train Acc:80.66 %  | 	Valid Loss:0.0314 	Valid Acc: 69.68 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0229	 Train Acc:83.12 %  | 	Valid Loss:0.0285 	Valid Acc: 74.20 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:17]	 Train Loss:0.0205	 Train Acc:86.64 %  | 	Valid Loss:0.0284 	Valid Acc: 76.06 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:18]	 Train Loss:0.0183	 Train Acc:87.97 %  | 	Valid Loss:0.0297 	Valid Acc: 77.13 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:19]	 Train Loss:0.0163	 Train Acc:90.37 %  | 	Valid Loss:0.0320 	Valid Acc: 71.28 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0394	 Train Acc:56.48 %  | 	Valid Loss:0.0359 	Valid Acc: 63.83 %
#
# Validation loss decreased (inf --> 0.035882).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0380	 Train Acc:59.00 %  | 	Valid Loss:0.0363 	Valid Acc: 63.30 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:3]	 Train Loss:0.0380	 Train Acc:59.53 %  | 	Valid Loss:0.0354 	Valid Acc: 64.10 %
#
# Validation loss decreased (0.035882 --> 0.035382).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0363	 Train Acc:63.72 %  | 	Valid Loss:0.0346 	Valid Acc: 65.43 %
#
# Validation loss decreased (0.035382 --> 0.034643).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0359	 Train Acc:63.12 %  | 	Valid Loss:0.0341 	Valid Acc: 65.43 %
#
# Validation loss decreased (0.034643 --> 0.034126).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0343	 Train Acc:65.51 %  | 	Valid Loss:0.0329 	Valid Acc: 65.69 %
#
# Validation loss decreased (0.034126 --> 0.032898).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0332	 Train Acc:67.04 %  | 	Valid Loss:0.0316 	Valid Acc: 71.54 %
#
# Validation loss decreased (0.032898 --> 0.031603).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0323	 Train Acc:67.38 %  | 	Valid Loss:0.0331 	Valid Acc: 71.54 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0316	 Train Acc:69.50 %  | 	Valid Loss:0.0310 	Valid Acc: 66.49 %
#
# Validation loss decreased (0.031603 --> 0.030969).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0303	 Train Acc:70.37 %  | 	Valid Loss:0.0350 	Valid Acc: 65.43 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0283	 Train Acc:74.95 %  | 	Valid Loss:0.0319 	Valid Acc: 73.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0274	 Train Acc:76.61 %  | 	Valid Loss:0.0315 	Valid Acc: 68.35 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0253	 Train Acc:77.87 %  | 	Valid Loss:0.0309 	Valid Acc: 70.74 %
#
# Validation loss decreased (0.030969 --> 0.030936).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0232	 Train Acc:82.39 %  | 	Valid Loss:0.0321 	Valid Acc: 69.68 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0212	 Train Acc:84.72 %  | 	Valid Loss:0.0323 	Valid Acc: 68.35 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:16]	 Train Loss:0.0178	 Train Acc:89.63 %  | 	Valid Loss:0.0361 	Valid Acc: 67.55 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:17]	 Train Loss:0.0186	 Train Acc:87.97 %  | 	Valid Loss:0.0297 	Valid Acc: 72.61 %
#
# Validation loss decreased (0.030936 --> 0.029729).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0153	 Train Acc:92.43 %  | 	Valid Loss:0.0327 	Valid Acc: 69.95 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:19]	 Train Loss:0.0118	 Train Acc:95.02 %  | 	Valid Loss:0.0450 	Valid Acc: 66.22 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:20]	 Train Loss:0.0109	 Train Acc:95.75 %  | 	Valid Loss:0.0425 	Valid Acc: 66.76 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:21]	 Train Loss:0.0105	 Train Acc:95.02 %  | 	Valid Loss:0.0320 	Valid Acc: 74.20 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:22]	 Train Loss:0.0114	 Train Acc:94.15 %  | 	Valid Loss:0.0452 	Valid Acc: 68.35 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %% [markdown]
# # Model 결과 확인

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 65.2926 |	 valid ACC: 71.0875
# [2 교차검증] train ACC : 72.1595 |	 valid ACC: 70.4787
# [3 교차검증] train ACC : 68.7043 |	 valid ACC: 77.3936
# [4 교차검증] train ACC : 78.3389 |	 valid ACC: 77.3936
# [5 교차검증] train ACC : 87.9734 |	 valid ACC: 72.6064
# 평균 검증 정확도 73.79197471640612 %

# %% [markdown]
# # Model Test
#
# - test set
# - confusion matrix

# %%
#confusion matrix 계산
#test set 계산.
def test_evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 결과를 모두 합쳐줘야한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))

predictions=[]
answers=[]

for data_ind in range(1,6):

    check_path = '../../checkpoint/checkpoint_spectro_resnet18_true_noros_'+str(data_ind)+'_i_300.pt'
    model.load_state_dict(torch.load(check_path))
    _,validation_loader = load_data(data_ind-1)

    prediction,answer,test_loss = test_evaluate(model, validation_loader)
    predictions+=[ dat.cpu().numpy() for dat in prediction]
    answers+=[ dat.cpu().numpy() for dat in answer]
    
    print(confusion_matrix(answers, predictions))

    
cf = confusion_matrix(answers, predictions)
acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
precision=cf[0,0]/(cf[0,0]+cf[1,0])
recall=cf[0,0]/(cf[0,0]+cf[0,1])
#fscore=2*precision*recall/(precision+recall)

fscore = f1_score(answers,predictions,average='macro')


print("Accuracy : {:.4f}% ".format(acc*100))
print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
print("f score : {:.4f} ".format(fscore))
# Out:
# [[213  26]
#  [ 83  55]]
# [[407  71]
#  [149 126]]
# [[600 117]
#  [188 224]]
# [[813 143]
#  [247 302]]
# [[994 200]
#  [293 394]]
# Accuracy : 73.7905%
# Precision (pathology 예측한 것중 맞는 것) : 0.7723
# recall (실제 pathology 중  예측이 맞는 것) : 0.8325
# f score : 0.7082

# %% [markdown]
# # 기타

# %%
#크기 알아보기
#일반 CNN

m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 500, 13])
# torch.Size([32, 1, 250, 6])
# torch.Size([32, 1, 125, 3])

# %%
#크기 알아보기
#주파수 영역 CNN

input = torch.randn(32, 1, 500, 13)
m=nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 32,# FeatureMap 수,커널 수
            kernel_size = (1,13),#1x13  no padding
        )
output=m(input)
print(output.size())
m=nn.Conv2d(
            in_channels = 32,# 채널이 1개
            out_channels = 64,# FeatureMap 수,커널 수
            kernel_size = (27,1),#9 x 1 no padding
        )
output=m(output)
print(output.size())
# Out:
# torch.Size([32, 32, 500, 1])
# torch.Size([32, 64, 474, 1])

# %%
input = torch.randn(500, 13)

out=torch.stack([input,input,input])
out.size()
# Out:
# torch.Size([3, 500, 13])
