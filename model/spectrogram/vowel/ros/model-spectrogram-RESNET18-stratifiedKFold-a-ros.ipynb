# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5
# - https://quokkas.tistory.com/37 : early stopping
# - https://continuous-development.tistory.com/166 : stratified kfold
# - https://deep-learning-study.tistory.com/476 fiter 시각화
# - https://wyatt37.tistory.com/10 : random over sampling

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys

p = os.path.abspath('../../..') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.0  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../../../../voice_data/pathology_new/a/export'):
    sig, sr = librosa.load('../../../../voice_data/pathology_new/a/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    pathology.append(log_spectrogram)
    

#Healthy data
for audio_path in os.listdir('../../../../voice_data/healthy_new/a/export'):
    sig, sr = librosa.load('../../../voice_data/healthy_new/a/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    stft = librosa.stft(sig,win_length=win_length ,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    healthy.append(log_spectrogram)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  1194
# healthy data 수 :  687
# 가장 긴 path sample : 131655
# 가장 긴 healthy sample : 50993

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 2.6331 초
# 1.01986 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
#headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
#pd.DataFrame(healthy[0].T,columns=headers)

print(healthy[0])
# Out:
# [[ 25.737942   20.944155   15.47011   ...   2.9658442  11.393017
#    10.894617 ]
#  [ 27.17081    17.944262   14.407186  ...   9.534363   12.579589
#    21.308865 ]
#  [ 30.96228    27.360094   21.776752  ...  28.504124   27.368908
#    30.187153 ]
#  ...
#  [-45.13852   -32.797817  -35.598606  ... -45.341442  -45.341442
#   -45.341442 ]
#  [-33.85245   -32.790295  -34.742134  ... -45.341442  -45.341442
#   -40.358055 ]
#  [-36.22928   -44.534653  -34.8247    ... -45.341442  -45.341442
#   -38.150257 ]]

# %%
print(healthy[0].shape) #1번 주파수 축, 2번 시간축.
print(healthy[1].shape)
# Out:
# (626, 163)
# (626, 163)

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기 - Stratified KFold
#
# - pathology : 1194 / healthy : 634 / 총 1828
# - k = 5

# %%
#1. train, test 나누기

import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split # train , test 분리에 사용.


pathology = glob('../../../../voice_data/pathology_new/a/export/*.wav')
healthy = glob('../../../../voice_data/healthy_new/a/export/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))

X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1194:
        Y.append("pathology")
    else:
        Y.append("healthy")


X, X_test, Y, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, stratify=Y, random_state=456)
#stratify를 넣어서, test에도 라벨별 잘 분류되게 한다.

print("---")
print("훈련 셋 : ",len(Y),Counter(Y))
print("테스트 셋 : ",len(Y_test),Counter(Y_test))
print("---")
# Out:
# Pathology :  1194
# Healthy:  687
# 총 데이터수 :  1881
# ---
# 훈련 셋 :  1504 Counter({'pathology': 955, 'healthy': 549})
# 테스트 셋 :  377 Counter({'pathology': 239, 'healthy': 138})
# ---

# %% [markdown]
# ## 2. random over sampling

# %%
#2. random over sampling

X = np.array(X).reshape(-1,1)#각 데이터를 다 행으로 넣음. (1194,1)
#Y = np.array(Y)
ros = RandomOverSampler(random_state = 123)
X_res,Y_res = ros.fit_resample(X,Y)

print('before dataset shape {}'.format(Counter(Y)) )
print('Resampled dataset shape {}'.format(Counter(Y_res)) )
# Out:
# before dataset shape Counter({'pathology': 955, 'healthy': 549})
# Resampled dataset shape Counter({'healthy': 955, 'pathology': 955})

# %%
X_res
# Out:
# array([['../../../../voice_data/healthy_new/a/export\\60-a_n.wav'],
#        ['../../../../voice_data/pathology_new/a/export\\2421-a_n.wav'],
#        ['../../../../voice_data/pathology_new/a/export\\1270-a_n.wav'],
#        ...,
#        ['../../../../voice_data/healthy_new/a/export\\1127-a_n.wav'],
#        ['../../../../voice_data/healthy_new/a/export\\1533-a_n.wav'],
#        ['../../../../voice_data/healthy_new/a/export\\1359-a_n.wav']],
#       dtype='<U58')

# %%
#원래대로 돌리기
X=X_res.reshape(1, -1)
print( '총 데이터수 : ',X[0].size )
print(  '복사된 수 : ',X[0].size - np.unique(X[0]).size )

X=X[0].tolist()
Y=Y_res
# Out:
# 총 데이터수 :  1910
# 복사된 수 :  406

# %% [markdown]
# ## 3. stratified k-fold

# %%
#1. train, test 나누기
#stratified kfold
import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter


skf_iris = StratifiedKFold(n_splits=5,shuffle=True,random_state=456)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_valid_list = []
Y_valid_list = []

for train_idx, test_idx in skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_valid = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_valid = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_valid_list.append(X_valid)
    
    Y_train_list.append(Y_train)
    Y_valid_list.append(Y_valid)
    
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_valid
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 764, 'pathology': 764}
# 검증 레이블 데이터 분포 :
#  {'healthy': 191, 'pathology': 191}

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.(여기서는 300frame)
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_valid_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. mfcc를 300프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        #stft 300 FRAME이 되도록 패딩.
        length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram = pad2d(log_spectrogram, length)
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 데이터 0~1 정규화
            log_spectrogram=torch.stack([log_spectrogram,log_spectrogram,log_spectrogram])# 3채널로 복사.
            log_spectrogram = log_spectrogram.squeeze(dim=1)
        else:
            #print("else")
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return log_spectrogram, self.classes.index(self.label[idx])

# %%
# test set 제작을 위한 class
class svd_test_set(Dataset):
    def __init__(self,data_path_list,classes,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list
        self.label = svd_test_set.get_label(self.path_list)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list):
        label_list=[]
        
        for idx,x in enumerate(data_path_list):
            label_list.append(Y_test[idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. 300프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        #stft 500 FRAME이 되도록 패딩.
        length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram = pad2d(log_spectrogram, length)
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 데이터 0~1 정규화
            log_spectrogram=torch.stack([log_spectrogram,log_spectrogram,log_spectrogram])# 3채널로 복사.
            log_spectrogram = log_spectrogram.squeeze(dim=1)
        else:
            #print("else")
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return log_spectrogram, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  18 #한 배치당 18개 음성데이터
EPOCHS = 40 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인


train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                               classes,
                                               transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_valid_list,
                                               classes,
                                               transform = transforms.ToTensor(),
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %%
# 테스트 데이터 로더.

test_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_test_set(
                                                   X_test,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,)

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])
librosa.display.specshow(X_train[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([18, 3, 626, 300]) type: torch.FloatTensor
# Y_train :  torch.Size([18]) type: torch.LongTensor
# tensor(1)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
#valiation set 확인
for (X_valid,Y_valid) in validation_loader:
    print("X_valid : ",X_valid.size(),'type:',X_valid.type())
    print("Y_valid : ",Y_valid.size(),'type:',Y_valid.type())
    break

print(Y_valid[0])
librosa.display.specshow(X_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")

#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_valid :  torch.Size([18, 3, 626, 300]) type: torch.FloatTensor
# Y_valid :  torch.Size([18]) type: torch.LongTensor
# tensor(1)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %% [markdown]
# # RESNET

# %%
# 모델 
# pretrained


def model_initialize():
    model = models.resnet34(pretrained=True).cuda()
    model.ftrs = model.fc.in_features # in_features : fully connected의 입력수.
    num_ftrs = model.fc.in_features

    model.fc = nn.Sequential(nn.Linear(num_ftrs, 256),
                             nn.BatchNorm1d(256),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(256,128),
                             nn.BatchNorm1d(128),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(128,64),
                             nn.BatchNorm1d(64),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(64,50),
                             nn.BatchNorm1d(50),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(50,2)
                            )

    model = model.cuda()
    return model
model=model_initialize()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=64, out_features=50, bias=True)
#     (13): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Linear(in_features=50, out_features=2, bias=True)
#   )
# )

# %%
# get the model summary
from torchsummary import summary
summary(model, input_size=(3, 128, 300), device=DEVICE.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 64, 64, 150]           9,408
#        BatchNorm2d-2          [-1, 64, 64, 150]             128
#               ReLU-3          [-1, 64, 64, 150]               0
#          MaxPool2d-4           [-1, 64, 32, 75]               0
#             Conv2d-5           [-1, 64, 32, 75]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 75]             128
#               ReLU-7           [-1, 64, 32, 75]               0
#             Conv2d-8           [-1, 64, 32, 75]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 75]             128
#              ReLU-10           [-1, 64, 32, 75]               0
#        BasicBlock-11           [-1, 64, 32, 75]               0
#            Conv2d-12           [-1, 64, 32, 75]          36,864
#       BatchNorm2d-13           [-1, 64, 32, 75]             128
#              ReLU-14           [-1, 64, 32, 75]               0
#            Conv2d-15           [-1, 64, 32, 75]          36,864
#       BatchNorm2d-16           [-1, 64, 32, 75]             128
#              ReLU-17           [-1, 64, 32, 75]               0
#        BasicBlock-18           [-1, 64, 32, 75]               0
#            Conv2d-19           [-1, 64, 32, 75]          36,864
#       BatchNorm2d-20           [-1, 64, 32, 75]             128
#              ReLU-21           [-1, 64, 32, 75]               0
#            Conv2d-22           [-1, 64, 32, 75]          36,864
#       BatchNorm2d-23           [-1, 64, 32, 75]             128
#              ReLU-24           [-1, 64, 32, 75]               0
#        BasicBlock-25           [-1, 64, 32, 75]               0
#            Conv2d-26          [-1, 128, 16, 38]          73,728
#       BatchNorm2d-27          [-1, 128, 16, 38]             256
#              ReLU-28          [-1, 128, 16, 38]               0
#            Conv2d-29          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-30          [-1, 128, 16, 38]             256
#            Conv2d-31          [-1, 128, 16, 38]           8,192
#       BatchNorm2d-32          [-1, 128, 16, 38]             256
#              ReLU-33          [-1, 128, 16, 38]               0
#        BasicBlock-34          [-1, 128, 16, 38]               0
#            Conv2d-35          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-36          [-1, 128, 16, 38]             256
#              ReLU-37          [-1, 128, 16, 38]               0
#            Conv2d-38          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-39          [-1, 128, 16, 38]             256
#              ReLU-40          [-1, 128, 16, 38]               0
#        BasicBlock-41          [-1, 128, 16, 38]               0
#            Conv2d-42          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-43          [-1, 128, 16, 38]             256
#              ReLU-44          [-1, 128, 16, 38]               0
#            Conv2d-45          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-46          [-1, 128, 16, 38]             256
#              ReLU-47          [-1, 128, 16, 38]               0
#        BasicBlock-48          [-1, 128, 16, 38]               0
#            Conv2d-49          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-50          [-1, 128, 16, 38]             256
#              ReLU-51          [-1, 128, 16, 38]               0
#            Conv2d-52          [-1, 128, 16, 38]         147,456
#       BatchNorm2d-53          [-1, 128, 16, 38]             256
#              ReLU-54          [-1, 128, 16, 38]               0
#        BasicBlock-55          [-1, 128, 16, 38]               0
#            Conv2d-56           [-1, 256, 8, 19]         294,912
#       BatchNorm2d-57           [-1, 256, 8, 19]             512
#              ReLU-58           [-1, 256, 8, 19]               0
#            Conv2d-59           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-60           [-1, 256, 8, 19]             512
#            Conv2d-61           [-1, 256, 8, 19]          32,768
#       BatchNorm2d-62           [-1, 256, 8, 19]             512
#              ReLU-63           [-1, 256, 8, 19]               0
#        BasicBlock-64           [-1, 256, 8, 19]               0
#            Conv2d-65           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-66           [-1, 256, 8, 19]             512
#              ReLU-67           [-1, 256, 8, 19]               0
#            Conv2d-68           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-69           [-1, 256, 8, 19]             512
#              ReLU-70           [-1, 256, 8, 19]               0
#        BasicBlock-71           [-1, 256, 8, 19]               0
#            Conv2d-72           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-73           [-1, 256, 8, 19]             512
#              ReLU-74           [-1, 256, 8, 19]               0
#            Conv2d-75           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-76           [-1, 256, 8, 19]             512
#              ReLU-77           [-1, 256, 8, 19]               0
#        BasicBlock-78           [-1, 256, 8, 19]               0
#            Conv2d-79           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-80           [-1, 256, 8, 19]             512
#              ReLU-81           [-1, 256, 8, 19]               0
#            Conv2d-82           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-83           [-1, 256, 8, 19]             512
#              ReLU-84           [-1, 256, 8, 19]               0
#        BasicBlock-85           [-1, 256, 8, 19]               0
#            Conv2d-86           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-87           [-1, 256, 8, 19]             512
#              ReLU-88           [-1, 256, 8, 19]               0
#            Conv2d-89           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-90           [-1, 256, 8, 19]             512
#              ReLU-91           [-1, 256, 8, 19]               0
#        BasicBlock-92           [-1, 256, 8, 19]               0
#            Conv2d-93           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-94           [-1, 256, 8, 19]             512
#              ReLU-95           [-1, 256, 8, 19]               0
#            Conv2d-96           [-1, 256, 8, 19]         589,824
#       BatchNorm2d-97           [-1, 256, 8, 19]             512
#              ReLU-98           [-1, 256, 8, 19]               0
#        BasicBlock-99           [-1, 256, 8, 19]               0
#           Conv2d-100           [-1, 512, 4, 10]       1,179,648
#      BatchNorm2d-101           [-1, 512, 4, 10]           1,024
#             ReLU-102           [-1, 512, 4, 10]               0
#           Conv2d-103           [-1, 512, 4, 10]       2,359,296
#      BatchNorm2d-104           [-1, 512, 4, 10]           1,024
#           Conv2d-105           [-1, 512, 4, 10]         131,072
#      BatchNorm2d-106           [-1, 512, 4, 10]           1,024
#             ReLU-107           [-1, 512, 4, 10]               0
#       BasicBlock-108           [-1, 512, 4, 10]               0
#           Conv2d-109           [-1, 512, 4, 10]       2,359,296
#      BatchNorm2d-110           [-1, 512, 4, 10]           1,024
#             ReLU-111           [-1, 512, 4, 10]               0
#           Conv2d-112           [-1, 512, 4, 10]       2,359,296
#      BatchNorm2d-113           [-1, 512, 4, 10]           1,024
#             ReLU-114           [-1, 512, 4, 10]               0
#       BasicBlock-115           [-1, 512, 4, 10]               0
#           Conv2d-116           [-1, 512, 4, 10]       2,359,296
#      BatchNorm2d-117           [-1, 512, 4, 10]           1,024
#             ReLU-118           [-1, 512, 4, 10]               0
#           Conv2d-119           [-1, 512, 4, 10]       2,359,296
#      BatchNorm2d-120           [-1, 512, 4, 10]           1,024
#             ReLU-121           [-1, 512, 4, 10]               0
#       BasicBlock-122           [-1, 512, 4, 10]               0
# AdaptiveAvgPool2d-123            [-1, 512, 1, 1]               0
#           Linear-124                  [-1, 256]         131,328
#      BatchNorm1d-125                  [-1, 256]             512
#             ReLU-126                  [-1, 256]               0
#          Dropout-127                  [-1, 256]               0
#           Linear-128                  [-1, 128]          32,896
#      BatchNorm1d-129                  [-1, 128]             256
#             ReLU-130                  [-1, 128]               0
#          Dropout-131                  [-1, 128]               0
#           Linear-132                   [-1, 64]           8,256
#      BatchNorm1d-133                   [-1, 64]             128
#             ReLU-134                   [-1, 64]               0
#          Dropout-135                   [-1, 64]               0
#           Linear-136                   [-1, 50]           3,250
#      BatchNorm1d-137                   [-1, 50]             100
#             ReLU-138                   [-1, 50]               0
#          Dropout-139                   [-1, 50]               0
#           Linear-140                    [-1, 2]             102
# ================================================================
# Total params: 21,461,500
# Trainable params: 21,461,500
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.44
# Forward/backward pass size (MB): 74.33
# Params size (MB): 81.87
# Estimated Total Size (MB): 156.64
# ----------------------------------------------------------------

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_valid_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# resnet34 pretrained true
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):
    
    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_a_300.pt'
    print(check_path)
    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break

        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_1_a_300.pt
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0413	 Train Acc:51.11 %  | 	Valid Loss:0.0394 	Valid Acc: 53.40 %
#
# Validation loss decreased (inf --> 0.039407).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0405	 Train Acc:50.46 %  | 	Valid Loss:0.0385 	Valid Acc: 68.32 %
#
# Validation loss decreased (0.039407 --> 0.038464).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0387	 Train Acc:54.32 %  | 	Valid Loss:0.0372 	Valid Acc: 65.45 %
#
# Validation loss decreased (0.038464 --> 0.037207).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0389	 Train Acc:55.69 %  | 	Valid Loss:0.0383 	Valid Acc: 61.78 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0384	 Train Acc:55.89 %  | 	Valid Loss:0.0370 	Valid Acc: 65.97 %
#
# Validation loss decreased (0.037207 --> 0.037012).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0368	 Train Acc:58.51 %  | 	Valid Loss:0.0353 	Valid Acc: 70.16 %
#
# Validation loss decreased (0.037012 --> 0.035319).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0369	 Train Acc:60.86 %  | 	Valid Loss:0.0337 	Valid Acc: 76.70 %
#
# Validation loss decreased (0.035319 --> 0.033663).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0352	 Train Acc:65.12 %  | 	Valid Loss:0.0339 	Valid Acc: 69.37 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0342	 Train Acc:66.36 %  | 	Valid Loss:0.0315 	Valid Acc: 73.30 %
#
# Validation loss decreased (0.033663 --> 0.031451).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0320	 Train Acc:69.24 %  | 	Valid Loss:0.0316 	Valid Acc: 76.44 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0296	 Train Acc:74.35 %  | 	Valid Loss:0.0298 	Valid Acc: 77.23 %
#
# Validation loss decreased (0.031451 --> 0.029840).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0287	 Train Acc:75.92 %  | 	Valid Loss:0.0314 	Valid Acc: 71.20 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0267	 Train Acc:78.99 %  | 	Valid Loss:0.0288 	Valid Acc: 75.13 %
#
# Validation loss decreased (0.029840 --> 0.028799).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0230	 Train Acc:84.95 %  | 	Valid Loss:0.0306 	Valid Acc: 73.04 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0202	 Train Acc:88.81 %  | 	Valid Loss:0.0259 	Valid Acc: 82.20 %
#
# Validation loss decreased (0.028799 --> 0.025868).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0177	 Train Acc:90.97 %  | 	Valid Loss:0.0277 	Valid Acc: 80.89 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0161	 Train Acc:92.28 %  | 	Valid Loss:0.0340 	Valid Acc: 71.20 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0148	 Train Acc:93.00 %  | 	Valid Loss:0.0249 	Valid Acc: 81.68 %
#
# Validation loss decreased (0.025868 --> 0.024854).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0146	 Train Acc:92.41 %  | 	Valid Loss:0.0253 	Valid Acc: 80.63 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0115	 Train Acc:95.42 %  | 	Valid Loss:0.0271 	Valid Acc: 77.49 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0122	 Train Acc:94.96 %  | 	Valid Loss:0.0308 	Valid Acc: 74.35 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0088	 Train Acc:97.58 %  | 	Valid Loss:0.0237 	Valid Acc: 81.41 %
#
# Validation loss decreased (0.024854 --> 0.023744).  Saving model ...
#
# [EPOCH:23]	 Train Loss:0.0086	 Train Acc:96.92 %  | 	Valid Loss:0.0289 	Valid Acc: 80.37 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:24]	 Train Loss:0.0080	 Train Acc:97.05 %  | 	Valid Loss:0.0248 	Valid Acc: 83.51 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:25]	 Train Loss:0.0095	 Train Acc:95.35 %  | 	Valid Loss:0.0328 	Valid Acc: 79.06 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:26]	 Train Loss:0.0074	 Train Acc:97.64 %  | 	Valid Loss:0.0251 	Valid Acc: 82.46 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:27]	 Train Loss:0.0066	 Train Acc:97.51 %  | 	Valid Loss:0.0264 	Valid Acc: 79.84 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_2_a_300.pt
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0420	 Train Acc:51.37 %  | 	Valid Loss:0.0377 	Valid Acc: 67.54 %
#
# Validation loss decreased (inf --> 0.037726).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0406	 Train Acc:55.69 %  | 	Valid Loss:0.0362 	Valid Acc: 68.06 %
#
# Validation loss decreased (0.037726 --> 0.036173).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0391	 Train Acc:56.48 %  | 	Valid Loss:0.0341 	Valid Acc: 71.73 %
#
# Validation loss decreased (0.036173 --> 0.034058).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0372	 Train Acc:59.29 %  | 	Valid Loss:0.0328 	Valid Acc: 72.77 %
#
# Validation loss decreased (0.034058 --> 0.032826).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0359	 Train Acc:62.96 %  | 	Valid Loss:0.0322 	Valid Acc: 75.39 %
#
# Validation loss decreased (0.032826 --> 0.032170).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0338	 Train Acc:67.74 %  | 	Valid Loss:0.0315 	Valid Acc: 75.65 %
#
# Validation loss decreased (0.032170 --> 0.031469).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0323	 Train Acc:70.16 %  | 	Valid Loss:0.0341 	Valid Acc: 68.06 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0305	 Train Acc:72.45 %  | 	Valid Loss:0.0307 	Valid Acc: 75.92 %
#
# Validation loss decreased (0.031469 --> 0.030721).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0280	 Train Acc:75.13 %  | 	Valid Loss:0.0275 	Valid Acc: 78.27 %
#
# Validation loss decreased (0.030721 --> 0.027537).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0267	 Train Acc:77.36 %  | 	Valid Loss:0.0279 	Valid Acc: 76.70 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:11]	 Train Loss:0.0229	 Train Acc:82.53 %  | 	Valid Loss:0.0307 	Valid Acc: 74.35 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:12]	 Train Loss:0.0208	 Train Acc:86.85 %  | 	Valid Loss:0.0301 	Valid Acc: 74.61 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:13]	 Train Loss:0.0193	 Train Acc:87.96 %  | 	Valid Loss:0.0247 	Valid Acc: 78.80 %
#
# Validation loss decreased (0.027537 --> 0.024668).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0164	 Train Acc:91.88 %  | 	Valid Loss:0.0295 	Valid Acc: 75.39 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:15]	 Train Loss:0.0161	 Train Acc:90.18 %  | 	Valid Loss:0.0244 	Valid Acc: 80.37 %
#
# Validation loss decreased (0.024668 --> 0.024396).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0137	 Train Acc:93.46 %  | 	Valid Loss:0.0223 	Valid Acc: 81.41 %
#
# Validation loss decreased (0.024396 --> 0.022288).  Saving model ...
#
# [EPOCH:17]	 Train Loss:0.0101	 Train Acc:96.73 %  | 	Valid Loss:0.0231 	Valid Acc: 83.25 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:18]	 Train Loss:0.0090	 Train Acc:97.32 %  | 	Valid Loss:0.0259 	Valid Acc: 80.10 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:19]	 Train Loss:0.0112	 Train Acc:94.83 %  | 	Valid Loss:0.0296 	Valid Acc: 80.63 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:20]	 Train Loss:0.0120	 Train Acc:93.65 %  | 	Valid Loss:0.0279 	Valid Acc: 79.58 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:21]	 Train Loss:0.0096	 Train Acc:95.94 %  | 	Valid Loss:0.0274 	Valid Acc: 81.94 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_3_a_300.pt
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0403	 Train Acc:52.68 %  | 	Valid Loss:0.0388 	Valid Acc: 57.33 %
#
# Validation loss decreased (inf --> 0.038755).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0385	 Train Acc:55.96 %  | 	Valid Loss:0.0384 	Valid Acc: 58.90 %
#
# Validation loss decreased (0.038755 --> 0.038361).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0382	 Train Acc:56.74 %  | 	Valid Loss:0.0365 	Valid Acc: 63.09 %
#
# Validation loss decreased (0.038361 --> 0.036529).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0362	 Train Acc:60.47 %  | 	Valid Loss:0.0354 	Valid Acc: 67.28 %
#
# Validation loss decreased (0.036529 --> 0.035419).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0354	 Train Acc:62.43 %  | 	Valid Loss:0.0355 	Valid Acc: 66.49 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0338	 Train Acc:66.56 %  | 	Valid Loss:0.0367 	Valid Acc: 59.16 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:7]	 Train Loss:0.0327	 Train Acc:69.44 %  | 	Valid Loss:0.0351 	Valid Acc: 64.92 %
#
# Validation loss decreased (0.035419 --> 0.035097).  Saving model ...
# [EPOCH:8]	 Train Loss:0.0313	 Train Acc:71.66 %  | 	Valid Loss:0.0303 	Valid Acc: 75.13 %
#
# Validation loss decreased (0.035097 --> 0.030285).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0304	 Train Acc:73.10 %  | 	Valid Loss:0.0283 	Valid Acc: 76.44 %
#
# Validation loss decreased (0.030285 --> 0.028343).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0283	 Train Acc:77.55 %  | 	Valid Loss:0.0283 	Valid Acc: 75.65 %
#
# Validation loss decreased (0.028343 --> 0.028333).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0269	 Train Acc:78.08 %  | 	Valid Loss:0.0263 	Valid Acc: 81.15 %
#
# Validation loss decreased (0.028333 --> 0.026298).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0251	 Train Acc:82.66 %  | 	Valid Loss:0.0383 	Valid Acc: 58.90 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0226	 Train Acc:84.88 %  | 	Valid Loss:0.0294 	Valid Acc: 75.65 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0212	 Train Acc:86.45 %  | 	Valid Loss:0.0263 	Valid Acc: 79.32 %
#
# Validation loss decreased (0.026298 --> 0.026292).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0186	 Train Acc:90.12 %  | 	Valid Loss:0.0253 	Valid Acc: 80.37 %
#
# Validation loss decreased (0.026292 --> 0.025297).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0173	 Train Acc:90.45 %  | 	Valid Loss:0.0255 	Valid Acc: 79.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0166	 Train Acc:90.58 %  | 	Valid Loss:0.0318 	Valid Acc: 71.99 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0156	 Train Acc:90.38 %  | 	Valid Loss:0.0223 	Valid Acc: 84.03 %
#
# Validation loss decreased (0.025297 --> 0.022280).  Saving model ...
#
# [EPOCH:19]	 Train Loss:0.0114	 Train Acc:95.55 %  | 	Valid Loss:0.0227 	Valid Acc: 82.98 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:20]	 Train Loss:0.0121	 Train Acc:94.44 %  | 	Valid Loss:0.0232 	Valid Acc: 82.20 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:21]	 Train Loss:0.0111	 Train Acc:95.16 %  | 	Valid Loss:0.0227 	Valid Acc: 81.68 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:22]	 Train Loss:0.0095	 Train Acc:95.94 %  | 	Valid Loss:0.0297 	Valid Acc: 77.23 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:23]	 Train Loss:0.0083	 Train Acc:96.92 %  | 	Valid Loss:0.0210 	Valid Acc: 84.82 %
#
# Validation loss decreased (0.022280 --> 0.020970).  Saving model ...
#
# [EPOCH:24]	 Train Loss:0.0110	 Train Acc:93.91 %  | 	Valid Loss:0.0204 	Valid Acc: 85.08 %
#
# Validation loss decreased (0.020970 --> 0.020359).  Saving model ...
#
# [EPOCH:25]	 Train Loss:0.0081	 Train Acc:96.34 %  | 	Valid Loss:0.0336 	Valid Acc: 78.01 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:26]	 Train Loss:0.0066	 Train Acc:97.12 %  | 	Valid Loss:0.0278 	Valid Acc: 79.58 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:27]	 Train Loss:0.0062	 Train Acc:97.58 %  | 	Valid Loss:0.0232 	Valid Acc: 85.34 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:28]	 Train Loss:0.0053	 Train Acc:98.36 %  | 	Valid Loss:0.0267 	Valid Acc: 81.68 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:29]	 Train Loss:0.0056	 Train Acc:97.77 %  | 	Valid Loss:0.0239 	Valid Acc: 84.03 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_4_a_300.pt
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0426	 Train Acc:48.82 %  | 	Valid Loss:0.0389 	Valid Acc: 60.47 %
#
# Validation loss decreased (inf --> 0.038854).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0414	 Train Acc:51.57 %  | 	Valid Loss:0.0384 	Valid Acc: 60.73 %
#
# Validation loss decreased (0.038854 --> 0.038409).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0400	 Train Acc:54.65 %  | 	Valid Loss:0.0373 	Valid Acc: 65.71 %
#
# Validation loss decreased (0.038409 --> 0.037291).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0383	 Train Acc:55.96 %  | 	Valid Loss:0.0354 	Valid Acc: 66.49 %
#
# Validation loss decreased (0.037291 --> 0.035439).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0367	 Train Acc:60.41 %  | 	Valid Loss:0.0344 	Valid Acc: 70.68 %
#
# Validation loss decreased (0.035439 --> 0.034355).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0363	 Train Acc:61.91 %  | 	Valid Loss:0.0342 	Valid Acc: 69.37 %
#
# Validation loss decreased (0.034355 --> 0.034184).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0343	 Train Acc:64.20 %  | 	Valid Loss:0.0321 	Valid Acc: 73.04 %
#
# Validation loss decreased (0.034184 --> 0.032077).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0327	 Train Acc:69.76 %  | 	Valid Loss:0.0305 	Valid Acc: 73.04 %
#
# Validation loss decreased (0.032077 --> 0.030513).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0325	 Train Acc:69.18 %  | 	Valid Loss:0.0342 	Valid Acc: 67.02 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0297	 Train Acc:73.56 %  | 	Valid Loss:0.0288 	Valid Acc: 78.01 %
#
# Validation loss decreased (0.030513 --> 0.028785).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0273	 Train Acc:78.08 %  | 	Valid Loss:0.0315 	Valid Acc: 72.51 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0258	 Train Acc:80.24 %  | 	Valid Loss:0.0289 	Valid Acc: 76.96 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:13]	 Train Loss:0.0236	 Train Acc:83.64 %  | 	Valid Loss:0.0542 	Valid Acc: 56.81 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:14]	 Train Loss:0.0208	 Train Acc:86.78 %  | 	Valid Loss:0.0295 	Valid Acc: 75.65 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:15]	 Train Loss:0.0181	 Train Acc:89.66 %  | 	Valid Loss:0.0337 	Valid Acc: 69.11 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# ../../../checkpoint/checkpoint_spectro_resnet18_true_ros_5_a_300.pt
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0484	 Train Acc:50.72 %  | 	Valid Loss:0.0408 	Valid Acc: 50.00 %
#
# Validation loss decreased (inf --> 0.040841).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0414	 Train Acc:53.27 %  | 	Valid Loss:0.0377 	Valid Acc: 50.00 %
#
# Validation loss decreased (0.040841 --> 0.037710).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0369	 Train Acc:54.25 %  | 	Valid Loss:0.0360 	Valid Acc: 51.57 %
#
# Validation loss decreased (0.037710 --> 0.036000).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0357	 Train Acc:56.15 %  | 	Valid Loss:0.0373 	Valid Acc: 62.57 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0337	 Train Acc:62.43 %  | 	Valid Loss:0.0350 	Valid Acc: 68.85 %
#
# Validation loss decreased (0.036000 --> 0.034959).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0331	 Train Acc:66.56 %  | 	Valid Loss:0.0348 	Valid Acc: 67.54 %
#
# Validation loss decreased (0.034959 --> 0.034814).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0304	 Train Acc:71.14 %  | 	Valid Loss:0.0345 	Valid Acc: 67.28 %
#
# Validation loss decreased (0.034814 --> 0.034522).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0289	 Train Acc:74.28 %  | 	Valid Loss:0.0337 	Valid Acc: 67.80 %
#
# Validation loss decreased (0.034522 --> 0.033713).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0275	 Train Acc:78.01 %  | 	Valid Loss:0.0348 	Valid Acc: 67.54 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0264	 Train Acc:80.50 %  | 	Valid Loss:0.0328 	Valid Acc: 69.63 %
#
# Validation loss decreased (0.033713 --> 0.032802).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0261	 Train Acc:79.91 %  | 	Valid Loss:0.0318 	Valid Acc: 73.04 %
#
# Validation loss decreased (0.032802 --> 0.031813).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0250	 Train Acc:81.61 %  | 	Valid Loss:0.0318 	Valid Acc: 71.47 %
#
# Validation loss decreased (0.031813 --> 0.031768).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0217	 Train Acc:85.86 %  | 	Valid Loss:0.0354 	Valid Acc: 65.71 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0212	 Train Acc:85.47 %  | 	Valid Loss:0.0294 	Valid Acc: 75.39 %
#
# Validation loss decreased (0.031768 --> 0.029433).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0187	 Train Acc:88.42 %  | 	Valid Loss:0.0254 	Valid Acc: 84.55 %
#
# Validation loss decreased (0.029433 --> 0.025446).  Saving model ...
#
# [EPOCH:16]	 Train Loss:0.0172	 Train Acc:90.05 %  | 	Valid Loss:0.0295 	Valid Acc: 73.56 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:17]	 Train Loss:0.0162	 Train Acc:90.51 %  | 	Valid Loss:0.0339 	Valid Acc: 68.85 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:18]	 Train Loss:0.0170	 Train Acc:89.33 %  | 	Valid Loss:0.0274 	Valid Acc: 77.49 %
#
# EarlyStopping counter: 3 out of 5
# [EPOCH:19]	 Train Loss:0.0136	 Train Acc:92.87 %  | 	Valid Loss:0.0245 	Valid Acc: 79.58 %
#
# Validation loss decreased (0.025446 --> 0.024475).  Saving model ...
#
# [EPOCH:20]	 Train Loss:0.0119	 Train Acc:94.31 %  | 	Valid Loss:0.0227 	Valid Acc: 83.51 %
#
# Validation loss decreased (0.024475 --> 0.022653).  Saving model ...
#
# [EPOCH:21]	 Train Loss:0.0107	 Train Acc:95.29 %  | 	Valid Loss:0.0241 	Valid Acc: 81.68 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:22]	 Train Loss:0.0093	 Train Acc:96.47 %  | 	Valid Loss:0.0224 	Valid Acc: 84.29 %
#
# Validation loss decreased (0.022653 --> 0.022395).  Saving model ...
#
# [EPOCH:23]	 Train Loss:0.0103	 Train Acc:95.03 %  | 	Valid Loss:0.0223 	Valid Acc: 82.72 %
#
# Validation loss decreased (0.022395 --> 0.022267).  Saving model ...
#
# [EPOCH:24]	 Train Loss:0.0088	 Train Acc:95.68 %  | 	Valid Loss:0.0238 	Valid Acc: 81.94 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:25]	 Train Loss:0.0093	 Train Acc:95.35 %  | 	Valid Loss:0.0276 	Valid Acc: 79.32 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:26]	 Train Loss:0.0086	 Train Acc:95.88 %  | 	Valid Loss:0.0248 	Valid Acc: 83.51 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:27]	 Train Loss:0.0083	 Train Acc:95.62 %  | 	Valid Loss:0.0274 	Valid Acc: 79.06 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:28]	 Train Loss:0.0061	 Train Acc:97.25 %  | 	Valid Loss:0.0233 	Valid Acc: 84.55 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %% [markdown]
# # Model 결과 확인

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 97.5785 |	 valid ACC: 81.4136
# [2 교차검증] train ACC : 93.4555 |	 valid ACC: 81.4136
# [3 교차검증] train ACC : 93.9136 |	 valid ACC: 85.0785
# [4 교차검증] train ACC : 73.5602 |	 valid ACC: 78.0105
# [5 교차검증] train ACC : 95.0262 |	 valid ACC: 82.7225
# 평균 검증 정확도 81.72774869109948 %

# %% [markdown]
# # Model Test
#
# - test set
# - confusion matrix

# %%
#confusion matrix 계산
#test set 계산.
def test_evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 test set을 평가한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))
cf_list = []
average_accuracy = 0
average_fscore = 0

for data_ind in range(1,6):

    check_path = '../../../checkpoint/checkpoint_spectro_resnet18_true_ros_'+str(data_ind)+'_a_300.pt'
    model.load_state_dict(torch.load(check_path))

    predictions,answers,test_loss = test_evaluate(model, test_loader)
    predictions=[ dat.cpu().numpy() for dat in predictions]
    answers=[ dat.cpu().numpy() for dat in answers]

    
    cf = confusion_matrix(answers, predictions)
    cf_list.append(cf)
    
    acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
    average_accuracy+=acc
    precision=cf[0,0]/(cf[0,0]+cf[1,0])
    recall=cf[0,0]/(cf[0,0]+cf[0,1])
    #fscore=2*precision*recall/(precision+recall)
    
    #fscroe macro추가
    fscore = f1_score(answers,predictions,average='macro')
    average_fscore+=fscore
    
    print('{}번 모델'.format(data_ind))
    print("Accuracy : {:.4f}% ".format(acc*100))
    print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
    print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
    print("f score : {:.4f} ".format(fscore))
    print(cf)
    print("-----")

print("평균 acc : {:.4f}".format(average_accuracy/5))
print("평균 f1score : {:.4f}".format(average_fscore/5))
# Out:
# 1번 모델
# Accuracy : 68.1698%
# Precision (pathology 예측한 것중 맞는 것) : 0.7767
# recall (실제 pathology 중  예측이 맞는 것) : 0.6987
# f score : 0.6678
# [[167  72]
#  [ 48  90]]
# -----
# 2번 모델
# Accuracy : 68.1698%
# Precision (pathology 예측한 것중 맞는 것) : 0.7554
# recall (실제 pathology 중  예측이 맞는 것) : 0.7364
# f score : 0.6601
# [[176  63]
#  [ 57  81]]
# -----
# 3번 모델
# Accuracy : 69.7613%
# Precision (pathology 예측한 것중 맞는 것) : 0.7413
# recall (실제 pathology 중  예측이 맞는 것) : 0.8033
# f score : 0.6629
# [[192  47]
#  [ 67  71]]
# -----
# 4번 모델
# Accuracy : 67.1088%
# Precision (pathology 예측한 것중 맞는 것) : 0.8616
# recall (실제 pathology 중  예측이 맞는 것) : 0.5732
# f score : 0.6701
# [[137 102]
#  [ 22 116]]
# -----
# 5번 모델
# Accuracy : 68.7003%
# Precision (pathology 예측한 것중 맞는 것) : 0.7923
# recall (실제 pathology 중  예측이 맞는 것) : 0.6862
# f score : 0.6762
# [[164  75]
#  [ 43  95]]
# -----
# 평균 acc : 0.6838
# 평균 f1score : 0.6674

# %% [markdown]
# # 기타

# %%
#크기 알아보기
#일반 CNN

m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 500, 13])
# torch.Size([32, 1, 250, 6])
# torch.Size([32, 1, 125, 3])

# %%
#크기 알아보기
#주파수 영역 CNN

input = torch.randn(32, 1, 500, 13)
m=nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 32,# FeatureMap 수,커널 수
            kernel_size = (1,13),#1x13  no padding
        )
output=m(input)
print(output.size())
m=nn.Conv2d(
            in_channels = 32,# 채널이 1개
            out_channels = 64,# FeatureMap 수,커널 수
            kernel_size = (27,1),#9 x 1 no padding
        )
output=m(output)
print(output.size())
# Out:
# torch.Size([32, 32, 500, 1])
# torch.Size([32, 64, 474, 1])

# %%
input = torch.randn(500, 13)

out=torch.stack([input,input,input])
out.size()
# Out:
# torch.Size([3, 500, 13])
