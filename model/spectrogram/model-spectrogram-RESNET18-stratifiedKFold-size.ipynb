# %% [markdown]
# - http://keunwoochoi.blogspot.com/2016/03/2.html
# - http://www.rex-ai.info/docs/AI_Example_CNN_speech_recognize
# - https://www.youtube.com/watch?v=oltGIc4uo5c
# - https://youdaeng-com.tistory.com/5
# - https://quokkas.tistory.com/37 : early stopping
# - https://continuous-development.tistory.com/166 : stratified kfold
# - https://deep-learning-study.tistory.com/476 fiter 시각화
# - https://wyatt37.tistory.com/10 : random over sampling

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn # 인공 신경망 모델들 모아놓은 모듈
import torch.nn.functional as F #그중 자주 쓰이는것들을 F로
from torchvision import transforms, datasets
import cv2
from torchvision import transforms, datasets
import pandas as pd
import os
from glob import glob
import torchvision.models as models
import sys

p = os.path.abspath('..') # 상위 폴더를 사용하기 위해서.
sys.path.insert(1, p)
from pytorchtools.pytorchtools import EarlyStopping # 상위 폴더에 추가된 모듈.


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
#DEVICE = torch.device('cpu')
print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.10.0  Device :  cuda

# %% [markdown]
# # SVD 문장 데이터에서 Feature 추출
# - mfcc

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

# %%
import numpy as np
import librosa, librosa.display 
import matplotlib.pyplot as plt
#window sizde : FFT를 할때 참조할 그래프 길이 ( 프레임 하나당 sample 수 )
#자연어 처리에서는 25ms 사용. https://ahnjg.tistory.com/93
#초당 50000hz 중 1250개씩 윈도우 사이즈로 사용.
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.

pathology_sig=[]
healthy_sig=[]

pathology=[]
healthy=[]


#PATHOLOGY DATA
for audio_path in os.listdir('../../voice_data/pathology_new/phrase/export'):
    sig, sr = librosa.load('../../voice_data/pathology_new/phrase/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    pathology_sig.append(sig)
    stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    pathology.append(log_spectrogram)
    

#Healthy data
for audio_path in os.listdir('../../voice_data/healthy_new/phrase/export'):
    sig, sr = librosa.load('../../voice_data/healthy_new/phrase/export/'+audio_path, sr=50000)# 논문에서 f_s = 50 000HZ
    healthy_sig.append(sig)
    stft = librosa.stft(sig,win_length=win_length ,n_fft=n_fft, hop_length=hop_length)
    magnitude = np.abs(stft)
    log_spectrogram = librosa.amplitude_to_db(magnitude)
    healthy.append(log_spectrogram)
    
print("pathology data 수 : ",len(pathology))
print("healthy data 수 : ",len(healthy))


path_max=max([ len(samples) for samples in pathology_sig])
healthy_max=max([ len(samples) for samples in healthy_sig])
print("가장 긴 path sample :" ,path_max)
print("가장 긴 healthy sample :" ,healthy_max)
# Out:
# pathology data 수 :  1194
# healthy data 수 :  634
# 가장 긴 path sample : 318596
# 가장 긴 healthy sample : 207017

# %%
print(path_max/sr,"초")
print(healthy_max/sr,"초")
# Out:
# 6.37192 초
# 4.14034 초

# %% [markdown]
# # 결과 확인
# - 1 row당 1 frame으로

# %%
len(healthy[0][2]) #1번 : 파일. 2번:mfcc
#headers = "mfcc1 mfcc2 mfcc3 mfcc4 mfcc5 mfcc6 mfcc7 mfcc8 mfcc9 mfcc10 mfcc11 mfcc12 mfcc13".split()
#pd.DataFrame(healthy[0].T,columns=headers)

print(healthy[0])
# Out:
# [[ -2.3987155  -6.395669   -9.314145  ...  -3.2875543 -10.8100605
#    -7.2497787]
#  [ -7.5357933  -6.9441347  -5.761348  ...  -5.3182898  -6.082364
#    -4.7767587]
#  [-29.555494  -14.497558  -29.27149   ... -16.410295  -22.691776
#    -5.8583922]
#  ...
#  [-43.8044    -43.8044    -43.8044    ... -43.8044    -43.8044
#   -43.8044   ]
#  [-43.8044    -43.8044    -43.8044    ... -43.8044    -43.8044
#   -43.8044   ]
#  [-43.8044    -43.8044    -43.8044    ... -43.8044    -43.8044
#   -43.8044   ]]

# %%
print(healthy[0].shape) #1번 주파수 축, 2번 시간축.
print(healthy[1].shape)
# Out:
# (626, 326)
# (626, 338)

# %%
del pathology
del healthy
del pathology_sig
del healthy_sig

# %% [markdown]
# # 데이터 나누기 - Stratified KFold
#
# - pathology : 1194 / healthy : 634 / 총 1828
# - k = 5

# %%
#1. train, test 나누기

import os
import random #데이터 shuffle 사용
from glob import glob
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

pathology = glob('../../voice_data/pathology_new/phrase/export/*.wav')
healthy = glob('../../voice_data/healthy_new/phrase/export/*.wav')
print("Pathology : ",len(pathology))
print("Healthy: ",len(healthy))

X = pathology+healthy # path 데이터 합
print("총 데이터수 : ",len(X))
Y = [] # 라벨
for idx,x in enumerate(X):
    if idx<1194:
        Y.append("pathology")
    else:
        Y.append("healthy")

skf_iris = StratifiedKFold(n_splits=5)
cnt_iter = 0

X_train_list = [] #데이터 셋 보관
Y_train_list = []

X_test_list = []
Y_test_list = []

for train_idx, test_idx in  skf_iris.split(X,Y):
    
    #split으로 반환된 인덱스를 이용하여, 학습 검증용 테스트 데이터 추출
    cnt_iter += 1
    X_train, X_test = [X[idx] for idx in train_idx.tolist() ], [X[idx] for idx in test_idx.tolist() ]
    Y_train, Y_test = [Y[idx] for idx in train_idx.tolist() ], [Y[idx] for idx in test_idx.tolist() ]
    
    X_train_list.append(X_train)
    X_test_list.append(X_test)
    
    Y_test_list.append(Y_test)
    Y_train_list.append(Y_train)
    
    #학습 및 예측
    
    label_train = Y_train
    label_test = Y_test
    unique_train, train_counts = np.unique(label_train, return_counts = True)
    unique_test, test_counts = np.unique(label_test, return_counts = True)
    
    uniq_cnt_train = dict(zip(unique_train, train_counts))
    uniq_cnt_test = dict(zip(unique_test, test_counts))
    
    
    
    print('교차 검증 : {}'.format(cnt_iter))
    print('학습 레이블 데이터 분포 : \n', uniq_cnt_train)
    print('검증 레이블 데이터 분포 : \n', uniq_cnt_test,'\n')
# Out:
# Pathology :  1194
# Healthy:  634
# 총 데이터수 :  1828
# 교차 검증 : 1
# 학습 레이블 데이터 분포 :
#  {'healthy': 507, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 127, 'pathology': 239}
#
# 교차 검증 : 2
# 학습 레이블 데이터 분포 :
#  {'healthy': 507, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 127, 'pathology': 239}
#
# 교차 검증 : 3
# 학습 레이블 데이터 분포 :
#  {'healthy': 507, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 127, 'pathology': 239}
#
# 교차 검증 : 4
# 학습 레이블 데이터 분포 :
#  {'healthy': 508, 'pathology': 955}
# 검증 레이블 데이터 분포 :
#  {'healthy': 126, 'pathology': 239}
#
# 교차 검증 : 5
# 학습 레이블 데이터 분포 :
#  {'healthy': 507, 'pathology': 956}
# 검증 레이블 데이터 분포 :
#  {'healthy': 127, 'pathology': 238}

# %% [markdown]
# # 데이터 정의
# - 추가적으로 데이터의 크기를 맞춰주기 위해 3초로 padding 및 truncate 실시 https://sequencedata.tistory.com/25 FixAudioLength
# - 논문에서는 400frame으로 설정.(여기서는 500frame)
# - 전처리 방법 결정.

# %%
from torch.utils.data import Dataset, DataLoader

classes = ["pathology","healthy"]
sr=50000
win_length =  np.int64(50000/40) # 1250
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기(sample)를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다.
#hop_length가 mfcc의 frame수를 결정한다.



class svd_dataset(Dataset):
    def __init__(self,data_path_list,classes,data_num,training,transform=None):
        #클래스에서 사용할 인자를 받아 인스턴스 변수로 저장하는 일을 한다.
        #예를들면, 이미지의 경로 리스트를 저장하는 일을 하게 된다.
        
        #data_num : k 개 데이터 셋 중 어떤것을 쓸지
        #test인지 아닌지.
        
        self.path_list = data_path_list[data_num]
        self.data_num = data_num
        self.training = training
        self.label = svd_dataset.get_label(self.path_list,training,data_num)
        self.classes=classes
        self.transform=transform
        
    
    @classmethod
    def get_label(cls,data_path_list,training,data_num):
        label_list=[]
        
        if training:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_train_list[data_num][idx])
        else:
            for idx,x in enumerate(data_path_list):
                label_list.append(Y_test_list[data_num][idx])
        #print(label_list)
        return label_list
    
    def __len__(self):
        return len(self.path_list)
        #데이터 셋의 길이를 정수로 반환한다. 
        
    def __getitem__(self, idx):
        """
        1. path를 받아서, 소리에서 mfcc를 추출
        2. mfcc를 300프레임으로 패딩.
        3. resnet에 사용되기 위해 3채널로 복사(rgb 처럼)
        4. 0~1 정규화
        
        """
        sig, sr = librosa.load(self.path_list[idx], sr=50000)# 논문에서 f_s = 50 000HZ
        
        stft = librosa.stft(sig, win_length=win_length,n_fft=n_fft, hop_length=hop_length)
        #stft 500 FRAME이 되도록 패딩.
        length = 300

        magnitude = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(magnitude)
        pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
        log_spectrogram = pad2d(log_spectrogram, length)
        
        
        if self.transform:
            #print('transform')
            log_spectrogram=self.transform(log_spectrogram).type(torch.float32)# 데이터 0~1 정규화
            log_spectrogram=torch.stack([log_spectrogram,log_spectrogram,log_spectrogram])# 3채널로 복사.
            log_spectrogram = log_spectrogram.squeeze(dim=1)
        else:
            #print("else")
            log_spectrogram = torch.from_numpy(log_spectrogram).type(torch.float32)
            log_spectrogram=log_spectrogram.unsqueeze(0)#cnn 사용위해서 추가
            #MFCCs = MFCCs.permute(2, 0, 1)
        return log_spectrogram, self.classes.index(self.label[idx])

# %% [markdown]
# # 데이터 로더

# %%
#3. 하이퍼 파라미터
BATCH_SIZE =  16 #한 배치당 32개 음성데이터
EPOCHS = 40 # 전체 데이터 셋을 50번 반복

# %%
#DATA LOADER 함수가 BATCH_size 단위로 분리해 지정.

#확인을 위해 데이터셋 하나만 확인


train_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_train_list,
                                               classes,
                                               transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                               data_num=0,
                                               training=True
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,
                                           ) # 순서가 암기되는것을 막기위해.

validation_loader = torch.utils.data.DataLoader(dataset = 
                                           svd_dataset(
                                               X_test_list,
                                               classes,
                                               transform = transforms.ToTensor(),
                                               data_num=0,
                                               training=False
                                           ),
                                           batch_size = BATCH_SIZE,
                                           shuffle = True,)

# %% [markdown]
# # 데이터 확인

# %%
# 4. 데이터 확인하기
for (X_train,Y_train) in train_loader:
    print("X_train : ",X_train.size(),'type:',X_train.type())
    print("Y_train : ",Y_train.size(),'type:',Y_train.type())
    break
    
print(Y_train[0])
librosa.display.specshow(X_train[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_train :  torch.Size([16, 3, 626, 300]) type: torch.FloatTensor
# Y_train :  torch.Size([16]) type: torch.LongTensor
# tensor(0)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
#valiation set 확인
for (X_valid,Y_valid) in validation_loader:
    print("X_valid : ",X_valid.size(),'type:',X_valid.type())
    print("Y_valid : ",Y_valid.size(),'type:',Y_valid.type())
    break

print(Y_valid[0])
librosa.display.specshow(X_valid[0][0].numpy(), sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")

#batch: 32 / 3채널 / frame수: 500  /  feature수: 13
# Out:
# X_valid :  torch.Size([16, 3, 626, 300]) type: torch.FloatTensor
# Y_valid :  torch.Size([16]) type: torch.LongTensor
# tensor(0)
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %% [markdown]
# # RESNET

# %%
# 모델 
# pretrained


def model_initialize():
    model = models.resnet34(pretrained=True).cuda()
    model.ftrs = model.fc.in_features # in_features : fully connected의 입력수.
    num_ftrs = model.fc.in_features

    model.fc = nn.Sequential(nn.Linear(num_ftrs, 256),
                             nn.BatchNorm1d(256),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(256,128),
                             nn.BatchNorm1d(128),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(128,64),
                             nn.BatchNorm1d(64),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(64,50),
                             nn.BatchNorm1d(50),
                             nn.ReLU(),
                             nn.Dropout(p=0.5),
                             nn.Linear(50,2)
                            )

    model = model.cuda()
    return model
model=model_initialize()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=64, out_features=50, bias=True)
#     (13): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Linear(in_features=50, out_features=2, bias=True)
#   )
# )

# %%
# get the model summary
from torchsummary import summary
summary(model, input_size=(3, 626, 500), device=DEVICE.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 313, 250]           9,408
#        BatchNorm2d-2         [-1, 64, 313, 250]             128
#               ReLU-3         [-1, 64, 313, 250]               0
#          MaxPool2d-4         [-1, 64, 157, 125]               0
#             Conv2d-5         [-1, 64, 157, 125]          36,864
#        BatchNorm2d-6         [-1, 64, 157, 125]             128
#               ReLU-7         [-1, 64, 157, 125]               0
#             Conv2d-8         [-1, 64, 157, 125]          36,864
#        BatchNorm2d-9         [-1, 64, 157, 125]             128
#              ReLU-10         [-1, 64, 157, 125]               0
#        BasicBlock-11         [-1, 64, 157, 125]               0
#            Conv2d-12         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-13         [-1, 64, 157, 125]             128
#              ReLU-14         [-1, 64, 157, 125]               0
#            Conv2d-15         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-16         [-1, 64, 157, 125]             128
#              ReLU-17         [-1, 64, 157, 125]               0
#        BasicBlock-18         [-1, 64, 157, 125]               0
#            Conv2d-19         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-20         [-1, 64, 157, 125]             128
#              ReLU-21         [-1, 64, 157, 125]               0
#            Conv2d-22         [-1, 64, 157, 125]          36,864
#       BatchNorm2d-23         [-1, 64, 157, 125]             128
#              ReLU-24         [-1, 64, 157, 125]               0
#        BasicBlock-25         [-1, 64, 157, 125]               0
#            Conv2d-26          [-1, 128, 79, 63]          73,728
#       BatchNorm2d-27          [-1, 128, 79, 63]             256
#              ReLU-28          [-1, 128, 79, 63]               0
#            Conv2d-29          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-30          [-1, 128, 79, 63]             256
#            Conv2d-31          [-1, 128, 79, 63]           8,192
#       BatchNorm2d-32          [-1, 128, 79, 63]             256
#              ReLU-33          [-1, 128, 79, 63]               0
#        BasicBlock-34          [-1, 128, 79, 63]               0
#            Conv2d-35          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-36          [-1, 128, 79, 63]             256
#              ReLU-37          [-1, 128, 79, 63]               0
#            Conv2d-38          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-39          [-1, 128, 79, 63]             256
#              ReLU-40          [-1, 128, 79, 63]               0
#        BasicBlock-41          [-1, 128, 79, 63]               0
#            Conv2d-42          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-43          [-1, 128, 79, 63]             256
#              ReLU-44          [-1, 128, 79, 63]               0
#            Conv2d-45          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-46          [-1, 128, 79, 63]             256
#              ReLU-47          [-1, 128, 79, 63]               0
#        BasicBlock-48          [-1, 128, 79, 63]               0
#            Conv2d-49          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-50          [-1, 128, 79, 63]             256
#              ReLU-51          [-1, 128, 79, 63]               0
#            Conv2d-52          [-1, 128, 79, 63]         147,456
#       BatchNorm2d-53          [-1, 128, 79, 63]             256
#              ReLU-54          [-1, 128, 79, 63]               0
#        BasicBlock-55          [-1, 128, 79, 63]               0
#            Conv2d-56          [-1, 256, 40, 32]         294,912
#       BatchNorm2d-57          [-1, 256, 40, 32]             512
#              ReLU-58          [-1, 256, 40, 32]               0
#            Conv2d-59          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-60          [-1, 256, 40, 32]             512
#            Conv2d-61          [-1, 256, 40, 32]          32,768
#       BatchNorm2d-62          [-1, 256, 40, 32]             512
#              ReLU-63          [-1, 256, 40, 32]               0
#        BasicBlock-64          [-1, 256, 40, 32]               0
#            Conv2d-65          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-66          [-1, 256, 40, 32]             512
#              ReLU-67          [-1, 256, 40, 32]               0
#            Conv2d-68          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-69          [-1, 256, 40, 32]             512
#              ReLU-70          [-1, 256, 40, 32]               0
#        BasicBlock-71          [-1, 256, 40, 32]               0
#            Conv2d-72          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-73          [-1, 256, 40, 32]             512
#              ReLU-74          [-1, 256, 40, 32]               0
#            Conv2d-75          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-76          [-1, 256, 40, 32]             512
#              ReLU-77          [-1, 256, 40, 32]               0
#        BasicBlock-78          [-1, 256, 40, 32]               0
#            Conv2d-79          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-80          [-1, 256, 40, 32]             512
#              ReLU-81          [-1, 256, 40, 32]               0
#            Conv2d-82          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-83          [-1, 256, 40, 32]             512
#              ReLU-84          [-1, 256, 40, 32]               0
#        BasicBlock-85          [-1, 256, 40, 32]               0
#            Conv2d-86          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-87          [-1, 256, 40, 32]             512
#              ReLU-88          [-1, 256, 40, 32]               0
#            Conv2d-89          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-90          [-1, 256, 40, 32]             512
#              ReLU-91          [-1, 256, 40, 32]               0
#        BasicBlock-92          [-1, 256, 40, 32]               0
#            Conv2d-93          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-94          [-1, 256, 40, 32]             512
#              ReLU-95          [-1, 256, 40, 32]               0
#            Conv2d-96          [-1, 256, 40, 32]         589,824
#       BatchNorm2d-97          [-1, 256, 40, 32]             512
#              ReLU-98          [-1, 256, 40, 32]               0
#        BasicBlock-99          [-1, 256, 40, 32]               0
#           Conv2d-100          [-1, 512, 20, 16]       1,179,648
#      BatchNorm2d-101          [-1, 512, 20, 16]           1,024
#             ReLU-102          [-1, 512, 20, 16]               0
#           Conv2d-103          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-104          [-1, 512, 20, 16]           1,024
#           Conv2d-105          [-1, 512, 20, 16]         131,072
#      BatchNorm2d-106          [-1, 512, 20, 16]           1,024
#             ReLU-107          [-1, 512, 20, 16]               0
#       BasicBlock-108          [-1, 512, 20, 16]               0
#           Conv2d-109          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-110          [-1, 512, 20, 16]           1,024
#             ReLU-111          [-1, 512, 20, 16]               0
#           Conv2d-112          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-113          [-1, 512, 20, 16]           1,024
#             ReLU-114          [-1, 512, 20, 16]               0
#       BasicBlock-115          [-1, 512, 20, 16]               0
#           Conv2d-116          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-117          [-1, 512, 20, 16]           1,024
#             ReLU-118          [-1, 512, 20, 16]               0
#           Conv2d-119          [-1, 512, 20, 16]       2,359,296
#      BatchNorm2d-120          [-1, 512, 20, 16]           1,024
#             ReLU-121          [-1, 512, 20, 16]               0
#       BasicBlock-122          [-1, 512, 20, 16]               0
# AdaptiveAvgPool2d-123            [-1, 512, 1, 1]               0
#           Linear-124                  [-1, 256]         131,328
#      BatchNorm1d-125                  [-1, 256]             512
#             ReLU-126                  [-1, 256]               0
#          Dropout-127                  [-1, 256]               0
#           Linear-128                  [-1, 128]          32,896
#      BatchNorm1d-129                  [-1, 128]             256
#             ReLU-130                  [-1, 128]               0
#          Dropout-131                  [-1, 128]               0
#           Linear-132                   [-1, 64]           8,256
#      BatchNorm1d-133                   [-1, 64]             128
#             ReLU-134                   [-1, 64]               0
#          Dropout-135                   [-1, 64]               0
#           Linear-136                   [-1, 50]           3,250
#      BatchNorm1d-137                   [-1, 50]             100
#             ReLU-138                   [-1, 50]               0
#          Dropout-139                   [-1, 50]               0
#           Linear-140                    [-1, 2]             102
# ================================================================
# Total params: 21,461,500
# Trainable params: 21,461,500
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.58
# Forward/backward pass size (MB): 610.02
# Params size (MB): 81.87
# Estimated Total Size (MB): 695.47
# ----------------------------------------------------------------

# %%
#8. 학습
def train(model,train_loader,optimizer, log_interval):
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx,(image,label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        #데이터들 장비에 할당
        optimizer.zero_grad() # device 에 저장된 gradient 제거
        output = model(image) # model로 output을 계산
        loss = criterion(output, label) #loss 계산
        train_loss += loss.item()
        prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
        correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
        loss.backward() # loss 값을 이용해 gradient를 계산
        optimizer.step() # Gradient 값을 이용해 파라미터 업데이트.
    train_loss/=len(train_loader.dataset)
    train_accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss,train_accuracy

# %%
#9. 학습 진행하며, validation 데이터로 모델 성능확인
def evaluate(model,valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            correct += prediction.eq(label.view_as(prediction)).sum().item()# 아웃풋이 배치 사이즈 32개라서.
            #true.false값을 sum해줌. item
        valid_loss /= len(valid_loader.dataset)
        valid_accuracy = 100. * correct / len(valid_loader.dataset)
        return valid_loss,valid_accuracy

# %%
#데이터 로더 제작 함수

def load_data(data_ind):

    train_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_train_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),#이걸 composed로 고쳐서 전처리 하도록 수정.
                                                   data_num=data_ind,
                                                   training=True
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,
                                               ) # 순서가 암기되는것을 막기위해.

    validation_loader = torch.utils.data.DataLoader(dataset = 
                                               svd_dataset(
                                                   X_test_list,
                                                   classes,
                                                   transform = transforms.ToTensor(),
                                                   data_num=data_ind,
                                                   training=False
                                               ),
                                               batch_size = BATCH_SIZE,
                                               shuffle = True,) 
    return train_loader,validation_loader

# %%
#10. 학습 및 평가.
# resnet34 pretrained true
# kfold 적용

train_accs = []
valid_accs = []

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_spectro_resnet18_true_noros_'+str(data_ind)+'_300.pt'

    early_stopping = EarlyStopping(patience = 5, verbose = True, path=check_path)
    train_loader,validation_loader = load_data(data_ind-1)
    
    best_train_acc=0 # accuracy 기록용
    best_valid_acc=0
    
    model=model_initialize()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
    
    
    print("[{} 교차검증] 학습 시작\n ----- ".format(data_ind))
    for Epoch in range(1,EPOCHS+1):
        train_loss,train_accuracy=train(model,train_loader,optimizer,log_interval=31)
        valid_loss,valid_accuracy = evaluate(model, validation_loader)


        print("\n[EPOCH:{}]\t Train Loss:{:.4f}\t Train Acc:{:.2f} %  | \tValid Loss:{:.4f} \tValid Acc: {:.2f} %\n".
              format(Epoch,train_loss,train_accuracy,valid_loss,valid_accuracy))
        

        early_stopping(valid_loss, model)
        if -early_stopping.best_score == valid_loss:
            best_train_acc, best_valid_acc = train_accuracy,valid_accuracy
        
        if early_stopping.early_stop:
                train_accs.append(best_train_acc)
                valid_accs.append(best_valid_acc)
                print("[{} 교차검증] Early stopping".format(data_ind))
                break
        
        if Epoch==EPOCHS:
            #만약 early stop 없이 40 epoch라서 중지 된 경우.
            train_accs.append(best_train_acc)
            valid_accs.append(best_valid_acc)
# Out:
# [1 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0484	 Train Acc:48.97 %  | 	Valid Loss:0.0409 	Valid Acc: 67.21 %
#
# Validation loss decreased (inf --> 0.040930).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0426	 Train Acc:60.05 %  | 	Valid Loss:0.0396 	Valid Acc: 72.68 %
#
# Validation loss decreased (0.040930 --> 0.039551).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0401	 Train Acc:65.05 %  | 	Valid Loss:0.0373 	Valid Acc: 71.04 %
#
# Validation loss decreased (0.039551 --> 0.037349).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0372	 Train Acc:71.00 %  | 	Valid Loss:0.0355 	Valid Acc: 71.31 %
#
# Validation loss decreased (0.037349 --> 0.035483).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0346	 Train Acc:75.99 %  | 	Valid Loss:0.0344 	Valid Acc: 72.40 %
#
# Validation loss decreased (0.035483 --> 0.034393).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0322	 Train Acc:76.95 %  | 	Valid Loss:0.0357 	Valid Acc: 69.95 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:7]	 Train Loss:0.0292	 Train Acc:80.10 %  | 	Valid Loss:0.0315 	Valid Acc: 77.60 %
#
# Validation loss decreased (0.034393 --> 0.031478).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0258	 Train Acc:84.95 %  | 	Valid Loss:0.0331 	Valid Acc: 71.86 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0240	 Train Acc:86.66 %  | 	Valid Loss:0.0388 	Valid Acc: 66.94 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0199	 Train Acc:90.36 %  | 	Valid Loss:0.0343 	Valid Acc: 69.67 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0197	 Train Acc:90.49 %  | 	Valid Loss:0.0288 	Valid Acc: 77.87 %
#
# Validation loss decreased (0.031478 --> 0.028770).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0177	 Train Acc:91.31 %  | 	Valid Loss:0.0322 	Valid Acc: 75.41 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0150	 Train Acc:92.82 %  | 	Valid Loss:0.0313 	Valid Acc: 75.14 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0127	 Train Acc:95.42 %  | 	Valid Loss:0.0319 	Valid Acc: 76.50 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0120	 Train Acc:95.35 %  | 	Valid Loss:0.0371 	Valid Acc: 72.40 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:16]	 Train Loss:0.0120	 Train Acc:94.94 %  | 	Valid Loss:0.0308 	Valid Acc: 76.50 %
#
# EarlyStopping counter: 5 out of 5
# [1 교차검증] Early stopping
# [2 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0448	 Train Acc:56.02 %  | 	Valid Loss:0.0392 	Valid Acc: 75.41 %
#
# Validation loss decreased (inf --> 0.039240).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0404	 Train Acc:61.35 %  | 	Valid Loss:0.0364 	Valid Acc: 80.60 %
#
# Validation loss decreased (0.039240 --> 0.036417).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0377	 Train Acc:65.53 %  | 	Valid Loss:0.0358 	Valid Acc: 83.61 %
#
# Validation loss decreased (0.036417 --> 0.035831).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0358	 Train Acc:69.56 %  | 	Valid Loss:0.0329 	Valid Acc: 80.60 %
#
# Validation loss decreased (0.035831 --> 0.032871).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0339	 Train Acc:72.91 %  | 	Valid Loss:0.0343 	Valid Acc: 76.50 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:6]	 Train Loss:0.0322	 Train Acc:73.87 %  | 	Valid Loss:0.0310 	Valid Acc: 82.79 %
#
# Validation loss decreased (0.032871 --> 0.030988).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0308	 Train Acc:76.81 %  | 	Valid Loss:0.0340 	Valid Acc: 74.32 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0279	 Train Acc:80.16 %  | 	Valid Loss:0.0347 	Valid Acc: 72.95 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:9]	 Train Loss:0.0258	 Train Acc:83.11 %  | 	Valid Loss:0.0360 	Valid Acc: 66.94 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:10]	 Train Loss:0.0232	 Train Acc:86.80 %  | 	Valid Loss:0.0370 	Valid Acc: 67.21 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:11]	 Train Loss:0.0213	 Train Acc:88.51 %  | 	Valid Loss:0.0257 	Valid Acc: 83.33 %
#
# Validation loss decreased (0.030988 --> 0.025713).  Saving model ...
#
# [EPOCH:12]	 Train Loss:0.0201	 Train Acc:90.56 %  | 	Valid Loss:0.0293 	Valid Acc: 77.87 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:13]	 Train Loss:0.0168	 Train Acc:92.07 %  | 	Valid Loss:0.0306 	Valid Acc: 77.87 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:14]	 Train Loss:0.0139	 Train Acc:95.62 %  | 	Valid Loss:0.0319 	Valid Acc: 73.77 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:15]	 Train Loss:0.0137	 Train Acc:95.35 %  | 	Valid Loss:0.0320 	Valid Acc: 73.50 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:16]	 Train Loss:0.0130	 Train Acc:94.94 %  | 	Valid Loss:0.0306 	Valid Acc: 77.60 %
#
# EarlyStopping counter: 5 out of 5
# [2 교차검증] Early stopping
# [3 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0447	 Train Acc:56.84 %  | 	Valid Loss:0.0396 	Valid Acc: 69.40 %
#
# Validation loss decreased (inf --> 0.039646).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0426	 Train Acc:58.62 %  | 	Valid Loss:0.0389 	Valid Acc: 72.68 %
#
# Validation loss decreased (0.039646 --> 0.038942).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0404	 Train Acc:62.86 %  | 	Valid Loss:0.0352 	Valid Acc: 75.96 %
#
# Validation loss decreased (0.038942 --> 0.035238).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0372	 Train Acc:68.26 %  | 	Valid Loss:0.0359 	Valid Acc: 76.50 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:5]	 Train Loss:0.0353	 Train Acc:70.73 %  | 	Valid Loss:0.0334 	Valid Acc: 78.14 %
#
# Validation loss decreased (0.035238 --> 0.033438).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0322	 Train Acc:73.19 %  | 	Valid Loss:0.0314 	Valid Acc: 80.60 %
#
# Validation loss decreased (0.033438 --> 0.031414).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0309	 Train Acc:75.85 %  | 	Valid Loss:0.0313 	Valid Acc: 80.33 %
#
# Validation loss decreased (0.031414 --> 0.031312).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0286	 Train Acc:78.93 %  | 	Valid Loss:0.0334 	Valid Acc: 71.04 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:9]	 Train Loss:0.0270	 Train Acc:81.05 %  | 	Valid Loss:0.0339 	Valid Acc: 75.41 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:10]	 Train Loss:0.0250	 Train Acc:83.93 %  | 	Valid Loss:0.0388 	Valid Acc: 67.49 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:11]	 Train Loss:0.0236	 Train Acc:84.47 %  | 	Valid Loss:0.0348 	Valid Acc: 72.13 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:12]	 Train Loss:0.0200	 Train Acc:89.26 %  | 	Valid Loss:0.0311 	Valid Acc: 74.59 %
#
# Validation loss decreased (0.031312 --> 0.031106).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0175	 Train Acc:92.07 %  | 	Valid Loss:0.0297 	Valid Acc: 78.42 %
#
# Validation loss decreased (0.031106 --> 0.029738).  Saving model ...
#
# [EPOCH:14]	 Train Loss:0.0140	 Train Acc:94.87 %  | 	Valid Loss:0.0281 	Valid Acc: 79.23 %
#
# Validation loss decreased (0.029738 --> 0.028123).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0136	 Train Acc:94.60 %  | 	Valid Loss:0.0311 	Valid Acc: 76.78 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0150	 Train Acc:92.68 %  | 	Valid Loss:0.0298 	Valid Acc: 75.68 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:17]	 Train Loss:0.0127	 Train Acc:94.46 %  | 	Valid Loss:0.0285 	Valid Acc: 79.23 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:18]	 Train Loss:0.0119	 Train Acc:95.42 %  | 	Valid Loss:0.0310 	Valid Acc: 77.32 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:19]	 Train Loss:0.0115	 Train Acc:95.49 %  | 	Valid Loss:0.0281 	Valid Acc: 79.78 %
#
# Validation loss decreased (0.028123 --> 0.028085).  Saving model ...
#
# [EPOCH:20]	 Train Loss:0.0116	 Train Acc:95.21 %  | 	Valid Loss:0.0340 	Valid Acc: 74.59 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:21]	 Train Loss:0.0095	 Train Acc:96.31 %  | 	Valid Loss:0.0352 	Valid Acc: 74.59 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:22]	 Train Loss:0.0092	 Train Acc:96.58 %  | 	Valid Loss:0.0442 	Valid Acc: 68.85 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:23]	 Train Loss:0.0090	 Train Acc:96.72 %  | 	Valid Loss:0.0357 	Valid Acc: 74.86 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:24]	 Train Loss:0.0077	 Train Acc:96.99 %  | 	Valid Loss:0.0432 	Valid Acc: 72.68 %
#
# EarlyStopping counter: 5 out of 5
# [3 교차검증] Early stopping
# [4 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0459	 Train Acc:51.88 %  | 	Valid Loss:0.0425 	Valid Acc: 55.89 %
#
# Validation loss decreased (inf --> 0.042504).  Saving model ...
# [EPOCH:2]	 Train Loss:0.0427	 Train Acc:57.83 %  | 	Valid Loss:0.0403 	Valid Acc: 66.30 %
#
# Validation loss decreased (0.042504 --> 0.040316).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0396	 Train Acc:62.47 %  | 	Valid Loss:0.0380 	Valid Acc: 76.16 %
#
# Validation loss decreased (0.040316 --> 0.037978).  Saving model ...
#
# [EPOCH:4]	 Train Loss:0.0378	 Train Acc:67.46 %  | 	Valid Loss:0.0364 	Valid Acc: 77.53 %
#
# Validation loss decreased (0.037978 --> 0.036351).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0362	 Train Acc:67.74 %  | 	Valid Loss:0.0335 	Valid Acc: 79.45 %
#
# Validation loss decreased (0.036351 --> 0.033520).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0332	 Train Acc:72.39 %  | 	Valid Loss:0.0317 	Valid Acc: 82.47 %
#
# Validation loss decreased (0.033520 --> 0.031748).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0317	 Train Acc:74.71 %  | 	Valid Loss:0.0328 	Valid Acc: 79.73 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:8]	 Train Loss:0.0301	 Train Acc:78.06 %  | 	Valid Loss:0.0294 	Valid Acc: 80.55 %
#
# Validation loss decreased (0.031748 --> 0.029396).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0275	 Train Acc:81.07 %  | 	Valid Loss:0.0346 	Valid Acc: 72.05 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:10]	 Train Loss:0.0256	 Train Acc:84.01 %  | 	Valid Loss:0.0315 	Valid Acc: 80.55 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:11]	 Train Loss:0.0217	 Train Acc:87.83 %  | 	Valid Loss:0.0335 	Valid Acc: 78.36 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:12]	 Train Loss:0.0193	 Train Acc:90.98 %  | 	Valid Loss:0.0291 	Valid Acc: 81.92 %
#
# Validation loss decreased (0.029396 --> 0.029123).  Saving model ...
#
# [EPOCH:13]	 Train Loss:0.0187	 Train Acc:90.23 %  | 	Valid Loss:0.0298 	Valid Acc: 81.10 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:14]	 Train Loss:0.0161	 Train Acc:92.89 %  | 	Valid Loss:0.0261 	Valid Acc: 83.56 %
#
# Validation loss decreased (0.029123 --> 0.026088).  Saving model ...
#
# [EPOCH:15]	 Train Loss:0.0148	 Train Acc:93.71 %  | 	Valid Loss:0.0343 	Valid Acc: 72.60 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:16]	 Train Loss:0.0135	 Train Acc:94.60 %  | 	Valid Loss:0.0608 	Valid Acc: 46.85 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:17]	 Train Loss:0.0128	 Train Acc:95.22 %  | 	Valid Loss:0.0237 	Valid Acc: 84.38 %
#
# Validation loss decreased (0.026088 --> 0.023685).  Saving model ...
#
# [EPOCH:18]	 Train Loss:0.0115	 Train Acc:95.01 %  | 	Valid Loss:0.0283 	Valid Acc: 79.45 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:19]	 Train Loss:0.0108	 Train Acc:95.69 %  | 	Valid Loss:0.0343 	Valid Acc: 75.89 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:20]	 Train Loss:0.0123	 Train Acc:94.46 %  | 	Valid Loss:0.0255 	Valid Acc: 83.56 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:21]	 Train Loss:0.0090	 Train Acc:96.92 %  | 	Valid Loss:0.0249 	Valid Acc: 82.74 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:22]	 Train Loss:0.0121	 Train Acc:95.01 %  | 	Valid Loss:0.0269 	Valid Acc: 80.82 %
#
# EarlyStopping counter: 5 out of 5
# [4 교차검증] Early stopping
# [5 교차검증] 학습 시작
#  -----
#
# [EPOCH:1]	 Train Loss:0.0446	 Train Acc:58.51 %  | 	Valid Loss:0.0404 	Valid Acc: 71.51 %
#
# Validation loss decreased (inf --> 0.040381).  Saving model ...
#
# [EPOCH:2]	 Train Loss:0.0408	 Train Acc:61.72 %  | 	Valid Loss:0.0367 	Valid Acc: 73.42 %
#
# Validation loss decreased (0.040381 --> 0.036671).  Saving model ...
#
# [EPOCH:3]	 Train Loss:0.0386	 Train Acc:65.28 %  | 	Valid Loss:0.0368 	Valid Acc: 71.51 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:4]	 Train Loss:0.0355	 Train Acc:70.06 %  | 	Valid Loss:0.0357 	Valid Acc: 76.71 %
#
# Validation loss decreased (0.036671 --> 0.035725).  Saving model ...
#
# [EPOCH:5]	 Train Loss:0.0333	 Train Acc:71.98 %  | 	Valid Loss:0.0354 	Valid Acc: 71.51 %
#
# Validation loss decreased (0.035725 --> 0.035412).  Saving model ...
#
# [EPOCH:6]	 Train Loss:0.0315	 Train Acc:75.53 %  | 	Valid Loss:0.0346 	Valid Acc: 75.07 %
#
# Validation loss decreased (0.035412 --> 0.034604).  Saving model ...
#
# [EPOCH:7]	 Train Loss:0.0299	 Train Acc:77.44 %  | 	Valid Loss:0.0322 	Valid Acc: 77.81 %
#
# Validation loss decreased (0.034604 --> 0.032150).  Saving model ...
#
# [EPOCH:8]	 Train Loss:0.0267	 Train Acc:81.75 %  | 	Valid Loss:0.0316 	Valid Acc: 76.16 %
#
# Validation loss decreased (0.032150 --> 0.031609).  Saving model ...
#
# [EPOCH:9]	 Train Loss:0.0247	 Train Acc:84.69 %  | 	Valid Loss:0.0295 	Valid Acc: 76.71 %
#
# Validation loss decreased (0.031609 --> 0.029538).  Saving model ...
#
# [EPOCH:10]	 Train Loss:0.0229	 Train Acc:86.06 %  | 	Valid Loss:0.0294 	Valid Acc: 79.45 %
#
# Validation loss decreased (0.029538 --> 0.029442).  Saving model ...
#
# [EPOCH:11]	 Train Loss:0.0202	 Train Acc:89.00 %  | 	Valid Loss:0.0338 	Valid Acc: 72.05 %
#
# EarlyStopping counter: 1 out of 5
#
# [EPOCH:12]	 Train Loss:0.0183	 Train Acc:91.11 %  | 	Valid Loss:0.0310 	Valid Acc: 79.18 %
#
# EarlyStopping counter: 2 out of 5
#
# [EPOCH:13]	 Train Loss:0.0165	 Train Acc:92.00 %  | 	Valid Loss:0.0309 	Valid Acc: 75.34 %
#
# EarlyStopping counter: 3 out of 5
#
# [EPOCH:14]	 Train Loss:0.0166	 Train Acc:92.41 %  | 	Valid Loss:0.0402 	Valid Acc: 68.77 %
#
# EarlyStopping counter: 4 out of 5
#
# [EPOCH:15]	 Train Loss:0.0142	 Train Acc:93.30 %  | 	Valid Loss:0.0313 	Valid Acc: 77.81 %
#
# EarlyStopping counter: 5 out of 5
# [5 교차검증] Early stopping

# %% [markdown]
# # Model 결과 확인

# %%
sum_valid=0
for data_ind in range(5):
    print("[{} 교차검증] train ACC : {:.4f} |\t valid ACC: {:.4f} ".format(data_ind+1,train_accs[data_ind],valid_accs[data_ind] ))
    sum_valid+=valid_accs[data_ind]
    
print("평균 검증 정확도",sum_valid/5,"%")
# Out:
# [1 교차검증] train ACC : 90.4925 |	 valid ACC: 77.8689
# [2 교차검증] train ACC : 88.5089 |	 valid ACC: 83.3333
# [3 교차검증] train ACC : 95.4856 |	 valid ACC: 79.7814
# [4 교차검증] train ACC : 95.2153 |	 valid ACC: 84.3836
# [5 교차검증] train ACC : 86.0560 |	 valid ACC: 79.4521
# 평균 검증 정확도 80.96384459914665 %

# %% [markdown]
# # Model Test
#
# - test set
# - confusion matrix

# %%
#confusion matrix 계산
#test set 계산.
def test_evaluate(model,test_loader):
    model.eval()
    test_loss = 0
    predictions = []
    answers = []
    #no_grad : 그래디언트 값 계산 막기.
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1,keepdim=True)[1] # 가장 확률이 높은 class 1개를 가져온다.그리고 인덱스만
            answers +=label
            predictions +=prediction
            
        return predictions,answers,test_loss

# %%
# Confusion matrix (resnet18)
# kfold의 confusion matrix는 계산 방법이 다르다.
# 모델을 각각 불러와서 결과를 모두 합쳐줘야한다.

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

cf = np.zeros((2,2))

predictions=[]
answers=[]

for data_ind in range(1,6):

    check_path = '../checkpoint/checkpoint_spectro_resnet18_true_noros_'+str(data_ind)+'_300.pt'
    model.load_state_dict(torch.load(check_path))
    _,validation_loader = load_data(data_ind-1)

    prediction,answer,test_loss = test_evaluate(model, validation_loader)
    predictions+=[ dat.cpu().numpy() for dat in prediction]
    answers+=[ dat.cpu().numpy() for dat in answer]
    
    print(confusion_matrix(answers, predictions))

    
cf = confusion_matrix(answers, predictions)
acc = (cf[0,0]+cf[1,1])/(cf[0,0]+cf[0,1]+cf[1,0]+cf[1,1])
precision=cf[0,0]/(cf[0,0]+cf[1,0])
recall=cf[0,0]/(cf[0,0]+cf[0,1])
#fscore=2*precision*recall/(precision+recall)

fscore = f1_score(answers,predictions,average='macro')


print("Accuracy : {:.4f}% ".format(acc*100))
print("Precision (pathology 예측한 것중 맞는 것) : {:.4f}".format(precision))
print("recall (실제 pathology 중  예측이 맞는 것) : {:.4f}".format(recall))
print("f score : {:.4f} ".format(fscore))
# Out:
# [[210  29]
#  [ 52  75]]
# [[411  67]
#  [ 75 179]]
# [[614 103]
#  [113 268]]
# [[827 129]
#  [144 363]]
# [[1024  170]
#  [ 178  456]]
# Accuracy : 80.9628%
# Precision (pathology 예측한 것중 맞는 것) : 0.8519
# recall (실제 pathology 중  예측이 맞는 것) : 0.8576
# f score : 0.7893

# %% [markdown]
# # 기타

# %%
#크기 알아보기
#일반 CNN

m = nn.MaxPool2d(2, stride=2)
#m = nn.MaxPool2d((3, 2), stride=(2, 1))
input = torch.randn(32, 1, 500, 13)
print(input.size())
output = m(input)
print(output.size())
output = m(output)
print(output.size())
# Out:
# torch.Size([32, 1, 500, 13])
# torch.Size([32, 1, 250, 6])
# torch.Size([32, 1, 125, 3])

# %%
#크기 알아보기
#주파수 영역 CNN

input = torch.randn(32, 1, 500, 13)
m=nn.Conv2d(
            in_channels = 1,# 채널이 1개
            out_channels = 32,# FeatureMap 수,커널 수
            kernel_size = (1,13),#1x13  no padding
        )
output=m(input)
print(output.size())
m=nn.Conv2d(
            in_channels = 32,# 채널이 1개
            out_channels = 64,# FeatureMap 수,커널 수
            kernel_size = (27,1),#9 x 1 no padding
        )
output=m(output)
print(output.size())
# Out:
# torch.Size([32, 32, 500, 1])
# torch.Size([32, 64, 474, 1])

# %%
input = torch.randn(500, 13)

out=torch.stack([input,input,input])
out.size()
# Out:
# torch.Size([3, 500, 13])
