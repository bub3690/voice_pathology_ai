# %%
import torch

# %%
torch.randn((32,16,1,128)).softmax(dim=1)
# Out:
# tensor([[[[0.0113, 0.0395, 0.0378,  ..., 0.1220, 0.0273, 0.0585]],
#
#          [[0.0121, 0.0203, 0.0273,  ..., 0.0349, 0.0217, 0.0296]],
#
#          [[0.1264, 0.0671, 0.0447,  ..., 0.0263, 0.0378, 0.0398]],
#
#          ...,
#
#          [[0.0471, 0.0110, 0.0021,  ..., 0.0391, 0.0146, 0.2184]],
#
#          [[0.0214, 0.0973, 0.0071,  ..., 0.1369, 0.1990, 0.1041]],
#
#          [[0.0069, 0.0745, 0.0550,  ..., 0.0517, 0.1960, 0.0199]]],
#
#
#         [[[0.0049, 0.0868, 0.0058,  ..., 0.0201, 0.0396, 0.0632]],
#
#          [[0.0152, 0.0635, 0.0612,  ..., 0.0172, 0.0424, 0.0097]],
#
#          [[0.0464, 0.0155, 0.1576,  ..., 0.0355, 0.0307, 0.0607]],
#
#          ...,
#
#          [[0.0186, 0.0209, 0.0171,  ..., 0.1486, 0.1338, 0.1453]],
#
#          [[0.0226, 0.0087, 0.1251,  ..., 0.0061, 0.0611, 0.0855]],
#
#          [[0.3150, 0.0164, 0.0538,  ..., 0.0166, 0.0799, 0.0940]]],
#
#
#         [[[0.0254, 0.0947, 0.2771,  ..., 0.0361, 0.0219, 0.0717]],
#
# ...
