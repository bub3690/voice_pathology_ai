# %%
#파일 분류에 사용
#출처: https://ourcstory.tistory.com/96

import shutil
filename = 'C:/Users/Desktop/Desktop/pathology/a/export/파일설명.txt' 
to = 
shutil.move(filename,to )
# Out:
# './파일설명.txt'

# %%
import re

# %%
sample1=glob('C:/Users/Desktop/Desktop/pathology/a/export/*-phrase.wav')[1]
sample1
re.search('\\\\(.*)',sample1).group(1)#아이템 번호
# Out:
# '1039-phrase.wav'

# %%
#문장들 옮기는 코드
#pathology 문장들.
from glob import glob

pathology = glob('C:/Users/Desktop/Desktop/pathology/a/export/*-phrase.wav')
pathology += glob('C:/Users/Desktop/Desktop/pathology/i/export/*-phrase.wav')
pathology += glob('C:/Users/Desktop/Desktop/pathology/u/export/*-phrase.wav')

to = 'C:/Users/Desktop/Desktop/pathology/phrase/export/'


for path in pathology:
    phrase_name = re.search('\\\\(.*)',path).group(1)
    print(to+phrase_name)
    shutil.move(path,to+phrase_name)
# Out:
# C:/Users/Desktop/Desktop/pathology/phrase/export/101-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1039-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1042-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1043-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1048-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/105-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1053-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1054-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1055-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1057-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1058-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/106-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/107-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/108-phrase.wav
# C:/Users/Desktop/Desktop/pathology/phrase/export/1083-phrase.wav
# ...

# %%
#문장들 옮기는 코드
#pathology 문장들.
from glob import glob
import shutil

pathology = glob('C:/Users/Desktop/Desktop/healthy/a/export/*-phrase.wav')
pathology += glob('C:/Users/Desktop/Desktop/healthy/i/export/*-phrase.wav')
pathology += glob('C:/Users/Desktop/Desktop/healthy/u/export/*-phrase.wav')

to = 'C:/Users/Desktop/Desktop/healthy/phrase/export/'


for path in pathology:
    phrase_name = re.search('\\\\(.*)',path).group(1)
    print(to+phrase_name)
    shutil.move(path,to+phrase_name)
# Out:
# C:/Users/Desktop/Desktop/healthy/phrase/export/1-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/10-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/100-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1000-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1002-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1003-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1004-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1005-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1006-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1007-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1008-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1009-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1010-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1011-phrase.wav
# C:/Users/Desktop/Desktop/healthy/phrase/export/1012-phrase.wav
# ...

# %%
#문장들 옮기는 코드
#pathology 문장들.
from glob import glob
import shutil

pathology = glob('C:/Users/Desktop/Desktop/healthy_new/a/export/*-phrase.wav')
pathology += glob('C:/Users/Desktop/Desktop/healthy_new/i/export/*-phrase.wav')
pathology += glob('C:/Users/Desktop/Desktop/healthy_new/u/export/*-phrase.wav')

to = 'C:/Users/Desktop/Desktop/healthy_new/phrase/export/'

count =0
for path in pathology:
    phrase_name = re.search('\\\\(.*)',path).group(1)
    print(to+phrase_name)
    count+=1
    shutil.move(path,to+phrase_name)

print(count)
# Out:
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/10-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/100-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1000-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1002-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1003-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1004-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1005-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1006-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1007-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1008-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1009-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1010-phrase.wav
# C:/Users/Desktop/Desktop/healthy_new/phrase/export/1011-phrase.wav
# ...
